# %% [markdown]
# # Extraction des NCTIds dans ClinicalTrial:

# %% [markdown]
# ## API v1:

# %% [markdown]
# Pour faciliter la récupération des données via l'API v1 de ClinicalTrial, on utilise le wrapper Python: [pytrials](https://github.com/jvfe/pytrials)

# %% [markdown]
# Installer ***pytrials***:
# - Dans Conda Navigator, se placer dans le meme environnement que celui qui execute Jupyter
# - Lancer Powershell Prompt dans cet environnement
# - Taper: `pip install pytrials`

# %%
from pytrials.client import ClinicalTrials
import urllib.parse
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from pytrials.client import ClinicalTrials
#       2 import urllib.parse
#
# ModuleNotFoundError: No module named 'pytrials'

# %%
ct = ClinicalTrials()

# %% [markdown]
# ### Création de la requête:

# %% [markdown]
# On crée la requête qui sera envoyé à l'API de ClinicalTrial

# %% [markdown]
# #### Sponsors:

# %%
sponsors = [
    "anrs",
    "inserm",
    "institut national de la santé et de la recherche médicale",
    "french national agency for research on aids and viral hepatitis",
]

# %%
sponsors_expr = [f"AREA[LeadSponsorName]{sponsor}" for sponsor in sponsors]

# Add OR keyword
sponsors_expr = " OR ".join(sponsors_expr)

# Add parenthesis for correct interpretation of OR expression
sponsors_expr = f"({sponsors_expr})"

sponsors_expr

# %% [markdown]
# #### Status:

# %%
status = "completed"

# %%
status_expr = f"AREA[OverallStatus]{status}"
status_expr

# %% [markdown]
# #### Search Expression:

# %%
search_expr = " AND ".join([sponsors_expr, status_expr])
search_expr

# %% [markdown]
# #### URL encode:

# %%
search_expr_url_encode = urllib.parse.quote_plus(search_expr)
search_expr_url_encode

# %% [markdown]
# #### Fields:

# %% [markdown]
# Les champs que l'on veut récupérer:

# %%
fields = [
    "NCTId",
    "BriefTitle",
    "OverallStatus",
    "StudyType",
    "LeadSponsorName",
    "CollaboratorName",
    "OrgStudyId",
    "SecondaryId",
    "StudyFirstPostDate",
    "ReferencePMID",
    "ReferenceCitation",
    "ReferenceType",
]

# %% [markdown]
# ### Envoi de la requête :

# %%
study_fields = ct.get_study_fields(
    search_expr=search_expr_url_encode,
    fields=fields,
    max_studies=1000,
    fmt="csv",
)

# %%
print(f"NStudiesReturned: {len(study_fields[1:])}")

# %% [markdown]
# ### Lire le résultat de la requête dans Pandas :

# %%
import pandas as pd

# %%
pd.DataFrame.from_records(study_fields[1:], index="Rank", columns=study_fields[0])

# %% [markdown]
# ## API v2:

# %% [markdown]
# L'API v1 ne sera plus supporté a partir de mi-2024

# %% [markdown]
# >***Notice to API users:
# >The new ClinicalTrials.gov API, version 2.0 is available. Classic API users are strongly encouraged to switch to the modernized API. We will continue to support the classic API until mid-2024 and are planning blackouts for the spring to help with the transition to the modernized API.***

# %% [markdown]
# De plus, l'API v2 supporte un nouveau champs **"HasResults"**, qui pour l'instant n'est que très peu utilisé mais qui pourrait être utile à l'avenir.
#
# En contre-partie, l'export des données sous forme de CSV est limité à un certain nombre de champs visible sur cette page: https://clinicaltrials.gov/data-api/about-api/csv-download
#
# On est donc obligé d'utiliser l'export de données sous forme de JSON.

# %% [markdown]
# ### Création de la requête:

# %% [markdown]
# `pytrials` n'étant pas compatible avec la v2, on envoie la requête manuellement en utilisant [Requests](https://requests.readthedocs.io/en/latest/)

# %% [markdown]
# #### Format:

# %%
format = "json"

# %% [markdown]
# #### Sponsors:

# %%
sponsors

# %%
sponsors_expr_v2 = " OR ".join(sponsors)
sponsors_expr_v2 = urllib.parse.quote_plus(sponsors_expr_v2)
sponsors_expr_v2

# %% [markdown]
# #### Overall_status:

# %%
overall_status = "COMPLETED"

# %% [markdown]
# #### Fields:

# %%
fields_v2 = [
    'NCTId',
    'BriefTitle',
    'OverallStatus',
    'StudyType',
    'LeadSponsorName',
    'CollaboratorName',
    # 'OrgStudyId',
    # 'SecondaryId',
    'StudyFirstPostDate',
    'ReferencePMID',
    'ReferenceCitation',
    'ReferenceType',
    'hasResults'
]
fields_v2

# %%
fields_expr_v2 = ",".join(fields_v2)
fields_expr_v2 = urllib.parse.quote_plus(fields_expr_v2)
fields_expr_v2

# %% [markdown]
# #### Nombre de résultats:

# %%
count_total = "true"

# %%
page_size = 1000

# %% [markdown]
# #### URL api:

# %%
query_url = f"https://clinicaltrials.gov/api/v2/studies?format={format}&query.lead={sponsors_expr_v2}&filter.overallStatus={overall_status}&fields={fields_expr_v2}&countTotal={count_total}&pageSize={page_size}"
query_url

# %% [markdown]
# ### Envoi de la requête :

# %%
import requests

# %%
response = requests.get(query_url)
response.raise_for_status()
response

# %%
print(f'Studies returned: {response.json()["totalCount"]}')

# %% [markdown]
# ### Traitement du JSON retourné:

# %%
import json

# %%
print(json.dumps(response.json(), indent=2))

# %% [markdown]
# ***La structure du JSON est bien trop imbriquée pour le normaliser avec Pandas, du coup on l'applatit à la main:***

# %% [markdown]
# A partir du JSON on construit un dictionnaire équivalent mais beaucoup plus "plat"

# %%
# Si la liste des collaborateurs est vide on renvoie None, sinon on concatène les valeurs de la liste
# sous la forme "collaborateur_0 | collaborateur_1 | ..."
def concatenate_collaborator_list(collaborator_list):
    if collaborator_list == []:
        return None
    else:
        return " | ".join(collaborator_list)

# %%
studies_list = []
for study in response.json()["studies"]:
    study_dict = {
        'NCTId' : study["protocolSection"]["identificationModule"]["nctId"],
        'BriefTitle' : study["protocolSection"]["identificationModule"]["briefTitle"],
        'LeadSponsorName' : study["protocolSection"]["sponsorCollaboratorsModule"]["leadSponsor"]["name"],
        "CollaboratorName": concatenate_collaborator_list(
            [c["name"] for c in (
                    study["protocolSection"]["sponsorCollaboratorsModule"].get("collaborators", [])  # can be missing
                )
            ]
        ),    
        'OverallStatus' : study["protocolSection"]["statusModule"]["overallStatus"],
        'StudyType' : study["protocolSection"]["designModule"]["studyType"],    
        'HasResults' : study["hasResults"],
        'StudyFirstPostDate' : study["protocolSection"]["statusModule"]["studyFirstPostDateStruct"]["date"],
        'Reference' : study["protocolSection"].get("referencesModule", {}).get("references"), # can be missing       
    }
    studies_list.append(study_dict)
print(json.dumps(studies_list, indent=2))

# %% [markdown]
# On vérifie que l'on n'a pas perdu de NCTId en route:

# %%
print(f"Nombre de NCTId: {len(studies_list)}")
assert(response.json()["totalCount"] == len(studies_list))

# %% [markdown]
# ### Import dans Pandas

# %%
df_ct = pd.json_normalize(data = studies_list)
df_ct

# %% [markdown]
# #### On "explose" la colonne "Reference":
#
# Pour chaque NCTId, la colonne réference contient potentiellement une liste de plusieurs références.
# Si par exemple, on a 3 références, on veut se retrouver avec 3 lignes, chacune indexée par le même NCTId et contenant une unique réference.
#
# *Avant*:
# **`NCTId    Reference`**
# `NCT0001, [Ref1, Ref2, Ref3]`
#
# *Après*:
# **`NCTId    Reference`**
# `NCT0001,   Ref1`
# `NCT0001,   Ref2`
# `NCT0001,   Ref3`

# %%
df_ct = df_ct.explode('Reference', ignore_index = True)
df_ct

# %% [markdown]
# Pour chaque NCTId, la colonne réference contient maintenant un dictionnaire de la forme:
# `{
# "pmid": "17545707",
# "type": "BACKGROUND",
# "citation": "...",
# }`
#
# Dont on veut extraire de nouvelles colonnes en utilant les clés du dictionnaire:
# **`pmid     type        citation`**
# `17545707, BACKGROUND, "..."`

# %%
df_ct_references = pd.json_normalize(df_ct.pop('Reference'))
df_ct_references

# %% [markdown]
# On réassemble la dataFrame complète:

# %%
df_ct = df_ct.join(df_references)
df_ct

# %% [markdown]
# ***On reconstruit l'index :***

# %%
# df_studies_v2.set_index('NCTId', inplace = True)

# %% [markdown]
# ***On précise les types :***

# %%
df_ct = df_ct.convert_dtypes()
# df_ct = df_ct.astype({"OverallStatus" : 'category', "StudyType" : 'category', "type": 'category',})
df_ct = df_ct.astype({"OverallStatus" : 'category', "StudyType" : 'category'})
df_ct.info()

# %%
df_ct.head(10)
# Out:
#          NCTId                                         BriefTitle  \
# 0  NCT01895920  Viral Biofilms: Hijacking T Cell Extracellular...
# 1  NCT02486731  Hormonal Sensitivity in Patients With Noonan a...
# 2  NCT02116374  Physiopathology Study of the Microbiota Biodiv...
# 3  NCT03537196  DRug Use & Infections in ViEtnam - Hepatitis C...
# 4  NCT03537196  DRug Use & Infections in ViEtnam - Hepatitis C...
# 5  NCT03537196  DRug Use & Infections in ViEtnam - Hepatitis C...
# 6  NCT03537196  DRug Use & Infections in ViEtnam - Hepatitis C...
# 7  NCT03537196  DRug Use & Infections in ViEtnam - Hepatitis C...
# 8  NCT03537196  DRug Use & Infections in ViEtnam - Hepatitis C...
# 9  NCT03537196  DRug Use & Infections in ViEtnam - Hepatitis C...
#
#                                      LeadSponsorName CollaboratorName  \
# 0                 ANRS, Emerging Infectious Diseases             <NA>
# 1  Institut National de la Santé Et de la Recherc...             <NA>
# 2                 ANRS, Emerging Infectious Diseases             <NA>
# 3                 ANRS, Emerging Infectious Diseases             <NA>
# 4                 ANRS, Emerging Infectious Diseases             <NA>
# 5                 ANRS, Emerging Infectious Diseases             <NA>
# 6                 ANRS, Emerging Infectious Diseases             <NA>
# 7                 ANRS, Emerging Infectious Diseases             <NA>
# 8                 ANRS, Emerging Infectious Diseases             <NA>
# 9                 ANRS, Emerging Infectious Diseases             <NA>
#
#   OverallStatus       StudyType  HasResults StudyFirstPostDate      pmid  \
# 0     COMPLETED  INTERVENTIONAL       False         2013-07-11      <NA>
# 1     COMPLETED   OBSERVATIONAL       False         2015-07-01      <NA>
# 2     COMPLETED   OBSERVATIONAL       False         2014-04-16      <NA>
# 3     COMPLETED  INTERVENTIONAL       False         2018-05-25  25086286
# 4     COMPLETED  INTERVENTIONAL       False         2018-05-25  23172780
# 5     COMPLETED  INTERVENTIONAL       False         2018-05-25  22828983
# 6     COMPLETED  INTERVENTIONAL       False         2018-05-25  20041309
# 7     COMPLETED  INTERVENTIONAL       False         2018-05-25  22098550
# 8     COMPLETED  INTERVENTIONAL       False         2018-05-25  20196807
# 9     COMPLETED  INTERVENTIONAL       False         2018-05-25  19839502
#
#          type                                           citation
# 0        <NA>                                               <NA>
# 1        <NA>                                               <NA>
# 2        <NA>                                               <NA>
# 3  BACKGROUND  Gower E, Estes C, Blach S, Razavi-Shearer K, R...
# 4  BACKGROUND  Mohd Hanafiah K, Groeger J, Flaxman AD, Wiersm...
# 5  BACKGROUND  Sereno L, Mesquita F, Kato M, Jacka D, Nguyen ...
# 6  BACKGROUND  Clatts MC, Colon-Lopez V, Giang LM, Goldsamt L...
# 7  BACKGROUND  Gish RG, Bui TD, Nguyen CT, Nguyen DT, Tran HV...
# 8  BACKGROUND  Kallman JB, Tran S, Arsalla A, Haddad D, Stepa...
# 9  BACKGROUND  Pham DA, Leuangwutiwong P, Jittmittraphap A, L...

# %% [markdown]
# #### Export en CSV :

# %%
# df_studies_v2.to_csv('Data/outputs/extract_CT_api_v2.csv', sep=";", encoding='utf-8-sig')
df_ct.to_csv('Data/outputs/extract_CT_api_v2.csv', sep=";", index=False, encoding='utf-8-sig')

# %% [markdown]
# # PubMed

# %% [markdown]
# ### Utilisation d'une clé pour l'API Pubmed :

# %% [markdown]
# Il est recommandé d'utiliser une clé pour accéder à l'API Pubmed, ce qui permet de lancer jusqu'à 10 requêtes par seconde.
# Sans clé, la limite est de 3 requêtes par seconde.
#
# > E-utils users are allowed 3 requests/second without an API key. Create an API key to increase your e-utils limit to 10 requests/second.
#
# **En pratique, l'API Pubmed étant beaucoup plus lente (~1 requête par seconde), cela ne semble pas changer grand chose.**
#
# Pour récupérer sa clé, se rendre sur la page en étant loggué:
# https://account.ncbi.nlm.nih.gov/settings/
#
# Une fois la clé récupérée, l'ajouter aux variables d'environnement avec la commande suivante:
#
# **Windows :**
#
# `setx NCBI_API_KEY “123456"`
#
# **Linux/MacOS :**
#
# `export NCBI_API_KEY = 123456`

# %%
import os

assert(os.getenv('NCBI_API_KEY', None) is not None)

# %% [markdown]
# ### Installer metapub :
# - Dans Conda Navigator, se placer dans le meme environnement que celui qui execute Jupyter
# - Lancer Powershell Prompt dans cet environnement
# - Taper la commande suivante :  `pip install metapub`

# %%
from metapub import PubMedFetcher
from metapub.exceptions import InvalidPMID

fetch = PubMedFetcher(cachedir='./.cache/')

# %% [markdown]
# #### Récupération des PMIDs via PubMed:

# %% [markdown]
# Pour chaque NCTId de CT, on récupère les PMIDs des publications associées via PubMed:

# %%
# Liste unique des NCTId extraits de ClinicalTrial
nctid_array = df_ct.loc[:, "NCTId"].unique()

pmids_pubmed_dict = {}
for i, nctid in enumerate(nctid_array):
    # Display the progress on a single line
    print(f"\r{i+1}/{len(nctid_array)}...", end="", flush=True)
    
    pmids = [pmid for pmid in fetch.pmids_for_query(nctid)]
    pmids_pubmed_dict[nctid] = set(pmids)
# Out:
# 286/286...

# %%
pmids_pubmed_dict
# Out:
# {'NCT01895920': set(),
#  'NCT02486731': set(),
#  'NCT02116374': set(),
#  'NCT03537196': {'33208326'},
#  'NCT01899196': set(),
#  'NCT04631224': set(),
#  'NCT01579435': set(),
#  'NCT03235258': set(),
#  'NCT00383734': {'23432777'},
#  'NCT00901524': {'24905490'},
#  'NCT01493934': set(),
#  'NCT03078439': {'38408861'},
#  'NCT04808986': set(),
#  'NCT01207986': set(),
#  'NCT02626286': {'33753460', '34022820', '34352834'},
#  'NCT02527096': set(),
#  'NCT00121758': {'20625264', '23759749'},
#  'NCT04684758': set(),
#  'NCT02057796': {'32558469', '36883573'},
#  'NCT03071458': set(),
#  'NCT02192658': {'26846895'},
#  'NCT01713335': set(),
#  'NCT00158522': set(),
#  'NCT00640263': {'23039034',
#   '26603917',
#   '27895016',
#   '28469697',
#   '30814028',
#   '31633158',
#   '31994250',
#   '32067040',
#   '32228542',
#   '32991450',
#   '34425825'},
#  'NCT02428816': set(),
#  'NCT00122616': {'23800784'},
#  'NCT00196586': set(),
#  'NCT00148863': {'23190183'},
#  'NCT03150290': set(),
#  'NCT01514890': {'23669289', '24704719', '25556540'},
#  'NCT03652090': set(),
#  'NCT02738502': set(),
#  'NCT02212379': {'31269208'},
#  'NCT00465790': set(),
#  'NCT01605890': {'29590335'},
#  'NCT00196664': set(),
#  'NCT00122603': {'19420019'},
#  'NCT02992184': {'29615488'},
#  'NCT02071784': set(),
#  'NCT01432821': set(),
#  'NCT00121121': {'17712402'},
#  'NCT02126384': set(),
#  'NCT02323308': set(),
#  'NCT02314208': set(),
#  'NCT01348308': {'32040959'},
#  'NCT02113943': set(),
#  'NCT00299143': set(),
#  'NCT04824638': set(),
#  'NCT00120367': {'21738597'},
#  'NCT00323804': set(),
#  'NCT03642704': set(),
#  'NCT04849767': {'34916316'},
#  'NCT00573001': set(),
#  'NCT02267304': set(),
#  'NCT01525472': set(),
#  'NCT02073604': set(),
#  'NCT01127204': {'27015798',
#   '28434406',
#   '28453240',
#   '28483965',
#   '28800382',
#   '31334298',
#   '34723858'},
#  'NCT01473472': {'26624850', '28747274', '29229440', '31784343', '36601747'},
#  'NCT00122538': {'20516271', '21857286', '23719348'},
#  'NCT01555450': {'28823681', '29909873'},
#  'NCT01696708': {'25568297'},
#  'NCT01100281': set(),
#  'NCT00424814': {'23766338', '25838291'},
#  'NCT00946595': {'29767684', '30968368'},
#  'NCT02488395': set(),
#  'NCT03335995': {'32026446', '37497675'},
#  'NCT01647295': set(),
#  'NCT01226446': {'25987791'},
#  'NCT00658346': {'31063537'},
#  'NCT01874808': set(),
#  'NCT01509508': {'23880306',
#   '25880823',
#   '27504637',
#   '28329393',
#   '29199100',
#   '29890048',
#   '30027600',
#   '30321314',
#   '30412926',
#   '31637821',
#   '32970730'},
#  'NCT00391638': set(),
#  'NCT01426243': {'26314624', '30096071'},
#  'NCT02496312': set(),
#  'NCT03519503': set(),
#  'NCT00196612': set(),
#  'NCT04133012': set(),
#  'NCT03298360': set(),
#  'NCT01490489': set(),
#  'NCT04780191': set(),
#  'NCT01164462': set(),
#  'NCT02051413': set(),
#  'NCT01531036': set(),
#  'NCT01164436': set(),
#  'NCT00870649': {'30532268'},
#  'NCT01842919': set(),
#  'NCT06260319': set(),
#  'NCT01569399': set(),
#  'NCT03193099': set(),
#  'NCT01094899': set(),
#  'NCT01038999': {'22829920', '23285253'},
#  'NCT03831906': {'32853411', '33743621', '36395782'},
#  'NCT01008813': set(),
#  'NCT00604149': set(),
#  'NCT01779713': {'30354977'},
#  'NCT02160119': set(),
#  'NCT01207349': {'22030240'},
#  'NCT00944541': set(),
#  'NCT02102737': set(),
#  'NCT01942655': set(),
#  'NCT03870438': set(),
#  'NCT04945655': {'35332045'},
#  'NCT01188512': {'24261996', '24421886', '24793938'},
#  'NCT01038401': set(),
#  'NCT01086904': set(),
#  'NCT01332955': {'25139963'},
#  'NCT02469350': {'29636105'},
#  'NCT00480792': {'21486976', '27064975'},
#  'NCT04484740': set(),
#  'NCT01095744': set(),
#  'NCT00236340': set(),
#  'NCT02384967': {'29905808'},
#  'NCT03109067': set(),
#  'NCT00988767': {'20090916'},
#  'NCT01552044': set(),
#  'NCT03047967': set(),
#  'NCT05199831': set(),
#  'NCT00113282': set(),
#  'NCT01039220': set(),
#  'NCT04265742': set(),
#  'NCT01089400': {'24646009'},
#  'NCT00445575': set(),
#  'NCT00158496': set(),
#  'NCT01271842': {'22948576'},
#  'NCT01917175': set(),
#  'NCT01905059': {'28566227'},
#  'NCT01592175': set(),
#  'NCT00574652': {'22129253'},
#  'NCT02236832': set(),
#  'NCT01269632': set(),
#  'NCT01024400': {'22147712'},
#  'NCT02542800': set(),
#  'NCT00158470': set(),
#  'NCT01779752': set(),
#  'NCT03005652': {'33873195', '35853750', '36068621', '38100477'},
#  'NCT01311752': set(),
#  'NCT02916732': {'29539287', '33657112'},
#  'NCT03215732': {'31320358', '37143029'},
#  'NCT02405013': {'36686592'},
#  'NCT00820118': {'26568566'},
#  'NCT01952587': set(),
#  'NCT00640887': {'25406657', '26482301'},
#  'NCT01725542': {'25977266'},
#  'NCT02038842': set(),
#  'NCT00115609': set(),
#  'NCT04120415': set(),
#  'NCT01192737': set(),
#  'NCT00265642': set(),
#  'NCT00918307': {'29329763', '34611902'},
#  'NCT01089387': {'25974235', '26439886', '28753830'},
#  'NCT00928187': {'31273686'},
#  'NCT03324633': {'30570526', '32798585', '34212476'},
#  'NCT02027051': set(),
#  'NCT02027233': set(),
#  'NCT00136630': {'22491195', '24780882'},
#  'NCT03459157': {'34048794'},
#  'NCT05040048': set(),
#  'NCT04470648': set(),
#  'NCT02497274': set(),
#  'NCT05311865': {'36438274', '37795682'},
#  'NCT00158457': set(),
#  'NCT04315948': {'32304640',
#   '32958495',
#   '33264556',
#   '34048876',
#   '34350582',
#   '34473343',
#   '34534511',
#   '35233617',
#   '35512728',
#   '36695483',
#   '37728045'},
#  'NCT01620957': set(),
#  'NCT01693848': set(),
#  'NCT02107365': set(),
#  'NCT00196625': set(),
#  'NCT01359774': set(),
#  'NCT02273765': {'33667406'},
#  'NCT00490074': set(),
#  'NCT02081066': set(),
#  'NCT00651066': {'24465443'},
#  'NCT02566148': {'29307383', '29437866', '29982518'},
#  'NCT02073630': set(),
#  'NCT02573948': set(),
#  'NCT00339157': {'21173013'},
#  'NCT02453048': {'31945015', '32687804'},
#  'NCT03446430': set(),
#  'NCT00120757': {'22353022'},
#  'NCT02987530': set(),
#  'NCT02100774': {'24808487', '26063065', '27798339'},
#  'NCT00460382': set(),
#  'NCT00820820': set(),
#  'NCT01066962': {'25103176', '26520926', '30365452', '33794182'},
#  'NCT03671291': set(),
#  'NCT00117494': {'22318219', '22739396'},
#  'NCT01771562': {'27881690', '30081838'},
#  'NCT02542891': {'27488181', '34874888'},
#  'NCT01508494': set(),
#  'NCT05349162': {'36735263'},
#  'NCT01882062': {'25568297'},
#  'NCT01489592': set(),
#  'NCT01453192': {'30688008'},
#  'NCT01033760': {'25701561', '28708873'},
#  'NCT00545194': set(),
#  'NCT00528060': {'23459496'},
#  'NCT02650427': set(),
#  'NCT04008927': {'35774932'},
#  'NCT01022476': set(),
#  'NCT01335529': {'27077673'},
#  'NCT02014727': {'28947345'},
#  'NCT00536627': {'24394187', '24555998'},
#  'NCT02078076': set(),
#  'NCT02777229': {'31339676', '33010241', '33355914', '37851566', '38156046'},
#  'NCT01703962': {'37668523'},
#  'NCT03546127': set(),
#  'NCT01331876': set(),
#  'NCT02886416': set(),
#  'NCT01188525': set(),
#  'NCT00302822': set(),
#  'NCT01693835': set(),
#  'NCT02978924': set(),
#  'NCT00226434': {'24096631', '24759827'},
#  'NCT00148824': {'20210645'},
#  'NCT00670839': {'26257021'},
#  'NCT01548586': set(),
#  'NCT01801618': {'29662875'},
#  'NCT01055873': {'22427678'},
#  'NCT00495326': {'23433590', '24663014'},
#  'NCT02099474': {'32661003'},
#  'NCT02592174': {'31755936'},
#  'NCT00334256': set(),
#  'NCT01492985': {'33568510'},
#  'NCT02125500': set(),
#  'NCT00196599': set(),
#  'NCT02906137': set(),
#  'NCT02647632': {'29077864'},
#  'NCT00822315': {'24726095'},
#  'NCT01413152': set(),
#  'NCT01463956': set(),
#  'NCT00454337': {'19757993', '21712241', '27042193'},
#  'NCT01698411': set(),
#  'NCT02214511': set(),
#  'NCT01331811': {'26908804', '29174612', '30689814', '31455612'},
#  'NCT05090956': set(),
#  'NCT00120185': {'19508157'},
#  'NCT04392388': {'34293141'},
#  'NCT01065207': set(),
#  'NCT02082171': set(),
#  'NCT02052271': set(),
#  'NCT00158509': {'17314338', '18593294', '18596069'},
#  'NCT02346409': set(),
#  'NCT02656407': set(),
#  'NCT02150993': set(),
#  'NCT00657397': {'22741944',
#   '24268548',
#   '25209306',
#   '25393311',
#   '27048152',
#   '27770695'},
#  'NCT03137797': set(),
#  'NCT01167283': set(),
#  'NCT02014883': {'26536893'},
#  'NCT02931097': set(),
#  'NCT02093754': set(),
#  'NCT00116454': set(),
#  'NCT03954054': {'35012570'},
#  'NCT02329054': {'26930627', '28231247'},
#  'NCT04842851': set(),
#  'NCT00118677': {'20657770'},
#  'NCT01880151': set(),
#  'NCT00495651': {'23639243',
#   '24985779',
#   '25330161',
#   '26193126',
#   '29020361',
#   '29297443',
#   '35093007'},
#  'NCT02481453': {'38273639'},
#  'NCT00421551': {'20802297', '22848481', '29767684'},
#  'NCT02658253': {'32032566', '33717176'},
#  'NCT01688453': {'29696179',
#   '29776897',
#   '29934380',
#   '32097754',
#   '34087324',
#   '35272723'},
#  'NCT02408354': {'28969699'},
#  'NCT02157311': {'29186458'},
#  'NCT04288128': {'38419144', '38421662'},
#  'NCT02721745': set(),
#  'NCT01494961': {'23343912', '29178852', '34329355'},
#  'NCT02833961': {'36318030'},
#  'NCT02567071': set(),
#  'NCT02453061': {'31381524'},
#  'NCT01693861': set(),
#  'NCT00272428': {'19491388',
#   '19828715',
#   '20176858',
#   '20431391',
#   '20605091',
#   '21106918',
#   '21490142',
#   '21775560',
#   '21955649',
#   '22158670',
#   '22378736',
#   '22633793',
#   '23082222',
#   '23283500',
#   '23284983',
#   '24027184',
#   '24089418',
#   '24527713',
#   '24553693',
#   '25651444',
#   '25994566',
#   '26156743',
#   '26409628',
#   '26447153',
#   '26812508',
#   '26817718',
#   '26864363',
#   '26962176',
#   '27000099',
#   '27055851',
#   '28033414',
#   '28356432',
#   '28494135',
#   '29546305',
#   '29649036',
#   '30517725',
#   '31164347',
#   '31927670',
#   '33738534'},
#  'NCT01534728': set(),
#  'NCT04409405': {'38043556'},
#  'NCT02976298': set(),
#  'NCT00647205': set(),
#  'NCT02960698': set(),
#  'NCT01842477': set(),
#  'NCT01037777': {'23707147', '24780882', '32822634', '35264424'},
#  'NCT02172677': set(),
#  'NCT02101398': set(),
#  'NCT01495897': set(),
#  'NCT00463983': {'22379151'},
#  'NCT00158483': {'19530940'},
#  'NCT00301561': {'21831714', '35248123'},
#  'NCT01075061': set(),
#  'NCT00158405': {'16782488', '18986246'},
#  'NCT00623051': set()}

# %% [markdown]
# **On veut fusionner la liste PMIDs que l'on vient de récupérer sur PubMed, à la liste des PMIDs déjà récupérés via CT.**

# %% [markdown]
# On met les PMIDs de CT sous la même forme:

# %%
pmids_ct_dict = {}
for nctid in nctid_array:
    pmids = df_studies_v2[df_studies_v2.loc[:, "NCTId"] == nctid].loc[:, "pmid"].dropna()
    pmids_ct_dict[nctid] = set(pmids)
pmids_ct_dict
# Out:
# {'NCT01895920': set(),
#  'NCT02486731': set(),
#  'NCT02116374': set(),
#  'NCT03537196': {'19839502',
#   '20041309',
#   '20196807',
#   '20572071',
#   '22098550',
#   '22564041',
#   '22828983',
#   '23172780',
#   '23553643',
#   '23675659',
#   '23728143',
#   '23884064',
#   '25086286',
#   '25245939',
#   '25920094',
#   '26298331',
#   '27148964',
#   '27178119',
#   '27227200',
#   '27349488',
#   '27427455',
#   '27667367',
#   '33208326'},
#  'NCT01899196': set(),
#  'NCT04631224': set(),
#  'NCT01579435': set(),
#  'NCT03235258': {'17712765',
#   '18614870',
#   '19194272',
#   '20536367',
#   '21511330',
#   '21971357',
#   '22198788',
#   '22427678',
#   '24253249',
#   '24705410',
#   '24945880',
#   '26762993'},
#  'NCT00383734': {'23432777'},
#  'NCT00901524': {'24905490'},
#  'NCT01493934': set(),
#  'NCT03078439': set(),
#  'NCT04808986': set(),
#  'NCT01207986': set(),
#  'NCT02626286': {'33753460', '34022820', '34352834'},
#  'NCT02527096': set(),
#  'NCT00121758': {'20625264', '23759749'},
#  'NCT04684758': set(),
#  'NCT02057796': {'32558469'},
#  'NCT03071458': set(),
#  'NCT02192658': {'26846895'},
#  'NCT01713335': set(),
#  'NCT00158522': {'15977225', '16434426'},
#  'NCT00640263': {'17825642',
#   '23039034',
#   '26603917',
#   '27895016',
#   '28469697',
#   '30814028',
#   '31633158',
#   '31994250',
#   '32067040',
#   '32228542',
#   '32991450'},
#  'NCT02428816': set(),
#  'NCT00122616': {'23800784'},
#  'NCT00196586': set(),
#  'NCT00148863': {'23190183'},
#  'NCT03150290': set(),
#  'NCT01514890': {'23669289', '24704719', '25556540'},
#  'NCT03652090': set(),
#  'NCT02738502': {'22160145',
#   '22848481',
#   '23559464',
#   '23766338',
#   '26197844',
#   '26709605',
#   '26854809'},
#  'NCT02212379': set(),
#  'NCT00465790': set(),
#  'NCT01605890': {'29590335'},
#  'NCT00196664': set(),
#  'NCT00122603': {'19420019'},
#  'NCT02992184': {'29615488'},
#  'NCT02071784': set(),
#  'NCT01432821': {'12914551', '15037514', '15249613', '15777732', '2271377'},
#  'NCT00121121': {'17712402'},
#  'NCT02126384': set(),
#  'NCT02323308': set(),
#  'NCT02314208': set(),
#  'NCT01348308': {'32040959'},
#  'NCT02113943': set(),
#  'NCT00299143': set(),
#  'NCT04824638': set(),
#  'NCT00120367': {'21738597'},
#  'NCT00323804': set(),
#  'NCT03642704': set(),
#  'NCT04849767': {'34916316'},
#  'NCT00573001': set(),
#  'NCT02267304': set(),
#  'NCT01525472': set(),
#  'NCT02073604': set(),
#  'NCT01127204': {'27015798',
#   '28434406',
#   '28453240',
#   '28483965',
#   '28800382',
#   '31334298',
#   '34723858'},
#  'NCT01473472': {'26624850', '28747274', '29229440', '31784343'},
#  'NCT00122538': {'20516271', '21857286', '23719348'},
#  'NCT01555450': {'21256688', '28823681', '29909873'},
#  'NCT01696708': {'25568297'},
#  'NCT01100281': set(),
#  'NCT00424814': {'23766338', '25838291'},
#  'NCT00946595': {'29767684', '30968368'},
#  'NCT02488395': {'22639796', '23916713', '6774653'},
#  'NCT03335995': {'32026446'},
#  'NCT01647295': set(),
#  'NCT01226446': {'25987791'},
#  'NCT00658346': {'31063537'},
#  'NCT01874808': set(),
#  'NCT01509508': {'23880306',
#   '25880823',
#   '27504637',
#   '28329393',
#   '29199100',
#   '29890048',
#   '30027600',
#   '30321314',
#   '30412926',
#   '31637821',
#   '32970730'},
#  'NCT00391638': set(),
#  'NCT01426243': {'30096071'},
#  'NCT02496312': {'10436334',
#   '10678322',
#   '10941190',
#   '12461757',
#   '15897497',
#   '16207933',
#   '16421064',
#   '17027767',
#   '17131230',
#   '1821241',
#   '18307266',
#   '19533496',
#   '19713543',
#   '19933975',
#   '21895376'},
#  'NCT03519503': {'21602695', '22814853', '26603917'},
#  'NCT00196612': {'15717256'},
#  'NCT04133012': set(),
#  'NCT03298360': set(),
#  'NCT01490489': {'16384869', '17531315', '19602057'},
#  'NCT04780191': {'32232101'},
#  'NCT01164462': set(),
#  'NCT02051413': set(),
#  'NCT01531036': {'20505064'},
#  'NCT01164436': set(),
#  'NCT00870649': {'30532268'},
#  'NCT01842919': set(),
#  'NCT06260319': set(),
#  'NCT01569399': set(),
#  'NCT03193099': set(),
#  'NCT01094899': set(),
#  'NCT01038999': {'22829920', '23285253'},
#  'NCT03831906': {'32853411', '33743621', '36395782'},
#  'NCT01008813': set(),
#  'NCT00604149': set(),
#  'NCT01779713': {'30354977'},
#  'NCT02160119': set(),
#  'NCT01207349': {'22030240'},
#  'NCT00944541': set(),
#  'NCT02102737': set(),
#  'NCT01942655': set(),
#  'NCT03870438': {'26603917', '33872801'},
#  'NCT04945655': {'35332045'},
#  'NCT01188512': {'16839199',
#   '18762220',
#   '19625486',
#   '20107007',
#   '20184606',
#   '24261996',
#   '24421886',
#   '24793938'},
#  'NCT01038401': set(),
#  'NCT01086904': set(),
#  'NCT01332955': {'25139963'},
#  'NCT02469350': {'29636105'},
#  'NCT00480792': {'21486976', '27064975'},
#  'NCT04484740': set(),
#  'NCT01095744': set(),
#  'NCT00236340': {'11438952', '14770396', '7970458', '9464739'},
#  'NCT02384967': {'29905808'},
#  'NCT03109067': set(),
#  'NCT00988767': {'15382173', '16310901', '20090916'},
#  'NCT01552044': set(),
#  'NCT03047967': set(),
#  'NCT05199831': set(),
#  'NCT00113282': set(),
#  'NCT01039220': set(),
#  'NCT04265742': set(),
#  'NCT01089400': {'24646009'},
#  'NCT00445575': set(),
#  'NCT00158496': {'16019104', '16434426', '16847958', '16956918'},
#  'NCT01271842': {'22948576'},
#  'NCT01917175': set(),
#  'NCT01905059': {'16249701',
#   '16549962',
#   '17545707',
#   '18097218',
#   '18540803',
#   '20010070',
#   '20802297',
#   '20802298',
#   '21811554',
#   '21886816',
#   '22441252',
#   '22814125',
#   '23075703',
#   '28566227'},
#  'NCT01592175': set(),
#  'NCT00574652': {'22129253'},
#  'NCT02236832': set(),
#  'NCT01269632': set(),
#  'NCT01024400': {'22147712'},
#  'NCT02542800': set(),
#  'NCT00158470': set(),
#  'NCT01779752': set(),
#  'NCT03005652': {'33873195', '35853750', '36068621'},
#  'NCT01311752': set(),
#  'NCT02916732': {'29539287', '33657112'},
#  'NCT03215732': {'31320358'},
#  'NCT02405013': set(),
#  'NCT00820118': {'26568566'},
#  'NCT01952587': set(),
#  'NCT00640887': {'25406657', '26482301'},
#  'NCT01725542': {'25977266'},
#  'NCT02038842': set(),
#  'NCT00115609': set(),
#  'NCT04120415': set(),
#  'NCT01192737': set(),
#  'NCT00265642': set(),
#  'NCT00918307': {'29329763', '34611902'},
#  'NCT01089387': {'25974235', '28753830'},
#  'NCT00928187': {'31273686'},
#  'NCT03324633': {'20493576',
#   '20876416',
#   '20969743',
#   '21239121',
#   '21692942',
#   '21819472',
#   '21888878',
#   '21920402',
#   '22173166',
#   '22285372',
#   '22409788',
#   '22535683',
#   '22781224',
#   '23052829',
#   '23226258',
#   '23421419',
#   '23461846',
#   '23978720',
#   '24166726',
#   '24499953',
#   '24580042',
#   '25015913',
#   '25778750',
#   '26372388',
#   '26528903',
#   '27073179',
#   '27177169',
#   '27317796',
#   '27339598',
#   '28235612',
#   '28418984',
#   '28430385',
#   '28780609',
#   '28942916',
#   '30570526',
#   '32798585',
#   '34212476'},
#  'NCT02027051': set(),
#  'NCT02027233': set(),
#  'NCT00136630': {'15313841',
#   '15365159',
#   '16055926',
#   '16193476',
#   '16501573',
#   '17098887',
#   '17597328',
#   '17605047',
#   '17957230',
#   '18378516',
#   '18853458',
#   '22491195',
#   '24780882'},
#  'NCT03459157': {'34048794'},
#  'NCT05040048': set(),
#  'NCT04470648': {'31978945',
#   '31995857',
#   '32046819',
#   '32070465',
#   '32109013',
#   '32224310',
#   '32338732',
#   '32371096'},
#  'NCT02497274': set(),
#  'NCT05311865': set(),
#  'NCT00158457': set(),
#  'NCT04315948': {'32304640',
#   '32473020',
#   '32958495',
#   '33089306',
#   '33264556',
#   '34048876',
#   '34350582',
#   '34473343',
#   '34534511',
#   '34763056',
#   '35233617',
#   '35512728',
#   '35533972',
#   '35623577',
#   '35643099',
#   '36680782',
#   '36828006',
#   '37269068',
#   '37302469',
#   '37728045'},
#  'NCT01620957': set(),
#  'NCT01693848': set(),
#  'NCT02107365': set(),
#  'NCT00196625': {'15060509', '15456093'},
#  'NCT01359774': {'17653274', '21285522', '21320997'},
#  'NCT02273765': {'33667406'},
#  'NCT00490074': set(),
#  'NCT02081066': set(),
#  'NCT00651066': {'24465443'},
#  'NCT02566148': {'29307383', '29437866', '29982518'},
#  'NCT02073630': set(),
#  'NCT02573948': {'25540950',
#   '26032121',
#   '26050614',
#   '26075647',
#   '26080690',
#   '27006257',
#   '27178119',
#   '28612212',
#   '28800503'},
#  'NCT00339157': {'21173013'},
#  'NCT02453048': {'18762220',
#   '19625486',
#   '20107007',
#   '20419113',
#   '20708998',
#   '21147936',
#   '21430219',
#   '22814407',
#   '24421886',
#   '24793938',
#   '24950361',
#   '31945015',
#   '32687804'},
#  'NCT03446430': set(),
#  'NCT00120757': {'22353022'},
#  'NCT02987530': set(),
#  'NCT02100774': {'21957063', '24808487', '26063065', '27798339'},
#  'NCT00460382': set(),
#  'NCT00820820': set(),
#  'NCT01066962': {'25103176', '26520926', '30365452', '33794182'},
#  'NCT03671291': set(),
#  'NCT00117494': {'22318219', '22739396'},
#  'NCT01771562': {'27881690', '30081838'},
#  'NCT02542891': {'27488181', '34874888'},
#  'NCT01508494': set(),
#  'NCT05349162': set(),
#  'NCT01882062': {'25568297'},
#  'NCT01489592': {'15501961', '15974953', '16946298', '18559556', '20169331'},
#  'NCT01453192': set(),
#  'NCT01033760': {'25701561', '28708873'},
#  'NCT00545194': {'11236117', '16553177', '17071427'},
#  'NCT00528060': {'23459496'},
#  'NCT02650427': set(),
#  'NCT04008927': {'22310560',
#   '26806260',
#   '27168667',
#   '27178119',
#   '27537841',
#   '28004616',
#   '29432973',
#   '35774932'},
#  'NCT01022476': set(),
#  'NCT01335529': {'27077673'},
#  'NCT02014727': {'28947345'},
#  'NCT00536627': {'15382173', '16310901', '24394187', '24555998'},
#  'NCT02078076': set(),
#  'NCT02777229': {'31339676', '33010241', '33355914'},
#  'NCT01703962': set(),
#  'NCT03546127': set(),
#  'NCT01331876': set(),
#  'NCT02886416': set(),
#  'NCT01188525': set(),
#  'NCT00302822': set(),
#  'NCT01693835': set(),
#  'NCT02978924': set(),
#  'NCT00226434': {'17624825',
#   '22010913',
#   '23237982',
#   '24096631',
#   '24608960',
#   '24759827'},
#  'NCT00148824': {'20210645'},
#  'NCT00670839': {'26257021'},
#  'NCT01548586': {'10990547',
#   '11723286',
#   '15272049',
#   '15634731',
#   '16002441',
#   '19805746',
#   '20161639',
#   '22085959',
#   '8756819'},
#  'NCT01801618': set(),
#  'NCT01055873': {'22427678'},
#  'NCT00495326': {'23433590', '24663014'},
#  'NCT02099474': {'32661003'},
#  'NCT02592174': {'31755936'},
#  'NCT00334256': {'18987623', '19104016', '19307941'},
#  'NCT01492985': {'33568510'},
#  'NCT02125500': set(),
#  'NCT00196599': {'10915095', '15012649'},
#  'NCT02906137': set(),
#  'NCT02647632': {'29077864'},
#  'NCT00822315': {'24726095'},
#  'NCT01413152': set(),
#  'NCT01463956': set(),
#  'NCT00454337': {'19757993',
#   '19995925',
#   '20683319',
#   '21126958',
#   '21326075',
#   '21576452',
#   '21712241',
#   '22416781',
#   '27042193'},
#  'NCT01698411': set(),
#  'NCT02214511': set(),
#  'NCT01331811': {'26908804', '29174612', '30689814', '31455612'},
#  'NCT05090956': set(),
#  'NCT00120185': {'19508157'},
#  'NCT04392388': set(),
#  'NCT01065207': set(),
#  'NCT02082171': set(),
#  'NCT02052271': set(),
#  'NCT00158509': {'16044019', '17314338', '18593294', '18596069'},
#  'NCT02346409': set(),
#  'NCT02656407': {'25955583'},
#  'NCT02150993': set(),
#  'NCT00657397': {'22741944',
#   '24268548',
#   '25209306',
#   '25393311',
#   '27048152',
#   '27770695'},
#  'NCT03137797': {'22008658',
#   '22267473',
#   '23079802',
#   '23936509',
#   '24058636',
#   '24465584',
#   '25573889',
#   '26636578',
#   '27509048'},
#  'NCT01167283': set(),
#  'NCT02014883': {'26536893'},
#  'NCT02931097': set(),
#  'NCT02093754': set(),
#  'NCT00116454': set(),
#  'NCT03954054': {'35012570'},
#  'NCT02329054': {'25435054', '26930627', '27046271', '28231247'},
#  'NCT04842851': set(),
#  'NCT00118677': {'20657770'},
#  'NCT01880151': set(),
#  'NCT00495651': {'23639243',
#   '24985779',
#   '25330161',
#   '26193126',
#   '29020361',
#   '29297443',
#   '35093007'},
#  'NCT02481453': {'20413309', '24975859'},
#  'NCT00421551': {'20802297', '22848481', '29767684'},
#  'NCT02658253': {'32032566', '33717176'},
#  'NCT01688453': {'29696179', '29776897', '29934380', '32097754', '34087324'},
#  'NCT02408354': {'28969699'},
#  'NCT02157311': {'29186458'},
#  'NCT04288128': set(),
#  'NCT02721745': set(),
#  'NCT01494961': {'20403152', '21857289', '23343912', '29178852', '34329355'},
#  'NCT02833961': set(),
#  'NCT02567071': set(),
#  'NCT02453061': {'31381524'},
#  'NCT01693861': set(),
#  'NCT00272428': {'15557412',
#   '19491388',
#   '19828715',
#   '20176858',
#   '20431391',
#   '20605091',
#   '21106918',
#   '21490142',
#   '21775560',
#   '21955649',
#   '22158670',
#   '22378736',
#   '22633793',
#   '23082222',
#   '23283500',
#   '23284983',
#   '24027184',
#   '24089418',
#   '24527713',
#   '24553693',
#   '25651444',
#   '25994566',
#   '26156743',
#   '26409628',
#   '26447153',
#   '26812508',
#   '26817718',
#   '26864363',
#   '26962176',
#   '27000099',
#   '27055851',
#   '28033414',
#   '28356432',
#   '28494135',
#   '29546305',
#   '29649036',
#   '30517725',
#   '31164347',
#   '31927670',
#   '33738534'},
#  'NCT01534728': set(),
#  'NCT04409405': set(),
#  'NCT02976298': set(),
#  'NCT00647205': set(),
#  'NCT02960698': set(),
#  'NCT01842477': set(),
#  'NCT01037777': {'23707147', '24780882', '32822634', '35264424'},
#  'NCT02172677': set(),
#  'NCT02101398': set(),
#  'NCT01495897': set(),
#  'NCT00463983': {'16883006', '22379151'},
#  'NCT00158483': {'16455895', '18385443', '19530940'},
#  'NCT00301561': {'21831714', '35248123'},
#  'NCT01075061': set(),
#  'NCT00158405': {'16152755', '16782488', '18986246'},
#  'NCT00623051': set()}

# %% [markdown]
# Pour un NCTDId donné, on fait l'union des deux ensembles de PMIDs:

# %%
pmids_complete_dict = {}
for nctid in nctid_array:
    # L'ensemble des PMIds présents dans PubMed et CT 
    pmids_complete_dict[nctid] = pmids_pubmed_dict[nctid] | pmids_ct_dict[nctid]
pmids_complete_dict
# Out:
# {'NCT01895920': set(),
#  'NCT02486731': set(),
#  'NCT02116374': set(),
#  'NCT03537196': {'19839502',
#   '20041309',
#   '20196807',
#   '20572071',
#   '22098550',
#   '22564041',
#   '22828983',
#   '23172780',
#   '23553643',
#   '23675659',
#   '23728143',
#   '23884064',
#   '25086286',
#   '25245939',
#   '25920094',
#   '26298331',
#   '27148964',
#   '27178119',
#   '27227200',
#   '27349488',
#   '27427455',
#   '27667367',
#   '33208326'},
#  'NCT01899196': set(),
#  'NCT04631224': set(),
#  'NCT01579435': set(),
#  'NCT03235258': {'17712765',
#   '18614870',
#   '19194272',
#   '20536367',
#   '21511330',
#   '21971357',
#   '22198788',
#   '22427678',
#   '24253249',
#   '24705410',
#   '24945880',
#   '26762993'},
#  'NCT00383734': {'23432777'},
#  'NCT00901524': {'24905490'},
#  'NCT01493934': set(),
#  'NCT03078439': {'38408861'},
#  'NCT04808986': set(),
#  'NCT01207986': set(),
#  'NCT02626286': {'33753460', '34022820', '34352834'},
#  'NCT02527096': set(),
#  'NCT00121758': {'20625264', '23759749'},
#  'NCT04684758': set(),
#  'NCT02057796': {'32558469', '36883573'},
#  'NCT03071458': set(),
#  'NCT02192658': {'26846895'},
#  'NCT01713335': set(),
#  'NCT00158522': {'15977225', '16434426'},
#  'NCT00640263': {'17825642',
#   '23039034',
#   '26603917',
#   '27895016',
#   '28469697',
#   '30814028',
#   '31633158',
#   '31994250',
#   '32067040',
#   '32228542',
#   '32991450',
#   '34425825'},
#  'NCT02428816': set(),
#  'NCT00122616': {'23800784'},
#  'NCT00196586': set(),
#  'NCT00148863': {'23190183'},
#  'NCT03150290': set(),
#  'NCT01514890': {'23669289', '24704719', '25556540'},
#  'NCT03652090': set(),
#  'NCT02738502': {'22160145',
#   '22848481',
#   '23559464',
#   '23766338',
#   '26197844',
#   '26709605',
#   '26854809'},
#  'NCT02212379': {'31269208'},
#  'NCT00465790': set(),
#  'NCT01605890': {'29590335'},
#  'NCT00196664': set(),
#  'NCT00122603': {'19420019'},
#  'NCT02992184': {'29615488'},
#  'NCT02071784': set(),
#  'NCT01432821': {'12914551', '15037514', '15249613', '15777732', '2271377'},
#  'NCT00121121': {'17712402'},
#  'NCT02126384': set(),
#  'NCT02323308': set(),
#  'NCT02314208': set(),
#  'NCT01348308': {'32040959'},
#  'NCT02113943': set(),
#  'NCT00299143': set(),
#  'NCT04824638': set(),
#  'NCT00120367': {'21738597'},
#  'NCT00323804': set(),
#  'NCT03642704': set(),
#  'NCT04849767': {'34916316'},
#  'NCT00573001': set(),
#  'NCT02267304': set(),
#  'NCT01525472': set(),
#  'NCT02073604': set(),
#  'NCT01127204': {'27015798',
#   '28434406',
#   '28453240',
#   '28483965',
#   '28800382',
#   '31334298',
#   '34723858'},
#  'NCT01473472': {'26624850', '28747274', '29229440', '31784343', '36601747'},
#  'NCT00122538': {'20516271', '21857286', '23719348'},
#  'NCT01555450': {'21256688', '28823681', '29909873'},
#  'NCT01696708': {'25568297'},
#  'NCT01100281': set(),
#  'NCT00424814': {'23766338', '25838291'},
#  'NCT00946595': {'29767684', '30968368'},
#  'NCT02488395': {'22639796', '23916713', '6774653'},
#  'NCT03335995': {'32026446', '37497675'},
#  'NCT01647295': set(),
#  'NCT01226446': {'25987791'},
#  'NCT00658346': {'31063537'},
#  'NCT01874808': set(),
#  'NCT01509508': {'23880306',
#   '25880823',
#   '27504637',
#   '28329393',
#   '29199100',
#   '29890048',
#   '30027600',
#   '30321314',
#   '30412926',
#   '31637821',
#   '32970730'},
#  'NCT00391638': set(),
#  'NCT01426243': {'26314624', '30096071'},
#  'NCT02496312': {'10436334',
#   '10678322',
#   '10941190',
#   '12461757',
#   '15897497',
#   '16207933',
#   '16421064',
#   '17027767',
#   '17131230',
#   '1821241',
#   '18307266',
#   '19533496',
#   '19713543',
#   '19933975',
#   '21895376'},
#  'NCT03519503': {'21602695', '22814853', '26603917'},
#  'NCT00196612': {'15717256'},
#  'NCT04133012': set(),
#  'NCT03298360': set(),
#  'NCT01490489': {'16384869', '17531315', '19602057'},
#  'NCT04780191': {'32232101'},
#  'NCT01164462': set(),
#  'NCT02051413': set(),
#  'NCT01531036': {'20505064'},
#  'NCT01164436': set(),
#  'NCT00870649': {'30532268'},
#  'NCT01842919': set(),
#  'NCT06260319': set(),
#  'NCT01569399': set(),
#  'NCT03193099': set(),
#  'NCT01094899': set(),
#  'NCT01038999': {'22829920', '23285253'},
#  'NCT03831906': {'32853411', '33743621', '36395782'},
#  'NCT01008813': set(),
#  'NCT00604149': set(),
#  'NCT01779713': {'30354977'},
#  'NCT02160119': set(),
#  'NCT01207349': {'22030240'},
#  'NCT00944541': set(),
#  'NCT02102737': set(),
#  'NCT01942655': set(),
#  'NCT03870438': {'26603917', '33872801'},
#  'NCT04945655': {'35332045'},
#  'NCT01188512': {'16839199',
#   '18762220',
#   '19625486',
#   '20107007',
#   '20184606',
#   '24261996',
#   '24421886',
#   '24793938'},
#  'NCT01038401': set(),
#  'NCT01086904': set(),
#  'NCT01332955': {'25139963'},
#  'NCT02469350': {'29636105'},
#  'NCT00480792': {'21486976', '27064975'},
#  'NCT04484740': set(),
#  'NCT01095744': set(),
#  'NCT00236340': {'11438952', '14770396', '7970458', '9464739'},
#  'NCT02384967': {'29905808'},
#  'NCT03109067': set(),
#  'NCT00988767': {'15382173', '16310901', '20090916'},
#  'NCT01552044': set(),
#  'NCT03047967': set(),
#  'NCT05199831': set(),
#  'NCT00113282': set(),
#  'NCT01039220': set(),
#  'NCT04265742': set(),
#  'NCT01089400': {'24646009'},
#  'NCT00445575': set(),
#  'NCT00158496': {'16019104', '16434426', '16847958', '16956918'},
#  'NCT01271842': {'22948576'},
#  'NCT01917175': set(),
#  'NCT01905059': {'16249701',
#   '16549962',
#   '17545707',
#   '18097218',
#   '18540803',
#   '20010070',
#   '20802297',
#   '20802298',
#   '21811554',
#   '21886816',
#   '22441252',
#   '22814125',
#   '23075703',
#   '28566227'},
#  'NCT01592175': set(),
#  'NCT00574652': {'22129253'},
#  'NCT02236832': set(),
#  'NCT01269632': set(),
#  'NCT01024400': {'22147712'},
#  'NCT02542800': set(),
#  'NCT00158470': set(),
#  'NCT01779752': set(),
#  'NCT03005652': {'33873195', '35853750', '36068621', '38100477'},
#  'NCT01311752': set(),
#  'NCT02916732': {'29539287', '33657112'},
#  'NCT03215732': {'31320358', '37143029'},
#  'NCT02405013': {'36686592'},
#  'NCT00820118': {'26568566'},
#  'NCT01952587': set(),
#  'NCT00640887': {'25406657', '26482301'},
#  'NCT01725542': {'25977266'},
#  'NCT02038842': set(),
#  'NCT00115609': set(),
#  'NCT04120415': set(),
#  'NCT01192737': set(),
#  'NCT00265642': set(),
#  'NCT00918307': {'29329763', '34611902'},
#  'NCT01089387': {'25974235', '26439886', '28753830'},
#  'NCT00928187': {'31273686'},
#  'NCT03324633': {'20493576',
#   '20876416',
#   '20969743',
#   '21239121',
#   '21692942',
#   '21819472',
#   '21888878',
#   '21920402',
#   '22173166',
#   '22285372',
#   '22409788',
#   '22535683',
#   '22781224',
#   '23052829',
#   '23226258',
#   '23421419',
#   '23461846',
#   '23978720',
#   '24166726',
#   '24499953',
#   '24580042',
#   '25015913',
#   '25778750',
#   '26372388',
#   '26528903',
#   '27073179',
#   '27177169',
#   '27317796',
#   '27339598',
#   '28235612',
#   '28418984',
#   '28430385',
#   '28780609',
#   '28942916',
#   '30570526',
#   '32798585',
#   '34212476'},
#  'NCT02027051': set(),
#  'NCT02027233': set(),
#  'NCT00136630': {'15313841',
#   '15365159',
#   '16055926',
#   '16193476',
#   '16501573',
#   '17098887',
#   '17597328',
#   '17605047',
#   '17957230',
#   '18378516',
#   '18853458',
#   '22491195',
#   '24780882'},
#  'NCT03459157': {'34048794'},
#  'NCT05040048': set(),
#  'NCT04470648': {'31978945',
#   '31995857',
#   '32046819',
#   '32070465',
#   '32109013',
#   '32224310',
#   '32338732',
#   '32371096'},
#  'NCT02497274': set(),
#  'NCT05311865': {'36438274', '37795682'},
#  'NCT00158457': set(),
#  'NCT04315948': {'32304640',
#   '32473020',
#   '32958495',
#   '33089306',
#   '33264556',
#   '34048876',
#   '34350582',
#   '34473343',
#   '34534511',
#   '34763056',
#   '35233617',
#   '35512728',
#   '35533972',
#   '35623577',
#   '35643099',
#   '36680782',
#   '36695483',
#   '36828006',
#   '37269068',
#   '37302469',
#   '37728045'},
#  'NCT01620957': set(),
#  'NCT01693848': set(),
#  'NCT02107365': set(),
#  'NCT00196625': {'15060509', '15456093'},
#  'NCT01359774': {'17653274', '21285522', '21320997'},
#  'NCT02273765': {'33667406'},
#  'NCT00490074': set(),
#  'NCT02081066': set(),
#  'NCT00651066': {'24465443'},
#  'NCT02566148': {'29307383', '29437866', '29982518'},
#  'NCT02073630': set(),
#  'NCT02573948': {'25540950',
#   '26032121',
#   '26050614',
#   '26075647',
#   '26080690',
#   '27006257',
#   '27178119',
#   '28612212',
#   '28800503'},
#  'NCT00339157': {'21173013'},
#  'NCT02453048': {'18762220',
#   '19625486',
#   '20107007',
#   '20419113',
#   '20708998',
#   '21147936',
#   '21430219',
#   '22814407',
#   '24421886',
#   '24793938',
#   '24950361',
#   '31945015',
#   '32687804'},
#  'NCT03446430': set(),
#  'NCT00120757': {'22353022'},
#  'NCT02987530': set(),
#  'NCT02100774': {'21957063', '24808487', '26063065', '27798339'},
#  'NCT00460382': set(),
#  'NCT00820820': set(),
#  'NCT01066962': {'25103176', '26520926', '30365452', '33794182'},
#  'NCT03671291': set(),
#  'NCT00117494': {'22318219', '22739396'},
#  'NCT01771562': {'27881690', '30081838'},
#  'NCT02542891': {'27488181', '34874888'},
#  'NCT01508494': set(),
#  'NCT05349162': {'36735263'},
#  'NCT01882062': {'25568297'},
#  'NCT01489592': {'15501961', '15974953', '16946298', '18559556', '20169331'},
#  'NCT01453192': {'30688008'},
#  'NCT01033760': {'25701561', '28708873'},
#  'NCT00545194': {'11236117', '16553177', '17071427'},
#  'NCT00528060': {'23459496'},
#  'NCT02650427': set(),
#  'NCT04008927': {'22310560',
#   '26806260',
#   '27168667',
#   '27178119',
#   '27537841',
#   '28004616',
#   '29432973',
#   '35774932'},
#  'NCT01022476': set(),
#  'NCT01335529': {'27077673'},
#  'NCT02014727': {'28947345'},
#  'NCT00536627': {'15382173', '16310901', '24394187', '24555998'},
#  'NCT02078076': set(),
#  'NCT02777229': {'31339676', '33010241', '33355914', '37851566', '38156046'},
#  'NCT01703962': {'37668523'},
#  'NCT03546127': set(),
#  'NCT01331876': set(),
#  'NCT02886416': set(),
#  'NCT01188525': set(),
#  'NCT00302822': set(),
#  'NCT01693835': set(),
#  'NCT02978924': set(),
#  'NCT00226434': {'17624825',
#   '22010913',
#   '23237982',
#   '24096631',
#   '24608960',
#   '24759827'},
#  'NCT00148824': {'20210645'},
#  'NCT00670839': {'26257021'},
#  'NCT01548586': {'10990547',
#   '11723286',
#   '15272049',
#   '15634731',
#   '16002441',
#   '19805746',
#   '20161639',
#   '22085959',
#   '8756819'},
#  'NCT01801618': {'29662875'},
#  'NCT01055873': {'22427678'},
#  'NCT00495326': {'23433590', '24663014'},
#  'NCT02099474': {'32661003'},
#  'NCT02592174': {'31755936'},
#  'NCT00334256': {'18987623', '19104016', '19307941'},
#  'NCT01492985': {'33568510'},
#  'NCT02125500': set(),
#  'NCT00196599': {'10915095', '15012649'},
#  'NCT02906137': set(),
#  'NCT02647632': {'29077864'},
#  'NCT00822315': {'24726095'},
#  'NCT01413152': set(),
#  'NCT01463956': set(),
#  'NCT00454337': {'19757993',
#   '19995925',
#   '20683319',
#   '21126958',
#   '21326075',
#   '21576452',
#   '21712241',
#   '22416781',
#   '27042193'},
#  'NCT01698411': set(),
#  'NCT02214511': set(),
#  'NCT01331811': {'26908804', '29174612', '30689814', '31455612'},
#  'NCT05090956': set(),
#  'NCT00120185': {'19508157'},
#  'NCT04392388': {'34293141'},
#  'NCT01065207': set(),
#  'NCT02082171': set(),
#  'NCT02052271': set(),
#  'NCT00158509': {'16044019', '17314338', '18593294', '18596069'},
#  'NCT02346409': set(),
#  'NCT02656407': {'25955583'},
#  'NCT02150993': set(),
#  'NCT00657397': {'22741944',
#   '24268548',
#   '25209306',
#   '25393311',
#   '27048152',
#   '27770695'},
#  'NCT03137797': {'22008658',
#   '22267473',
#   '23079802',
#   '23936509',
#   '24058636',
#   '24465584',
#   '25573889',
#   '26636578',
#   '27509048'},
#  'NCT01167283': set(),
#  'NCT02014883': {'26536893'},
#  'NCT02931097': set(),
#  'NCT02093754': set(),
#  'NCT00116454': set(),
#  'NCT03954054': {'35012570'},
#  'NCT02329054': {'25435054', '26930627', '27046271', '28231247'},
#  'NCT04842851': set(),
#  'NCT00118677': {'20657770'},
#  'NCT01880151': set(),
#  'NCT00495651': {'23639243',
#   '24985779',
#   '25330161',
#   '26193126',
#   '29020361',
#   '29297443',
#   '35093007'},
#  'NCT02481453': {'20413309', '24975859', '38273639'},
#  'NCT00421551': {'20802297', '22848481', '29767684'},
#  'NCT02658253': {'32032566', '33717176'},
#  'NCT01688453': {'29696179',
#   '29776897',
#   '29934380',
#   '32097754',
#   '34087324',
#   '35272723'},
#  'NCT02408354': {'28969699'},
#  'NCT02157311': {'29186458'},
#  'NCT04288128': {'38419144', '38421662'},
#  'NCT02721745': set(),
#  'NCT01494961': {'20403152', '21857289', '23343912', '29178852', '34329355'},
#  'NCT02833961': {'36318030'},
#  'NCT02567071': set(),
#  'NCT02453061': {'31381524'},
#  'NCT01693861': set(),
#  'NCT00272428': {'15557412',
#   '19491388',
#   '19828715',
#   '20176858',
#   '20431391',
#   '20605091',
#   '21106918',
#   '21490142',
#   '21775560',
#   '21955649',
#   '22158670',
#   '22378736',
#   '22633793',
#   '23082222',
#   '23283500',
#   '23284983',
#   '24027184',
#   '24089418',
#   '24527713',
#   '24553693',
#   '25651444',
#   '25994566',
#   '26156743',
#   '26409628',
#   '26447153',
#   '26812508',
#   '26817718',
#   '26864363',
#   '26962176',
#   '27000099',
#   '27055851',
#   '28033414',
#   '28356432',
#   '28494135',
#   '29546305',
#   '29649036',
#   '30517725',
#   '31164347',
#   '31927670',
#   '33738534'},
#  'NCT01534728': set(),
#  'NCT04409405': {'38043556'},
#  'NCT02976298': set(),
#  'NCT00647205': set(),
#  'NCT02960698': set(),
#  'NCT01842477': set(),
#  'NCT01037777': {'23707147', '24780882', '32822634', '35264424'},
#  'NCT02172677': set(),
#  'NCT02101398': set(),
#  'NCT01495897': set(),
#  'NCT00463983': {'16883006', '22379151'},
#  'NCT00158483': {'16455895', '18385443', '19530940'},
#  'NCT00301561': {'21831714', '35248123'},
#  'NCT01075061': set(),
#  'NCT00158405': {'16152755', '16782488', '18986246'},
#  'NCT00623051': set()}

# %% [markdown]
# #### Verifications:

# %%
num_pmids_ct = sum((len(v) for v in pmids_ct_dict.values()))
print(f"Nombre total de publications issus de CT: {num_pmids_ct}")
# Out:
# Nombre total de publications issus de CT: 521

# %%
num_pmids_complete = sum((len(v) for v in pmids_complete_dict.values()))
print(f"Nombre total de publications après consultation PubMed: {num_pmids_complete}")
# Out:
# Nombre total de publications après consultation PubMed: 548

# %%
pmids_pubmed_only_dict = {}
for nctid in nctid_array:
    # L'ensemble des PMIds présents dans PubMed uniquement 
    pmids_pubmed_only_dict[nctid] = pmids_pubmed_dict[nctid] - pmids_ct_dict[nctid]

# %%
num_pmids_pubmed_only = sum((len(v) for v in pmids_pubmed_only_dict.values()))
print(f"Nombre de nouveaux PMIDs trouvés via Pubmed: {num_pmids_pubmed_only}")
# Out:
# Nombre de nouveaux PMIDs trouvés via Pubmed: 27

# %%
assert (num_pmids_complete - num_pmids_ct == num_pmids_pubmed_only)

# %%
print("NCTId des nouveaux PMIDs trouvés via Pubmed:")
{k: v for k, v in pmids_pubmed_only_dict.items() if v != set()}
# Out:
# NCTId des nouveaux PMIDs trouvés via Pubmed:
# {'NCT03078439': {'38408861'},
#  'NCT02057796': {'36883573'},
#  'NCT00640263': {'34425825'},
#  'NCT02212379': {'31269208'},
#  'NCT01473472': {'36601747'},
#  'NCT03335995': {'37497675'},
#  'NCT01426243': {'26314624'},
#  'NCT03005652': {'38100477'},
#  'NCT03215732': {'37143029'},
#  'NCT02405013': {'36686592'},
#  'NCT01089387': {'26439886'},
#  'NCT05311865': {'36438274', '37795682'},
#  'NCT04315948': {'36695483'},
#  'NCT05349162': {'36735263'},
#  'NCT01453192': {'30688008'},
#  'NCT02777229': {'37851566', '38156046'},
#  'NCT01703962': {'37668523'},
#  'NCT01801618': {'29662875'},
#  'NCT04392388': {'34293141'},
#  'NCT02481453': {'38273639'},
#  'NCT01688453': {'35272723'},
#  'NCT04288128': {'38419144', '38421662'},
#  'NCT02833961': {'36318030'},
#  'NCT04409405': {'38043556'}}

# %%
num_nctid_empty_ct = sum((1 for v in pmids_ct_dict.values() if v == set()))
print(f"Nombre d'études sans PMIDs issus de CT: {num_nctid_empty_ct}")
# Out:
# Nombre d'études sans PMIDs issus de CT: 148

# %%
num_nctid_empty_pubmed = sum((1 for v in pmids_complete_dict.values() if v == set()))
print(f"Nombre d'études sans PMIDs après consultation PubMed: {num_nctid_empty_pubmed}")
# Out:
# Nombre d'études sans PMIDs après consultation PubMed: 136

# %%
print("NCTIds qui n'avait aucun PMIDs sous CT, mais enrichis via Pubmed:")
nctids_previously_empty = {k for k, v in pmids_ct_dict.items() if v == set()} - {k for k, v in pmids_complete_dict.items() if v == set()}
{k : pmids_complete_dict[k] for k in nctids_previously_empty}
# Out:
# NCTIds qui n'avait aucun PMIDs sous CT, mais enrichis via Pubmed:
# {'NCT02405013': {'36686592'},
#  'NCT04392388': {'34293141'},
#  'NCT01703962': {'37668523'},
#  'NCT02833961': {'36318030'},
#  'NCT01801618': {'29662875'},
#  'NCT01453192': {'30688008'},
#  'NCT02212379': {'31269208'},
#  'NCT05311865': {'36438274', '37795682'},
#  'NCT04409405': {'38043556'},
#  'NCT05349162': {'36735263'},
#  'NCT03078439': {'38408861'},
#  'NCT04288128': {'38419144', '38421662'}}

# %%
len(nctids_previously_empty)
# Out:
# 12

# %%
assert (num_nctid_empty_ct - num_nctid_empty_pubmed == len(nctids_previously_empty))

# %% [markdown]
# ### Enrichissement des PMIDs via l'API Pubmed

# %% [markdown]
# Pour chaque PMID récupéré, on l'enrichit avec les données de PubMed tel que le titre, les auteurs, ...:

# %%
counter = 0 # To keep track of progress
book_counter = 0 # type different from 'article', get ignored
total_publications_list = []

#For each NTCID...
for nctid, pmids in pmids_complete_dict.items():
    pmids_list = []
    
    # We process each PMID...
    for pmid in pmids:
        
        # Display the progress on a single line
        print(f'\r{counter+1} / {num_pmids_complete}...', end='', flush=True)

        try:
            # Fetch article details from Pubmed
            article = fetch.article_by_pmid(pmid)

            # We are not interested by articles with type 'book'
            # TODO: book special case ?
            if article.pubmed_type == 'article':
                pmids_list.append(
                    {
                        'pmid': pmid,
                        'title': article.title,
                        'authors': article.authors_str.strip(),
                        'doi': article.doi,
                        'year': article.year,
                        'publication_types': list(
                            article.publication_types.values()
                        ),
                        'citation': article.citation,
                    }
                )
            else:
                book_counter += 1
                book = (nctid, pmid)
                
            counter += 1
        except InvalidPMID as e:
            print(f'\n{e}')

    publication_dict = {'NCTId': nctid, 'publications': pmids_list}

    total_publications_list.append(publication_dict)
# Out:
# 548 / 548...

# %%
print(f'Nb de publications avec un type différent d"article": {book_counter}')
print(book)
# Out:
# Nb de publications avec un type différent d"article": 1
# ('NCT03537196', '27227200')

# %%
print(json.dumps(total_publications_list, indent=2))
# Out:
# [
#   {
#     "NCTId": "NCT01895920",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT02486731",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT02116374",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT03537196",
#     "publications": [
#       {
#         "pmid": "26298331",
#         "title": "Hepatitis C virus (HCV) disease progression in people who inject drugs (PWID): A systematic review and meta-analysis.",
#         "authors": "Smith DJ; Combellick J; Jordan AE; Hagan H",
#         "doi": "10.1016/j.drugpo.2015.07.004",
#         "year": "2015",
#         "publication_types": [
#           "Journal Article",
#           "Meta-Analysis",
#           "Research Support, N.I.H., Extramural",
#           "Review",
#           "Systematic Review"
#         ],
#         "citation": "Smith DJ, et al. Hepatitis C virus (HCV) disease progression in people who inject drugs (PWID): A systematic review and meta-analysis. Hepatitis C virus (HCV) disease progression in people who inject drugs (PWID): A systematic review and meta-analysis. 2015; 26:911-21. doi: 10.1016/j.drugpo.2015.07.004"
#       },
#       {
#         "pmid": "23172780",
#         "title": "Global epidemiology of hepatitis C virus infection: new estimates of age-specific antibody to HCV seroprevalence.",
#         "authors": "Mohd Hanafiah K; Groeger J; Flaxman AD; Wiersma ST",
#         "doi": "10.1002/hep.26141",
#         "year": "2013",
#         "publication_types": [
#           "Journal Article",
#           "Meta-Analysis",
#           "Review",
#           "Systematic Review"
#         ],
#         "citation": "Mohd Hanafiah K, et al. Global epidemiology of hepatitis C virus infection: new estimates of age-specific antibody to HCV seroprevalence. Global epidemiology of hepatitis C virus infection: new estimates of age-specific antibody to HCV seroprevalence. 2013; 57:1333-42. doi: 10.1002/hep.26141"
#       },
#       {
#         "pmid": "20572071",
#         "title": "Multiple routes of hepatitis C virus transmission among injection drug users in Hai Phong, Northern Vietnam.",
#         "authors": "Tanimoto T; Nguyen HC; Ishizaki A; Chung PT; Hoang TT; Nguyen VT; Kageyama S; Oka S; Pham VT; Ichimura H",
#         "doi": "10.1002/jmv.21787",
#         "year": "2010",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Tanimoto T, et al. Multiple routes of hepatitis C virus transmission among injection drug users in Hai Phong, Northern Vietnam. Multiple routes of hepatitis C virus transmission among injection drug users in Hai Phong, Northern Vietnam. 2010; 82:1355-63. doi: 10.1002/jmv.21787"
#       },
#       {
#         "pmid": "23553643",
#         "title": "Hepatitis C virus treatment for prevention among people who inject drugs: Modeling treatment scale-up in the age of direct-acting antivirals.",
#         "authors": "Martin NK; Vickerman P; Grebely J; Hellard M; Hutchinson SJ; Lima VD; Foster GR; Dillon JF; Goldberg DJ; Dore GJ; Hickman M",
#         "doi": "10.1002/hep.26431",
#         "year": "2013",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, N.I.H., Extramural",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Martin NK, et al. Hepatitis C virus treatment for prevention among people who inject drugs: Modeling treatment scale-up in the age of direct-acting antivirals. Hepatitis C virus treatment for prevention among people who inject drugs: Modeling treatment scale-up in the age of direct-acting antivirals. 2013; 58:1598-609. doi: 10.1002/hep.26431"
#       },
#       {
#         "pmid": "23884064",
#         "title": "Combination interventions to prevent HCV transmission among people who inject drugs: modeling the impact of antiviral treatment, needle and syringe programs, and opiate substitution therapy.",
#         "authors": "Martin NK; Hickman M; Hutchinson SJ; Goldberg DJ; Vickerman P",
#         "doi": "10.1093/cid/cit296",
#         "year": "2013",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Martin NK, et al. Combination interventions to prevent HCV transmission among people who inject drugs: modeling the impact of antiviral treatment, needle and syringe programs, and opiate substitution therapy. Combination interventions to prevent HCV transmission among people who inject drugs: modeling the impact of antiviral treatment, needle and syringe programs, and opiate substitution therapy. 2013; 57 Suppl 2:S39-45. doi: 10.1093/cid/cit296"
#       },
#       {
#         "pmid": "20196807",
#         "title": "Vietnamese community screening for hepatitis B virus and hepatitis C virus.",
#         "authors": "Kallman JB; Tran S; Arsalla A; Haddad D; Stepanova M; Fang Y; Wrobel VJ; Srishord M; Younossi ZM",
#         "doi": "10.1111/j.1365-2893.2010.01278.x",
#         "year": "2011",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Kallman JB, et al. Vietnamese community screening for hepatitis B virus and hepatitis C virus. Vietnamese community screening for hepatitis B virus and hepatitis C virus. 2011; 18:70-6. doi: 10.1111/j.1365-2893.2010.01278.x"
#       },
#       {
#         "pmid": "23728143",
#         "title": "Elimination of hepatitis C virus infection among people who inject drugs through treatment as prevention: feasibility and future requirements.",
#         "authors": "Grebely J; Matthews GV; Lloyd AR; Dore GJ",
#         "doi": "10.1093/cid/cit377",
#         "year": "2013",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Grebely J, et al. Elimination of hepatitis C virus infection among people who inject drugs through treatment as prevention: feasibility and future requirements. Elimination of hepatitis C virus infection among people who inject drugs through treatment as prevention: feasibility and future requirements. 2013; 57:1014-20. doi: 10.1093/cid/cit377"
#       },
#       {
#         "pmid": "27667367",
#         "title": "EASL Recommendations on Treatment of Hepatitis C 2016.",
#         "authors": "European Association for the Study of the Liver. Electronic address: easloffice@easloffice.eu",
#         "doi": "10.1016/j.jhep.2016.09.001",
#         "year": "2017",
#         "publication_types": [
#           "Journal Article",
#           "Practice Guideline"
#         ],
#         "citation": "European Association for the Study of the Liver. Electronic address: easloffice@easloffice.eu. EASL Recommendations on Treatment of Hepatitis C 2016. EASL Recommendations on Treatment of Hepatitis C 2016. 2017; 66:153-194. doi: 10.1016/j.jhep.2016.09.001"
#       },
#       {
#         "pmid": "33208326",
#         "title": "Towards HCV elimination among people who inject drugs in Hai Phong, Vietnam: study protocol for an effectiveness-implementation trial evaluating an integrated model of HCV care (DRIVE-C: DRug use & Infections in ViEtnam-hepatitis C).",
#         "authors": "Rapoud D; Quillet C; Pham Minh K; Vu Hai V; Nguyen Thanh B; Nham Thi Tuyet T; Tran Thi H; Mol\u00e8s JP; Vallo R; Michel L; Feelemyer J; Weiss L; Lemoine M; Vickerman P; Fraser H; Duong Thi H; Khuat Thi Hai O; Des Jarlais D; Nagot N; Laureillard D; DRIVE-C Study Group",
#         "doi": "10.1136/bmjopen-2020-039234",
#         "year": "2020",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Rapoud D, et al. Towards HCV elimination among people who inject drugs in Hai Phong, Vietnam: study protocol for an effectiveness-implementation trial evaluating an integrated model of HCV care (DRIVE-C: DRug use & Infections in ViEtnam-hepatitis C). Towards HCV elimination among people who inject drugs in Hai Phong, Vietnam: study protocol for an effectiveness-implementation trial evaluating an integrated model of HCV care (DRIVE-C: DRug use & Infections in ViEtnam-hepatitis C). 2020; 10:e039234. doi: 10.1136/bmjopen-2020-039234"
#       },
#       {
#         "pmid": "25920094",
#         "title": "From non-A, non-B hepatitis to hepatitis C virus cure.",
#         "authors": "Pawlotsky JM; Feld JJ; Zeuzem S; Hoofnagle JH",
#         "doi": "10.1016/j.jhep.2015.02.006",
#         "year": "2015",
#         "publication_types": [
#           "Journal Article",
#           "Review"
#         ],
#         "citation": "Pawlotsky JM, et al. From non-A, non-B hepatitis to hepatitis C virus cure. From non-A, non-B hepatitis to hepatitis C virus cure. 2015; 62:S87-99. doi: 10.1016/j.jhep.2015.02.006"
#       },
#       {
#         "pmid": "22098550",
#         "title": "Liver disease in Viet Nam: screening, surveillance, management and education: a 5-year plan and call to action.",
#         "authors": "Gish RG; Bui TD; Nguyen CT; Nguyen DT; Tran HV; Tran DM; Trinh HN; International Group for Liver Health in Viet Nam",
#         "doi": "10.1111/j.1440-1746.2011.06974.x",
#         "year": "2012",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't",
#           "Review"
#         ],
#         "citation": "Gish RG, et al. Liver disease in Viet Nam: screening, surveillance, management and education: a 5-year plan and call to action. Liver disease in Viet Nam: screening, surveillance, management and education: a 5-year plan and call to action. 2012; 27:238-47. doi: 10.1111/j.1440-1746.2011.06974.x"
#       },
#       {
#         "pmid": "20041309",
#         "title": "Prevalence and incidence of HCV infection among Vietnam heroin users with recent onset of injection.",
#         "authors": "Clatts MC; Col\u00f3n-L\u00f3pez V; Giang LM; Goldsamt LA",
#         "doi": "10.1007/s11524-009-9417-9",
#         "year": "2010",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, N.I.H., Extramural",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Clatts MC, et al. Prevalence and incidence of HCV infection among Vietnam heroin users with recent onset of injection. Prevalence and incidence of HCV infection among Vietnam heroin users with recent onset of injection. 2010; 87:278-291. doi: 10.1007/s11524-009-9417-9"
#       },
#       {
#         "pmid": "27148964",
#         "title": "High Proportion of HIV-HCV Coinfected Patients with Advanced Liver Fibrosis Requiring Hepatitis C Treatment in Haiphong, Northern Vietnam (ANRS 12262).",
#         "authors": "Nguyen Truong T; Laureillard D; Lacombe K; Duong Thi H; Pham Thi Hanh P; Truong Thi Xuan L; Chu Thi N; Luong Que A; Vu Hai V; Nagot N; Tuaillon E; Dominguez S; Lemoine M",
#         "doi": "10.1371/journal.pone.0153744",
#         "year": "2016",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Nguyen Truong T, et al. High Proportion of HIV-HCV Coinfected Patients with Advanced Liver Fibrosis Requiring Hepatitis C Treatment in Haiphong, Northern Vietnam (ANRS 12262). High Proportion of HIV-HCV Coinfected Patients with Advanced Liver Fibrosis Requiring Hepatitis C Treatment in Haiphong, Northern Vietnam (ANRS 12262). 2016; 11:e0153744. doi: 10.1371/journal.pone.0153744"
#       },
#       {
#         "pmid": "25086286",
#         "title": "Global epidemiology and genotype distribution of the hepatitis C virus infection.",
#         "authors": "Gower E; Estes C; Blach S; Razavi-Shearer K; Razavi H",
#         "doi": "10.1016/j.jhep.2014.07.027",
#         "year": "2014",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't",
#           "Review"
#         ],
#         "citation": "Gower E, et al. Global epidemiology and genotype distribution of the hepatitis C virus infection. Global epidemiology and genotype distribution of the hepatitis C virus infection. 2014; 61:S45-57. doi: 10.1016/j.jhep.2014.07.027"
#       },
#       {
#         "pmid": "23675659",
#         "title": "Current and future therapies for hepatitis C virus infection.",
#         "authors": "Liang TJ; Ghany MG",
#         "doi": "10.1056/NEJMra1213651",
#         "year": "2013",
#         "publication_types": [
#           "Journal Article",
#           "Review"
#         ],
#         "citation": "Liang TJ and Ghany MG. Current and future therapies for hepatitis C virus infection. Current and future therapies for hepatitis C virus infection. 2013; 368:1907-17. doi: 10.1056/NEJMra1213651"
#       },
#       {
#         "pmid": "19839502",
#         "title": "High prevalence of Hepatitis C virus genotype 6 in Vietnam.",
#         "authors": "Pham DA; Leuangwutiwong P; Jittmittraphap A; Luplertlop N; Bach HK; Akkarathamrongsin S; Theamboonlers A; Poovorawan Y",
#         "doi": null,
#         "year": "2009",
#         "publication_types": [
#           "Journal Article"
#         ],
#         "citation": "Pham DA, et al. High prevalence of Hepatitis C virus genotype 6 in Vietnam. High prevalence of Hepatitis C virus genotype 6 in Vietnam. 2009; 27:153-60."
#       },
#       {
#         "pmid": "22564041",
#         "title": "Can needle and syringe programmes and opiate substitution therapy achieve substantial reductions in hepatitis C virus prevalence? Model projections for different epidemic settings.",
#         "authors": "Vickerman P; Martin N; Turner K; Hickman M",
#         "doi": "10.1111/j.1360-0443.2012.03932.x",
#         "year": "2012",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Vickerman P, et al. Can needle and syringe programmes and opiate substitution therapy achieve substantial reductions in hepatitis C virus prevalence? Model projections for different epidemic settings. Can needle and syringe programmes and opiate substitution therapy achieve substantial reductions in hepatitis C virus prevalence? Model projections for different epidemic settings. 2012; 107:1984-95. doi: 10.1111/j.1360-0443.2012.03932.x"
#       },
#       {
#         "pmid": "27427455",
#         "title": "The perfect storm: incarceration and the high-risk environment perpetuating transmission of HIV, hepatitis C virus, and tuberculosis in Eastern Europe and Central Asia.",
#         "authors": "Altice FL; Azbel L; Stone J; Brooks-Pollock E; Smyrnov P; Dvoriak S; Taxman FS; El-Bassel N; Martin NK; Booth R; St\u00f6ver H; Dolan K; Vickerman P",
#         "doi": "10.1016/S0140-6736(16)30856-X",
#         "year": "2016",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, N.I.H., Extramural",
#           "Research Support, U.S. Gov't, Non-P.H.S.",
#           "Review"
#         ],
#         "citation": "Altice FL, et al. The perfect storm: incarceration and the high-risk environment perpetuating transmission of HIV, hepatitis C virus, and tuberculosis in Eastern Europe and Central Asia. The perfect storm: incarceration and the high-risk environment perpetuating transmission of HIV, hepatitis C virus, and tuberculosis in Eastern Europe and Central Asia. 2016; 388:1228-48. doi: 10.1016/S0140-6736(16)30856-X"
#       },
#       {
#         "pmid": "27349488",
#         "title": "Early occurrence and recurrence of hepatocellular carcinoma in HCV-related cirrhosis treated with direct-acting antivirals.",
#         "authors": "Conti F; Buonfiglioli F; Scuteri A; Crespi C; Bolondi L; Caraceni P; Foschi FG; Lenzi M; Mazzella G; Verucchi G; Andreone P; Brillanti S",
#         "doi": "10.1016/j.jhep.2016.06.015",
#         "year": "2016",
#         "publication_types": [
#           "Journal Article"
#         ],
#         "citation": "Conti F, et al. Early occurrence and recurrence of hepatocellular carcinoma in HCV-related cirrhosis treated with direct-acting antivirals. Early occurrence and recurrence of hepatocellular carcinoma in HCV-related cirrhosis treated with direct-acting antivirals. 2016; 65:727-733. doi: 10.1016/j.jhep.2016.06.015"
#       },
#       {
#         "pmid": "22828983",
#         "title": "Epidemiology, responses, and way forward: the silent epidemic of viral hepatitis and HIV coinfection in Vietnam.",
#         "authors": "Sereno L; Mesquita F; Kato M; Jacka D; Nguyen TT; Nguyen TN",
#         "doi": "10.1177/1545109712453939",
#         "year": "2012",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't",
#           "Review"
#         ],
#         "citation": "Sereno L, et al. Epidemiology, responses, and way forward: the silent epidemic of viral hepatitis and HIV coinfection in Vietnam. Epidemiology, responses, and way forward: the silent epidemic of viral hepatitis and HIV coinfection in Vietnam. 2012; 11:311-20. doi: 10.1177/1545109712453939"
#       },
#       {
#         "pmid": "25245939",
#         "title": "Prevention, treatment and care of hepatitis C virus infection among people who inject drugs.",
#         "authors": "Bruggmann P; Grebely J",
#         "doi": "10.1016/j.drugpo.2014.08.014",
#         "year": "2015",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Bruggmann P and Grebely J. Prevention, treatment and care of hepatitis C virus infection among people who inject drugs. Prevention, treatment and care of hepatitis C virus infection among people who inject drugs. 2015; 26 Suppl 1:S22-6. doi: 10.1016/j.drugpo.2014.08.014"
#       },
#       {
#         "pmid": "27178119",
#         "title": "Integrated respondent-driven sampling and peer support for persons who inject drugs in Haiphong, Vietnam: a case study with implications for interventions.",
#         "authors": "Des Jarlais D; Duong HT; Pham Minh K; Khuat OH; Nham TT; Arasteh K; Feelemyer J; Heckathorn DD; Peries M; Moles JP; Laureillard D; Nagot N; (The Drive Study Team)",
#         "doi": "10.1080/09540121.2016.1178698",
#         "year": "2016",
#         "publication_types": [
#           "Journal Article"
#         ],
#         "citation": "Des Jarlais D, et al. Integrated respondent-driven sampling and peer support for persons who inject drugs in Haiphong, Vietnam: a case study with implications for interventions. Integrated respondent-driven sampling and peer support for persons who inject drugs in Haiphong, Vietnam: a case study with implications for interventions. 2016; 28:1312-5. doi: 10.1080/09540121.2016.1178698"
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT01899196",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT04631224",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT01579435",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT03235258",
#     "publications": [
#       {
#         "pmid": "21971357",
#         "title": "Early antiretroviral therapy in HIV-1-infected infants, 1996-2008: treatment response and duration of first-line regimens.",
#         "authors": "Judd A; European Pregnancy and Paediatric HIV Cohort Collaboration (EPPICC) study group in EuroCoord",
#         "doi": "10.1097/QAD.0b013e32834d614c",
#         "year": "2011",
#         "publication_types": [
#           "Comparative Study",
#           "Journal Article"
#         ],
#         "citation": "Judd A and European Pregnancy and Paediatric HIV Cohort Collaboration (EPPICC) study group in EuroCoord. Early antiretroviral therapy in HIV-1-infected infants, 1996-2008: treatment response and duration of first-line regimens. Early antiretroviral therapy in HIV-1-infected infants, 1996-2008: treatment response and duration of first-line regimens. 2011; 25:2279-87. doi: 10.1097/QAD.0b013e32834d614c"
#       },
#       {
#         "pmid": "21511330",
#         "title": "Risk of triple-class virological failure in children with HIV: a retrospective cohort study.",
#         "authors": "Pursuing Later Treatment Options II (PLATO II) project team for the Collaboration of Observational HIV Epidemiological Research Europe (COHERE); Castro H; Judd A; Gibb DM; Butler K; Lodwick RK; van Sighem A; Ramos JT; Warsawski J; Thorne C; Noguera-Julian A; Obel N; Costagliola D; Tookey PA; Colin C; Kjaer J; Grarup J; Chene G; Phillips A",
#         "doi": "10.1016/S0140-6736(11)60208-0",
#         "year": "2011",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Pursuing Later Treatment Options II (PLATO II) project team for the Collaboration of Observational HIV Epidemiological Research Europe (COHERE), et al. Risk of triple-class virological failure in children with HIV: a retrospective cohort study. Risk of triple-class virological failure in children with HIV: a retrospective cohort study. 2011; 377:1580-7. doi: 10.1016/S0140-6736(11)60208-0"
#       },
#       {
#         "pmid": "24705410",
#         "title": "Low birth weight in perinatally HIV-exposed uninfected infants: observations in urban settings in Cameroon.",
#         "authors": "Sofeu CL; Warszawski J; Ateba Ndongo F; Penda IC; Tetang Ndiang S; Guemkam G; Makwet N; Owona F; Kfutwah A; Tchendjou P; Texier G; Tchuente M; Faye A; Tejiokem MC; ANRS-PEDIACAM Study Group",
#         "doi": "10.1371/journal.pone.0093554",
#         "year": "2014",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Sofeu CL, et al. Low birth weight in perinatally HIV-exposed uninfected infants: observations in urban settings in Cameroon. Low birth weight in perinatally HIV-exposed uninfected infants: observations in urban settings in Cameroon. 2014; 9:e93554. doi: 10.1371/journal.pone.0093554"
#       },
#       {
#         "pmid": "17712765",
#         "title": "Long-term nonprogression of HIV infection in children: evaluation of the ANRS prospective French Pediatric Cohort.",
#         "authors": "Warszawski J; Lechenadec J; Faye A; Dollfus C; Firtion G; Meyer L; Douard D; Monpoux F; Tricoire J; Benmebarek Y; Rouzioux C; Blanche S",
#         "doi": "10.1086/521165",
#         "year": "2007",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Warszawski J, et al. Long-term nonprogression of HIV infection in children: evaluation of the ANRS prospective French Pediatric Cohort. Long-term nonprogression of HIV infection in children: evaluation of the ANRS prospective French Pediatric Cohort. 2007; 45:785-94. doi: 10.1086/521165"
#       },
#       {
#         "pmid": "22198788",
#         "title": "Short- and long-term immunological and virological outcome in HIV-infected infants according to the age at antiretroviral treatment initiation.",
#         "authors": "Goetghebuer T; Le Chenadec J; Haelterman E; Galli L; Dollfus C; Thorne C; Judd A; Keiser O; Ramos JT; Levy J; Warszawski J; European Infant Collaboration Group",
#         "doi": "10.1093/cid/cir950",
#         "year": "2012",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Goetghebuer T, et al. Short- and long-term immunological and virological outcome in HIV-infected infants according to the age at antiretroviral treatment initiation. Short- and long-term immunological and virological outcome in HIV-infected infants according to the age at antiretroviral treatment initiation. 2012; 54:878-81. doi: 10.1093/cid/cir950"
#       },
#       {
#         "pmid": "22427678",
#         "title": "Relationships between HIV disease history and blood HIV-1 DNA load in perinatally infected adolescents and young adults: the ANRS-EP38-IMMIP study.",
#         "authors": "Avettand-Fenoel V; Blanche S; Le Chenadec J; Scott-Algara D; Dollfus C; Viard JP; Bouallag N; Benmebarek Y; Rivi\u00e8re Y; Warszawski J; Rouzioux C; Buseyne F",
#         "doi": "10.1093/infdis/jis233",
#         "year": "2012",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Avettand-Fenoel V, et al. Relationships between HIV disease history and blood HIV-1 DNA load in perinatally infected adolescents and young adults: the ANRS-EP38-IMMIP study. Relationships between HIV disease history and blood HIV-1 DNA load in perinatally infected adolescents and young adults: the ANRS-EP38-IMMIP study. 2012; 205:1520-8. doi: 10.1093/infdis/jis233"
#       },
#       {
#         "pmid": "26762993",
#         "title": "HIV-1 virological remission lasting more than 12 years after interruption of early antiretroviral therapy in a perinatally infected teenager enrolled in the French ANRS EPF-CO10 paediatric cohort: a case report.",
#         "authors": "Frange P; Faye A; Avettand-Feno\u00ebl V; Bellaton E; Descamps D; Angin M; David A; Caillat-Zucman S; Peytavin G; Dollfus C; Le Chenadec J; Warszawski J; Rouzioux C; S\u00e1ez-Ciri\u00f3n A; ANRS EPF-CO10 Pediatric Cohort and the ANRS EP47 VISCONTI study group",
#         "doi": "10.1016/S2352-3018(15)00232-5",
#         "year": "2016",
#         "publication_types": [
#           "Case Reports",
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Frange P, et al. HIV-1 virological remission lasting more than 12 years after interruption of early antiretroviral therapy in a perinatally infected teenager enrolled in the French ANRS EPF-CO10 paediatric cohort: a case report. HIV-1 virological remission lasting more than 12 years after interruption of early antiretroviral therapy in a perinatally infected teenager enrolled in the French ANRS EPF-CO10 paediatric cohort: a case report. 2016; 3:e49-54. doi: 10.1016/S2352-3018(15)00232-5"
#       },
#       {
#         "pmid": "20536367",
#         "title": "Long-term outcomes in adolescents perinatally infected with HIV-1 and followed up since birth in the French perinatal cohort (EPF/ANRS CO10).",
#         "authors": "Dollfus C; Le Chenadec J; Faye A; Blanche S; Briand N; Rouzioux C; Warszawski J",
#         "doi": "10.1086/653674",
#         "year": "2010",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Dollfus C, et al. Long-term outcomes in adolescents perinatally infected with HIV-1 and followed up since birth in the French perinatal cohort (EPF/ANRS CO10). Long-term outcomes in adolescents perinatally infected with HIV-1 and followed up since birth in the French perinatal cohort (EPF/ANRS CO10). 2010; 51:214-24. doi: 10.1086/653674"
#       },
#       {
#         "pmid": "18614870",
#         "title": "Response to combination antiretroviral therapy: variation by age.",
#         "authors": "Collaboration of Observational HIV Epidemiological Research Europe (COHERE) Study Group; Sabin CA; Smith CJ; d'Arminio Monforte A; Battegay M; Gabiano C; Galli L; Geelen S; Gibb D; Guiguet M; Judd A; Leport C; Dabis F; Pantazis N; Porter K; Raffi F; Thorne C; Torti C; Walker S; Warszawski J; Wintergerst U; Chene G; Lundgren J",
#         "doi": "10.1097/QAD.0b013e3282f88d02",
#         "year": "2008",
#         "publication_types": [
#           "Journal Article",
#           "Multicenter Study",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Collaboration of Observational HIV Epidemiological Research Europe (COHERE) Study Group, et al. Response to combination antiretroviral therapy: variation by age. Response to combination antiretroviral therapy: variation by age. 2008; 22:1463-73. doi: 10.1097/QAD.0b013e3282f88d02"
#       },
#       {
#         "pmid": "24945880",
#         "title": "Interruption of cART in clinical practice is associated with an increase in the long-term risk of subsequent immunosuppression in HIV-1-infected children.",
#         "authors": "Aupiais C; Faye A; Le Chenadec J; Rouzioux C; Bouallag N; Laurent C; Blanche S; Dollfus C; Warszawski J; ANRS EPF-CO10 French Pediatric Cohort",
#         "doi": "10.1097/INF.0000000000000450",
#         "year": "2014",
#         "publication_types": [
#           "Journal Article",
#           "Multicenter Study",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Aupiais C, et al. Interruption of cART in clinical practice is associated with an increase in the long-term risk of subsequent immunosuppression in HIV-1-infected children. Interruption of cART in clinical practice is associated with an increase in the long-term risk of subsequent immunosuppression in HIV-1-infected children. 2014; 33:1237-45. doi: 10.1097/INF.0000000000000450"
#       },
#       {
#         "pmid": "19194272",
#         "title": "Effect of early antiretroviral therapy on the risk of AIDS/death in HIV-infected infants.",
#         "authors": "Goetghebuer T; Haelterman E; Le Chenadec J; Dollfus C; Gibb D; Judd A; Green H; Galli L; Ramos JT; Giaquinto C; Warszawski J; Levy J; European Infant Collaboration group",
#         "doi": "10.1097/QAD.0b013e328326ca37",
#         "year": "2009",
#         "publication_types": [
#           "Journal Article",
#           "Multicenter Study",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Goetghebuer T, et al. Effect of early antiretroviral therapy on the risk of AIDS/death in HIV-infected infants. Effect of early antiretroviral therapy on the risk of AIDS/death in HIV-infected infants. 2009; 23:597-604. doi: 10.1097/QAD.0b013e328326ca37"
#       },
#       {
#         "pmid": "24253249",
#         "title": "Naive T lymphocytes and recent thymic emigrants are associated with HIV-1 disease history in french adolescents and young adults infected in the perinatal period: the ANRS-EP38-IMMIP study.",
#         "authors": "Blanche S; Scott-Algara D; Le Chenadec J; Didier C; Montange T; Avettand-Fenoel V; Rouzioux C; M\u00e9lard A; Viard JP; Dollfus C; Bouallag N; Warszawski J; Buseyne F",
#         "doi": "10.1093/cid/cit729",
#         "year": "2014",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Blanche S, et al. Naive T lymphocytes and recent thymic emigrants are associated with HIV-1 disease history in french adolescents and young adults infected in the perinatal period: the ANRS-EP38-IMMIP study. Naive T lymphocytes and recent thymic emigrants are associated with HIV-1 disease history in french adolescents and young adults infected in the perinatal period: the ANRS-EP38-IMMIP study. 2014; 58:573-87. doi: 10.1093/cid/cit729"
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT00383734",
#     "publications": [
#       {
#         "pmid": "23432777",
#         "title": "Polylactic acid vs. polyacrylamide hydrogel for treatment of facial lipoatrophy: a randomized controlled trial [Agence Nationale de Recherches sur le SIDA et les H\u00e9patites Virales (ANRS) 132 SMILE].",
#         "authors": "Lafaurie M; Dolivo M; Girard PM; May T; Bouchaud O; Carbonnel E; Madelaine I; Loze B; Porcher R; Molina JM; ANRS 132 SMILE study group",
#         "doi": "10.1111/hiv.12021",
#         "year": "2013",
#         "publication_types": [
#           "Clinical Trial",
#           "Comparative Study",
#           "Journal Article",
#           "Multicenter Study",
#           "Randomized Controlled Trial"
#         ],
#         "citation": "Lafaurie M, et al. Polylactic acid vs. polyacrylamide hydrogel for treatment of facial lipoatrophy: a randomized controlled trial [Agence Nationale de Recherches sur le SIDA et les H\u00e9patites Virales (ANRS) 132 SMILE]. Polylactic acid vs. polyacrylamide hydrogel for treatment of facial lipoatrophy: a randomized controlled trial [Agence Nationale de Recherches sur le SIDA et les H\u00e9patites Virales (ANRS) 132 SMILE]. 2013; 14:410-20. doi: 10.1111/hiv.12021"
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT00901524",
#     "publications": [
#       {
#         "pmid": "24905490",
#         "title": "Apolipoprotein H expression is associated with IL28B genotype and viral clearance in hepatitis C virus infection.",
#         "authors": "Laird ME; Mohsen A; Duffy D; Mamdouh R; LeFouler L; Casrouge A; El-Daly M; Rafik M; Abdel-Hamid M; Soulier A; Pawlotsky JM; H\u00e9zode C; Rosa I; Renard P; Mohamed MK; Bonnard P; Izopet J; Mallet V; Pol S; Albert ML; Fontanet A",
#         "doi": "10.1016/j.jhep.2014.05.040",
#         "year": "2014",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Laird ME, et al. Apolipoprotein H expression is associated with IL28B genotype and viral clearance in hepatitis C virus infection. Apolipoprotein H expression is associated with IL28B genotype and viral clearance in hepatitis C virus infection. 2014; 61:770-6. doi: 10.1016/j.jhep.2014.05.040"
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT01493934",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT03078439",
#     "publications": [
#       {
#         "pmid": "38408861",
#         "title": "Birth weight and head circumference discordance and outcome in preterms: results from the EPIPAGE-2 cohort.",
#         "authors": "Guellec I; Brunet A; Lapillonne A; Taine M; Torchin H; Favrais G; Gascoin G; Simon L; Heude B; Scherdel P; Kayem G; Delorme P; Jarreau PH; Ancel PY",
#         "doi": "10.1136/archdischild-2023-326336",
#         "year": "2024",
#         "publication_types": [
#           "Journal Article"
#         ],
#         "citation": "Guellec I, et al. Birth weight and head circumference discordance and outcome in preterms: results from the EPIPAGE-2 cohort. Birth weight and head circumference discordance and outcome in preterms: results from the EPIPAGE-2 cohort. 2024; (unknown volume):(unknown pages). doi: 10.1136/archdischild-2023-326336"
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT04808986",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT01207986",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT02626286",
#     "publications": [
#       {
#         "pmid": "33753460",
#         "title": "Decrease in incidence of sexually transmitted infections symptoms in men who have sex with men enrolled in a quarterly HIV prevention and care programme in West Africa (CohMSM ANRS 12324-Expertise France).",
#         "authors": "Yaya I; Diallo F; Kouam\u00e9 MJ; Agboyibor MK; Traor\u00e9 I; Coulibaly A; Maiga K; Mora M; Palvadeau P; Dah ETT; Mensah E; Anoma C; Demb\u00e9l\u00e9 Keita B; Spire B; Laurent C; CohMSM Study Group",
#         "doi": "10.1136/sextrans-2020-054755",
#         "year": "2022",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Yaya I, et al. Decrease in incidence of sexually transmitted infections symptoms in men who have sex with men enrolled in a quarterly HIV prevention and care programme in West Africa (CohMSM ANRS 12324-Expertise France). Decrease in incidence of sexually transmitted infections symptoms in men who have sex with men enrolled in a quarterly HIV prevention and care programme in West Africa (CohMSM ANRS 12324-Expertise France). 2022; 98:85-94. doi: 10.1136/sextrans-2020-054755"
#       },
#       {
#         "pmid": "34022820",
#         "title": "Adherence to quarterly HIV prevention services and its impact on HIV incidence in men who have sex with men in West Africa (CohMSM ANRS 12324 - Expertise France).",
#         "authors": "Dah TTE; Yaya I; Sagaon-Teyssier L; Coulibaly A; Kouam\u00e9 MJ; Agboyibor MK; Maiga K; Traor\u00e9 I; Mora M; Palvadeau P; Rojas-Castro D; Diallo F; Mensah E; Anoma C; Keita BD; Spire B; Laurent C; CohMSM Study Group",
#         "doi": "10.1186/s12889-021-10994-4",
#         "year": "2021",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Dah TTE, et al. Adherence to quarterly HIV prevention services and its impact on HIV incidence in men who have sex with men in West Africa (CohMSM ANRS 12324 - Expertise France). Adherence to quarterly HIV prevention services and its impact on HIV incidence in men who have sex with men in West Africa (CohMSM ANRS 12324 - Expertise France). 2021; 21:972. doi: 10.1186/s12889-021-10994-4"
#       },
#       {
#         "pmid": "34352834",
#         "title": "Rapid antiretroviral therapy initiation and its effect on treatment response in MSM in West Africa.",
#         "authors": "Dah TTE; Yaya I; Mensah E; Coulibaly A; Kouam\u00e9 JM; Traor\u00e9 I; Mora M; Palvadeau P; Anoma C; Keita BD; Spire B; Laurent C; CohMSM Study Group",
#         "doi": "10.1097/QAD.0000000000003046",
#         "year": "2021",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Dah TTE, et al. Rapid antiretroviral therapy initiation and its effect on treatment response in MSM in West Africa. Rapid antiretroviral therapy initiation and its effect on treatment response in MSM in West Africa. 2021; 35:2201-2210. doi: 10.1097/QAD.0000000000003046"
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT02527096",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT00121758",
#     "publications": [
#       {
#         "pmid": "23759749",
#         "title": "Cytokine and gene transcription profiles of immune responses elicited by HIV lipopeptide vaccine in HIV-negative volunteers.",
#         "authors": "Richert L; Hue S; Hocini H; Raimbault M; Lacabaratz C; Surenaud M; Wiedemann A; Tisserand P; Durier C; Salmon D; Leli\u00e8vre JD; Ch\u00eane G; Thi\u00e9baut R; L\u00e9vy Y; ANRS Vaccine Network/Vaccine Research Institute",
#         "doi": "10.1097/QAD.0b013e32835f5b60",
#         "year": "2013",
#         "publication_types": [
#           "Clinical Trial, Phase II",
#           "Journal Article",
#           "Multicenter Study",
#           "Randomized Controlled Trial",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Richert L, et al. Cytokine and gene transcription profiles of immune responses elicited by HIV lipopeptide vaccine in HIV-negative volunteers. Cytokine and gene transcription profiles of immune responses elicited by HIV lipopeptide vaccine in HIV-negative volunteers. 2013; 27:1421-31. doi: 10.1097/QAD.0b013e32835f5b60"
#       },
#       {
#         "pmid": "20625264",
#         "title": "Immunogenicity and safety of an HIV-1 lipopeptide vaccine in healthy adults: a phase 2 placebo-controlled ANRS trial.",
#         "authors": "Salmon-C\u00e9ron D; Durier C; Desaint C; Cuzin L; Surenaud M; Hamouda NB; Leli\u00e8vre JD; Bonnet B; Pialoux G; Poizot-Martin I; Aboulker JP; L\u00e9vy Y; Launay O; ANRS VAC18 trial group",
#         "doi": "10.1097/QAD.0b013e32833ce566",
#         "year": "2010",
#         "publication_types": [
#           "Clinical Trial, Phase II",
#           "Journal Article",
#           "Multicenter Study",
#           "Randomized Controlled Trial",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Salmon-C\u00e9ron D, et al. Immunogenicity and safety of an HIV-1 lipopeptide vaccine in healthy adults: a phase 2 placebo-controlled ANRS trial. Immunogenicity and safety of an HIV-1 lipopeptide vaccine in healthy adults: a phase 2 placebo-controlled ANRS trial. 2010; 24:2211-23. doi: 10.1097/QAD.0b013e32833ce566"
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT04684758",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT02057796",
#     "publications": [
#       {
#         "pmid": "32558469",
#         "title": "Systematic or Test-Guided Treatment for Tuberculosis in HIV-Infected Adults.",
#         "authors": "Blanc FX; Badje AD; Bonnet M; Gabillard D; Messou E; Muzoora C; Samreth S; Nguyen BD; Borand L; Domergue A; Rapoud D; Natukunda N; Thai S; Juchet S; Eholi\u00e9 SP; Lawn SD; Domoua SK; Anglaret X; Laureillard D; STATIS ANRS 12290 Trial Team",
#         "doi": "10.1056/NEJMoa1910708",
#         "year": "2020",
#         "publication_types": [
#           "Comparative Study",
#           "Journal Article",
#           "Multicenter Study",
#           "Randomized Controlled Trial",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Blanc FX, et al. Systematic or Test-Guided Treatment for Tuberculosis in HIV-Infected Adults. Systematic or Test-Guided Treatment for Tuberculosis in HIV-Infected Adults. 2020; 382:2397-2410. doi: 10.1056/NEJMoa1910708"
#       },
#       {
#         "pmid": "36883573",
#         "title": "High performance of systematic combined urine LAM test and sputum Xpert MTB/RIF\u00ae for tuberculosis screening in severely immunosuppressed ambulatory adults with HIV.",
#         "authors": "Bonnet M; Gabillard D; Domoua S; Muzoora C; Messou E; Sovannarith S; Nguyen DB; Badje A; Juchet S; Bunnet D; Borand L; Natukunda N; Tran TH; Anglaret X; Laureillard D; Blanc FX; STATIS ANRS 12290 Trial Team",
#         "doi": "10.1093/cid/ciad125",
#         "year": "2023",
#         "publication_types": [
#           "Journal Article"
#         ],
#         "citation": "Bonnet M, et al. High performance of systematic combined urine LAM test and sputum Xpert MTB/RIF\u00ae for tuberculosis screening in severely immunosuppressed ambulatory adults with HIV. High performance of systematic combined urine LAM test and sputum Xpert MTB/RIF\u00ae for tuberculosis screening in severely immunosuppressed ambulatory adults with HIV. 2023; (unknown volume):(unknown pages). doi: 10.1093/cid/ciad125"
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT03071458",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT02192658",
#     "publications": [
#       {
#         "pmid": "26846895",
#         "title": "HandiVIH--A population-based survey to understand the vulnerability of people with disabilities to HIV and other sexual and reproductive health problems in Cameroon: protocol and methodological considerations.",
#         "authors": "De Beaudrap P; Pasquier E; Tchoumkeu A; Touko A; Essomba F; Brus A; Desgr\u00e9es du Lo\u00fb A; Aderemi TJ; Hanass-Hancock J; Eide AH; Mont D; Mac-Seing M; Beninguisse G",
#         "doi": "10.1136/bmjopen-2015-008934",
#         "year": "2016",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "De Beaudrap P, et al. HandiVIH--A population-based survey to understand the vulnerability of people with disabilities to HIV and other sexual and reproductive health problems in Cameroon: protocol and methodological considerations. HandiVIH--A population-based survey to understand the vulnerability of people with disabilities to HIV and other sexual and reproductive health problems in Cameroon: protocol and methodological considerations. 2016; 6:e008934. doi: 10.1136/bmjopen-2015-008934"
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT01713335",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT00158522",
#     "publications": [
#       {
#         "pmid": "16434426",
#         "title": "Higher clearance of hepatitis C virus infection in females compared with males.",
#         "authors": "Bakr I; Rekacewicz C; El Hosseiny M; Ismail S; El Daly M; El-Kafrawy S; Esmat G; Hamid MA; Mohamed MK; Fontanet A",
#         "doi": "10.1136/gut.2005.078147",
#         "year": "2006",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Bakr I, et al. Higher clearance of hepatitis C virus infection in females compared with males. Higher clearance of hepatitis C virus infection in females compared with males. 2006; 55:1183-7. doi: 10.1136/gut.2005.078147"
#       },
#       {
#         "pmid": "15977225",
#         "title": "Surveillance of acute hepatitis C in Cairo, Egypt.",
#         "authors": "El Gaafary MM; Rekacewicz C; Abdel-Rahman AG; Allam MF; El Hosseiny M; Hamid MA; Colombani F; Sultan Y; El-Aidy S; Fontanet A; Mohamed MK",
#         "doi": "10.1002/jmv.20392",
#         "year": "2005",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "El Gaafary MM, et al. Surveillance of acute hepatitis C in Cairo, Egypt. Surveillance of acute hepatitis C in Cairo, Egypt. 2005; 76:520-5. doi: 10.1002/jmv.20392"
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT00640263",
#     "publications": [
#       {
#         "pmid": "26603917",
#         "title": "Extended pre-exposure prophylaxis with lopinavir-ritonavir versus lamivudine to prevent HIV-1 transmission through breastfeeding up to 50 weeks in infants in Africa (ANRS 12174): a randomised controlled trial.",
#         "authors": "Nagot N; Kankasa C; Tumwine JK; Meda N; Hofmeyr GJ; Vallo R; Mwiya M; Kwagala M; Traore H; Sunday A; Singata M; Siuluta C; Some E; Rutagwera D; Neboua D; Ndeezi G; Jackson D; Mar\u00e9chal V; Neveu D; Engebretsen IMS; Lombard C; Blanche S; Sommerfelt H; Rekacewicz C; Tyllesk\u00e4r T; Van de Perre P; ANRS 12174 Trial Group",
#         "doi": "10.1016/S0140-6736(15)00984-8",
#         "year": "2016",
#         "publication_types": [
#           "Journal Article",
#           "Multicenter Study",
#           "Randomized Controlled Trial",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Nagot N, et al. Extended pre-exposure prophylaxis with lopinavir-ritonavir versus lamivudine to prevent HIV-1 transmission through breastfeeding up to 50 weeks in infants in Africa (ANRS 12174): a randomised controlled trial. Extended pre-exposure prophylaxis with lopinavir-ritonavir versus lamivudine to prevent HIV-1 transmission through breastfeeding up to 50 weeks in infants in Africa (ANRS 12174): a randomised controlled trial. 2016; 387:566-573. doi: 10.1016/S0140-6736(15)00984-8"
#       },
#       {
#         "pmid": "30814028",
#         "title": "Growth in HIV-1-exposed but uninfected infants treated with lopinavir-ritonavir versus lamivudine: a secondary analysis of the ANRS 12174 trial.",
#         "authors": "Blanche S; Tyllesk\u00e4r T; Peries M; Kankasa C; Engebretsen I; Meda N; Tumwine JK; Singata-Madliki M; Mwiya M; Van de Perre P; Nagot N; ANRS 12174 Trial Group",
#         "doi": "10.1016/S2352-3018(18)30361-8",
#         "year": "2019",
#         "publication_types": [
#           "Journal Article",
#           "Multicenter Study",
#           "Randomized Controlled Trial",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Blanche S, et al. Growth in HIV-1-exposed but uninfected infants treated with lopinavir-ritonavir versus lamivudine: a secondary analysis of the ANRS 12174 trial. Growth in HIV-1-exposed but uninfected infants treated with lopinavir-ritonavir versus lamivudine: a secondary analysis of the ANRS 12174 trial. 2019; 6:e307-e314. doi: 10.1016/S2352-3018(18)30361-8"
#       },
#       {
#         "pmid": "31633158",
#         "title": "Lopinavir-Ritonavir Impairs Adrenal Function in Infants.",
#         "authors": "Kariyawasam D; Peries M; Foissac F; Eymard-Duvernay S; Tyllesk\u00e4r T; Singata-Madliki M; Kankasa C; Meda N; Tumwine J; Mwiya M; Engebretsen I; Fl\u00fcck CE; Hartmann MF; Wudy SA; Hirt D; Treluyer JM; Mol\u00e8s JP; Blanche S; Van De Perre P; Polak M; Nagot N; ANRS 12174 Trial Group",
#         "doi": "10.1093/cid/ciz888",
#         "year": "2020",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Kariyawasam D, et al. Lopinavir-Ritonavir Impairs Adrenal Function in Infants. Lopinavir-Ritonavir Impairs Adrenal Function in Infants. 2020; 71:1030-1039. doi: 10.1093/cid/ciz888"
#       },
#       {
#         "pmid": "28469697",
#         "title": "Breastfeeding patterns and its determinants among mothers living with Human Immuno-deficiency Virus -1 in four African countries participating in the ANRS 12174 trial.",
#         "authors": "Som\u00e9 EN; Engebretsen IMS; Nagot N; Meda N; Lombard C; Vallo R; Peries M; Kankasa C; Tumwine JK; Hofmeyr GJ; Singata M; Harper K; Van De Perre P; Tylleskar T; ANRS 12174 Trial Group",
#         "doi": "10.1186/s13006-017-0112-2",
#         "year": "2016",
#         "publication_types": [
#           "Journal Article"
#         ],
# ...
#         "doi": "10.1016/S1473-3099(23)00552-2",
#         "year": "2024",
#         "publication_types": [
#           "Observational Study",
#           "Journal Article"
#         ],
#         "citation": "Nkuba-Ndaye A, et al. Effect of anti-Ebola virus monoclonal antibodies on endogenous antibody production in survivors of Ebola virus disease in the Democratic Republic of the Congo: an observational cohort study. Effect of anti-Ebola virus monoclonal antibodies on endogenous antibody production in survivors of Ebola virus disease in the Democratic Republic of the Congo: an observational cohort study. 2024; 24:266-274. doi: 10.1016/S1473-3099(23)00552-2"
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT02976298",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT00647205",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT02960698",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT01842477",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT01037777",
#     "publications": [
#       {
#         "pmid": "32822634",
#         "title": "Conversion of individuals at risk for spinocerebellar ataxia types 1, 2, 3, and 6 to manifest ataxia (RISCA): a longitudinal cohort study.",
#         "authors": "Jacobi H; du Montcel ST; Romanzetti S; Harmuth F; Mariotti C; Nanetti L; Rakowicz M; Makowicz G; Durr A; Monin ML; Filla A; Roca A; Sch\u00f6ls L; Hengel H; Infante J; Kang JS; Timmann D; Casali C; Masciullo M; Baliko L; Melegh B; Nachbauer W; B\u00fcrk-Gergs K; Schulz JB; Riess O; Reetz K; Klockgether T",
#         "doi": "10.1016/S1474-4422(20)30235-0",
#         "year": "2020",
#         "publication_types": [
#           "Clinical Trial",
#           "Journal Article",
#           "Multicenter Study",
#           "Observational Study",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Jacobi H, et al. Conversion of individuals at risk for spinocerebellar ataxia types 1, 2, 3, and 6 to manifest ataxia (RISCA): a longitudinal cohort study. Conversion of individuals at risk for spinocerebellar ataxia types 1, 2, 3, and 6 to manifest ataxia (RISCA): a longitudinal cohort study. 2020; 19:738-747. doi: 10.1016/S1474-4422(20)30235-0"
#       },
#       {
#         "pmid": "35264424",
#         "title": "Levels of Neurofilament Light at the Preataxic and Ataxic Stages of Spinocerebellar Ataxia Type 1.",
#         "authors": "Wilke C; Mengel D; Sch\u00f6ls L; Hengel H; Rakowicz M; Klockgether T; Durr A; Filla A; Melegh B; Sch\u00fcle R; Reetz K; Jacobi H; Synofzik M",
#         "doi": "10.1212/WNL.0000000000200257",
#         "year": "2022",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Wilke C, et al. Levels of Neurofilament Light at the Preataxic and Ataxic Stages of Spinocerebellar Ataxia Type 1. Levels of Neurofilament Light at the Preataxic and Ataxic Stages of Spinocerebellar Ataxia Type 1. 2022; 98:e1985-e1996. doi: 10.1212/WNL.0000000000200257"
#       },
#       {
#         "pmid": "24780882",
#         "title": "Prediction of the age at onset in spinocerebellar ataxia type 1, 2, 3 and 6.",
#         "authors": "Tezenas du Montcel S; Durr A; Rakowicz M; Nanetti L; Charles P; Sulek A; Mariotti C; Rola R; Schols L; Bauer P; Dufaure-Gar\u00e9 I; Jacobi H; Forlani S; Schmitz-H\u00fcbsch T; Filla A; Timmann D; van de Warrenburg BP; Marelli C; Kang JS; Giunti P; Cook A; Baliko L; Melegh B; Boesch S; Szymanski S; Berciano J; Infante J; Buerk K; Masciullo M; Di Fabio R; Depondt C; Ratka S; Stevanin G; Klockgether T; Brice A; Golmard JL",
#         "doi": "10.1136/jmedgenet-2013-102200",
#         "year": "2014",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Tezenas du Montcel S, et al. Prediction of the age at onset in spinocerebellar ataxia type 1, 2, 3 and 6. Prediction of the age at onset in spinocerebellar ataxia type 1, 2, 3 and 6. 2014; 51:479-86. doi: 10.1136/jmedgenet-2013-102200"
#       },
#       {
#         "pmid": "23707147",
#         "title": "Biological and clinical characteristics of individuals at risk for spinocerebellar ataxia types 1, 2, 3, and 6 in the longitudinal RISCA study: analysis of baseline data.",
#         "authors": "Jacobi H; Reetz K; du Montcel ST; Bauer P; Mariotti C; Nanetti L; Rakowicz M; Sulek A; Durr A; Charles P; Filla A; Antenora A; Sch\u00f6ls L; Schicks J; Infante J; Kang JS; Timmann D; Di Fabio R; Masciullo M; Baliko L; Melegh B; Boesch S; B\u00fcrk K; Peltz A; Schulz JB; Dufaure-Gar\u00e9 I; Klockgether T",
#         "doi": "10.1016/S1474-4422(13)70104-2",
#         "year": "2013",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Jacobi H, et al. Biological and clinical characteristics of individuals at risk for spinocerebellar ataxia types 1, 2, 3, and 6 in the longitudinal RISCA study: analysis of baseline data. Biological and clinical characteristics of individuals at risk for spinocerebellar ataxia types 1, 2, 3, and 6 in the longitudinal RISCA study: analysis of baseline data. 2013; 12:650-8. doi: 10.1016/S1474-4422(13)70104-2"
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT02172677",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT02101398",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT01495897",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT00463983",
#     "publications": [
#       {
#         "pmid": "16883006",
#         "title": "Increased uptake of 111In-octreotide in idiopathic pulmonary fibrosis.",
#         "authors": "Lebtahi R; Moreau S; Marchand-Adam S; Debray MP; Brauner M; Soler P; Marchal J; Raguin O; Gruaz-Guyon A; Reubi JC; Le Guludec D; Crestani B",
#         "doi": null,
#         "year": "2006",
#         "publication_types": [
#           "Clinical Trial",
#           "Journal Article"
#         ],
#         "citation": "Lebtahi R, et al. Increased uptake of 111In-octreotide in idiopathic pulmonary fibrosis. Increased uptake of 111In-octreotide in idiopathic pulmonary fibrosis. 2006; 47:1281-7."
#       },
#       {
#         "pmid": "22379151",
#         "title": "Octreotide treatment of idiopathic pulmonary fibrosis: a proof-of-concept study.",
#         "authors": "Crestani B; Chapron J; Wallaert B; Bergot E; Delaval P; Israel-Biet D; Lacronique J; Monnet I; Reynaud-Gaubert M; Tazi A; Lebtahi R; Debray MP; Brauner M; Dehoux M; Dornic Q; Aubier M; Mentr\u00e9 F; Duval X",
#         "doi": "10.1183/09031936.00113011",
#         "year": "2012",
#         "publication_types": [
#           "Clinical Trial, Phase II",
#           "Letter",
#           "Multicenter Study"
#         ],
#         "citation": "Crestani B, et al. Octreotide treatment of idiopathic pulmonary fibrosis: a proof-of-concept study. Octreotide treatment of idiopathic pulmonary fibrosis: a proof-of-concept study. 2012; 39:772-5. doi: 10.1183/09031936.00113011"
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT00158483",
#     "publications": [
#       {
#         "pmid": "19530940",
#         "title": "Impact of acyclovir on genital and plasma HIV-1 RNA, genital herpes simplex virus type 2 DNA, and ulcer healing among HIV-1-infected African women with herpes ulcers: a randomized placebo-controlled trial.",
#         "authors": "Mayaud P; Legoff J; Weiss HA; Gr\u00e9senguet G; Nzambi K; Bouhlal H; Frost E; P\u00e9pin J; Malkin JE; Hayes RJ; Mabey DC; B\u00e9lec L; ANRS 1212 Study Group",
#         "doi": "10.1086/599991",
#         "year": "2009",
#         "publication_types": [
#           "Journal Article",
#           "Randomized Controlled Trial",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Mayaud P, et al. Impact of acyclovir on genital and plasma HIV-1 RNA, genital herpes simplex virus type 2 DNA, and ulcer healing among HIV-1-infected African women with herpes ulcers: a randomized placebo-controlled trial. Impact of acyclovir on genital and plasma HIV-1 RNA, genital herpes simplex virus type 2 DNA, and ulcer healing among HIV-1-infected African women with herpes ulcers: a randomized placebo-controlled trial. 2009; 200:216-26. doi: 10.1086/599991"
#       },
#       {
#         "pmid": "18385443",
#         "title": "Performance of HerpeSelect and Kalon assays in detection of antibodies to herpes simplex virus type 2.",
#         "authors": "LeGoff J; Mayaud P; Gresenguet G; Weiss HA; Nzambi K; Frost E; Pepin J; Belec L; ANRS 12-12 Study Group",
#         "doi": "10.1128/JCM.02332-07",
#         "year": "2008",
#         "publication_types": [
#           "Evaluation Study",
#           "Journal Article",
#           "Randomized Controlled Trial"
#         ],
#         "citation": "LeGoff J, et al. Performance of HerpeSelect and Kalon assays in detection of antibodies to herpes simplex virus type 2. Performance of HerpeSelect and Kalon assays in detection of antibodies to herpes simplex virus type 2. 2008; 46:1914-8. doi: 10.1128/JCM.02332-07"
#       },
#       {
#         "pmid": "16455895",
#         "title": "Real-time PCR quantification of genital shedding of herpes simplex virus (HSV) and human immunodeficiency virus (HIV) in women coinfected with HSV and HIV.",
#         "authors": "Legoff J; Bouhlal H; Gr\u00e9senguet G; Weiss H; Khonde N; Hocini H; D\u00e9sir\u00e9 N; Si-Mohamed A; de Dieu Longo J; Chemin C; Frost E; P\u00e9pin J; Malkin JE; Mayaud P; B\u00e9lec L",
#         "doi": "10.1128/JCM.44.2.423-432.2006",
#         "year": "2006",
#         "publication_types": [
#           "Evaluation Study",
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Legoff J, et al. Real-time PCR quantification of genital shedding of herpes simplex virus (HSV) and human immunodeficiency virus (HIV) in women coinfected with HSV and HIV. Real-time PCR quantification of genital shedding of herpes simplex virus (HSV) and human immunodeficiency virus (HIV) in women coinfected with HSV and HIV. 2006; 44:423-32. doi: 10.1128/JCM.44.2.423-432.2006"
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT00301561",
#     "publications": [
#       {
#         "pmid": "21831714",
#         "title": "Monitoring of HIV viral loads, CD4 cell counts, and clinical assessments versus clinical monitoring alone for antiretroviral therapy in rural district hospitals in Cameroon (Stratall ANRS 12110/ESTHER): a randomised non-inferiority trial.",
#         "authors": "Laurent C; Kouanfack C; Laborde-Balen G; Aghokeng AF; Mbougua JB; Boyer S; Carrieri MP; Mben JM; Dontsop M; Kaz\u00e9 S; Molinari N; Bourgeois A; Mpoudi-Ngol\u00e9 E; Spire B; Koulla-Shiro S; Delaporte E; Stratall ANRS 12110/ESTHER study group",
#         "doi": "10.1016/S1473-3099(11)70168-2",
#         "year": "2011",
#         "publication_types": [
#           "Comparative Study",
#           "Journal Article",
#           "Multicenter Study",
#           "Randomized Controlled Trial",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Laurent C, et al. Monitoring of HIV viral loads, CD4 cell counts, and clinical assessments versus clinical monitoring alone for antiretroviral therapy in rural district hospitals in Cameroon (Stratall ANRS 12110/ESTHER): a randomised non-inferiority trial. Monitoring of HIV viral loads, CD4 cell counts, and clinical assessments versus clinical monitoring alone for antiretroviral therapy in rural district hospitals in Cameroon (Stratall ANRS 12110/ESTHER): a randomised non-inferiority trial. 2011; 11:825-33. doi: 10.1016/S1473-3099(11)70168-2"
#       },
#       {
#         "pmid": "35248123",
#         "title": "Non-inferiority test for a continuous variable with a flexible margin in an active controlled trial: an application to the \"Stratall ANRS 12110 / ESTHER\" trial.",
#         "authors": "Sandie AB; Molinari N; Wanjoya A; Kouanfack C; Laurent C; Tchatchueng-Mbougua JB",
#         "doi": "10.1186/s13063-022-06118-x",
#         "year": "2022",
#         "publication_types": [
#           "Journal Article",
#           "Randomized Controlled Trial"
#         ],
#         "citation": "Sandie AB, et al. Non-inferiority test for a continuous variable with a flexible margin in an active controlled trial: an application to the \"Stratall ANRS 12110 / ESTHER\" trial. Non-inferiority test for a continuous variable with a flexible margin in an active controlled trial: an application to the \"Stratall ANRS 12110 / ESTHER\" trial. 2022; 23:202. doi: 10.1186/s13063-022-06118-x"
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT01075061",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT00158405",
#     "publications": [
#       {
#         "pmid": "16152755",
#         "title": "Haematological changes in adults receiving a zidovudine-containing HAART regimen in combination with cotrimoxazole in C\u00f4te d'Ivoire.",
#         "authors": "Moh R; Danel C; Sorho S; Sauvageot D; Anzian A; Minga A; Gomis OB; Konga C; Inwoley A; Gabillard D; Bissagnene E; Salamon R; Anglaret X",
#         "doi": "10.1177/135965350501000510",
#         "year": "2005",
#         "publication_types": [
#           "Clinical Trial",
#           "Journal Article",
#           "Randomized Controlled Trial",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Moh R, et al. Haematological changes in adults receiving a zidovudine-containing HAART regimen in combination with cotrimoxazole in C\u00f4te d'Ivoire. Haematological changes in adults receiving a zidovudine-containing HAART regimen in combination with cotrimoxazole in C\u00f4te d'Ivoire. 2005; 10:615-24. doi: 10.1177/135965350501000510"
#       },
#       {
#         "pmid": "16782488",
#         "title": "CD4-guided structured antiretroviral treatment interruption strategy in HIV-infected adults in west Africa (Trivacan ANRS 1269 trial): a randomised trial.",
#         "authors": "Danel C; Moh R; Minga A; Anzian A; Ba-Gomis O; Kanga C; Nzunetu G; Gabillard D; Rouet F; Sorho S; Chaix ML; Eholi\u00e9 S; Menan H; Sauvageot D; Bissagnene E; Salamon R; Anglaret X; Trivacan ANRS 1269 trial group",
#         "doi": "10.1016/S0140-6736(06)68887-9",
#         "year": "2006",
#         "publication_types": [
#           "Journal Article",
#           "Multicenter Study",
#           "Randomized Controlled Trial",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Danel C, et al. CD4-guided structured antiretroviral treatment interruption strategy in HIV-infected adults in west Africa (Trivacan ANRS 1269 trial): a randomised trial. CD4-guided structured antiretroviral treatment interruption strategy in HIV-infected adults in west Africa (Trivacan ANRS 1269 trial): a randomised trial. 2006; 367:1981-9. doi: 10.1016/S0140-6736(06)68887-9"
#       },
#       {
#         "pmid": "18986246",
#         "title": "Two-months-off, four-months-on antiretroviral regimen increases the risk of resistance, compared with continuous therapy: a randomized trial involving West African adults.",
#         "authors": "Danel C; Moh R; Chaix ML; Gabillard D; Gnokoro J; Diby CJ; Toni T; Dohoun L; Rouzioux C; Bissagnene E; Salamon R; Anglaret X; Trivacan ANRS 1269 Trial Group",
#         "doi": "10.1086/595298",
#         "year": "2009",
#         "publication_types": [
#           "Journal Article",
#           "Multicenter Study",
#           "Randomized Controlled Trial",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Danel C, et al. Two-months-off, four-months-on antiretroviral regimen increases the risk of resistance, compared with continuous therapy: a randomized trial involving West African adults. Two-months-off, four-months-on antiretroviral regimen increases the risk of resistance, compared with continuous therapy: a randomized trial involving West African adults. 2009; 199:66-76. doi: 10.1086/595298"
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT00623051",
#     "publications": []
#   }
# ]

# %%
# The number of NCTId didn't change
assert(len(total_publications_list) == len(studies_list))

# %% [markdown]
# ### Import dans Pandas

# %%
df_pubmed = pd.DataFrame.from_records(total_publications_list)
df_pubmed
# Out:
#            NCTId                                       publications
# 0    NCT01895920                                                 []
# 1    NCT02486731                                                 []
# 2    NCT02116374                                                 []
# 3    NCT03537196  [{'pmid': '26298331', 'title': 'Hepatitis C vi...
# 4    NCT01899196                                                 []
# ..           ...                                                ...
# 281  NCT00158483  [{'pmid': '19530940', 'title': 'Impact of acyc...
# 282  NCT00301561  [{'pmid': '21831714', 'title': 'Monitoring of ...
# 283  NCT01075061                                                 []
# 284  NCT00158405  [{'pmid': '16152755', 'title': 'Haematological...
# 285  NCT00623051                                                 []
#
# [286 rows x 2 columns]

# %% [markdown]
# #### On "explose" la colonne "publications":
#
# Pour chaque NCTId, la colonne 'publications' contient potentiellement une liste de plusieurs publications.
# Si par exemple, on a 3 publications, on veut se retrouver avec 3 lignes, chacune indexée par le même NCTId et contenant une unique publication.
#
# *Avant*:
# **`NCTId    Reference`**
# `NCT0001, [Pub1, Pub2, Pub3]`
#
# *Après*:
# **`NCTId    Reference`**
# `NCT0001,   Pub1`
# `NCT0001,   Pub2`
# `NCT0001,   Pub3`

# %%
df_pubmed = df_pubmed.explode('publications', ignore_index = True)
df_pubmed
# Out:
#            NCTId                                       publications
# 0    NCT01895920                                                NaN
# 1    NCT02486731                                                NaN
# 2    NCT02116374                                                NaN
# 3    NCT03537196  {'pmid': '26298331', 'title': 'Hepatitis C vir...
# 4    NCT03537196  {'pmid': '23172780', 'title': 'Global epidemio...
# ..           ...                                                ...
# 678  NCT01075061                                                NaN
# 679  NCT00158405  {'pmid': '16152755', 'title': 'Haematological ...
# 680  NCT00158405  {'pmid': '16782488', 'title': 'CD4-guided stru...
# 681  NCT00158405  {'pmid': '18986246', 'title': 'Two-months-off,...
# 682  NCT00623051                                                NaN
#
# [683 rows x 2 columns]

# %% [markdown]
# On vérifie que l'on a retrouvé plus de publications avec PubMed + CT que CT tout seul:

# %%
assert(len(df_pubmed) >= len(df_ct))

# %% [markdown]
# Pour chaque NCTId, la colonne 'publications' contient maintenant un dictionnaire de la forme:
# `{
# "pmid": "17545707",
# "title": "Haematological ...",
# "authors": "Smith DJ; ...",
# }`
#
# Dont on veut extraire de nouvelles colonnes en utilant les clés du dictionnaire:
# **`pmid      title                 authors`**
# `17545707, "Haematological ...", "Smith DJ; ..."`

# %%
df_pubmed_publications = pd.json_normalize(df_pubmed.pop('publications'))
df_pubmed_publications
# Out:
#          pmid                                              title  \
# 0         NaN                                                NaN
# 1         NaN                                                NaN
# 2         NaN                                                NaN
# 3    26298331  Hepatitis C virus (HCV) disease progression in...
# 4    23172780  Global epidemiology of hepatitis C virus infec...
# ..        ...                                                ...
# 678       NaN                                                NaN
# 679  16152755  Haematological changes in adults receiving a z...
# 680  16782488  CD4-guided structured antiretroviral treatment...
# 681  18986246  Two-months-off, four-months-on antiretroviral ...
# 682       NaN                                                NaN
#
#                                                authors  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3           Smith DJ; Combellick J; Jordan AE; Hagan H
# 4    Mohd Hanafiah K; Groeger J; Flaxman AD; Wiersm...
# ..                                                 ...
# 678                                                NaN
# 679  Moh R; Danel C; Sorho S; Sauvageot D; Anzian A...
# 680  Danel C; Moh R; Minga A; Anzian A; Ba-Gomis O;...
# 681  Danel C; Moh R; Chaix ML; Gabillard D; Gnokoro...
# 682                                                NaN
#
#                                doi  year  \
# 0                              NaN   NaN
# 1                              NaN   NaN
# 2                              NaN   NaN
# 3     10.1016/j.drugpo.2015.07.004  2015
# 4                10.1002/hep.26141  2013
# ..                             ...   ...
# 678                            NaN   NaN
# 679     10.1177/135965350501000510  2005
# 680  10.1016/S0140-6736(06)68887-9  2006
# 681                 10.1086/595298  2009
# 682                            NaN   NaN
#
#                                      publication_types  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    [Journal Article, Meta-Analysis, Research Supp...
# 4    [Journal Article, Meta-Analysis, Review, Syste...
# ..                                                 ...
# 678                                                NaN
# 679  [Clinical Trial, Journal Article, Randomized C...
# 680  [Journal Article, Multicenter Study, Randomize...
# 681  [Journal Article, Multicenter Study, Randomize...
# 682                                                NaN
#
#                                               citation
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    Smith DJ, et al. Hepatitis C virus (HCV) disea...
# 4    Mohd Hanafiah K, et al. Global epidemiology of...
# ..                                                 ...
# 678                                                NaN
# 679  Moh R, et al. Haematological changes in adults...
# 680  Danel C, et al. CD4-guided structured antiretr...
# 681  Danel C, et al. Two-months-off, four-months-on...
# 682                                                NaN
#
# [683 rows x 7 columns]

# %% [markdown]
# On réassemble la dataFrame complète:

# %%
df_pubmed = df_pubmed.join(df_pubmed_publications)
df_pubmed
# Out:
#            NCTId      pmid                                              title  \
# 0    NCT01895920       NaN                                                NaN
# 1    NCT02486731       NaN                                                NaN
# 2    NCT02116374       NaN                                                NaN
# 3    NCT03537196  26298331  Hepatitis C virus (HCV) disease progression in...
# 4    NCT03537196  23172780  Global epidemiology of hepatitis C virus infec...
# ..           ...       ...                                                ...
# 678  NCT01075061       NaN                                                NaN
# 679  NCT00158405  16152755  Haematological changes in adults receiving a z...
# 680  NCT00158405  16782488  CD4-guided structured antiretroviral treatment...
# 681  NCT00158405  18986246  Two-months-off, four-months-on antiretroviral ...
# 682  NCT00623051       NaN                                                NaN
#
#                                                authors  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3           Smith DJ; Combellick J; Jordan AE; Hagan H
# 4    Mohd Hanafiah K; Groeger J; Flaxman AD; Wiersm...
# ..                                                 ...
# 678                                                NaN
# 679  Moh R; Danel C; Sorho S; Sauvageot D; Anzian A...
# 680  Danel C; Moh R; Minga A; Anzian A; Ba-Gomis O;...
# 681  Danel C; Moh R; Chaix ML; Gabillard D; Gnokoro...
# 682                                                NaN
#
#                                doi  year  \
# 0                              NaN   NaN
# 1                              NaN   NaN
# 2                              NaN   NaN
# 3     10.1016/j.drugpo.2015.07.004  2015
# 4                10.1002/hep.26141  2013
# ..                             ...   ...
# 678                            NaN   NaN
# 679     10.1177/135965350501000510  2005
# 680  10.1016/S0140-6736(06)68887-9  2006
# 681                 10.1086/595298  2009
# 682                            NaN   NaN
#
#                                      publication_types  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    [Journal Article, Meta-Analysis, Research Supp...
# 4    [Journal Article, Meta-Analysis, Review, Syste...
# ..                                                 ...
# 678                                                NaN
# 679  [Clinical Trial, Journal Article, Randomized C...
# 680  [Journal Article, Multicenter Study, Randomize...
# 681  [Journal Article, Multicenter Study, Randomize...
# 682                                                NaN
#
#                                               citation
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    Smith DJ, et al. Hepatitis C virus (HCV) disea...
# 4    Mohd Hanafiah K, et al. Global epidemiology of...
# ..                                                 ...
# 678                                                NaN
# 679  Moh R, et al. Haematological changes in adults...
# 680  Danel C, et al. CD4-guided structured antiretr...
# 681  Danel C, et al. Two-months-off, four-months-on...
# 682                                                NaN
#
# [683 rows x 8 columns]

# %% [markdown]
# ### Jointure des DataFrame de CT et Pubmed:

# %%
df_final = df_ct.merge(df_pubmed, on = ['NCTId', 'pmid'], how='right')
df_final
# Out:
#            NCTId                                         BriefTitle  \
# 0    NCT01895920  Viral Biofilms: Hijacking T Cell Extracellular...
# 1    NCT02486731  Hormonal Sensitivity in Patients With Noonan a...
# 2    NCT02116374  Physiopathology Study of the Microbiota Biodiv...
# 3    NCT03537196  DRug Use & Infections in ViEtnam - Hepatitis C...
# 4    NCT03537196  DRug Use & Infections in ViEtnam - Hepatitis C...
# ..           ...                                                ...
# 678  NCT01075061  Study of a Large Family With Congenital Mirror...
# 679  NCT00158405  Randomised Trial of Structured Treatment Inter...
# 680  NCT00158405  Randomised Trial of Structured Treatment Inter...
# 681  NCT00158405  Randomised Trial of Structured Treatment Inter...
# 682  NCT00623051  Evaluation of the Extension at Community Level...
#
#                                        LeadSponsorName      CollaboratorName  \
# 0                   ANRS, Emerging Infectious Diseases                  <NA>
# 1    Institut National de la Santé Et de la Recherc...                  <NA>
# 2                   ANRS, Emerging Infectious Diseases                  <NA>
# 3                   ANRS, Emerging Infectious Diseases                  <NA>
# 4                   ANRS, Emerging Infectious Diseases                  <NA>
# ..                                                 ...                   ...
# 678  Institut National de la Santé Et de la Recherc...                  <NA>
# 679  French National Agency for Research on AIDS an...  Bristol-Myers Squibb
# 680  French National Agency for Research on AIDS an...  Bristol-Myers Squibb
# 681  French National Agency for Research on AIDS an...  Bristol-Myers Squibb
# 682  French National Agency for Research on AIDS an...                  <NA>
#
#     OverallStatus       StudyType  HasResults StudyFirstPostDate      pmid  \
# 0       COMPLETED  INTERVENTIONAL       False         2013-07-11      <NA>
# 1       COMPLETED   OBSERVATIONAL       False         2015-07-01      <NA>
# 2       COMPLETED   OBSERVATIONAL       False         2014-04-16      <NA>
# 3       COMPLETED  INTERVENTIONAL       False         2018-05-25  26298331
# 4       COMPLETED  INTERVENTIONAL       False         2018-05-25  23172780
# ..            ...             ...         ...                ...       ...
# 678     COMPLETED  INTERVENTIONAL       False         2010-02-24      <NA>
# 679     COMPLETED  INTERVENTIONAL       False         2005-09-12  16152755
# 680     COMPLETED  INTERVENTIONAL       False         2005-09-12  16782488
# 681     COMPLETED  INTERVENTIONAL       False         2005-09-12  18986246
# 682     COMPLETED  INTERVENTIONAL       False         2008-02-25      <NA>
#
#            type                                         citation_x  \
# 0          <NA>                                               <NA>
# 1          <NA>                                               <NA>
# 2          <NA>                                               <NA>
# 3    BACKGROUND  Smith DJ, Combellick J, Jordan AE, Hagan H. He...
# 4    BACKGROUND  Mohd Hanafiah K, Groeger J, Flaxman AD, Wiersm...
# ..          ...                                                ...
# 678        <NA>                                               <NA>
# 679  BACKGROUND  Moh R, Danel C, Sorho S, Sauvageot D, Anzian A...
# 680      RESULT  Danel C, Moh R, Minga A, Anzian A, Ba-Gomis O,...
# 681      RESULT  Danel C, Moh R, Chaix ML, Gabillard D, Gnokoro...
# 682        <NA>                                               <NA>
#
#                                                  title  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    Hepatitis C virus (HCV) disease progression in...
# 4    Global epidemiology of hepatitis C virus infec...
# ..                                                 ...
# 678                                                NaN
# 679  Haematological changes in adults receiving a z...
# 680  CD4-guided structured antiretroviral treatment...
# 681  Two-months-off, four-months-on antiretroviral ...
# 682                                                NaN
#
#                                                authors  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3           Smith DJ; Combellick J; Jordan AE; Hagan H
# 4    Mohd Hanafiah K; Groeger J; Flaxman AD; Wiersm...
# ..                                                 ...
# 678                                                NaN
# 679  Moh R; Danel C; Sorho S; Sauvageot D; Anzian A...
# 680  Danel C; Moh R; Minga A; Anzian A; Ba-Gomis O;...
# 681  Danel C; Moh R; Chaix ML; Gabillard D; Gnokoro...
# 682                                                NaN
#
#                                doi  year  \
# 0                              NaN   NaN
# 1                              NaN   NaN
# 2                              NaN   NaN
# 3     10.1016/j.drugpo.2015.07.004  2015
# 4                10.1002/hep.26141  2013
# ..                             ...   ...
# 678                            NaN   NaN
# 679     10.1177/135965350501000510  2005
# 680  10.1016/S0140-6736(06)68887-9  2006
# 681                 10.1086/595298  2009
# 682                            NaN   NaN
#
#                                      publication_types  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    [Journal Article, Meta-Analysis, Research Supp...
# 4    [Journal Article, Meta-Analysis, Review, Syste...
# ..                                                 ...
# 678                                                NaN
# 679  [Clinical Trial, Journal Article, Randomized C...
# 680  [Journal Article, Multicenter Study, Randomize...
# 681  [Journal Article, Multicenter Study, Randomize...
# 682                                                NaN
#
#                                             citation_y
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    Smith DJ, et al. Hepatitis C virus (HCV) disea...
# 4    Mohd Hanafiah K, et al. Global epidemiology of...
# ..                                                 ...
# 678                                                NaN
# 679  Moh R, et al. Haematological changes in adults...
# 680  Danel C, et al. CD4-guided structured antiretr...
# 681  Danel C, et al. Two-months-off, four-months-on...
# 682                                                NaN
#
# [683 rows x 17 columns]

# %% [markdown]
# Suppression des colonnes 'citation':

# %%
df_final.drop(['citation_x', 'citation_y'], axis = 1, inplace = True)

# %%
df_final
# Out:
#            NCTId                                         BriefTitle  \
# 0    NCT01895920  Viral Biofilms: Hijacking T Cell Extracellular...
# 1    NCT02486731  Hormonal Sensitivity in Patients With Noonan a...
# 2    NCT02116374  Physiopathology Study of the Microbiota Biodiv...
# 3    NCT03537196  DRug Use & Infections in ViEtnam - Hepatitis C...
# 4    NCT03537196  DRug Use & Infections in ViEtnam - Hepatitis C...
# ..           ...                                                ...
# 678  NCT01075061  Study of a Large Family With Congenital Mirror...
# 679  NCT00158405  Randomised Trial of Structured Treatment Inter...
# 680  NCT00158405  Randomised Trial of Structured Treatment Inter...
# 681  NCT00158405  Randomised Trial of Structured Treatment Inter...
# 682  NCT00623051  Evaluation of the Extension at Community Level...
#
#                                        LeadSponsorName      CollaboratorName  \
# 0                   ANRS, Emerging Infectious Diseases                  <NA>
# 1    Institut National de la Santé Et de la Recherc...                  <NA>
# 2                   ANRS, Emerging Infectious Diseases                  <NA>
# 3                   ANRS, Emerging Infectious Diseases                  <NA>
# 4                   ANRS, Emerging Infectious Diseases                  <NA>
# ..                                                 ...                   ...
# 678  Institut National de la Santé Et de la Recherc...                  <NA>
# 679  French National Agency for Research on AIDS an...  Bristol-Myers Squibb
# 680  French National Agency for Research on AIDS an...  Bristol-Myers Squibb
# 681  French National Agency for Research on AIDS an...  Bristol-Myers Squibb
# 682  French National Agency for Research on AIDS an...                  <NA>
#
#     OverallStatus       StudyType  HasResults StudyFirstPostDate      pmid  \
# 0       COMPLETED  INTERVENTIONAL       False         2013-07-11      <NA>
# 1       COMPLETED   OBSERVATIONAL       False         2015-07-01      <NA>
# 2       COMPLETED   OBSERVATIONAL       False         2014-04-16      <NA>
# 3       COMPLETED  INTERVENTIONAL       False         2018-05-25  26298331
# 4       COMPLETED  INTERVENTIONAL       False         2018-05-25  23172780
# ..            ...             ...         ...                ...       ...
# 678     COMPLETED  INTERVENTIONAL       False         2010-02-24      <NA>
# 679     COMPLETED  INTERVENTIONAL       False         2005-09-12  16152755
# 680     COMPLETED  INTERVENTIONAL       False         2005-09-12  16782488
# 681     COMPLETED  INTERVENTIONAL       False         2005-09-12  18986246
# 682     COMPLETED  INTERVENTIONAL       False         2008-02-25      <NA>
#
#            type                                              title  \
# 0          <NA>                                               <NA>
# 1          <NA>                                               <NA>
# 2          <NA>                                               <NA>
# 3    BACKGROUND  Hepatitis C virus (HCV) disease progression in...
# 4    BACKGROUND  Global epidemiology of hepatitis C virus infec...
# ..          ...                                                ...
# 678        <NA>                                               <NA>
# 679  BACKGROUND  Haematological changes in adults receiving a z...
# 680      RESULT  CD4-guided structured antiretroviral treatment...
# 681      RESULT  Two-months-off, four-months-on antiretroviral ...
# 682        <NA>                                               <NA>
#
#                                                authors  \
# 0                                                 <NA>
# 1                                                 <NA>
# 2                                                 <NA>
# 3           Smith DJ; Combellick J; Jordan AE; Hagan H
# 4    Mohd Hanafiah K; Groeger J; Flaxman AD; Wiersm...
# ..                                                 ...
# 678                                               <NA>
# 679  Moh R; Danel C; Sorho S; Sauvageot D; Anzian A...
# 680  Danel C; Moh R; Minga A; Anzian A; Ba-Gomis O;...
# 681  Danel C; Moh R; Chaix ML; Gabillard D; Gnokoro...
# 682                                               <NA>
#
#                                doi  year  \
# 0                             <NA>  <NA>
# 1                             <NA>  <NA>
# 2                             <NA>  <NA>
# 3     10.1016/j.drugpo.2015.07.004  2015
# 4                10.1002/hep.26141  2013
# ..                             ...   ...
# 678                           <NA>  <NA>
# 679     10.1177/135965350501000510  2005
# 680  10.1016/S0140-6736(06)68887-9  2006
# 681                 10.1086/595298  2009
# 682                           <NA>  <NA>
#
#                                      publication_types
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    [Journal Article, Meta-Analysis, Research Supp...
# 4    [Journal Article, Meta-Analysis, Review, Syste...
# ..                                                 ...
# 678                                                NaN
# 679  [Clinical Trial, Journal Article, Randomized C...
# 680  [Journal Article, Multicenter Study, Randomize...
# 681  [Journal Article, Multicenter Study, Randomize...
# 682                                                NaN
#
# [683 rows x 15 columns]

# %% [markdown]
# Les nouveaux PMIDs trouvés via Pubmed, n'ont aucune des infos associées avec CT présents: BriefTitle, LeadSponsorName, etc ...

# %%
df_final[df_final.loc[:, 'BriefTitle'].isna()]
# Out:
#            NCTId BriefTitle LeadSponsorName CollaboratorName OverallStatus  \
# 43   NCT03078439       <NA>            <NA>             <NA>          <NA>
# 54   NCT02057796       <NA>            <NA>             <NA>          <NA>
# 70   NCT00640263       <NA>            <NA>             <NA>          <NA>
# 88   NCT02212379       <NA>            <NA>             <NA>          <NA>
# 124  NCT01473472       <NA>            <NA>             <NA>          <NA>
# 143  NCT03335995       <NA>            <NA>             <NA>          <NA>
# 161  NCT01426243       <NA>            <NA>             <NA>          <NA>
# 277  NCT03005652       <NA>            <NA>             <NA>          <NA>
# 283  NCT03215732       <NA>            <NA>             <NA>          <NA>
# 284  NCT02405013       <NA>            <NA>             <NA>          <NA>
# 298  NCT01089387       <NA>            <NA>             <NA>          <NA>
# 364  NCT05311865       <NA>            <NA>             <NA>          <NA>
# 365  NCT05311865       <NA>            <NA>             <NA>          <NA>
# 384  NCT04315948       <NA>            <NA>             <NA>          <NA>
# 448  NCT05349162       <NA>            <NA>             <NA>          <NA>
# 455  NCT01453192       <NA>            <NA>             <NA>          <NA>
# 481  NCT02777229       <NA>            <NA>             <NA>          <NA>
# 483  NCT02777229       <NA>            <NA>             <NA>          <NA>
# 484  NCT01703962       <NA>            <NA>             <NA>          <NA>
# 509  NCT01801618       <NA>            <NA>             <NA>          <NA>
# 544  NCT04392388       <NA>            <NA>             <NA>          <NA>
# 592  NCT02481453       <NA>            <NA>             <NA>          <NA>
# 603  NCT01688453       <NA>            <NA>             <NA>          <NA>
# 606  NCT04288128       <NA>            <NA>             <NA>          <NA>
# 607  NCT04288128       <NA>            <NA>             <NA>          <NA>
# 614  NCT02833961       <NA>            <NA>             <NA>          <NA>
# 659  NCT04409405       <NA>            <NA>             <NA>          <NA>
#
#     StudyType  HasResults StudyFirstPostDate      pmid    type  \
# 43       <NA>        <NA>               <NA>  38408861  PUBMED
# 54       <NA>        <NA>               <NA>  36883573  PUBMED
# 70       <NA>        <NA>               <NA>  34425825  PUBMED
# 88       <NA>        <NA>               <NA>  31269208  PUBMED
# 124      <NA>        <NA>               <NA>  36601747  PUBMED
# 143      <NA>        <NA>               <NA>  37497675  PUBMED
# 161      <NA>        <NA>               <NA>  26314624  PUBMED
# 277      <NA>        <NA>               <NA>  38100477  PUBMED
# 283      <NA>        <NA>               <NA>  37143029  PUBMED
# 284      <NA>        <NA>               <NA>  36686592  PUBMED
# 298      <NA>        <NA>               <NA>  26439886  PUBMED
# 364      <NA>        <NA>               <NA>  37795682  PUBMED
# 365      <NA>        <NA>               <NA>  36438274  PUBMED
# 384      <NA>        <NA>               <NA>  36695483  PUBMED
# 448      <NA>        <NA>               <NA>  36735263  PUBMED
# 455      <NA>        <NA>               <NA>  30688008  PUBMED
# 481      <NA>        <NA>               <NA>  38156046  PUBMED
# 483      <NA>        <NA>               <NA>  37851566  PUBMED
# 484      <NA>        <NA>               <NA>  37668523  PUBMED
# 509      <NA>        <NA>               <NA>  29662875  PUBMED
# 544      <NA>        <NA>               <NA>  34293141  PUBMED
# 592      <NA>        <NA>               <NA>  38273639  PUBMED
# 603      <NA>        <NA>               <NA>  35272723  PUBMED
# 606      <NA>        <NA>               <NA>  38421662  PUBMED
# 607      <NA>        <NA>               <NA>  38419144  PUBMED
# 614      <NA>        <NA>               <NA>  36318030  PUBMED
# 659      <NA>        <NA>               <NA>  38043556  PUBMED
#
#                                                  title  \
# 43   Birth weight and head circumference discordanc...
# 54   High performance of systematic combined urine ...
# 70   The prevalence and socio-behavioural and clini...
# 88   Dual therapy combining raltegravir with etravi...
# 124  Hepatitis A and B vaccine uptake and immunisat...
# 143  One-Year Outcomes in Patients With Acute Strok...
# 161  Molecular characterization of the 17D-204 yell...
# 277  Effects of a mindfulness-based intervention an...
# 283  Hepatitis B prevention and treatment needs in ...
# 284  Patient-reported outcomes with direct-acting a...
# 298  Safety of Intracavernous Bone Marrow-Mononucle...
# 364  A randomised controlled trial to study the tra...
# 365  Transmission of SARS-CoV-2 during indoor clubb...
# 384          Remdesivir for the treatment of COVID-19.
# 448  Epicardial vs. transvenous implantable cardiov...
# 455  Low incidence of acute rejection within 6 mont...
# 481  Durability of the Efficacy and Safety of Dolut...
# 483  Improvements in Patient-Reported Outcomes Foll...
# 484  Neurochemical Differences between 1p/19q Codel...
# 509  Positive Virological Outcomes of HIV-Infected ...
# 544  Antibody status and cumulative incidence of SA...
# 592  Sirolimus for treatment of patients with inclu...
# 603  Behavioural risk patterns in adolescents with ...
# 606  ATXN7-Related Cone-Rod Dystrophy: The Integrat...
# 607  Digital Gait Measures Capture 1-Year Progressi...
# 614  Longitudinal Monitoring of Microstructural Alt...
# 659  Effect of anti-Ebola virus monoclonal antibodi...
#
#                                                authors  \
# 43   Guellec I; Brunet A; Lapillonne A; Taine M; To...
# 54   Bonnet M; Gabillard D; Domoua S; Muzoora C; Me...
# 70   Birungi N; Fadnes LT; Engebretsen IMS; Tumwine...
# 88   Katlama C; Assoumou L; Valantin MA; Soulié C; ...
# 124  Le Turnier P; Charreau I; Gabassi A; Carette D...
# 143  Sonneville R; Mazighi M; Collet M; Gayat E; De...
# 161  Salmona M; Gazaignes S; Mercier-Delarue S; Gar...
# 277  Schlosser M; Demnitz-King H; Barnhofer T; Coll...
# 283  Djaogol T; Périères L; Marcellin F; Diouf A; C...
# 284  Marcellin F; Mourad A; Lemoine M; Kouanfack C;...
# 298  Yiou R; Hamidou L; Birebent B; Bitari D; Lecor...
# 364  Luong Nguyen LB; Goupil de Bouillé J; Menant L...
# 365  Goupil de Bouillé J; Luong Nguyen LB; Crépey P...
# 384  Grundeis F; Ansems K; Dahms K; Thieme V; Metze...
# 448  Le Bos PA; Pontailler M; Maltret A; Kraiche D;...
# 455  Matignon M; Lelièvre JD; Lahiani A; Abbassi K;...
# 481  Mpoudi-Etame M; Tovar Sanchez T; Bousmah MA; O...
# 483  Bousmah MA; Protopopescu C; Mpoudi-Etame M; Om...
# 484  Branzoli F; Liserre R; Deelchand DK; Poliani P...
# 509  Ségéral O; Nerrienet E; Neth S; Spire B; Khol ...
# 544  Carrat F; de Lamballerie X; Rahib D; Blanché H...
# 592  Benveniste O; Hogrel JY; Belin L; Annoussamy M...
# 603  Julia C; Omorou A; Lecomte E; Langlois J; Touv...
# 606  Nassisi M; Coarelli G; Blanchard B; Dubec-Fleu...
# 607  Seemann J; Daghsen L; Cazier M; Lamy JC; Welte...
# 614  Genovese G; Diaz-Fernandez B; Lejeune FX; Rone...
# 659  Nkuba-Ndaye A; Dilu-Keti A; Tovar-Sanchez T; D...
#
#                                   doi  year  \
# 43   10.1136/archdischild-2023-326336  2024
# 54                10.1093/cid/ciad125  2023
# 70         10.1186/s12955-021-01844-3  2021
# 88                 10.1093/jac/dkz224  2019
# 124      10.1136/sextrans-2022-055634  2023
# 143      10.1161/STROKEAHA.123.042910  2023
# 161     10.1016/j.vaccine.2015.08.055  2015
# 277      10.1371/journal.pone.0295175  2023
# 283        10.1186/s12889-023-15710-y  2023
# 284       10.1016/j.jhepr.2022.100665  2023
# 298      10.1016/j.eururo.2015.09.026  2016
# 364               10.1093/cid/ciad603  2023
# 365         10.3389/fpubh.2022.981213  2022
# 384    10.1002/14651858.CD014962.pub2  2023
# 448          10.1093/europace/euad015  2023
# 455                 10.1111/hiv.12700  2019
# 481              10.1093/ofid/ofad582  2023
# 483      10.1097/QAI.0000000000003273  2023
# 484             10.1148/radiol.223255  2023
# 509          10.3389/fpubh.2018.00063  2018
# 544               10.1093/ije/dyab110  2021
# 592     10.1016/S2665-9913(20)30280-0  2021
# 603         10.1017/S136898002200057X  2023
# 606  10.1001/jamaophthalmol.2024.0001  2024
# 607                 10.1002/mds.29757  2024
# 614             10.1148/radiol.220430  2023
# 659     10.1016/S1473-3099(23)00552-2  2024
#
#                                      publication_types
# 43                                   [Journal Article]
# 54                                   [Journal Article]
# 70                                   [Journal Article]
# 88   [Journal Article, Multicenter Study, Research ...
# 124  [Clinical Trial, Research Support, Non-U.S. Go...
# 143  [Multicenter Study, Journal Article, Research ...
# 161  [Journal Article, Research Support, Non-U.S. G...
# 277     [Randomized Controlled Trial, Journal Article]
# 283  [Journal Article, Research Support, Non-U.S. G...
# 284                                  [Journal Article]
# 298  [Journal Article, Research Support, Non-U.S. G...
# 364                                  [Journal Article]
# 365  [Clinical Trial Protocol, Journal Article, Res...
# 384  [Journal Article, Review, Research Support, No...
# 448                  [Clinical Trial, Journal Article]
# 455  [Journal Article, Multicenter Study, Research ...
# 481                                  [Journal Article]
# 483  [Randomized Controlled Trial, Journal Article,...
# 484  [Journal Article, Observational Study, Researc...
# 509                                  [Journal Article]
# 544                                  [Journal Article]
# 592                                  [Journal Article]
# 603  [Journal Article, Research Support, Non-U.S. G...
# 606                                  [Journal Article]
# 607                                  [Journal Article]
# 614  [Journal Article, Research Support, Non-U.S. G...
# 659             [Observational Study, Journal Article]

# %% [markdown]
# On va remplir ces colonnes avec les infos contenus dans la DataFrame CT:

# %%
# Index of empty rows we need to fill 
change_index = df_final.loc[:, 'BriefTitle'].isna()

# Columns we wish to copy
columns_to_copy = [
    'BriefTitle',
    'LeadSponsorName',
    'CollaboratorName',
    'OverallStatus',
    'StudyType',
    'HasResults',
    'StudyFirstPostDate',
]

# We copy the data from the CT dataframe to the final dataframe
df_final.loc[change_index, columns_to_copy] = df_ct.loc[change_index, columns_to_copy]

# %% [markdown]
# On rajoute un type 'PUBMED' pour les PMIDs issues de PubMed uniquement:

# %%
# We add a 'PUBMED' type to the PMIDs extracted from Pubmed exclusively
df_final.loc[change_index, 'type'] = 'PUBMED'

# %% [markdown]
# ### Resultat final:

# %%
df_final.loc[df_final['HasResults'] == True, 'NCTId'].unique()
# Out:
# <StringArray>
# ['NCT01605890', 'NCT00928187', 'NCT02573948', 'NCT02453048', 'NCT01882062']
# Length: 5, dtype: string

# %%
df_final[df_final.loc[:, 'NCTId'].isin(['NCT01605890', 'NCT00928187', 'NCT02573948', 'NCT02453048', 'NCT01882062'])]
# Out:
#            NCTId                                         BriefTitle  \
# 90   NCT01605890  Trial Evaluating a First Line Combination Ther...
# 300  NCT00928187  Evaluation of Three Strategies of Second-line ...
# 404  NCT02573948  Feasibility of Interventions on People Who Inj...
# 405  NCT02573948  Feasibility of Interventions on People Who Inj...
# 406  NCT02573948  Feasibility of Interventions on People Who Inj...
# 407  NCT02573948  Feasibility of Interventions on People Who Inj...
# 408  NCT02573948  Feasibility of Interventions on People Who Inj...
# 409  NCT02573948  Feasibility of Interventions on People Who Inj...
# 410  NCT02573948  Feasibility of Interventions on People Who Inj...
# 411  NCT02573948  Feasibility of Interventions on People Who Inj...
# 412  NCT02573948  Feasibility of Interventions on People Who Inj...
# 414  NCT02453048  Study of BPZE1 (High Dose) Nasal Live Attenuat...
# 415  NCT02453048  Study of BPZE1 (High Dose) Nasal Live Attenuat...
# 416  NCT02453048  Study of BPZE1 (High Dose) Nasal Live Attenuat...
# 417  NCT02453048  Study of BPZE1 (High Dose) Nasal Live Attenuat...
# 418  NCT02453048  Study of BPZE1 (High Dose) Nasal Live Attenuat...
# 419  NCT02453048  Study of BPZE1 (High Dose) Nasal Live Attenuat...
# 420  NCT02453048  Study of BPZE1 (High Dose) Nasal Live Attenuat...
# 421  NCT02453048  Study of BPZE1 (High Dose) Nasal Live Attenuat...
# 422  NCT02453048  Study of BPZE1 (High Dose) Nasal Live Attenuat...
# 423  NCT02453048  Study of BPZE1 (High Dose) Nasal Live Attenuat...
# 424  NCT02453048  Study of BPZE1 (High Dose) Nasal Live Attenuat...
# 425  NCT02453048  Study of BPZE1 (High Dose) Nasal Live Attenuat...
# 426  NCT02453048  Study of BPZE1 (High Dose) Nasal Live Attenuat...
# 449  NCT01882062  Proof of Concept of an Anaplerotic Study Using...
#
#                                        LeadSponsorName  \
# 90                  ANRS, Emerging Infectious Diseases
# 300                 ANRS, Emerging Infectious Diseases
# 404                 ANRS, Emerging Infectious Diseases
# 405                 ANRS, Emerging Infectious Diseases
# 406                 ANRS, Emerging Infectious Diseases
# 407                 ANRS, Emerging Infectious Diseases
# 408                 ANRS, Emerging Infectious Diseases
# 409                 ANRS, Emerging Infectious Diseases
# 410                 ANRS, Emerging Infectious Diseases
# 411                 ANRS, Emerging Infectious Diseases
# 412                 ANRS, Emerging Infectious Diseases
# 414  Institut National de la Santé Et de la Recherc...
# 415  Institut National de la Santé Et de la Recherc...
# 416  Institut National de la Santé Et de la Recherc...
# 417  Institut National de la Santé Et de la Recherc...
# 418  Institut National de la Santé Et de la Recherc...
# 419  Institut National de la Santé Et de la Recherc...
# 420  Institut National de la Santé Et de la Recherc...
# 421  Institut National de la Santé Et de la Recherc...
# 422  Institut National de la Santé Et de la Recherc...
# 423  Institut National de la Santé Et de la Recherc...
# 424  Institut National de la Santé Et de la Recherc...
# 425  Institut National de la Santé Et de la Recherc...
# 426  Institut National de la Santé Et de la Recherc...
# 449  Institut National de la Santé Et de la Recherc...
#
#                               CollaboratorName OverallStatus       StudyType  \
# 90   Gilead Sciences | Merck Sharp & Dohme LLC     COMPLETED  INTERVENTIONAL
# 300    Gilead Sciences | Janssen Pharmaceutica     COMPLETED  INTERVENTIONAL
# 404    National Institute on Drug Abuse (NIDA)     COMPLETED   OBSERVATIONAL
# 405    National Institute on Drug Abuse (NIDA)     COMPLETED   OBSERVATIONAL
# 406    National Institute on Drug Abuse (NIDA)     COMPLETED   OBSERVATIONAL
# 407    National Institute on Drug Abuse (NIDA)     COMPLETED   OBSERVATIONAL
# 408    National Institute on Drug Abuse (NIDA)     COMPLETED   OBSERVATIONAL
# 409    National Institute on Drug Abuse (NIDA)     COMPLETED   OBSERVATIONAL
# 410    National Institute on Drug Abuse (NIDA)     COMPLETED   OBSERVATIONAL
# 411    National Institute on Drug Abuse (NIDA)     COMPLETED   OBSERVATIONAL
# 412    National Institute on Drug Abuse (NIDA)     COMPLETED   OBSERVATIONAL
# 414                                       <NA>     COMPLETED  INTERVENTIONAL
# 415                                       <NA>     COMPLETED  INTERVENTIONAL
# 416                                       <NA>     COMPLETED  INTERVENTIONAL
# 417                                       <NA>     COMPLETED  INTERVENTIONAL
# 418                                       <NA>     COMPLETED  INTERVENTIONAL
# 419                                       <NA>     COMPLETED  INTERVENTIONAL
# 420                                       <NA>     COMPLETED  INTERVENTIONAL
# 421                                       <NA>     COMPLETED  INTERVENTIONAL
# 422                                       <NA>     COMPLETED  INTERVENTIONAL
# 423                                       <NA>     COMPLETED  INTERVENTIONAL
# 424                                       <NA>     COMPLETED  INTERVENTIONAL
# 425                                       <NA>     COMPLETED  INTERVENTIONAL
# 426                                       <NA>     COMPLETED  INTERVENTIONAL
# 449                                       <NA>     COMPLETED  INTERVENTIONAL
#
#      HasResults StudyFirstPostDate      pmid        type  \
# 90         True         2012-05-25  29590335     DERIVED
# 300        True         2009-06-25  31273686     DERIVED
# 404        True         2015-10-12  27006257      RESULT
# 405        True         2015-10-12  25540950  BACKGROUND
# 406        True         2015-10-12  28800503      RESULT
# 407        True         2015-10-12  26050614  BACKGROUND
# 408        True         2015-10-12  26075647  BACKGROUND
# 409        True         2015-10-12  28612212      RESULT
# 410        True         2015-10-12  26032121  BACKGROUND
# 411        True         2015-10-12  27178119      RESULT
# 412        True         2015-10-12  26080690  BACKGROUND
# 414        True         2015-05-25  24950361  BACKGROUND
# 415        True         2015-05-25  19625486  BACKGROUND
# 416        True         2015-05-25  31945015     DERIVED
# 417        True         2015-05-25  22814407  BACKGROUND
# 418        True         2015-05-25  24793938  BACKGROUND
# 419        True         2015-05-25  24421886  BACKGROUND
# 420        True         2015-05-25  18762220  BACKGROUND
# 421        True         2015-05-25  32687804     DERIVED
# 422        True         2015-05-25  20419113  BACKGROUND
# 423        True         2015-05-25  20708998  BACKGROUND
# 424        True         2015-05-25  21147936  BACKGROUND
# 425        True         2015-05-25  21430219  BACKGROUND
# 426        True         2015-05-25  20107007  BACKGROUND
# 449        True         2013-06-20  25568297      RESULT
#
#                                                  title  \
# 90   First-line Raltegravir/Emtricitabine/Tenofovir...
# 300  Cost-Effectiveness of Three Alternative Booste...
# 404  Prospects for ending the HIV epidemic among pe...
# 405  AIDS, people who use drugs, and altruism: refl...
# 406  Intravenous heroin use in Haiphong, Vietnam: N...
# 407  An international perspective on using opioid s...
# 408  Can HIV and Hepatitis C Virus Infection be Eli...
# 409  Risk Behaviors for HIV and HCV Infection Among...
# 410  Design and baseline findings of a large-scale ...
# 411  Integrated respondent-driven sampling and peer...
# 412  HIV, Hepatitis C, and Abstinence from Alcohol ...
# 414  Heterologous prime-boost immunization with liv...
# 415  A live attenuated Bordetella pertussis candida...
# 416  Live attenuated pertussis vaccine BPZE1 induce...
# 417  Dual mechanism of protection by live attenuate...
# 418  B-cell responses after intranasal vaccination ...
# 419  A phase I clinical study of a live attenuated ...
# 420  Genetic stability of the live attenuated Borde...
# 421  Safety and immunogenicity of the live attenuat...
# 422  T- and B-cell-mediated protection induced by n...
# 423  Long-term immunity against pertussis induced b...
# 424  A live, attenuated Bordetella pertussis vaccin...
# 425  Attenuated Bordetella pertussis vaccine candid...
# 426  Dose response of attenuated Bordetella pertuss...
# 449  Triheptanoin improves brain energy metabolism ...
#
#                                                authors  \
# 90   Matheron S; Descamps D; Gallien S; Besseghir A...
# 300  Boyer S; Nishimwe ML; Sagaon-Teyssier L; March...
# 404  Des Jarlais DC; Thi Huong D; Thi Hai Oanh K; K...
# 405                                     Des Jarlais DC
# 406  Michel L; Des Jarlais DC; Duong Thi H; Khuat T...
# 407  Perlman DC; Jordan AE; Uuskula A; Huong DT; Ma...
# 408            Perlman DC; Des Jarlais DC; Feelemyer J
# 409  Duong HT; Jarlais DD; Khuat OHT; Arasteh K; Fe...
# 410  Hatzakis A; Sypsa V; Paraskevis D; Nikolopoulo...
# 411  Des Jarlais D; Duong HT; Pham Minh K; Khuat OH...
# 412      Elliott JC; Hasin DS; Stohl M; Des Jarlais DC
# 414           Feunou PF; Kammoun H; Debrie AS; Locht C
# 415  Skerry CM; Cassidy JP; English K; Feunou-Feuno...
# 416  Lin A; Apostolovic D; Jahnmatz M; Liang F; Ols...
# 417  Kammoun H; Feunou PF; Foligne B; Debrie AS; Ra...
# 418  Jahnmatz M; Amu S; Ljungman M; Wehlin L; Chiod...
# 419  Thorstensson R; Trollfors B; Al-Tawil N; Jahnm...
# 420  Feunou PF; Ismaili J; Debrie AS; Huot L; Hot D...
# 421  Jahnmatz M; Richert L; Al-Tawil N; Storsaeter ...
# 422                      Feunou PF; Bertout J; Locht C
# 423  Feunou PF; Kammoun H; Debrie AS; Mielcarek N; ...
# 424                                Skerry CM; Mahon BP
# 425  Fedele G; Bianco M; Debrie AS; Locht C; Ausiel...
# 426         Mielcarek N; Debrie AS; Mahieux S; Locht C
# 449  Adanyeguh IM; Rinaldi D; Henry PG; Caillet S; ...
#
#                                   doi  year  \
# 90                 10.1093/cid/ciy245  2018
# 300         10.1007/s41669-019-0157-9  2020
# 404      10.1016/j.drugpo.2016.02.021  2016
# 405      10.3109/10826084.2015.978185  2015
# 406  10.1016/j.drugalcdep.2017.07.004  2017
# 407      10.1016/j.drugpo.2015.04.015  2015
# 408     10.1080/10550887.2015.1059111  2015
# 409         10.1007/s10461-017-1814-6  2018
# 410                 10.1111/add.12999  2015
# 411     10.1080/09540121.2016.1178698  2016
# 412         10.1007/s10461-015-1113-z  2016
# 414     10.1016/j.vaccine.2014.06.019  2014
# 415              10.1128/CVI.00082-09  2009
# 416                 10.1172/JCI135020  2020
# 417     10.1016/j.vaccine.2012.07.005  2012
# 418     10.1016/j.vaccine.2014.04.048  2014
# 419      10.1371/journal.pone.0083449  2014
# 420     10.1016/j.vaccine.2008.08.018  2008
# 421     10.1016/S1473-3099(20)30274-7  2020
# 422      10.1371/journal.pone.0010178  2010
# 423     10.1016/j.vaccine.2010.08.017  2010
# 424              10.1128/CVI.00371-10  2011
# 425          10.4049/jimmunol.1003765  2011
# 426              10.1128/CVI.00322-09  2010
# 449      10.1212/WNL.0000000000001214  2015
#
#                                      publication_types
# 90   [Clinical Trial, Phase II, Journal Article, Mu...
# 300                                  [Journal Article]
# 404  [Journal Article, Research Support, Non-U.S. G...
# 405                                  [Journal Article]
# 406                                  [Journal Article]
# 407  [Journal Article, Research Support, N.I.H., Ex...
# 408  [Journal Article, Research Support, N.I.H., Ex...
# 409                                  [Journal Article]
# 410  [Journal Article, Research Support, N.I.H., Ex...
# 411                                  [Journal Article]
# 412  [Journal Article, Research Support, N.I.H., Ex...
# 414  [Journal Article, Research Support, Non-U.S. G...
# 415  [Journal Article, Research Support, Non-U.S. G...
# 416  [Journal Article, Randomized Controlled Trial,...
# 417  [Journal Article, Research Support, Non-U.S. G...
# 418  [Clinical Trial, Phase I, Journal Article, Ran...
# 419  [Clinical Trial, Phase I, Journal Article, Ran...
# 420  [Journal Article, Research Support, Non-U.S. G...
# 421  [Clinical Trial, Phase I, Journal Article, Ran...
# 422  [Journal Article, Research Support, Non-U.S. G...
# 423  [Journal Article, Research Support, Non-U.S. G...
# 424  [Journal Article, Research Support, Non-U.S. G...
# 425  [Journal Article, Research Support, Non-U.S. G...
# 426  [Journal Article, Research Support, Non-U.S. G...
# 449  [Clinical Trial, Journal Article, Research Sup...

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 683 entries, 0 to 682
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   NCTId               683 non-null    object
#  1   BriefTitle          683 non-null    string
#  2   LeadSponsorName     683 non-null    string
#  3   CollaboratorName    357 non-null    string
#  4   OverallStatus       683 non-null    category
#  5   StudyType           683 non-null    category
#  6   HasResults          683 non-null    boolean
#  7   StudyFirstPostDate  683 non-null    string
#  8   pmid                547 non-null    object
#  9   type                547 non-null    string
#  10  title               547 non-null    object
#  11  authors             547 non-null    object
#  12  doi                 542 non-null    object
#  13  year                547 non-null    object
#  14  publication_types   547 non-null    object
# dtypes: boolean(1), category(2), object(7), string(5)
# memory usage: 67.1+ KB

# %%
df_final = df_final.convert_dtypes()
# df_final = df_final.astype({"OverallStatus" : 'category', "StudyType" : 'category'})
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 683 entries, 0 to 682
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   NCTId               683 non-null    string
#  1   BriefTitle          683 non-null    string
#  2   LeadSponsorName     683 non-null    string
#  3   CollaboratorName    357 non-null    string
#  4   OverallStatus       683 non-null    category
#  5   StudyType           683 non-null    category
#  6   HasResults          683 non-null    boolean
#  7   StudyFirstPostDate  683 non-null    string
#  8   pmid                547 non-null    string
#  9   type                547 non-null    string
#  10  title               547 non-null    string
#  11  authors             547 non-null    string
#  12  doi                 542 non-null    string
#  13  year                547 non-null    string
#  14  publication_types   547 non-null    object
# dtypes: boolean(1), category(2), object(1), string(11)
# memory usage: 67.1+ KB

# %% [markdown]
# ### Export en CSV:

# %%
df_final.to_csv('Data/outputs/extract_df_final.csv', sep=";", index=False, encoding='utf-8-sig')
