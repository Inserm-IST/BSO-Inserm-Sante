# %% [markdown]
# # Objectif:
#
# On souhaite évaluer le nombre de publications qui sont le résultat d'études cliniques liées à l'INSERM.
#
# En particulier, on souhaite identifier les études cliniques qui ne donnent lieu à aucune publication et essayer de comprendre les raisons de cette absence de publication.

# %% [markdown]
# # Organisation :
# - On récupère via l'API de *ClinicalTrial* les *ID* (**NCTId**) des études cliniques qui ont pour sponsors l'*INSERM*, l'*ANRS* etc.
#
# - A partir de ces **NCTIds**, on récupère sur *ClinicalTrial* les **PMIDs** des publications liées à ces études.
#     Ces publications sont de 2 types:
#     1. Elles ont été uploadées sur *CT* par les auteurs de l'étude: `BACKGROUND, RESULT`
#     2. Elles ont été automatiquement récupérés sur PubMed par *CT*: `DERIVED`
# - A partir de ces **NCTIds**, on récupère sur *PubMed* les **PMIDs** des publications liées à ces études.
#     On retrouve général un peu plus de publications que le traitement automatique réalisé par *CT*.
#
# - Pour chaque **NCTIds**, on fusionne l'ensemble des **PMIDs** retournées par *CT* et *PubMed*.
#
# - A partir de cet ensemble de **PMIDs**, on récupère les infos liés : `titre, auteurs, doi`...

# %% [markdown]
# # Extraction des NCTIds dans ClinicalTrial:

# %% [markdown]
# ## API v1:

# %% [markdown]
# Pour faciliter la récupération des données via l'API v1 de ClinicalTrial, on utilise le wrapper Python: [pytrials](https://github.com/jvfe/pytrials)

# %% [markdown]
# Installer ***pytrials***:
# - Dans Conda Navigator, se placer dans le meme environnement que celui qui execute Jupyter
# - Lancer Powershell Prompt dans cet environnement
# - Taper: `pip install pytrials`

# %%
from pytrials.client import ClinicalTrials
import urllib.parse

# %%
ct = ClinicalTrials()

# %% [markdown]
# ### Création de la requête:

# %% [markdown]
# On crée la requête qui sera envoyé à l'API de ClinicalTrial

# %% [markdown]
# #### Sponsors:

# %%
sponsors = [
    'anrs',
    'inserm',
    'institut national de la santé et de la recherche médicale',
    'french national agency for research on aids and viral hepatitis',
]

# %%
sponsors_expr = [f'AREA[LeadSponsorName]{sponsor}' for sponsor in sponsors]

# Add OR keyword
sponsors_expr = ' OR '.join(sponsors_expr)

# Add parenthesis for correct interpretation of OR expression
sponsors_expr = f'({sponsors_expr})'

sponsors_expr
# Out:
# '(AREA[LeadSponsorName]anrs OR AREA[LeadSponsorName]inserm OR AREA[LeadSponsorName]institut national de la santé et de la recherche médicale OR AREA[LeadSponsorName]french national agency for research on aids and viral hepatitis)'

# %% [markdown]
# #### Status:

# %%
status = 'completed'

# %%
status_expr = f'AREA[OverallStatus]{status}'
status_expr
# Out:
# 'AREA[OverallStatus]completed'

# %% [markdown]
# #### Search Expression:

# %%
search_expr = ' AND '.join([sponsors_expr, status_expr])
search_expr
# Out:
# '(AREA[LeadSponsorName]anrs OR AREA[LeadSponsorName]inserm OR AREA[LeadSponsorName]institut national de la santé et de la recherche médicale OR AREA[LeadSponsorName]french national agency for research on aids and viral hepatitis) AND AREA[OverallStatus]completed'

# %% [markdown]
# #### URL encode:

# %%
search_expr_url_encode = urllib.parse.quote_plus(search_expr)
search_expr_url_encode
# Out:
# '%28AREA%5BLeadSponsorName%5Danrs+OR+AREA%5BLeadSponsorName%5Dinserm+OR+AREA%5BLeadSponsorName%5Dinstitut+national+de+la+sant%C3%A9+et+de+la+recherche+m%C3%A9dicale+OR+AREA%5BLeadSponsorName%5Dfrench+national+agency+for+research+on+aids+and+viral+hepatitis%29+AND+AREA%5BOverallStatus%5Dcompleted'

# %% [markdown]
# #### Fields:

# %% [markdown]
# Les champs que l'on veut récupérer:

# %%
fields = [
    'NCTId',
    'BriefTitle',
    'OverallStatus',
    'StudyType',
    'LeadSponsorName',
    'CollaboratorName',
    'OrgStudyId',
    'SecondaryId',
    'StudyFirstPostDate',
    'ReferencePMID',
    'ReferenceCitation',
    'ReferenceType',
]

# %% [markdown]
# ### Envoi de la requête :

# %%
study_fields = ct.get_study_fields(
    search_expr=search_expr_url_encode,
    fields=fields,
    max_studies=1000,
    fmt='csv',
)

# %%
print(f'NStudiesReturned: {len(study_fields[1:])}')
# Out:
# NStudiesReturned: 289

# %% [markdown]
# ### Lire le résultat de la requête dans Pandas :

# %%
import pandas as pd

# %%
pd.DataFrame.from_records(
    study_fields[1:], index='Rank', columns=study_fields[0]
)
# Out:
#             NCTId                                         BriefTitle  \
# Rank
# 1     NCT03671291  Missed Opportunities to Pre-exposure Prophylax...
# 2     NCT01494961  Couple-oriented Prenatal HIV Counseling in Low...
# 3     NCT01463956  Efficacy of PegInterferon-Ribavirin-Boceprevir...
# 4     NCT01426243  The Yellow Fever Vaccine Immunity in HIV Infec...
# 5     NCT01413152       Residual Risk Assessment Of HIV Transmission
# ...           ...                                                ...
# 285   NCT00265642  Evaluation of Irbesartan on Hepatic Fibrosis i...
# 286   NCT00116454  Trial for Hepatocellular Carcinoma Adjuvant Tr...
# 287   NCT05349162        Epicardial vs. Transvenous ICDs in Children
# 288   NCT04842851  Cardiac Resynchronization Therapy in Congenita...
# 289   NCT05199831  Situational Analysis of HIV-related Disability...
#
#      OverallStatus       StudyType  \
# Rank
# 1        Completed  Interventional
# 2        Completed  Interventional
# 3        Completed  Interventional
# 4        Completed  Interventional
# 5        Completed  Interventional
# ...            ...             ...
# 285      Completed  Interventional
# 286      Completed  Interventional
# 287      Completed   Observational
# 288      Completed   Observational
# 289      Completed   Observational
#
#                                         LeadSponsorName  \
# Rank
# 1     French National Agency for Research on AIDS an...
# 2     French National Agency for Research on AIDS an...
# 3     French National Agency for Research on AIDS an...
# 4     French National Agency for Research on AIDS an...
# 5     French National Agency for Research on AIDS an...
# ...                                                 ...
# 285                  ANRS, Emerging Infectious Diseases
# 286                  ANRS, Emerging Infectious Diseases
# 287   Paris Cardiovascular Research Center (Inserm U...
# 288   Paris Cardiovascular Research Center (Inserm U...
# 289    Programme PAC-CI, Site ANRS-MIE de Côte d'Ivoire
#
#                                        CollaboratorName  \
# Rank
# 1     University Hospital, Marseille|University Hosp...
# 2            Elizabeth Glaser Pediatric AIDS Foundation
# 3                               Merck Sharp & Dohme LLC
# 4
# 5
# ...                                                 ...
# 285                                              Sanofi
# 286
# 287                      Hôpital Necker-Enfants Malades
# 288   Marie Lannelongue Hospital, Le Plessis Robinso...
# 289   Institute of Research for Development, France|...
#
#                          OrgStudyId          SecondaryId  StudyFirstPostDate  \
# Rank
# 1     ANRS 95041 Missed Opportunity                       September 14, 2018
# 2             ANRS 12127 Prenahtest                        December 19, 2011
# 3                  2011- 001089 -17                         November 2, 2011
# 4                    2009-014921-17                          August 31, 2011
# 5                        AOO 370-41                          August 10, 2011
# ...                             ...                  ...                 ...
# 285                  2005-006027-37  ANRS HC 19 Fibrosar   December 15, 2005
# 286                  2004-003883-31   ANRS HC06 LIPIOCIS       June 30, 2005
# 287                          134526                           April 27, 2022
# 288                         2219047                           April 13, 2021
# 289                          VIRAGE                         January 20, 2022
#
#                                      ReferencePMID  \
# Rank
# 1
# 2     20403152|21857289|34329355|29178852|23343912
# 3
# 4                                         30096071
# 5
# ...                                            ...
# 285
# 286
# 287
# 288
# 289
#
#                                       ReferenceCitation  \
# Rank
# 1
# 2     Orne-Gliemann J, Tchendjou PT, Miric M, Gadgil...
# 3
# 4     Colin de Verdiere N, Durier C, Samri A, Meiffr...
# 5
# ...                                                 ...
# 285
# 286
# 287
# 288
# 289
#
#                               ReferenceType
# Rank
# 1
# 2     result|result|derived|derived|derived
# 3
# 4                                   derived
# 5
# ...                                     ...
# 285
# 286
# 287
# 288
# 289
#
# [289 rows x 12 columns]

# %% [markdown]
# ## API v2:

# %% [markdown]
# L'API v1 ne sera plus supporté a [partir de mi-2024](https://clinicaltrials.gov/data-api/api) :

# %% [markdown]
# >***Notice to API users:
# >The new ClinicalTrials.gov API, version 2.0 is available. Classic API users are strongly encouraged to switch to the modernized API. We will continue to support the classic API until mid-2024 and are planning blackouts for the spring to help with the transition to the modernized API.***

# %% [markdown]
# De plus, l'API v2 supporte un nouveau champs **"HasResults"**, qui pour l'instant n'est que très peu utilisé mais qui pourrait être utile à l'avenir.
#
# En contre-partie, l'export des données sous forme de CSV est limité à un certain nombre de champs visible sur cette page: https://clinicaltrials.gov/data-api/about-api/csv-download
#
# On est donc obligé d'utiliser l'export de données sous forme de JSON.

# %% [markdown]
# ### Création de la requête:

# %% [markdown]
# `pytrials` n'étant pas compatible avec la v2, on envoie la requête manuellement en utilisant [Requests](https://requests.readthedocs.io/en/latest/)

# %% [markdown]
# #### Format:

# %%
format = 'json'

# %% [markdown]
# #### Sponsors:

# %%
sponsors
# Out:
# ['anrs',
#  'inserm',
#  'institut national de la santé et de la recherche médicale',
#  'french national agency for research on aids and viral hepatitis']

# %%
sponsors_expr_v2 = ' OR '.join(sponsors)
sponsors_expr_v2 = urllib.parse.quote_plus(sponsors_expr_v2)
sponsors_expr_v2
# Out:
# 'anrs+OR+inserm+OR+institut+national+de+la+sant%C3%A9+et+de+la+recherche+m%C3%A9dicale+OR+french+national+agency+for+research+on+aids+and+viral+hepatitis'

# %% [markdown]
# #### Overall_status:

# %%
overall_status = 'COMPLETED'

# %% [markdown]
# #### Fields:

# %%
fields_v2 = [
    'NCTId',
    'BriefTitle',
    # 'OfficialTitle',
    'OverallStatus',
    'StudyType',
    'LeadSponsorName',
    'CollaboratorName',
    # 'OrgStudyId',
    # 'SecondaryId',
    'StudyFirstPostDate',
    'StartDate',
    # 'PrimaryCompletionDate',
    'CompletionDate',
    'ReferencePMID',
    'ReferenceCitation',
    'ReferenceType',
    'hasResults',
]
fields_v2
# Out:
# ['NCTId',
#  'BriefTitle',
#  'OverallStatus',
#  'StudyType',
#  'LeadSponsorName',
#  'CollaboratorName',
#  'StudyFirstPostDate',
#  'StartDate',
#  'CompletionDate',
#  'ReferencePMID',
#  'ReferenceCitation',
#  'ReferenceType',
#  'hasResults']

# %%
fields_expr_v2 = ','.join(fields_v2)
fields_expr_v2 = urllib.parse.quote_plus(fields_expr_v2)
fields_expr_v2
# Out:
# 'NCTId%2CBriefTitle%2COverallStatus%2CStudyType%2CLeadSponsorName%2CCollaboratorName%2CStudyFirstPostDate%2CStartDate%2CCompletionDate%2CReferencePMID%2CReferenceCitation%2CReferenceType%2ChasResults'

# %% [markdown]
# #### Nombre de résultats max :

# %%
count_total = 'true'

# %%
page_size = 1000

# %% [markdown]
# #### URL api:

# %%
query_url = f'https://clinicaltrials.gov/api/v2/studies?format={format}&query.lead={sponsors_expr_v2}&filter.overallStatus={overall_status}&fields={fields_expr_v2}&countTotal={count_total}&pageSize={page_size}'
query_url
# Out:
# 'https://clinicaltrials.gov/api/v2/studies?format=json&query.lead=anrs+OR+inserm+OR+institut+national+de+la+sant%C3%A9+et+de+la+recherche+m%C3%A9dicale+OR+french+national+agency+for+research+on+aids+and+viral+hepatitis&filter.overallStatus=COMPLETED&fields=NCTId%2CBriefTitle%2COverallStatus%2CStudyType%2CLeadSponsorName%2CCollaboratorName%2CStudyFirstPostDate%2CStartDate%2CCompletionDate%2CReferencePMID%2CReferenceCitation%2CReferenceType%2ChasResults&countTotal=true&pageSize=1000'

# %% [markdown]
# ### Envoi de la requête :

# %%
import requests

# %%
response = requests.get(query_url)
response.raise_for_status()
response
# Out:
# <Response [200]>

# %%
print(f'Studies returned: {response.json()["totalCount"]}')
# Out:
# Studies returned: 289

# %% [markdown]
# ### Traitement du JSON retourné:

# %%
import json

# %%
print(json.dumps(response.json(), indent=2))
# Out:
# {
#   "totalCount": 289,
#   "studies": [
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT02014727",
#           "briefTitle": "Safety and Immunogenicity of Recombinant Pichia Pastoris AMA1-DiCo Candidate Malaria Vaccine With GLA-SE and Alhydrogel \u00ae as Adjuvant in Healthy Malaria Non-Exposed European and Malaria Exposed African Adults"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2014-01"
#           },
#           "completionDateStruct": {
#             "date": "2015-07"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2013-12-18"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France"
#           },
#           "collaborators": [
#             {
#               "name": "EVI Industries, Inc."
#             },
#             {
#               "name": "BPRC"
#             },
#             {
#               "name": "Recherche Clinique Paris Descartes Necker Cochin Sainte Anne"
#             },
#             {
#               "name": "Centre national de recherche et de formation sur le paludisme"
#             }
#           ]
#         },
#         "designModule": {
#           "studyType": "INTERVENTIONAL"
#         },
#         "referencesModule": {
#           "references": [
#             {
#               "pmid": "28947345",
#               "type": "DERIVED",
#               "citation": "Sirima SB, Durier C, Kara L, Houard S, Gansane A, Loulergue P, Bahuaud M, Benhamouda N, Nebie I, Faber B, Remarque E, Launay O; AMA1-DiCo Study Group. Safety and immunogenicity of a recombinant Plasmodium falciparum AMA1-DiCo malaria vaccine adjuvanted with GLA-SE or Alhydrogel(R) in European and African adults: A phase 1a/1b, randomized, double-blind multi-centre trial. Vaccine. 2017 Oct 27;35(45):6218-6227. doi: 10.1016/j.vaccine.2017.09.027. Epub 2017 Sep 22."
#             }
#           ]
#         }
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT00117494",
#           "briefTitle": "Rosuvastatin Versus Pravastatin in HIV Patients Treated With Boosted Protease Inhibitors (PI) (ANRS126)"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2005-10"
#           },
#           "completionDateStruct": {
#             "date": "2007-06"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2005-07-07"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "French National Agency for Research on AIDS and Viral Hepatitis"
#           }
#         },
#         "designModule": {
#           "studyType": "INTERVENTIONAL"
#         },
#         "referencesModule": {
#           "references": [
#             {
#               "pmid": "22739396",
#               "type": "DERIVED",
#               "citation": "Bittar R, Giral P, Aslangul E, Assoumou L, Valantin MA, Kalmykova O, Federspiel MC, Cherfils C, Costagliola D, Bonnefont-Rousselot D; French National Agency for AIDS and Viral Hepatitis Research (ANRS) 126 study group. Effects of rosuvastatin versus pravastatin on low-density lipoprotein diameter in HIV-1-infected patients receiving ritonavir-boosted protease inhibitor. AIDS. 2012 Sep 10;26(14):1801-5. doi: 10.1097/QAD.0b013e328357063c."
#             },
#             {
#               "pmid": "22318219",
#               "type": "DERIVED",
#               "citation": "Bittar R, Giral P, Aslangul E, Assoumou L, Valantin MA, Kalmykova O, Fesel-Fouquier V, Costagliola D, Bonnefont-Rousselot D; ANRS 126 study group. Determinants of low-density lipoprotein particle diameter during antiretroviral therapy including protease inhibitors in HIV-1-infected patients. Antivir Ther. 2012;17(5):855-60. doi: 10.3851/IMP2065. Epub 2012 Feb 9."
#             }
#           ]
#         }
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT00536627",
#           "briefTitle": "Efficacy and Tolerance of Naked DNA Vaccine in Patients With Chronic B Hepatitis"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2008-01"
#           },
#           "completionDateStruct": {
#             "date": "2010-11"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2007-09-28"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "French National Agency for Research on AIDS and Viral Hepatitis"
#           }
#         },
#         "designModule": {
#           "studyType": "INTERVENTIONAL"
#         },
#         "referencesModule": {
#           "references": [
#             {
#               "pmid": "16310901",
#               "type": "BACKGROUND",
#               "citation": "Mancini-Bourgine M, Fontaine H, Brechot C, Pol S, Michel ML. Immunogenicity of a hepatitis B DNA vaccine administered to chronic HBV carriers. Vaccine. 2006 May 22;24(21):4482-9. doi: 10.1016/j.vaccine.2005.08.013. Epub 2005 Aug 18."
#             },
#             {
#               "pmid": "15382173",
#               "type": "BACKGROUND",
#               "citation": "Mancini-Bourgine M, Fontaine H, Scott-Algara D, Pol S, Brechot C, Michel ML. Induction or expansion of T-cell responses by a hepatitis B DNA vaccine administered to chronic HBV carriers. Hepatology. 2004 Oct;40(4):874-82. doi: 10.1002/hep.20408."
#             },
#             {
#               "pmid": "24555998",
#               "type": "DERIVED",
#               "citation": "Fontaine H, Kahi S, Chazallon C, Bourgine M, Varaut A, Buffet C, Godon O, Meritet JF, Saidi Y, Michel ML, Scott-Algara D, Aboulker JP, Pol S; ANRS HB02 study group. Anti-HBV DNA vaccination does not prevent relapse after discontinuation of analogues in the treatment of chronic hepatitis B: a randomised trial--ANRS HB02 VAC-ADN. Gut. 2015 Jan;64(1):139-47. doi: 10.1136/gutjnl-2013-305707. Epub 2014 Feb 20."
#             },
#             {
#               "pmid": "24394187",
#               "type": "DERIVED",
#               "citation": "Godon O, Fontaine H, Kahi S, Meritet JF, Scott-Algara D, Pol S, Michel ML, Bourgine M; ANRS HB02 study group. Immunological and antiviral responses after therapeutic DNA immunization in chronic hepatitis B patients efficiently treated by analogues. Mol Ther. 2014 Mar;22(3):675-684. doi: 10.1038/mt.2013.274. Epub 2013 Dec 5."
#             }
#           ]
#         }
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT01033760",
#           "briefTitle": "Optimisation of Primary HIV1 Infection Treatment(ANRS 147 OPTIPRIM)"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2010-04"
#           },
#           "completionDateStruct": {
#             "date": "2013-12"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2009-12-16"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "ANRS, Emerging Infectious Diseases"
#           },
#           "collaborators": [
#             {
#               "name": "Gilead Sciences"
#             },
#             {
#               "name": "Merck Sharp & Dohme LLC"
#             },
#             {
#               "name": "Pfizer"
#             },
#             {
#               "name": "Janssen-Cilag Ltd."
#             }
#           ]
#         },
#         "designModule": {
#           "studyType": "INTERVENTIONAL"
#         },
#         "referencesModule": {
#           "references": [
#             {
#               "pmid": "28708873",
#               "type": "DERIVED",
#               "citation": "Cheret A, Durier C, Melard A, Ploquin M, Heitzmann J, Lecuroux C, Avettand-Fenoel V, David L, Pialoux G, Chennebault JM, Muller-Trutwin M, Goujard C, Rouzioux C, Meyer L; ANRS OPTIPRIM study group. Impact of early cART on HIV blood and semen compartments at the time of primary infection. PLoS One. 2017 Jul 14;12(7):e0180191. doi: 10.1371/journal.pone.0180191. eCollection 2017."
#             },
#             {
#               "pmid": "25701561",
#               "type": "DERIVED",
#               "citation": "Cheret A, Nembot G, Melard A, Lascoux C, Slama L, Miailhes P, Yeni P, Abel S, Avettand-Fenoel V, Venet A, Chaix ML, Molina JM, Katlama C, Goujard C, Tamalet C, Raffi F, Lafeuillade A, Reynes J, Ravaux I, Hoen B, Delfraissy JF, Meyer L, Rouzioux C; OPTIPRIM ANRS Study Group. Intensive five-drug antiretroviral therapy regimen versus standard triple-drug therapy during primary HIV-1 infection (OPTIPRIM-ANRS 147): a randomised, open-label, phase 3 trial. Lancet Infect Dis. 2015 Apr;15(4):387-96. doi: 10.1016/S1473-3099(15)70021-6. Epub 2015 Feb 18."
#             }
#           ]
#         }
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT05349162",
#           "briefTitle": "Epicardial vs. Transvenous ICDs in Children"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2003-01-01"
#           },
#           "completionDateStruct": {
#             "date": "2022-04-01"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2022-04-27"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "Paris Cardiovascular Research Center (Inserm U970)"
#           },
#           "collaborators": [
#             {
#               "name": "H\u00f4pital Necker-Enfants Malades"
#             }
#           ]
#         },
#         "designModule": {
#           "studyType": "OBSERVATIONAL"
#         }
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT01164462",
#           "briefTitle": "Feasibility and Limitations of Offering Community Based Rapid HIV Testing to Men Who Have Sex With Men (MSM)"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2010-03"
#           },
#           "completionDateStruct": {
#             "date": "2011-04"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2010-07-16"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "French National Agency for Research on AIDS and Viral Hepatitis"
#           }
#         },
#         "designModule": {
#           "studyType": "INTERVENTIONAL"
#         },
#         "referencesModule": {}
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT02777229",
#           "briefTitle": "Efficacy and Safety of a Dolutegravir-based Regimen for the Initial Management of HIV Infected Adults in Resource-limited Settings"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2016-07"
#           },
#           "completionDateStruct": {
#             "date": "2021-07"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2016-05-19"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "ANRS, Emerging Infectious Diseases"
#           },
#           "collaborators": [
#             {
#               "name": "Institut de Recherche pour le Developpement"
#             },
#             {
#               "name": "UNITAID"
#             }
#           ]
#         },
#         "designModule": {
#           "studyType": "INTERVENTIONAL"
#         },
#         "referencesModule": {
#           "references": [
#             {
#               "pmid": "33355914",
#               "type": "DERIVED",
#               "citation": "Bousmah MA, Nishimwe ML, Tovar-Sanchez T, Lantche Wandji M, Mpoudi-Etame M, Maradan G, Omgba Bassega P, Varloteaux M, Montoyo A, Kouanfack C, Delaporte E, Boyer S; New Antiretroviral and Monitoring Strategies in HIV-infected Adults in Low-Income Countries (NAMSAL) ANRS 12313 Study Group. Cost-Utility Analysis of a Dolutegravir-Based Versus Low-Dose Efavirenz-Based Regimen for the Initial Treatment of HIV-Infected Patients in Cameroon (NAMSAL ANRS 12313 Trial). Pharmacoeconomics. 2021 Mar;39(3):331-343. doi: 10.1007/s40273-020-00987-3. Epub 2020 Dec 23."
#             },
#             {
#               "pmid": "33010241",
#               "type": "DERIVED",
#               "citation": "Calmy A, Tovar Sanchez T, Kouanfack C, Mpoudi-Etame M, Leroy S, Perrineau S, Lantche Wandji M, Tetsa Tata D, Omgba Bassega P, Abong Bwenda T, Varloteaux M, Tongo M, Mpoudi-Ngole E, Montoyo A, Mercier N, LeMoing V, Peeters M, Reynes J, Delaporte E; New Antiretroviral and Monitoring Strategies in HIV-infected Adults in Low-Income Countries (NAMSAL) ANRS 12313 Study Group. Dolutegravir-based and low-dose efavirenz-based regimen for the initial treatment of HIV-1 infection (NAMSAL): week 96 results from a two-group, multicentre, randomised, open label, phase 3 non-inferiority trial in Cameroon. Lancet HIV. 2020 Oct;7(10):e677-e687. doi: 10.1016/S2352-3018(20)30238-1."
#             },
#             {
#               "pmid": "31339676",
#               "type": "DERIVED",
#               "citation": "NAMSAL ANRS 12313 Study Group; Kouanfack C, Mpoudi-Etame M, Omgba Bassega P, Eymard-Duvernay S, Leroy S, Boyer S, Peeters M, Calmy A, Delaporte E. Dolutegravir-Based or Low-Dose Efavirenz-Based Regimen for the Treatment of HIV-1. N Engl J Med. 2019 Aug 29;381(9):816-826. doi: 10.1056/NEJMoa1904340. Epub 2019 Jul 24."
#             }
#           ]
#         }
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT00480792",
#           "briefTitle": "Trial Comparing Three Strategies of Vaccination Against the Virus of Hepatitis B in HIV Infected Patients"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2007-06"
#           },
#           "completionDateStruct": {
#             "date": "2012-09"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2007-05-31"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "ANRS, Emerging Infectious Diseases"
#           },
#           "collaborators": [
#             {
#               "name": "MCM Vaccines B.V."
#             }
#           ]
#         },
#         "designModule": {
#           "studyType": "INTERVENTIONAL"
#         },
#         "referencesModule": {
#           "references": [
#             {
#               "pmid": "27064975",
#               "type": "DERIVED",
#               "citation": "Launay O, Rosenberg AR, Rey D, Pouget N, Michel ML, Reynes J, Neau D, Raffi F, Piroth L, Carrat F; ANRS HB03 VIHVAC-B (Trial Comparing 3 Strategies of Vaccination Against the Virus of Hepatitis B in HIV-Infected Patients) Group. Long-term Immune Response to Hepatitis B Virus Vaccination Regimens in Adults With Human Immunodeficiency Virus 1: Secondary Analysis of a Randomized Clinical Trial. JAMA Intern Med. 2016 May 1;176(5):603-10. doi: 10.1001/jamainternmed.2016.0741."
#             },
#             {
#               "pmid": "21486976",
#               "type": "DERIVED",
#               "citation": "Launay O, van der Vliet D, Rosenberg AR, Michel ML, Piroth L, Rey D, Colin de Verdiere N, Slama L, Martin K, Lortholary O, Carrat F; ANRS HB03 VIHVAC-B Trial. Safety and immunogenicity of 4 intramuscular double doses and 4 intradermal low doses vs standard hepatitis B vaccine regimen in adults with HIV-1: a randomized controlled trial. JAMA. 2011 Apr 13;305(14):1432-40. doi: 10.1001/jama.2011.351."
#             }
#           ]
#         }
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT01095744",
#           "briefTitle": "Influence of Age on Amyloid Load in Alzheimer's Disease and in Atypical Focal Cortical Alzheimer's Disease"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2009-03"
#           },
#           "completionDateStruct": {
#             "date": "2012-05"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2010-03-30"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France"
#           }
#         },
#         "designModule": {
#           "studyType": "OBSERVATIONAL"
#         }
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT01489592",
#           "briefTitle": "Effect of Curcumin on Iron Metabolism in Healthy Volunteer"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2011-10"
#           },
#           "completionDateStruct": {
#             "date": "2012-03"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2011-12-09"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France"
#           }
#         },
#         "designModule": {
#           "studyType": "INTERVENTIONAL"
#         },
#         "referencesModule": {
#           "references": [
#             {
#               "pmid": "20169331",
#               "type": "BACKGROUND",
#               "citation": "Fatih N, Camberlein E, Island ML, Corlu A, Abgueguen E, Detivaud L, Leroyer P, Brissot P, Loreal O. Natural and synthetic STAT3 inhibitors reduce hepcidin expression in differentiated mouse hepatocytes expressing the active phosphorylated STAT3 form. J Mol Med (Berl). 2010 May;88(5):477-86. doi: 10.1007/s00109-009-0588-3. Epub 2010 Feb 19."
#             },
#             {
#               "pmid": "15974953",
#               "type": "BACKGROUND",
#               "citation": "Loreal O, Haziza-Pigeon C, Troadec MB, Detivaud L, Turlin B, Courselaud B, Ilyin G, Brissot P. Hepcidin in iron metabolism. Curr Protein Pept Sci. 2005 Jun;6(3):279-91. doi: 10.2174/1389203054065392."
#             },
#             {
#               "pmid": "16946298",
#               "type": "BACKGROUND",
#               "citation": "Verga Falzacappa MV, Vujic Spasic M, Kessler R, Stolte J, Hentze MW, Muckenthaler MU. STAT3 mediates hepatic hepcidin expression and its inflammatory stimulation. Blood. 2007 Jan 1;109(1):353-8. doi: 10.1182/blood-2006-07-033969. Epub 2006 Aug 31."
#             },
#             {
#               "pmid": "15501961",
#               "type": "BACKGROUND",
#               "citation": "Sharma RA, Euden SA, Platton SL, Cooke DN, Shafayat A, Hewitt HR, Marczylo TH, Morgan B, Hemingway D, Plummer SM, Pirmohamed M, Gescher AJ, Steward WP. Phase I clinical trial of oral curcumin: biomarkers of systemic activity and compliance. Clin Cancer Res. 2004 Oct 15;10(20):6847-54. doi: 10.1158/1078-0432.CCR-04-0744."
#             },
#             {
#               "pmid": "18559556",
#               "type": "BACKGROUND",
#               "citation": "Vareed SK, Kakarala M, Ruffin MT, Crowell JA, Normolle DP, Djuric Z, Brenner DE. Pharmacokinetics of curcumin conjugate metabolites in healthy human subjects. Cancer Epidemiol Biomarkers Prev. 2008 Jun;17(6):1411-7. doi: 10.1158/1055-9965.EPI-07-2693."
#             }
#           ]
#         }
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT01453192",
#           "briefTitle": "Renal Transplantation and Raltegravir in HIV-Infected Patients"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2011-12"
#           },
#           "completionDateStruct": {
#             "date": "2015-11"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2011-10-17"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "ANRS, Emerging Infectious Diseases"
#           },
#           "collaborators": [
#             {
#               "name": "Merck Sharp & Dohme LLC"
#             }
#           ]
#         },
#         "designModule": {
#           "studyType": "INTERVENTIONAL"
#         },
#         "referencesModule": {}
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT00460382",
#           "briefTitle": "Clinical Trial to Assess the Efficacy of Darunavir/Ritonavir (DRV/r), Etravirine (ETV) and Raltegravir (MK-0518) in HIV Patients With Resistant Viruses"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2007-05"
#           },
#           "completionDateStruct": {
#             "date": "2009-09"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2007-04-13"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "French National Agency for Research on AIDS and Viral Hepatitis"
#           },
#           "collaborators": [
#             {
#               "name": "Merck Sharp & Dohme LLC"
#             },
#             {
#               "name": "Janssen-Cilag Tibotec"
#             }
#           ]
#         },
#         "designModule": {
#           "studyType": "INTERVENTIONAL"
#         }
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT02486731",
#           "briefTitle": "Hormonal Sensitivity in Patients With Noonan and LEOPARD Syndromes"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2015-12-16"
#           },
#           "completionDateStruct": {
#             "date": "2018-12"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2015-07-01"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France"
#           }
#         },
#         "designModule": {
#           "studyType": "OBSERVATIONAL"
#         }
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT02116374",
#           "briefTitle": "Physiopathology Study of the Microbiota Biodiversity of HIV Seropositive Patients"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2014-12"
#           },
#           "completionDateStruct": {
#             "date": "2016-06"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2014-04-16"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "ANRS, Emerging Infectious Diseases"
#           }
#         },
#         "designModule": {
#           "studyType": "OBSERVATIONAL"
#         }
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT02497274",
#           "briefTitle": "Obesity and Lipids: a Matter of Taste?"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2016-01-11"
#           },
#           "completionDateStruct": {
#             "date": "2019-01"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2015-07-14"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France"
#           }
#         },
#         "designModule": {
#           "studyType": "INTERVENTIONAL"
#         }
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT01022476",
#           "briefTitle": "Raltegravir in Patients With End Stage Liver Disease and in Transplant Recipients"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2010-05"
#           },
#           "completionDateStruct": {
#             "date": "2013-05"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2009-12-01"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "ANRS, Emerging Infectious Diseases"
#           },
#           "collaborators": [
#             {
#               "name": "Merck Sharp & Dohme LLC"
#             }
#           ]
#         },
#         "designModule": {
#           "studyType": "INTERVENTIONAL"
#         },
#         "referencesModule": {}
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT00528060",
#           "briefTitle": "Measure of Pharmacokinetic Parameters and Adherence With MEMS in Naive HIV Infected Patients Treated With Reyataz Once Daily Combined With Norvir and Truvada"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2008-01"
#           },
#           "completionDateStruct": {
#             "date": "2008-11"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2007-09-11"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "French National Agency for Research on AIDS and Viral Hepatitis"
#           },
#           "collaborators": [
#             {
#               "name": "Bristol-Myers Squibb"
#             },
#             {
#               "name": "Gilead Sciences"
#             }
#           ]
#         },
#         "designModule": {
#           "studyType": "INTERVENTIONAL"
#         },
#         "referencesModule": {
#           "references": [
#             {
#               "pmid": "23459496",
#               "type": "DERIVED",
#               "citation": "Parienti JJ, Barrail-Tran A, Duval X, Nembot G, Descamps D, Vigan M, Vrijens B, Panhard X, Taburet AM, Mentre F, Goujard C. Adherence profiles and therapeutic responses of treatment-naive HIV-infected patients starting boosted atazanavir-based therapy in the ANRS 134-COPHAR 3 trial. Antimicrob Agents Chemother. 2013 May;57(5):2265-71. doi: 10.1128/AAC.02605-12. Epub 2013 Mar 4."
#             }
#           ]
#         }
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT02078076",
#           "briefTitle": "IRM Cardiaque en Respiration Libre Pour Des Patients Atteints de Dystrophinopathie s\u00e9v\u00e8re"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2013-06"
#           },
#           "completionDateStruct": {
#             "date": "2015-11"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2014-03-05"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France"
#           }
#         },
#         "designModule": {
#           "studyType": "INTERVENTIONAL"
#         }
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT04008927",
#           "briefTitle": "A Community-based Intervention Among Active Drug Users in Montpellier"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2020-09-18"
#           },
#           "completionDateStruct": {
#             "date": "2021-09-10"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2019-07-05"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "ANRS, Emerging Infectious Diseases"
#           }
#         },
#         "designModule": {
#           "studyType": "INTERVENTIONAL"
#         },
#         "referencesModule": {
#           "references": [
#             {
#               "pmid": "27168667",
#               "type": "BACKGROUND",
#               "citation": "Blackburn NA, Patel RC, Zibbell JE. Improving Screening Methods for Hepatitis C Among People Who Inject Drugs: Findings from the HepTLC Initiative, 2012-2014. Public Health Rep. 2016 May-Jun;131 Suppl 2(Suppl 2):91-7. doi: 10.1177/00333549161310S214."
#             },
#             {
#               "pmid": "26806260",
#               "type": "BACKGROUND",
#               "citation": "Chevaliez S, Poiteau L, Rosa I, Soulier A, Roudot-Thoraval F, Laperche S, Hezode C, Pawlotsky JM. Prospective assessment of rapid diagnostic tests for the detection of antibodies to hepatitis C virus, a tool for improving access to care. Clin Microbiol Infect. 2016 May;22(5):459.e1-6. doi: 10.1016/j.cmi.2016.01.009. Epub 2016 Jan 22."
#             },
#             {
#               "pmid": "22310560",
#               "type": "BACKGROUND",
#               "citation": "Curran GM, Bauer M, Mittman B, Pyne JM, Stetler C. Effectiveness-implementation hybrid designs: combining elements of clinical effectiveness and implementation research to enhance public health impact. Med Care. 2012 Mar;50(3):217-26. doi: 10.1097/MLR.0b013e3182408812."
#             },
#             {
#               "pmid": "29432973",
#               "type": "BACKGROUND",
#               "citation": "Des Jarlais D, Khue PM, Feelemyer J, Arasteh K, Thi Huong D, Thi Hai Oanh K, Thi Giang H, Thi Tuyet Thanh N, Vinh VH, Heckathorn DD, Moles JP, Vallo R, Quillet C, Rapoud D, Michel L, Laureillard D, Hammett T, Nagot N. Using dual capture/recapture studies to estimate the population size of persons who inject drugs (PWID) in the city of Hai Phong, Vietnam. Drug Alcohol Depend. 2018 Apr 1;185:106-111. doi: 10.1016/j.drugalcdep.2017.11.033. Epub 2018 Feb 2."
#             },
#             {
#               "pmid": "27178119",
#               "type": "BACKGROUND",
#               "citation": "Des Jarlais D, Duong HT, Pham Minh K, Khuat OH, Nham TT, Arasteh K, Feelemyer J, Heckathorn DD, Peries M, Moles JP, Laureillard D, Nagot N; (The Drive Study Team). Integrated respondent-driven sampling and peer support for persons who inject drugs in Haiphong, Vietnam: a case study with implications for interventions. AIDS Care. 2016 Oct;28(10):1312-5. doi: 10.1080/09540121.2016.1178698. Epub 2016 May 13."
#             },
#             {
#               "pmid": "27537841",
#               "type": "BACKGROUND",
#               "citation": "Dore GJ, Altice F, Litwin AH, Dalgard O, Gane EJ, Shibolet O, Luetkemeyer A, Nahass R, Peng CY, Conway B, Grebely J, Howe AY, Gendrano IN, Chen E, Huang HC, Dutko FJ, Nickle DC, Nguyen BY, Wahl J, Barr E, Robertson MN, Platt HL; C-EDGE CO-STAR Study Group. Elbasvir-Grazoprevir to Treat Hepatitis C Virus Infection in Persons Receiving Opioid Agonist Therapy: A Randomized Trial. Ann Intern Med. 2016 Nov 1;165(9):625-634. doi: 10.7326/M16-0816. Epub 2016 Aug 9."
#             },
#             {
#               "pmid": "28004616",
#               "type": "BACKGROUND",
#               "citation": "Leon L, Kasereka S, Barin F, Larsen C, Weill-Barillet L, Pascal X, Chevaliez S, Pillonel J, Jauffret-Roustide M, LE Strat Y. Age- and time-dependent prevalence and incidence of hepatitis C virus infection in drug users in France, 2004-2011: model-based estimation from two national cross-sectional serosurveys. Epidemiol Infect. 2017 Apr;145(5):895-907. doi: 10.1017/S0950268816002934. Epub 2016 Dec 22."
#             },
#             {
#               "pmid": "35774932",
#               "type": "DERIVED",
#               "citation": "Nagot N, D'Ottavi M, Quillet C, Debellefontaine A, Castellani J, Langendorfer N, Hanslik B, Guichard S, Baglioni R, Faucherre V, Tuaillon E, Pageaux GP, Laureillard D, Donnadieu-Rigole H. Reaching Hard-to-Reach People Who Use Drugs: A Community-Based Strategy for the Elimination of Hepatitis C. Open Forum Infect Dis. 2022 Apr 14;9(6):ofac181. doi: 10.1093/ofid/ofac181. eCollection 2022 Jun."
#             }
#           ]
#         }
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT01331876",
#           "briefTitle": "Modification of Cerebral Activity of Obsessive Compulsive Disorder (OCD) Patients During Cognitive and Behavioral Therapy"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2009-10"
#           },
#           "completionDateStruct": {
#             "date": "2012-07"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2011-04-08"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France"
#           }
#         },
#         "designModule": {
#           "studyType": "INTERVENTIONAL"
#         }
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT00820820",
#           "briefTitle": "IDA (Immunoth\u00e9rapie de la Dermatite Atopique) Adult - Immunotherapy in Atopic Dermatitis"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2009-01-09"
#           },
#           "completionDateStruct": {
#             "date": "2012-03-26"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2009-01-12"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France"
#           },
#           "collaborators": [
#             {
#               "name": "Ministry of Health, France"
#             }
#           ]
#         },
#         "designModule": {
#           "studyType": "INTERVENTIONAL"
#         }
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT02273765",
#           "briefTitle": "Raltegravir Versus Efavirenz in Naive HIV-1-infected Patients Receiving Rifampin for Active Tuberculosis"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2015-09-11"
#           },
#           "completionDateStruct": {
#             "date": "2018-11-28"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2014-10-24"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "ANRS, Emerging Infectious Diseases"
#           },
#           "collaborators": [
#             {
#               "name": "Merck Sharp & Dohme LLC"
#             },
#             {
#               "name": "Ministry of Health, Brazil"
#             }
#           ]
#         },
#         "designModule": {
#           "studyType": "INTERVENTIONAL"
#         },
#         "referencesModule": {
#           "references": [
#             {
#               "pmid": "33667406",
#               "type": "DERIVED",
#               "citation": "De Castro N, Marcy O, Chazallon C, Messou E, Eholie S, N'takpe JB, Bhatt N, Khosa C, Timana Massango I, Laureillard D, Chau GD, Domergue A, Veloso V, Escada R, Wagner Cardoso S, Delaugerre C, Anglaret X, Molina JM, Grinsztejn B; ANRS 12300 Reflate TB2 study group. Standard dose raltegravir or efavirenz-based antiretroviral treatment for patients co-infected with HIV and tuberculosis (ANRS 12 300 Reflate TB 2): an open-label, non-inferiority, randomised, phase 3 trial. Lancet Infect Dis. 2021 Jun;21(6):813-822. doi: 10.1016/S1473-3099(20)30869-0. Epub 2021 Mar 2."
#             }
#           ]
#         }
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT02107365",
#           "briefTitle": "Therapy With Asunaprevir, Daclatasvir, Ribavirin and Pegylated Interferon Alpha-2a in HCV Genotype 4-infected Patients Who Have Failed to a Previous Therapy With Peg-Interferon/Ribavirin (ANRS HC32 QUATTRO)"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2013-11"
#           },
#           "completionDateStruct": {
#             "date": "2015-04"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2014-04-08"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "ANRS, Emerging Infectious Diseases"
#           },
#           "collaborators": [
#             {
#               "name": "Bristol-Myers Squibb"
#             }
#           ]
#         },
#         "designModule": {
#           "studyType": "INTERVENTIONAL"
#         }
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT00113282",
#           "briefTitle": "Efficacy of Adding Interleukin-2 to an Optimized Antiretroviral Regimen in HIV Patients in Therapeutic Failure (ANRS123)"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2004-06"
#           },
#           "completionDateStruct": {
#             "date": "2008-02"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2005-06-08"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "French National Agency for Research on AIDS and Viral Hepatitis"
#           },
#           "collaborators": [
#             {
#               "name": "Chiron Corporation"
#             }
#           ]
#         },
#         "designModule": {
#           "studyType": "INTERVENTIONAL"
#         }
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT01055873",
#           "briefTitle": "Immunology of the Infection Perinatal"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2007-02"
#           },
#           "completionDateStruct": {
#             "date": "2009-02"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2010-01-26"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "French National Agency for Research on AIDS and Viral Hepatitis"
#           },
#           "collaborators": [
#             {
#               "name": "Institut Pasteur"
#             },
#             {
#               "name": "University of Paris 5 - Rene Descartes"
#             },
#             {
#               "name": "H\u00f4pital Necker-Enfants Malades"
#             }
#           ]
#         },
#         "designModule": {
#           "studyType": "OBSERVATIONAL"
#         },
#         "referencesModule": {
#           "references": [
#             {
#               "pmid": "22427678",
#               "type": "DERIVED",
#               "citation": "Avettand-Fenoel V, Blanche S, Le Chenadec J, Scott-Algara D, Dollfus C, Viard JP, Bouallag N, Benmebarek Y, Riviere Y, Warszawski J, Rouzioux C, Buseyne F. Relationships between HIV disease history and blood HIV-1 DNA load in perinatally infected adolescents and young adults: the ANRS-EP38-IMMIP study. J Infect Dis. 2012 May 15;205(10):1520-8. doi: 10.1093/infdis/jis233. Epub 2012 Mar 15."
#             }
#           ]
#         }
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT05199831",
#           "briefTitle": "Situational Analysis of HIV-related Disability in the Context of Ivory Coast"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2021-02-05"
#           },
#           "completionDateStruct": {
#             "date": "2022-08-10"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2022-01-20"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "Programme PAC-CI, Site ANRS-MIE de C\u00f4te d'Ivoire"
#           },
#           "collaborators": [
#             {
#               "name": "Institute of Research for Development, France"
#             },
#             {
#               "name": "Institut de Sante Publique, d'Epidemiologie et de Developpement"
#             },
#             {
#               "name": "University of Toronto"
#             },
#             {
#               "name": "Universit\u00e9 de Lille"
#             }
#           ]
#         },
#         "designModule": {
#           "studyType": "OBSERVATIONAL"
#         }
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT01359774",
#           "briefTitle": "31P-MRS and Huntington Disease"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2011-04"
#           },
#           "completionDateStruct": {
#             "date": "2012-04"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2011-05-25"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France"
#           }
#         },
#         "designModule": {
#           "studyType": "INTERVENTIONAL"
#         },
#         "referencesModule": {
#           "references": [
#             {
#               "pmid": "21285522",
#               "type": "BACKGROUND",
#               "citation": "Mochel F, Haller RG. Energy deficit in Huntington disease: why it matters. J Clin Invest. 2011 Feb;121(2):493-9. doi: 10.1172/JCI45691. Epub 2011 Feb 1."
#             },
#             {
#               "pmid": "17653274",
#               "type": "BACKGROUND",
#               "citation": "Mochel F, Charles P, Seguin F, Barritault J, Coussieu C, Perin L, Le Bouc Y, Gervais C, Carcelain G, Vassault A, Feingold J, Rabier D, Durr A. Early energy deficit in Huntington disease: identification of a plasma biomarker traceable during disease progression. PLoS One. 2007 Jul 25;2(7):e647. doi: 10.1371/journal.pone.0000647."
#             },
#             {
#               "pmid": "21320997",
#               "type": "BACKGROUND",
#               "citation": "Mochel F, Benaich S, Rabier D, Durr A. Validation of plasma branched chain amino acids as biomarkers in Huntington disease. Arch Neurol. 2011 Feb;68(2):265-7. doi: 10.1001/archneurol.2010.358. No abstract available."
#             }
#           ]
#         }
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT02099474",
#           "briefTitle": "Evaluation of Raltegravir During the Third Trimester of Pregnancy"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2014-06-30"
#           },
#           "completionDateStruct": {
#             "date": "2017-04"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2014-03-31"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "ANRS, Emerging Infectious Diseases"
#           }
#         },
#         "designModule": {
#           "studyType": "INTERVENTIONAL"
#         },
#         "referencesModule": {
#           "references": [
#             {
#               "pmid": "32661003",
#               "type": "DERIVED",
#               "citation": "Zheng Y, Hirt D, Delmas S, Lui G, Benaboud S, Lechedanec J, Treluyer JM, Chenevier-Gobeaux C, Arezes E, Gelley A, Amri I, Urien S, Bouazza N, Foissac F, Warszawski J, Ghosn J. Effect of Pregnancy on Unbound Raltegravir Concentrations in the ANRS 160 RalFe Trial. Antimicrob Agents Chemother. 2020 Sep 21;64(10):e00759-20. doi: 10.1128/AAC.00759-20. Print 2020 Sep 21."
#             }
#           ]
#         }
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT03546127",
#           "briefTitle": "Molecular Profiling to Improve Outcome of Patients in Cancer. A Pilot Study"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2017-05-23"
#           },
#           "completionDateStruct": {
#             "date": "2017-09-21"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2018-06-06"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France"
#           },
#           "collaborators": [
#             {
#               "name": "Institut Bergoni\u00e9"
#             },
#             {
#               "name": "Plateforme labellis\u00e9e Inca - Institut Bergoni\u00e9, Bordeaux"
#             },
#             {
#               "name": "Plateforme labellis\u00e9e Inca - H\u00f4pital Europ\u00e9en Georges Pompidou, Paris"
#             },
#             {
#               "name": "CNRGH, Evry"
#             },
#             {
#               "name": "EUCLID Clinical Trial Platform"
#             }
#           ]
#         },
#         "designModule": {
#           "studyType": "OBSERVATIONAL"
#         }
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT04315948",
#           "briefTitle": "Trial of Treatments for COVID-19 in Hospitalized Adults"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2020-03-22"
#           },
#           "completionDateStruct": {
#             "date": "2023-09-25"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2020-03-20"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France"
#           }
#         },
#         "designModule": {
#           "studyType": "INTERVENTIONAL"
#         },
#         "referencesModule": {
#           "references": [
#             {
#               "pmid": "32958495",
#               "type": "BACKGROUND",
#               "citation": "Ader F; Discovery French Trial Management Team. Protocol for the DisCoVeRy trial: multicentre, adaptive, randomised trial of the safety and efficacy of treatments for COVID-19 in hospitalised adults. BMJ Open. 2020 Sep 21;10(9):e041437. doi: 10.1136/bmjopen-2020-041437."
#             },
#             {
#               "pmid": "34763056",
#               "type": "BACKGROUND",
#               "citation": "EU-Response investigators group; Diallo A, Troseid M, Simensen VC, Boston A, Demotes J, Olsen IC, Chung F, Paiva JA, Hites M, Ader F, Arribas JR, Baratt-Due A, Melien O, Tacconelli E, Staub T, Greil R, Tsiodras S, Briel M, Esperou H, Mentre F, Eustace J, Saillard J, Delmas C, LeMestre S, Dumousseaux M, Costagliola D, Rottingen JA, Yazdanpanah Y. Accelerating clinical trial implementation in the context of the COVID-19 pandemic: challenges, lessons learned and recommendations from DisCoVeRy and the EU-SolidAct EU response group. Clin Microbiol Infect. 2022 Jan;28(1):1-5. doi: 10.1016/j.cmi.2021.10.011. Epub 2021 Nov 8. No abstract available."
#             },
#             {
#               "pmid": "35623577",
#               "type": "BACKGROUND",
# ...
#             },
#             {
#               "pmid": "24780882",
#               "type": "DERIVED",
#               "citation": "Tezenas du Montcel S, Durr A, Rakowicz M, Nanetti L, Charles P, Sulek A, Mariotti C, Rola R, Schols L, Bauer P, Dufaure-Gare I, Jacobi H, Forlani S, Schmitz-Hubsch T, Filla A, Timmann D, van de Warrenburg BP, Marelli C, Kang JS, Giunti P, Cook A, Baliko L, Melegh B, Boesch S, Szymanski S, Berciano J, Infante J, Buerk K, Masciullo M, Di Fabio R, Depondt C, Ratka S, Stevanin G, Klockgether T, Brice A, Golmard JL. Prediction of the age at onset in spinocerebellar ataxia type 1, 2, 3 and 6. J Med Genet. 2014 Jul;51(7):479-86. doi: 10.1136/jmedgenet-2013-102200. Epub 2014 Apr 29. Erratum In: J Med Genet. 2014 Sep;51(9):613. Bela, Melegh [corrected to Melegh, Bela]."
#             },
#             {
#               "pmid": "23707147",
#               "type": "DERIVED",
#               "citation": "Jacobi H, Reetz K, du Montcel ST, Bauer P, Mariotti C, Nanetti L, Rakowicz M, Sulek A, Durr A, Charles P, Filla A, Antenora A, Schols L, Schicks J, Infante J, Kang JS, Timmann D, Di Fabio R, Masciullo M, Baliko L, Melegh B, Boesch S, Burk K, Peltz A, Schulz JB, Dufaure-Gare I, Klockgether T. Biological and clinical characteristics of individuals at risk for spinocerebellar ataxia types 1, 2, 3, and 6 in the longitudinal RISCA study: analysis of baseline data. Lancet Neurol. 2013 Jul;12(7):650-8. doi: 10.1016/S1474-4422(13)70104-2. Epub 2013 May 22. Erratum In: Lancet Neurol. 2013 Jul;12(7):630."
#             }
#           ]
#         }
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT01842477",
#           "briefTitle": "Evaluation of Efficacy and Safety of Autologous MSCs Combined to Biomaterials to Enhance Bone Healing"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2013-05"
#           },
#           "completionDateStruct": {
#             "date": "2016-02-05"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2013-04-29"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France"
#           }
#         },
#         "designModule": {
#           "studyType": "INTERVENTIONAL"
#         },
#         "referencesModule": {}
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT02721745",
#           "briefTitle": "Cause and Consequence of Neural Fatigue"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2016-05-23"
#           },
#           "completionDateStruct": {
#             "date": "2020-12"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2016-03-29"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France"
#           }
#         },
#         "designModule": {
#           "studyType": "INTERVENTIONAL"
#         }
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT02408354",
#           "briefTitle": "Pilot Study, Comparative, Single-center, Randomized, Crossover, Double-blind, Against Placebo, Testing the Effectiveness of Triheptanoin Oil in Alternating Hemiplegia of Childhood"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2015-04-15"
#           },
#           "completionDateStruct": {
#             "date": "2017-04-05"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2015-04-03"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France"
#           }
#         },
#         "designModule": {
#           "studyType": "INTERVENTIONAL"
#         },
#         "referencesModule": {
#           "references": [
#             {
#               "pmid": "28969699",
#               "type": "DERIVED",
#               "citation": "Hainque E, Caillet S, Leroy S, Flamand-Roze C, Adanyeguh I, Charbonnier-Beaupel F, Retail M, Le Toullec B, Atencio M, Rivaud-Pechoux S, Brochard V, Habarou F, Ottolenghi C, Cormier F, Meneret A, Ruiz M, Doulazmi M, Roubergue A, Corvol JC, Vidailhet M, Mochel F, Roze E. A randomized, controlled, double-blind, crossover trial of triheptanoin in alternating hemiplegia of childhood. Orphanet J Rare Dis. 2017 Oct 2;12(1):160. doi: 10.1186/s13023-017-0713-2."
#             }
#           ]
#         }
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT01688453",
#           "briefTitle": "Overweight Management and Social Inequalities"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2012-04"
#           },
#           "completionDateStruct": {
#             "date": "2015-11"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2012-09-19"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France"
#           }
#         },
#         "designModule": {
#           "studyType": "INTERVENTIONAL"
#         },
#         "referencesModule": {
#           "references": [
#             {
#               "pmid": "34087324",
#               "type": "DERIVED",
#               "citation": "Manneville F, Omorou AY, Legrand K, Lecomte E, Rydberg JA, Briancon S, Guillemin F; PRALIMAP Trial Group. Sociodemographic and psychological characteristics associated with discrepancy between body satisfaction and weight change among adolescents. Prev Med. 2021 Sep;150:106668. doi: 10.1016/j.ypmed.2021.106668. Epub 2021 Jun 1."
#             },
#             {
#               "pmid": "32097754",
#               "type": "DERIVED",
#               "citation": "Omorou AY, Manneville F, Langlois J, Legrand K, Bohme P, Muller L, Guillemin F, Briancon S, Lecomte E; PRALIMAP-INES Trial Group. Physical activity rather than sedentary behaviour is socially determined in French adolescents with overweight and obesity. Prev Med. 2020 May;134:106043. doi: 10.1016/j.ypmed.2020.106043. Epub 2020 Feb 22."
#             },
#             {
#               "pmid": "29934380",
#               "type": "DERIVED",
#               "citation": "Saez L, Legrand K, Alleyrat C, Ramisasoa S, Langlois J, Muller L, Omorou AY, De Lavenne R, Kivits J, Lecomte E, Briancon S; PRALIMAP-INES Trial Group. Using facilitator-receiver peer dyads matched according to socioeconomic status to promote behaviour change in overweight adolescents: a feasibility study. BMJ Open. 2018 Jun 22;8(6):e019731. doi: 10.1136/bmjopen-2017-019731."
#             },
#             {
#               "pmid": "29776897",
#               "type": "DERIVED",
#               "citation": "Saez L, Langlois J, Legrand K, Quinet MH, Lecomte E, Omorou AY, Briancon S; PRALIMAP-INES Trial Group. Reach and Acceptability of a Mobile Reminder Strategy and Facebook Group Intervention for Weight Management in Less Advantaged Adolescents: Insights From the PRALIMAP-INES Trial. JMIR Mhealth Uhealth. 2018 May 18;6(5):e110. doi: 10.2196/mhealth.7657."
#             },
#             {
#               "pmid": "29696179",
#               "type": "DERIVED",
#               "citation": "Legrand K, Lecomte E, Langlois J, Muller L, Saez L, Quinet MH, Bohme P, Spitz E, Omorou AY, Briancon S; PRALIMAP-INES trial group. Reducing social inequalities in access to overweight and obesity care management for adolescents: The PRALIMAP-INES trial protocol and inclusion data analysis. Contemp Clin Trials Commun. 2017 Jun 16;7:141-157. doi: 10.1016/j.conctc.2017.05.010. eCollection 2017 Sep."
#             }
#           ]
#         }
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT02172677",
#           "briefTitle": "The Influence of Collective Schemas on Individual Memory"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2014-10"
#           },
#           "completionDateStruct": {
#             "date": "2016-10-14"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2014-06-24"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France"
#           },
#           "collaborators": [
#             {
#               "name": "La R\u00e9gion Basse-Normandie"
#             },
#             {
#               "name": "Universit\u00e9 de Caen Normandie"
#             },
#             {
#               "name": "University Hospital, Caen"
#             },
#             {
#               "name": "Ecole Pratique des Hautes Etudes"
#             },
#             {
#               "name": "Equipement d'Excellence Matrice"
#             }
#           ]
#         },
#         "designModule": {
#           "studyType": "INTERVENTIONAL"
#         }
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT01880151",
#           "briefTitle": "Neuroelectrical Biomarkers for Alzheimer's Disease Stages"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2013-07-12"
#           },
#           "completionDateStruct": {
#             "date": "2019-01"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2013-06-18"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France"
#           }
#         },
#         "designModule": {
#           "studyType": "INTERVENTIONAL"
#         }
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT02658253",
#           "briefTitle": "Trial to Evaluate the Safety and Immunogenicity of a Placental Malaria Vaccine Candidate (PRIMVAC ) in Healthy Adults"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2016-01"
#           },
#           "completionDateStruct": {
#             "date": "2019-02-21"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2016-01-18"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France"
#           },
#           "collaborators": [
#             {
#               "name": "EVI Industries, Inc."
#             },
#             {
#               "name": "Recherche Clinique Paris Descartes Necker Cochin Sainte Anne"
#             },
#             {
#               "name": "Centre national de recherche et de formation sur le paludisme"
#             },
#             {
#               "name": "EUCLID Clinical Trial Platform"
#             }
#           ]
#         },
#         "designModule": {
#           "studyType": "INTERVENTIONAL"
#         },
#         "referencesModule": {
#           "references": [
#             {
#               "pmid": "33717176",
#               "type": "DERIVED",
#               "citation": "Gamain B, Chene A, Viebig NK, Tuikue Ndam N, Nielsen MA. Progress and Insights Toward an Effective Placental Malaria Vaccine. Front Immunol. 2021 Feb 25;12:634508. doi: 10.3389/fimmu.2021.634508. eCollection 2021."
#             },
#             {
#               "pmid": "32032566",
#               "type": "DERIVED",
#               "citation": "Sirima SB, Richert L, Chene A, Konate AT, Campion C, Dechavanne S, Semblat JP, Benhamouda N, Bahuaud M, Loulergue P, Ouedraogo A, Nebie I, Kabore M, Kargougou D, Barry A, Ouattara SM, Boilet V, Allais F, Roguet G, Havelange N, Lopez-Perez E, Kuppers A, Konate E, Roussillon C, Kante M, Belarbi L, Diarra A, Henry N, Soulama I, Ouedraogo A, Esperou H, Leroy O, Batteux F, Tartour E, Viebig NK, Thiebaut R, Launay O, Gamain B. PRIMVAC vaccine adjuvanted with Alhydrogel or GLA-SE to prevent placental malaria: a first-in-human, randomised, double-blind, placebo-controlled study. Lancet Infect Dis. 2020 May;20(5):585-597. doi: 10.1016/S1473-3099(19)30739-X. Epub 2020 Feb 4."
#             }
#           ]
#         }
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT02027051",
#           "briefTitle": "Etude g\u00e9n\u00e9tique Des Arm\u00e9niens"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2014-01"
#           },
#           "completionDateStruct": {
#             "date": "2017-01"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2014-01-03"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France"
#           }
#         },
#         "designModule": {
#           "studyType": "OBSERVATIONAL"
#         }
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT00118677",
#           "briefTitle": "Long-Term Supervised Treatment Interruption in HIV-Infected Patients"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2003-02"
#           },
#           "completionDateStruct": {
#             "date": "2007-05"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2005-07-12"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "French National Agency for Research on AIDS and Viral Hepatitis"
#           }
#         },
#         "designModule": {
#           "studyType": "INTERVENTIONAL"
#         },
#         "referencesModule": {
#           "references": [
#             {
#               "pmid": "20657770",
#               "type": "DERIVED",
#               "citation": "Weiss L, Piketty C, Assoumou L, Didier C, Caccavelli L, Donkova-Petrini V, Levy Y, Girard PM, Burgard M, Viard JP, Rouzioux C, Costagliola D; ANRS 116 SALTO study group. Relationship between regulatory T cells and immune activation in human immunodeficiency virus-infected patients interrupting antiretroviral therapy. PLoS One. 2010 Jul 21;5(7):e11659. doi: 10.1371/journal.pone.0011659."
#             }
#           ]
#         }
#       },
#       "hasResults": false
#     },
#     {
#       "protocolSection": {
#         "identificationModule": {
#           "nctId": "NCT00647205",
#           "briefTitle": "Evaluation of 2 Interferon \u03b3 Assays in the Diagnosis of Latent Tuberculosis in HIV-infected Patients.ANRS EP 40 QUANTI SPOT"
#         },
#         "statusModule": {
#           "overallStatus": "COMPLETED",
#           "startDateStruct": {
#             "date": "2008-01"
#           },
#           "completionDateStruct": {
#             "date": "2010-11"
#           },
#           "studyFirstPostDateStruct": {
#             "date": "2008-03-31"
#           }
#         },
#         "sponsorCollaboratorsModule": {
#           "leadSponsor": {
#             "name": "French National Agency for Research on AIDS and Viral Hepatitis"
#           }
#         },
#         "designModule": {
#           "studyType": "INTERVENTIONAL"
#         }
#       },
#       "hasResults": false
#     }
#   ]
# }

# %% [markdown]
# ***La structure du JSON est bien trop imbriquée pour le normaliser avec Pandas, du coup on l'applatit à la main:***

# %% [markdown]
# A partir du JSON on construit un dictionnaire équivalent mais beaucoup plus "plat"

# %%
# Si la liste des collaborateurs est vide on renvoie None, sinon on concatène les valeurs de la liste
# sous la forme "collaborateur_0 | collaborateur_1 | ..."
def concatenate_collaborator_list(collaborator_list):
    if collaborator_list == []:
        return None
    else:
        return ' | '.join(collaborator_list)

# %%
studies_list = []
for study in response.json()['studies']:
    study_dict = {
        'NCTId': study['protocolSection']['identificationModule']['nctId'],
        'BriefTitle': study['protocolSection']['identificationModule']['briefTitle'],
        'LeadSponsorName': study['protocolSection']['sponsorCollaboratorsModule']['leadSponsor']['name'],
        'CollaboratorName': concatenate_collaborator_list(
            [
                c['name']
                for c in (
                    study['protocolSection']['sponsorCollaboratorsModule'].get('collaborators', [])  # can be missing
                )
            ]
        ),
        'OverallStatus': study['protocolSection']['statusModule']['overallStatus'],
        'StudyType': study['protocolSection']['designModule']['studyType'],
        'HasResults': study['hasResults'],
        'StudyFirstPostDate': study['protocolSection']['statusModule']['studyFirstPostDateStruct']['date'],
        'StartDate': study['protocolSection']['statusModule'].get('startDateStruct', {}).get('date', None),  # can be missing
        # 'PrimaryCompletionDate' : study["protocolSection"]["statusModule"].get('primaryCompletionDateStruct', {}).get('date', None), # can be missing
        'CompletionDate': study['protocolSection']['statusModule'].get('completionDateStruct', {}).get('date', None),  # can be missing
        'Reference': study['protocolSection'].get('referencesModule', {}).get('references', []),  # can be missing
    }
    studies_list.append(study_dict)

print(json.dumps(studies_list, indent=2))
# Out:
# [
#   {
#     "NCTId": "NCT02014727",
#     "BriefTitle": "Safety and Immunogenicity of Recombinant Pichia Pastoris AMA1-DiCo Candidate Malaria Vaccine With GLA-SE and Alhydrogel \u00ae as Adjuvant in Healthy Malaria Non-Exposed European and Malaria Exposed African Adults",
#     "LeadSponsorName": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France",
#     "CollaboratorName": "EVI Industries, Inc. | BPRC | Recherche Clinique Paris Descartes Necker Cochin Sainte Anne | Centre national de recherche et de formation sur le paludisme",
#     "OverallStatus": "COMPLETED",
#     "StudyType": "INTERVENTIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2013-12-18",
#     "StartDate": "2014-01",
#     "CompletionDate": "2015-07",
#     "Reference": [
#       {
#         "pmid": "28947345",
#         "type": "DERIVED",
#         "citation": "Sirima SB, Durier C, Kara L, Houard S, Gansane A, Loulergue P, Bahuaud M, Benhamouda N, Nebie I, Faber B, Remarque E, Launay O; AMA1-DiCo Study Group. Safety and immunogenicity of a recombinant Plasmodium falciparum AMA1-DiCo malaria vaccine adjuvanted with GLA-SE or Alhydrogel(R) in European and African adults: A phase 1a/1b, randomized, double-blind multi-centre trial. Vaccine. 2017 Oct 27;35(45):6218-6227. doi: 10.1016/j.vaccine.2017.09.027. Epub 2017 Sep 22."
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT00117494",
#     "BriefTitle": "Rosuvastatin Versus Pravastatin in HIV Patients Treated With Boosted Protease Inhibitors (PI) (ANRS126)",
#     "LeadSponsorName": "French National Agency for Research on AIDS and Viral Hepatitis",
#     "CollaboratorName": null,
#     "OverallStatus": "COMPLETED",
#     "StudyType": "INTERVENTIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2005-07-07",
#     "StartDate": "2005-10",
#     "CompletionDate": "2007-06",
#     "Reference": [
#       {
#         "pmid": "22739396",
#         "type": "DERIVED",
#         "citation": "Bittar R, Giral P, Aslangul E, Assoumou L, Valantin MA, Kalmykova O, Federspiel MC, Cherfils C, Costagliola D, Bonnefont-Rousselot D; French National Agency for AIDS and Viral Hepatitis Research (ANRS) 126 study group. Effects of rosuvastatin versus pravastatin on low-density lipoprotein diameter in HIV-1-infected patients receiving ritonavir-boosted protease inhibitor. AIDS. 2012 Sep 10;26(14):1801-5. doi: 10.1097/QAD.0b013e328357063c."
#       },
#       {
#         "pmid": "22318219",
#         "type": "DERIVED",
#         "citation": "Bittar R, Giral P, Aslangul E, Assoumou L, Valantin MA, Kalmykova O, Fesel-Fouquier V, Costagliola D, Bonnefont-Rousselot D; ANRS 126 study group. Determinants of low-density lipoprotein particle diameter during antiretroviral therapy including protease inhibitors in HIV-1-infected patients. Antivir Ther. 2012;17(5):855-60. doi: 10.3851/IMP2065. Epub 2012 Feb 9."
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT00536627",
#     "BriefTitle": "Efficacy and Tolerance of Naked DNA Vaccine in Patients With Chronic B Hepatitis",
#     "LeadSponsorName": "French National Agency for Research on AIDS and Viral Hepatitis",
#     "CollaboratorName": null,
#     "OverallStatus": "COMPLETED",
#     "StudyType": "INTERVENTIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2007-09-28",
#     "StartDate": "2008-01",
#     "CompletionDate": "2010-11",
#     "Reference": [
#       {
#         "pmid": "16310901",
#         "type": "BACKGROUND",
#         "citation": "Mancini-Bourgine M, Fontaine H, Brechot C, Pol S, Michel ML. Immunogenicity of a hepatitis B DNA vaccine administered to chronic HBV carriers. Vaccine. 2006 May 22;24(21):4482-9. doi: 10.1016/j.vaccine.2005.08.013. Epub 2005 Aug 18."
#       },
#       {
#         "pmid": "15382173",
#         "type": "BACKGROUND",
#         "citation": "Mancini-Bourgine M, Fontaine H, Scott-Algara D, Pol S, Brechot C, Michel ML. Induction or expansion of T-cell responses by a hepatitis B DNA vaccine administered to chronic HBV carriers. Hepatology. 2004 Oct;40(4):874-82. doi: 10.1002/hep.20408."
#       },
#       {
#         "pmid": "24555998",
#         "type": "DERIVED",
#         "citation": "Fontaine H, Kahi S, Chazallon C, Bourgine M, Varaut A, Buffet C, Godon O, Meritet JF, Saidi Y, Michel ML, Scott-Algara D, Aboulker JP, Pol S; ANRS HB02 study group. Anti-HBV DNA vaccination does not prevent relapse after discontinuation of analogues in the treatment of chronic hepatitis B: a randomised trial--ANRS HB02 VAC-ADN. Gut. 2015 Jan;64(1):139-47. doi: 10.1136/gutjnl-2013-305707. Epub 2014 Feb 20."
#       },
#       {
#         "pmid": "24394187",
#         "type": "DERIVED",
#         "citation": "Godon O, Fontaine H, Kahi S, Meritet JF, Scott-Algara D, Pol S, Michel ML, Bourgine M; ANRS HB02 study group. Immunological and antiviral responses after therapeutic DNA immunization in chronic hepatitis B patients efficiently treated by analogues. Mol Ther. 2014 Mar;22(3):675-684. doi: 10.1038/mt.2013.274. Epub 2013 Dec 5."
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT01033760",
#     "BriefTitle": "Optimisation of Primary HIV1 Infection Treatment(ANRS 147 OPTIPRIM)",
#     "LeadSponsorName": "ANRS, Emerging Infectious Diseases",
#     "CollaboratorName": "Gilead Sciences | Merck Sharp & Dohme LLC | Pfizer | Janssen-Cilag Ltd.",
#     "OverallStatus": "COMPLETED",
#     "StudyType": "INTERVENTIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2009-12-16",
#     "StartDate": "2010-04",
#     "CompletionDate": "2013-12",
#     "Reference": [
#       {
#         "pmid": "28708873",
#         "type": "DERIVED",
#         "citation": "Cheret A, Durier C, Melard A, Ploquin M, Heitzmann J, Lecuroux C, Avettand-Fenoel V, David L, Pialoux G, Chennebault JM, Muller-Trutwin M, Goujard C, Rouzioux C, Meyer L; ANRS OPTIPRIM study group. Impact of early cART on HIV blood and semen compartments at the time of primary infection. PLoS One. 2017 Jul 14;12(7):e0180191. doi: 10.1371/journal.pone.0180191. eCollection 2017."
#       },
#       {
#         "pmid": "25701561",
#         "type": "DERIVED",
#         "citation": "Cheret A, Nembot G, Melard A, Lascoux C, Slama L, Miailhes P, Yeni P, Abel S, Avettand-Fenoel V, Venet A, Chaix ML, Molina JM, Katlama C, Goujard C, Tamalet C, Raffi F, Lafeuillade A, Reynes J, Ravaux I, Hoen B, Delfraissy JF, Meyer L, Rouzioux C; OPTIPRIM ANRS Study Group. Intensive five-drug antiretroviral therapy regimen versus standard triple-drug therapy during primary HIV-1 infection (OPTIPRIM-ANRS 147): a randomised, open-label, phase 3 trial. Lancet Infect Dis. 2015 Apr;15(4):387-96. doi: 10.1016/S1473-3099(15)70021-6. Epub 2015 Feb 18."
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT05349162",
#     "BriefTitle": "Epicardial vs. Transvenous ICDs in Children",
#     "LeadSponsorName": "Paris Cardiovascular Research Center (Inserm U970)",
#     "CollaboratorName": "H\u00f4pital Necker-Enfants Malades",
#     "OverallStatus": "COMPLETED",
#     "StudyType": "OBSERVATIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2022-04-27",
#     "StartDate": "2003-01-01",
#     "CompletionDate": "2022-04-01",
#     "Reference": []
#   },
#   {
#     "NCTId": "NCT01164462",
#     "BriefTitle": "Feasibility and Limitations of Offering Community Based Rapid HIV Testing to Men Who Have Sex With Men (MSM)",
#     "LeadSponsorName": "French National Agency for Research on AIDS and Viral Hepatitis",
#     "CollaboratorName": null,
#     "OverallStatus": "COMPLETED",
#     "StudyType": "INTERVENTIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2010-07-16",
#     "StartDate": "2010-03",
#     "CompletionDate": "2011-04",
#     "Reference": []
#   },
#   {
#     "NCTId": "NCT02777229",
#     "BriefTitle": "Efficacy and Safety of a Dolutegravir-based Regimen for the Initial Management of HIV Infected Adults in Resource-limited Settings",
#     "LeadSponsorName": "ANRS, Emerging Infectious Diseases",
#     "CollaboratorName": "Institut de Recherche pour le Developpement | UNITAID",
#     "OverallStatus": "COMPLETED",
#     "StudyType": "INTERVENTIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2016-05-19",
#     "StartDate": "2016-07",
#     "CompletionDate": "2021-07",
#     "Reference": [
#       {
#         "pmid": "33355914",
#         "type": "DERIVED",
#         "citation": "Bousmah MA, Nishimwe ML, Tovar-Sanchez T, Lantche Wandji M, Mpoudi-Etame M, Maradan G, Omgba Bassega P, Varloteaux M, Montoyo A, Kouanfack C, Delaporte E, Boyer S; New Antiretroviral and Monitoring Strategies in HIV-infected Adults in Low-Income Countries (NAMSAL) ANRS 12313 Study Group. Cost-Utility Analysis of a Dolutegravir-Based Versus Low-Dose Efavirenz-Based Regimen for the Initial Treatment of HIV-Infected Patients in Cameroon (NAMSAL ANRS 12313 Trial). Pharmacoeconomics. 2021 Mar;39(3):331-343. doi: 10.1007/s40273-020-00987-3. Epub 2020 Dec 23."
#       },
#       {
#         "pmid": "33010241",
#         "type": "DERIVED",
#         "citation": "Calmy A, Tovar Sanchez T, Kouanfack C, Mpoudi-Etame M, Leroy S, Perrineau S, Lantche Wandji M, Tetsa Tata D, Omgba Bassega P, Abong Bwenda T, Varloteaux M, Tongo M, Mpoudi-Ngole E, Montoyo A, Mercier N, LeMoing V, Peeters M, Reynes J, Delaporte E; New Antiretroviral and Monitoring Strategies in HIV-infected Adults in Low-Income Countries (NAMSAL) ANRS 12313 Study Group. Dolutegravir-based and low-dose efavirenz-based regimen for the initial treatment of HIV-1 infection (NAMSAL): week 96 results from a two-group, multicentre, randomised, open label, phase 3 non-inferiority trial in Cameroon. Lancet HIV. 2020 Oct;7(10):e677-e687. doi: 10.1016/S2352-3018(20)30238-1."
#       },
#       {
#         "pmid": "31339676",
#         "type": "DERIVED",
#         "citation": "NAMSAL ANRS 12313 Study Group; Kouanfack C, Mpoudi-Etame M, Omgba Bassega P, Eymard-Duvernay S, Leroy S, Boyer S, Peeters M, Calmy A, Delaporte E. Dolutegravir-Based or Low-Dose Efavirenz-Based Regimen for the Treatment of HIV-1. N Engl J Med. 2019 Aug 29;381(9):816-826. doi: 10.1056/NEJMoa1904340. Epub 2019 Jul 24."
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT00480792",
#     "BriefTitle": "Trial Comparing Three Strategies of Vaccination Against the Virus of Hepatitis B in HIV Infected Patients",
#     "LeadSponsorName": "ANRS, Emerging Infectious Diseases",
#     "CollaboratorName": "MCM Vaccines B.V.",
#     "OverallStatus": "COMPLETED",
#     "StudyType": "INTERVENTIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2007-05-31",
#     "StartDate": "2007-06",
#     "CompletionDate": "2012-09",
#     "Reference": [
#       {
#         "pmid": "27064975",
#         "type": "DERIVED",
#         "citation": "Launay O, Rosenberg AR, Rey D, Pouget N, Michel ML, Reynes J, Neau D, Raffi F, Piroth L, Carrat F; ANRS HB03 VIHVAC-B (Trial Comparing 3 Strategies of Vaccination Against the Virus of Hepatitis B in HIV-Infected Patients) Group. Long-term Immune Response to Hepatitis B Virus Vaccination Regimens in Adults With Human Immunodeficiency Virus 1: Secondary Analysis of a Randomized Clinical Trial. JAMA Intern Med. 2016 May 1;176(5):603-10. doi: 10.1001/jamainternmed.2016.0741."
#       },
#       {
#         "pmid": "21486976",
#         "type": "DERIVED",
#         "citation": "Launay O, van der Vliet D, Rosenberg AR, Michel ML, Piroth L, Rey D, Colin de Verdiere N, Slama L, Martin K, Lortholary O, Carrat F; ANRS HB03 VIHVAC-B Trial. Safety and immunogenicity of 4 intramuscular double doses and 4 intradermal low doses vs standard hepatitis B vaccine regimen in adults with HIV-1: a randomized controlled trial. JAMA. 2011 Apr 13;305(14):1432-40. doi: 10.1001/jama.2011.351."
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT01095744",
#     "BriefTitle": "Influence of Age on Amyloid Load in Alzheimer's Disease and in Atypical Focal Cortical Alzheimer's Disease",
#     "LeadSponsorName": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France",
#     "CollaboratorName": null,
#     "OverallStatus": "COMPLETED",
#     "StudyType": "OBSERVATIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2010-03-30",
#     "StartDate": "2009-03",
#     "CompletionDate": "2012-05",
#     "Reference": []
#   },
#   {
#     "NCTId": "NCT01489592",
#     "BriefTitle": "Effect of Curcumin on Iron Metabolism in Healthy Volunteer",
#     "LeadSponsorName": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France",
#     "CollaboratorName": null,
#     "OverallStatus": "COMPLETED",
#     "StudyType": "INTERVENTIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2011-12-09",
#     "StartDate": "2011-10",
#     "CompletionDate": "2012-03",
#     "Reference": [
#       {
#         "pmid": "20169331",
#         "type": "BACKGROUND",
#         "citation": "Fatih N, Camberlein E, Island ML, Corlu A, Abgueguen E, Detivaud L, Leroyer P, Brissot P, Loreal O. Natural and synthetic STAT3 inhibitors reduce hepcidin expression in differentiated mouse hepatocytes expressing the active phosphorylated STAT3 form. J Mol Med (Berl). 2010 May;88(5):477-86. doi: 10.1007/s00109-009-0588-3. Epub 2010 Feb 19."
#       },
#       {
#         "pmid": "15974953",
#         "type": "BACKGROUND",
#         "citation": "Loreal O, Haziza-Pigeon C, Troadec MB, Detivaud L, Turlin B, Courselaud B, Ilyin G, Brissot P. Hepcidin in iron metabolism. Curr Protein Pept Sci. 2005 Jun;6(3):279-91. doi: 10.2174/1389203054065392."
#       },
#       {
#         "pmid": "16946298",
#         "type": "BACKGROUND",
#         "citation": "Verga Falzacappa MV, Vujic Spasic M, Kessler R, Stolte J, Hentze MW, Muckenthaler MU. STAT3 mediates hepatic hepcidin expression and its inflammatory stimulation. Blood. 2007 Jan 1;109(1):353-8. doi: 10.1182/blood-2006-07-033969. Epub 2006 Aug 31."
#       },
#       {
#         "pmid": "15501961",
#         "type": "BACKGROUND",
#         "citation": "Sharma RA, Euden SA, Platton SL, Cooke DN, Shafayat A, Hewitt HR, Marczylo TH, Morgan B, Hemingway D, Plummer SM, Pirmohamed M, Gescher AJ, Steward WP. Phase I clinical trial of oral curcumin: biomarkers of systemic activity and compliance. Clin Cancer Res. 2004 Oct 15;10(20):6847-54. doi: 10.1158/1078-0432.CCR-04-0744."
#       },
#       {
#         "pmid": "18559556",
#         "type": "BACKGROUND",
#         "citation": "Vareed SK, Kakarala M, Ruffin MT, Crowell JA, Normolle DP, Djuric Z, Brenner DE. Pharmacokinetics of curcumin conjugate metabolites in healthy human subjects. Cancer Epidemiol Biomarkers Prev. 2008 Jun;17(6):1411-7. doi: 10.1158/1055-9965.EPI-07-2693."
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT01453192",
#     "BriefTitle": "Renal Transplantation and Raltegravir in HIV-Infected Patients",
#     "LeadSponsorName": "ANRS, Emerging Infectious Diseases",
#     "CollaboratorName": "Merck Sharp & Dohme LLC",
#     "OverallStatus": "COMPLETED",
#     "StudyType": "INTERVENTIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2011-10-17",
#     "StartDate": "2011-12",
#     "CompletionDate": "2015-11",
#     "Reference": []
#   },
#   {
#     "NCTId": "NCT00460382",
#     "BriefTitle": "Clinical Trial to Assess the Efficacy of Darunavir/Ritonavir (DRV/r), Etravirine (ETV) and Raltegravir (MK-0518) in HIV Patients With Resistant Viruses",
#     "LeadSponsorName": "French National Agency for Research on AIDS and Viral Hepatitis",
#     "CollaboratorName": "Merck Sharp & Dohme LLC | Janssen-Cilag Tibotec",
#     "OverallStatus": "COMPLETED",
#     "StudyType": "INTERVENTIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2007-04-13",
#     "StartDate": "2007-05",
#     "CompletionDate": "2009-09",
#     "Reference": []
#   },
#   {
#     "NCTId": "NCT02486731",
#     "BriefTitle": "Hormonal Sensitivity in Patients With Noonan and LEOPARD Syndromes",
#     "LeadSponsorName": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France",
#     "CollaboratorName": null,
#     "OverallStatus": "COMPLETED",
#     "StudyType": "OBSERVATIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2015-07-01",
#     "StartDate": "2015-12-16",
#     "CompletionDate": "2018-12",
#     "Reference": []
#   },
#   {
#     "NCTId": "NCT02116374",
#     "BriefTitle": "Physiopathology Study of the Microbiota Biodiversity of HIV Seropositive Patients",
#     "LeadSponsorName": "ANRS, Emerging Infectious Diseases",
#     "CollaboratorName": null,
#     "OverallStatus": "COMPLETED",
#     "StudyType": "OBSERVATIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2014-04-16",
#     "StartDate": "2014-12",
#     "CompletionDate": "2016-06",
#     "Reference": []
#   },
#   {
#     "NCTId": "NCT02497274",
#     "BriefTitle": "Obesity and Lipids: a Matter of Taste?",
#     "LeadSponsorName": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France",
#     "CollaboratorName": null,
#     "OverallStatus": "COMPLETED",
#     "StudyType": "INTERVENTIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2015-07-14",
#     "StartDate": "2016-01-11",
#     "CompletionDate": "2019-01",
#     "Reference": []
#   },
#   {
#     "NCTId": "NCT01022476",
#     "BriefTitle": "Raltegravir in Patients With End Stage Liver Disease and in Transplant Recipients",
#     "LeadSponsorName": "ANRS, Emerging Infectious Diseases",
#     "CollaboratorName": "Merck Sharp & Dohme LLC",
#     "OverallStatus": "COMPLETED",
#     "StudyType": "INTERVENTIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2009-12-01",
#     "StartDate": "2010-05",
#     "CompletionDate": "2013-05",
#     "Reference": []
#   },
#   {
#     "NCTId": "NCT00528060",
#     "BriefTitle": "Measure of Pharmacokinetic Parameters and Adherence With MEMS in Naive HIV Infected Patients Treated With Reyataz Once Daily Combined With Norvir and Truvada",
#     "LeadSponsorName": "French National Agency for Research on AIDS and Viral Hepatitis",
#     "CollaboratorName": "Bristol-Myers Squibb | Gilead Sciences",
#     "OverallStatus": "COMPLETED",
#     "StudyType": "INTERVENTIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2007-09-11",
#     "StartDate": "2008-01",
#     "CompletionDate": "2008-11",
#     "Reference": [
#       {
#         "pmid": "23459496",
#         "type": "DERIVED",
#         "citation": "Parienti JJ, Barrail-Tran A, Duval X, Nembot G, Descamps D, Vigan M, Vrijens B, Panhard X, Taburet AM, Mentre F, Goujard C. Adherence profiles and therapeutic responses of treatment-naive HIV-infected patients starting boosted atazanavir-based therapy in the ANRS 134-COPHAR 3 trial. Antimicrob Agents Chemother. 2013 May;57(5):2265-71. doi: 10.1128/AAC.02605-12. Epub 2013 Mar 4."
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT02078076",
#     "BriefTitle": "IRM Cardiaque en Respiration Libre Pour Des Patients Atteints de Dystrophinopathie s\u00e9v\u00e8re",
#     "LeadSponsorName": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France",
#     "CollaboratorName": null,
#     "OverallStatus": "COMPLETED",
#     "StudyType": "INTERVENTIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2014-03-05",
#     "StartDate": "2013-06",
#     "CompletionDate": "2015-11",
#     "Reference": []
#   },
#   {
#     "NCTId": "NCT04008927",
#     "BriefTitle": "A Community-based Intervention Among Active Drug Users in Montpellier",
#     "LeadSponsorName": "ANRS, Emerging Infectious Diseases",
#     "CollaboratorName": null,
#     "OverallStatus": "COMPLETED",
#     "StudyType": "INTERVENTIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2019-07-05",
#     "StartDate": "2020-09-18",
#     "CompletionDate": "2021-09-10",
#     "Reference": [
#       {
#         "pmid": "27168667",
#         "type": "BACKGROUND",
#         "citation": "Blackburn NA, Patel RC, Zibbell JE. Improving Screening Methods for Hepatitis C Among People Who Inject Drugs: Findings from the HepTLC Initiative, 2012-2014. Public Health Rep. 2016 May-Jun;131 Suppl 2(Suppl 2):91-7. doi: 10.1177/00333549161310S214."
#       },
#       {
#         "pmid": "26806260",
#         "type": "BACKGROUND",
#         "citation": "Chevaliez S, Poiteau L, Rosa I, Soulier A, Roudot-Thoraval F, Laperche S, Hezode C, Pawlotsky JM. Prospective assessment of rapid diagnostic tests for the detection of antibodies to hepatitis C virus, a tool for improving access to care. Clin Microbiol Infect. 2016 May;22(5):459.e1-6. doi: 10.1016/j.cmi.2016.01.009. Epub 2016 Jan 22."
#       },
#       {
#         "pmid": "22310560",
#         "type": "BACKGROUND",
#         "citation": "Curran GM, Bauer M, Mittman B, Pyne JM, Stetler C. Effectiveness-implementation hybrid designs: combining elements of clinical effectiveness and implementation research to enhance public health impact. Med Care. 2012 Mar;50(3):217-26. doi: 10.1097/MLR.0b013e3182408812."
#       },
#       {
#         "pmid": "29432973",
#         "type": "BACKGROUND",
#         "citation": "Des Jarlais D, Khue PM, Feelemyer J, Arasteh K, Thi Huong D, Thi Hai Oanh K, Thi Giang H, Thi Tuyet Thanh N, Vinh VH, Heckathorn DD, Moles JP, Vallo R, Quillet C, Rapoud D, Michel L, Laureillard D, Hammett T, Nagot N. Using dual capture/recapture studies to estimate the population size of persons who inject drugs (PWID) in the city of Hai Phong, Vietnam. Drug Alcohol Depend. 2018 Apr 1;185:106-111. doi: 10.1016/j.drugalcdep.2017.11.033. Epub 2018 Feb 2."
#       },
#       {
#         "pmid": "27178119",
#         "type": "BACKGROUND",
#         "citation": "Des Jarlais D, Duong HT, Pham Minh K, Khuat OH, Nham TT, Arasteh K, Feelemyer J, Heckathorn DD, Peries M, Moles JP, Laureillard D, Nagot N; (The Drive Study Team). Integrated respondent-driven sampling and peer support for persons who inject drugs in Haiphong, Vietnam: a case study with implications for interventions. AIDS Care. 2016 Oct;28(10):1312-5. doi: 10.1080/09540121.2016.1178698. Epub 2016 May 13."
#       },
#       {
#         "pmid": "27537841",
#         "type": "BACKGROUND",
#         "citation": "Dore GJ, Altice F, Litwin AH, Dalgard O, Gane EJ, Shibolet O, Luetkemeyer A, Nahass R, Peng CY, Conway B, Grebely J, Howe AY, Gendrano IN, Chen E, Huang HC, Dutko FJ, Nickle DC, Nguyen BY, Wahl J, Barr E, Robertson MN, Platt HL; C-EDGE CO-STAR Study Group. Elbasvir-Grazoprevir to Treat Hepatitis C Virus Infection in Persons Receiving Opioid Agonist Therapy: A Randomized Trial. Ann Intern Med. 2016 Nov 1;165(9):625-634. doi: 10.7326/M16-0816. Epub 2016 Aug 9."
#       },
#       {
#         "pmid": "28004616",
#         "type": "BACKGROUND",
#         "citation": "Leon L, Kasereka S, Barin F, Larsen C, Weill-Barillet L, Pascal X, Chevaliez S, Pillonel J, Jauffret-Roustide M, LE Strat Y. Age- and time-dependent prevalence and incidence of hepatitis C virus infection in drug users in France, 2004-2011: model-based estimation from two national cross-sectional serosurveys. Epidemiol Infect. 2017 Apr;145(5):895-907. doi: 10.1017/S0950268816002934. Epub 2016 Dec 22."
#       },
#       {
#         "pmid": "35774932",
#         "type": "DERIVED",
#         "citation": "Nagot N, D'Ottavi M, Quillet C, Debellefontaine A, Castellani J, Langendorfer N, Hanslik B, Guichard S, Baglioni R, Faucherre V, Tuaillon E, Pageaux GP, Laureillard D, Donnadieu-Rigole H. Reaching Hard-to-Reach People Who Use Drugs: A Community-Based Strategy for the Elimination of Hepatitis C. Open Forum Infect Dis. 2022 Apr 14;9(6):ofac181. doi: 10.1093/ofid/ofac181. eCollection 2022 Jun."
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT01331876",
#     "BriefTitle": "Modification of Cerebral Activity of Obsessive Compulsive Disorder (OCD) Patients During Cognitive and Behavioral Therapy",
#     "LeadSponsorName": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France",
#     "CollaboratorName": null,
#     "OverallStatus": "COMPLETED",
#     "StudyType": "INTERVENTIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2011-04-08",
#     "StartDate": "2009-10",
#     "CompletionDate": "2012-07",
#     "Reference": []
#   },
#   {
#     "NCTId": "NCT00820820",
#     "BriefTitle": "IDA (Immunoth\u00e9rapie de la Dermatite Atopique) Adult - Immunotherapy in Atopic Dermatitis",
#     "LeadSponsorName": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France",
#     "CollaboratorName": "Ministry of Health, France",
#     "OverallStatus": "COMPLETED",
#     "StudyType": "INTERVENTIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2009-01-12",
#     "StartDate": "2009-01-09",
#     "CompletionDate": "2012-03-26",
#     "Reference": []
#   },
#   {
#     "NCTId": "NCT02273765",
#     "BriefTitle": "Raltegravir Versus Efavirenz in Naive HIV-1-infected Patients Receiving Rifampin for Active Tuberculosis",
#     "LeadSponsorName": "ANRS, Emerging Infectious Diseases",
#     "CollaboratorName": "Merck Sharp & Dohme LLC | Ministry of Health, Brazil",
#     "OverallStatus": "COMPLETED",
#     "StudyType": "INTERVENTIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2014-10-24",
#     "StartDate": "2015-09-11",
#     "CompletionDate": "2018-11-28",
#     "Reference": [
#       {
#         "pmid": "33667406",
#         "type": "DERIVED",
#         "citation": "De Castro N, Marcy O, Chazallon C, Messou E, Eholie S, N'takpe JB, Bhatt N, Khosa C, Timana Massango I, Laureillard D, Chau GD, Domergue A, Veloso V, Escada R, Wagner Cardoso S, Delaugerre C, Anglaret X, Molina JM, Grinsztejn B; ANRS 12300 Reflate TB2 study group. Standard dose raltegravir or efavirenz-based antiretroviral treatment for patients co-infected with HIV and tuberculosis (ANRS 12 300 Reflate TB 2): an open-label, non-inferiority, randomised, phase 3 trial. Lancet Infect Dis. 2021 Jun;21(6):813-822. doi: 10.1016/S1473-3099(20)30869-0. Epub 2021 Mar 2."
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT02107365",
#     "BriefTitle": "Therapy With Asunaprevir, Daclatasvir, Ribavirin and Pegylated Interferon Alpha-2a in HCV Genotype 4-infected Patients Who Have Failed to a Previous Therapy With Peg-Interferon/Ribavirin (ANRS HC32 QUATTRO)",
#     "LeadSponsorName": "ANRS, Emerging Infectious Diseases",
#     "CollaboratorName": "Bristol-Myers Squibb",
#     "OverallStatus": "COMPLETED",
#     "StudyType": "INTERVENTIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2014-04-08",
#     "StartDate": "2013-11",
#     "CompletionDate": "2015-04",
#     "Reference": []
#   },
#   {
#     "NCTId": "NCT00113282",
#     "BriefTitle": "Efficacy of Adding Interleukin-2 to an Optimized Antiretroviral Regimen in HIV Patients in Therapeutic Failure (ANRS123)",
#     "LeadSponsorName": "French National Agency for Research on AIDS and Viral Hepatitis",
#     "CollaboratorName": "Chiron Corporation",
#     "OverallStatus": "COMPLETED",
#     "StudyType": "INTERVENTIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2005-06-08",
#     "StartDate": "2004-06",
#     "CompletionDate": "2008-02",
#     "Reference": []
#   },
#   {
#     "NCTId": "NCT01055873",
#     "BriefTitle": "Immunology of the Infection Perinatal",
#     "LeadSponsorName": "French National Agency for Research on AIDS and Viral Hepatitis",
#     "CollaboratorName": "Institut Pasteur | University of Paris 5 - Rene Descartes | H\u00f4pital Necker-Enfants Malades",
#     "OverallStatus": "COMPLETED",
#     "StudyType": "OBSERVATIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2010-01-26",
#     "StartDate": "2007-02",
#     "CompletionDate": "2009-02",
#     "Reference": [
#       {
#         "pmid": "22427678",
#         "type": "DERIVED",
#         "citation": "Avettand-Fenoel V, Blanche S, Le Chenadec J, Scott-Algara D, Dollfus C, Viard JP, Bouallag N, Benmebarek Y, Riviere Y, Warszawski J, Rouzioux C, Buseyne F. Relationships between HIV disease history and blood HIV-1 DNA load in perinatally infected adolescents and young adults: the ANRS-EP38-IMMIP study. J Infect Dis. 2012 May 15;205(10):1520-8. doi: 10.1093/infdis/jis233. Epub 2012 Mar 15."
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT05199831",
#     "BriefTitle": "Situational Analysis of HIV-related Disability in the Context of Ivory Coast",
#     "LeadSponsorName": "Programme PAC-CI, Site ANRS-MIE de C\u00f4te d'Ivoire",
#     "CollaboratorName": "Institute of Research for Development, France | Institut de Sante Publique, d'Epidemiologie et de Developpement | University of Toronto | Universit\u00e9 de Lille",
#     "OverallStatus": "COMPLETED",
#     "StudyType": "OBSERVATIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2022-01-20",
#     "StartDate": "2021-02-05",
#     "CompletionDate": "2022-08-10",
#     "Reference": []
#   },
#   {
#     "NCTId": "NCT01359774",
#     "BriefTitle": "31P-MRS and Huntington Disease",
#     "LeadSponsorName": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France",
#     "CollaboratorName": null,
#     "OverallStatus": "COMPLETED",
#     "StudyType": "INTERVENTIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2011-05-25",
#     "StartDate": "2011-04",
#     "CompletionDate": "2012-04",
#     "Reference": [
#       {
#         "pmid": "21285522",
#         "type": "BACKGROUND",
#         "citation": "Mochel F, Haller RG. Energy deficit in Huntington disease: why it matters. J Clin Invest. 2011 Feb;121(2):493-9. doi: 10.1172/JCI45691. Epub 2011 Feb 1."
#       },
#       {
#         "pmid": "17653274",
#         "type": "BACKGROUND",
#         "citation": "Mochel F, Charles P, Seguin F, Barritault J, Coussieu C, Perin L, Le Bouc Y, Gervais C, Carcelain G, Vassault A, Feingold J, Rabier D, Durr A. Early energy deficit in Huntington disease: identification of a plasma biomarker traceable during disease progression. PLoS One. 2007 Jul 25;2(7):e647. doi: 10.1371/journal.pone.0000647."
#       },
#       {
#         "pmid": "21320997",
#         "type": "BACKGROUND",
#         "citation": "Mochel F, Benaich S, Rabier D, Durr A. Validation of plasma branched chain amino acids as biomarkers in Huntington disease. Arch Neurol. 2011 Feb;68(2):265-7. doi: 10.1001/archneurol.2010.358. No abstract available."
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT02099474",
#     "BriefTitle": "Evaluation of Raltegravir During the Third Trimester of Pregnancy",
#     "LeadSponsorName": "ANRS, Emerging Infectious Diseases",
#     "CollaboratorName": null,
#     "OverallStatus": "COMPLETED",
#     "StudyType": "INTERVENTIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2014-03-31",
#     "StartDate": "2014-06-30",
#     "CompletionDate": "2017-04",
#     "Reference": [
#       {
#         "pmid": "32661003",
#         "type": "DERIVED",
#         "citation": "Zheng Y, Hirt D, Delmas S, Lui G, Benaboud S, Lechedanec J, Treluyer JM, Chenevier-Gobeaux C, Arezes E, Gelley A, Amri I, Urien S, Bouazza N, Foissac F, Warszawski J, Ghosn J. Effect of Pregnancy on Unbound Raltegravir Concentrations in the ANRS 160 RalFe Trial. Antimicrob Agents Chemother. 2020 Sep 21;64(10):e00759-20. doi: 10.1128/AAC.00759-20. Print 2020 Sep 21."
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT03546127",
#     "BriefTitle": "Molecular Profiling to Improve Outcome of Patients in Cancer. A Pilot Study",
#     "LeadSponsorName": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France",
#     "CollaboratorName": "Institut Bergoni\u00e9 | Plateforme labellis\u00e9e Inca - Institut Bergoni\u00e9, Bordeaux | Plateforme labellis\u00e9e Inca - H\u00f4pital Europ\u00e9en Georges Pompidou, Paris | CNRGH, Evry | EUCLID Clinical Trial Platform",
#     "OverallStatus": "COMPLETED",
#     "StudyType": "OBSERVATIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2018-06-06",
#     "StartDate": "2017-05-23",
#     "CompletionDate": "2017-09-21",
#     "Reference": []
#   },
#   {
#     "NCTId": "NCT04315948",
#     "BriefTitle": "Trial of Treatments for COVID-19 in Hospitalized Adults",
#     "LeadSponsorName": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France",
#     "CollaboratorName": null,
#     "OverallStatus": "COMPLETED",
#     "StudyType": "INTERVENTIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2020-03-20",
#     "StartDate": "2020-03-22",
#     "CompletionDate": "2023-09-25",
#     "Reference": [
#       {
#         "pmid": "32958495",
#         "type": "BACKGROUND",
#         "citation": "Ader F; Discovery French Trial Management Team. Protocol for the DisCoVeRy trial: multicentre, adaptive, randomised trial of the safety and efficacy of treatments for COVID-19 in hospitalised adults. BMJ Open. 2020 Sep 21;10(9):e041437. doi: 10.1136/bmjopen-2020-041437."
#       },
#       {
#         "pmid": "34763056",
#         "type": "BACKGROUND",
#         "citation": "EU-Response investigators group; Diallo A, Troseid M, Simensen VC, Boston A, Demotes J, Olsen IC, Chung F, Paiva JA, Hites M, Ader F, Arribas JR, Baratt-Due A, Melien O, Tacconelli E, Staub T, Greil R, Tsiodras S, Briel M, Esperou H, Mentre F, Eustace J, Saillard J, Delmas C, LeMestre S, Dumousseaux M, Costagliola D, Rottingen JA, Yazdanpanah Y. Accelerating clinical trial implementation in the context of the COVID-19 pandemic: challenges, lessons learned and recommendations from DisCoVeRy and the EU-SolidAct EU response group. Clin Microbiol Infect. 2022 Jan;28(1):1-5. doi: 10.1016/j.cmi.2021.10.011. Epub 2021 Nov 8. No abstract available."
#       },
#       {
#         "pmid": "35623577",
#         "type": "BACKGROUND",
#         "citation": "Troseid M, Hentzien M, Ader F, Cardoso SW, Arribas JR, Molina JM, Mueller N, Hites M, Bonnet F, Manuel O, Costagliola D, Grinsztejn B, Olsen IC, Yazdapanah Y, Calmy A; EU RESPONSE; COMBINE. Immunocompromised patients have been neglected in COVID-19 trials: a call for action. Clin Microbiol Infect. 2022 Sep;28(9):1182-1183. doi: 10.1016/j.cmi.2022.05.005. Epub 2022 May 25. No abstract available."
#       },
#       {
#         "pmid": "36680782",
#         "type": "BACKGROUND",
#         "citation": "Terzic V, Levoyer L, Figarella M, Bigagli E, Mercier N, De Gastines L, Gibowski S, Troseid M, Demotes J, Olsen IC, Hites M, Ader F, Lopez JRA, Mentre F, Esperou H, Costagliola D, Rottingen JA, Poissy J, Roze JC, Warris A, O'Leary J, Fernandes RM, Assoumou L, Hankard R, Turner MA, Yazdanpanah Y, Diallo A; EU-Response safety group; c4c safety group. Implementation of a centralized pharmacovigilance system in academic pan-European clinical trials: Experience from EU-Response and conect4children consortia. Br J Clin Pharmacol. 2023 Apr;89(4):1318-1328. doi: 10.1111/bcp.15669. Epub 2023 Feb 8."
#       },
#       {
#         "pmid": "36828006",
#         "type": "BACKGROUND",
#         "citation": "Amstutz A, Speich B, Mentre F, Rueegg CS, Belhadi D, Assoumou L, Burdet C, Murthy S, Dodd LE, Wang Y, Tikkinen KAO, Ader F, Hites M, Bouscambert M, Trabaud MA, Fralick M, Lee TC, Pinto R, Barratt-Due A, Lund-Johansen F, Muller F, Nevalainen OPO, Cao B, Bonnett T, Griessbach A, Taji Heravi A, Schonenberger C, Janiaud P, Werlen L, Aghlmandi S, Schandelmaier S, Yazdanpanah Y, Costagliola D, Olsen IC, Briel M. Effects of remdesivir in patients hospitalised with COVID-19: a systematic review and individual patient data meta-analysis of randomised controlled trials. Lancet Respir Med. 2023 May;11(5):453-464. doi: 10.1016/S2213-2600(22)00528-8. Epub 2023 Feb 21. Erratum In: Lancet Respir Med. 2023 Aug;11(8):e77."
#       },
#       {
#         "pmid": "32473020",
#         "type": "BACKGROUND",
#         "citation": "Le MP, Peiffer-Smadja N, Guedj J, Neant N, Mentre F, Ader F, Yazdanpanah Y, Peytavin G. Rationale of a loading dose initiation for hydroxychloroquine treatment in COVID-19 infection in the DisCoVeRy trial. J Antimicrob Chemother. 2020 Sep 1;75(9):2376-2380. doi: 10.1093/jac/dkaa191."
#       },
#       {
#         "pmid": "33089306",
#         "type": "BACKGROUND",
#         "citation": "Le MP, Peiffer-Smadja N, Guedj J, Neant N, Mentre F, Ader F, Yazdanpanah Y, Peytavin G; C-20-15 DisCoVeRy French Steering Committee. Rationale of a loading dose initiation for hydroxychloroquine treatment in COVID-19 infection in the DisCoVeRy trial-authors' response. J Antimicrob Chemother. 2021 Jan 1;76(1):277-279. doi: 10.1093/jac/dkaa415. No abstract available."
#       },
#       {
#         "pmid": "37269068",
#         "type": "BACKGROUND",
#         "citation": "Mercier N, Belhadi D, DeChanet A, Delmas C, Saillard J, Dumousseaux M, Le Mestre S, Fougerou-Leurent C, Ferrane A, Burdet C, Esperou H, Ader F, Hites M, Peiffer-Smadja N, Poissy J, Andrejak C, Paiva JA, Tacconelli E, Staub T, Greil R, Costagliola D, Mentre F, Yazdanpanah Y, Diallo A; DisCoVeRy Safety Working group. Management of pharmacovigilance during the COVID-19 pandemic crisis by the safety department of an academic sponsor: Lessons learnt and challenges from the EU DisCoVeRy clinical trial. Pharmacol Res Perspect. 2023 Jun;11(3):e01072. doi: 10.1002/prp2.1072."
#       },
#       {
#         "pmid": "37302469",
#         "type": "BACKGROUND",
#         "citation": "Fougerou-Leurent C, Delmas C, Saillard J, Dumousseaux M, Ferrane A, Mercier N, Terzic V, Le Mestre S, Dechanet A, Belhadi D, Metois A, Burdet C, Mentre F, Noret M, Diallo A, Petrov-Sanchez V, Couffin-Cadiergues S, Hites M, Ader F, Esperou H. Ensuring quality control in a COVID-19 clinical trial during the pandemic: The experience of the Inserm C20-15 DisCoVeRy study. Contemp Clin Trials. 2023 Aug;131:107267. doi: 10.1016/j.cct.2023.107267. Epub 2023 Jun 9."
#       },
#       {
#         "pmid": "33264556",
#         "type": "RESULT",
#         "citation": "WHO Solidarity Trial Consortium; Pan H, Peto R, Henao-Restrepo AM, Preziosi MP, Sathiyamoorthy V, Abdool Karim Q, Alejandria MM, Hernandez Garcia C, Kieny MP, Malekzadeh R, Murthy S, Reddy KS, Roses Periago M, Abi Hanna P, Ader F, Al-Bader AM, Alhasawi A, Allum E, Alotaibi A, Alvarez-Moreno CA, Appadoo S, Asiri A, Aukrust P, Barratt-Due A, Bellani S, Branca M, Cappel-Porter HBC, Cerrato N, Chow TS, Como N, Eustace J, Garcia PJ, Godbole S, Gotuzzo E, Griskevicius L, Hamra R, Hassan M, Hassany M, Hutton D, Irmansyah I, Jancoriene L, Kirwan J, Kumar S, Lennon P, Lopardo G, Lydon P, Magrini N, Maguire T, Manevska S, Manuel O, McGinty S, Medina MT, Mesa Rubio ML, Miranda-Montoya MC, Nel J, Nunes EP, Perola M, Portoles A, Rasmin MR, Raza A, Rees H, Reges PPS, Rogers CA, Salami K, Salvadori MI, Sinani N, Sterne JAC, Stevanovikj M, Tacconelli E, Tikkinen KAO, Trelle S, Zaid H, Rottingen JA, Swaminathan S. Repurposed Antiviral Drugs for Covid-19 - Interim WHO Solidarity Trial Results. N Engl J Med. 2021 Feb 11;384(6):497-511. doi: 10.1056/NEJMoa2023184. Epub 2020 Dec 2."
#       },
#       {
#         "pmid": "34048876",
#         "type": "RESULT",
#         "citation": "Ader F, Peiffer-Smadja N, Poissy J, Bouscambert-Duchamp M, Belhadi D, Diallo A, Delmas C, Saillard J, Dechanet A, Mercier N, Dupont A, Alfaiate T, Lescure FX, Raffi F, Goehringer F, Kimmoun A, Jaureguiberry S, Reignier J, Nseir S, Danion F, Clere-Jehl R, Bouiller K, Navellou JC, Tolsma V, Cabie A, Dubost C, Courjon J, Leroy S, Mootien J, Gaci R, Mourvillier B, Faure E, Pourcher V, Gallien S, Launay O, Lacombe K, Lanoix JP, Makinson A, Martin-Blondel G, Bouadma L, Botelho-Nevers E, Gagneux-Brunon A, Epaulard O, Piroth L, Wallet F, Richard JC, Reuter J, Staub T, Lina B, Noret M, Andrejak C, Le MP, Peytavin G, Hites M, Costagliola D, Yazdanpanah Y, Burdet C, Mentre F; DisCoVeRy study group. An open-label randomized controlled trial of the effect of lopinavir/ritonavir, lopinavir/ritonavir plus IFN-beta-1a and hydroxychloroquine in hospitalized patients with COVID-19. Clin Microbiol Infect. 2021 Dec;27(12):1826-1837. doi: 10.1016/j.cmi.2021.05.020. Epub 2021 May 26."
#       },
#       {
#         "pmid": "34534511",
#         "type": "RESULT",
#         "citation": "Ader F, Bouscambert-Duchamp M, Hites M, Peiffer-Smadja N, Poissy J, Belhadi D, Diallo A, Le MP, Peytavin G, Staub T, Greil R, Guedj J, Paiva JA, Costagliola D, Yazdanpanah Y, Burdet C, Mentre F; DisCoVeRy Study Group. Remdesivir plus standard of care versus standard of care alone for the treatment of patients admitted to hospital with COVID-19 (DisCoVeRy): a phase 3, randomised, controlled, open-label trial. Lancet Infect Dis. 2022 Feb;22(2):209-221. doi: 10.1016/S1473-3099(21)00485-0. Epub 2021 Sep 14."
#       },
#       {
#         "pmid": "35233617",
#         "type": "RESULT",
#         "citation": "Lingas G, Neant N, Gaymard A, Belhadi D, Peytavin G, Hites M, Staub T, Greil R, Paiva JA, Poissy J, Peiffer-Smadja N, Costagliola D, Yazdanpanah Y, Wallet F, Gagneux-Brunon A, Mentre F, Ader F, Burdet C, Guedj J, Bouscambert-Duchamp M. Effect of remdesivir on viral dynamics in COVID-19 hospitalized patients: a modelling analysis of the randomized, controlled, open-label DisCoVeRy trial. J Antimicrob Chemother. 2022 Apr 27;77(5):1404-1412. doi: 10.1093/jac/dkac048."
#       },
#       {
#         "pmid": "35643099",
#         "type": "RESULT",
#         "citation": "Ader F, Bouscambert-Duchamp M, Hites M, Peiffer-Smadja N, Mentre F, Burdet C; DisCoVeRy Study Group. Final results of the DisCoVeRy trial of remdesivir for patients admitted to hospital with COVID-19. Lancet Infect Dis. 2022 Jun;22(6):764-765. doi: 10.1016/S1473-3099(22)00295-X. No abstract available."
#       },
#       {
#         "pmid": "35533972",
#         "type": "RESULT",
#         "citation": "Ader F; DisCoVeRy Study Group. An open-label randomized, controlled trial of the effect of lopinavir and ritonavir, lopinavir and ritonavir plus interferon-beta-1a, and hydroxychloroquine in hospitalized patients with COVID-19: final results. Clin Microbiol Infect. 2022 Sep;28(9):1293-1296. doi: 10.1016/j.cmi.2022.04.016. Epub 2022 May 7. No abstract available."
#       },
#       {
#         "pmid": "37728045",
#         "type": "RESULT",
#         "citation": "Neant N, Lingas G, Gaymard A, Belhadi D, Hites M, Staub T, Greil R, Paiva JA, Poissy J, Peiffer-Smadja N, Costagliola D, Yazdanpanah Y, Bouscambert-Duchamp M, Gagneux-Brunon A, Ader F, Mentre F, Wallet F, Burdet C, Guedj J; DisCoVeRy study group. Association between SARS-CoV-2 viral kinetics and clinical score evolution in hospitalized patients. CPT Pharmacometrics Syst Pharmacol. 2023 Dec;12(12):2027-2037. doi: 10.1002/psp4.13051. Epub 2023 Oct 11."
#       },
#       {
#         "pmid": "35512728",
#         "type": "DERIVED",
#         "citation": "WHO Solidarity Trial Consortium. Remdesivir and three other drugs for hospitalised patients with COVID-19: final results of the WHO Solidarity randomised trial and updated meta-analyses. Lancet. 2022 May 21;399(10339):1941-1953. doi: 10.1016/S0140-6736(22)00519-0. Epub 2022 May 2. Erratum In: Lancet. 2022 Oct 29;400(10362):1512. Lancet. 2024 Jan 13;403(10422):146."
#       },
#       {
#         "pmid": "34473343",
#         "type": "DERIVED",
#         "citation": "Kreuzberger N, Hirsch C, Chai KL, Tomlinson E, Khosravi Z, Popp M, Neidhardt M, Piechotta V, Salomon S, Valk SJ, Monsef I, Schmaderer C, Wood EM, So-Osman C, Roberts DJ, McQuilten Z, Estcourt LJ, Skoetz N. SARS-CoV-2-neutralising monoclonal antibodies for treatment of COVID-19. Cochrane Database Syst Rev. 2021 Sep 2;9(9):CD013825. doi: 10.1002/14651858.CD013825.pub2."
#       },
#       {
#         "pmid": "34350582",
#         "type": "DERIVED",
#         "citation": "Ansems K, Grundeis F, Dahms K, Mikolajewska A, Thieme V, Piechotta V, Metzendorf MI, Stegemann M, Benstoem C, Fichtner F. Remdesivir for the treatment of COVID-19. Cochrane Database Syst Rev. 2021 Aug 5;8(8):CD014962. doi: 10.1002/14651858.CD014962."
#       },
#       {
#         "pmid": "32304640",
#         "type": "DERIVED",
#         "citation": "Taccone FS, Gorham J, Vincent JL. Hydroxychloroquine in the management of critically ill patients with COVID-19: the need for an evidence base. Lancet Respir Med. 2020 Jun;8(6):539-541. doi: 10.1016/S2213-2600(20)30172-7. Epub 2020 Apr 15. No abstract available."
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT02987530",
#     "BriefTitle": "National Multicenter Trial Evaluating Two Treatments in Patients With Primary Human Immunodeficiency Virus (HIV-1) Infection",
#     "LeadSponsorName": "ANRS, Emerging Infectious Diseases",
#     "CollaboratorName": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France",
#     "OverallStatus": "COMPLETED",
#     "StudyType": "INTERVENTIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2016-12-09",
#     "StartDate": "2017-04-11",
#     "CompletionDate": "2020-01-31",
#     "Reference": []
#   },
#   {
#     "NCTId": "NCT05311865",
#     "BriefTitle": "Transmission of Covid-19 During Clubbing Events in Closed Places",
#     "LeadSponsorName": "ANRS, Emerging Infectious Diseases",
#     "CollaboratorName": "Cerballiance | Kappa Sant\u00e9",
#     "OverallStatus": "COMPLETED",
#     "StudyType": "INTERVENTIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2022-04-05",
#     "StartDate": "2021-09-04",
#     "CompletionDate": "2022-02-26",
#     "Reference": []
#   },
#   {
#     "NCTId": "NCT00122616",
#     "BriefTitle": "Efficacy of Pegylated Interferon on Liver Fibrosis in Co-infected Patient With HIV and Hepatitis C",
#     "LeadSponsorName": "French National Agency for Research on AIDS and Viral Hepatitis",
#     "CollaboratorName": "Hoffmann-La Roche",
#     "OverallStatus": "COMPLETED",
#     "StudyType": "INTERVENTIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2005-07-22",
#     "StartDate": "2003-11",
#     "CompletionDate": "2009-03",
#     "Reference": [
#       {
#         "pmid": "23800784",
#         "type": "DERIVED",
#         "citation": "Chapplain JM, Bellissant E, Guyader D, Molina JM, Poizot-Martin I, Perre P, Pialoux G, Turlin B, Mouchel C, Renault A, Michelet C; ANRS HC-12 Study Group. The effects of a maintenance therapy with peg-interferon alpha-2a on liver fibrosis in HIV/HCV co-infected patients: a randomized controlled trial. J Infect. 2013 Oct;67(4):313-21. doi: 10.1016/j.jinf.2013.05.007. Epub 2013 Jun 22."
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT02428816",
#     "BriefTitle": "Evaluation of a Multimodal Neuroimaging Method for Diagnosis in Parkinsonian Syndromes",
#     "LeadSponsorName": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France",
#     "CollaboratorName": null,
#     "OverallStatus": "COMPLETED",
#     "StudyType": "INTERVENTIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2015-04-29",
#     "StartDate": "2013-01-24",
#     "CompletionDate": "2016-07-28",
#     "Reference": []
#   },
#   {
#     "NCTId": "NCT02453048",
#     "BriefTitle": "Study of BPZE1 (High Dose) Nasal Live Attenuated B. Pertussis Vaccine",
#     "LeadSponsorName": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France",
#     "CollaboratorName": null,
#     "OverallStatus": "COMPLETED",
#     "StudyType": "INTERVENTIONAL",
#     "HasResults": true,
#     "StudyFirstPostDate": "2015-05-25",
#     "StartDate": "2015-09",
#     "CompletionDate": "2017-12",
#     "Reference": [
#       {
#         "pmid": "24421886",
#         "type": "BACKGROUND",
#         "citation": "Thorstensson R, Trollfors B, Al-Tawil N, Jahnmatz M, Bergstrom J, Ljungman M, Torner A, Wehlin L, Van Broekhoven A, Bosman F, Debrie AS, Mielcarek N, Locht C. A phase I clinical study of a live attenuated Bordetella pertussis vaccine--BPZE1; a single centre, double-blind, placebo-controlled, dose-escalating study of BPZE1 given intranasally to healthy adult male volunteers. PLoS One. 2014 Jan 8;9(1):e83449. doi: 10.1371/journal.pone.0083449. eCollection 2014."
#       },
#       {
#         "pmid": "24793938",
#         "type": "BACKGROUND",
#         "citation": "Jahnmatz M, Amu S, Ljungman M, Wehlin L, Chiodi F, Mielcarek N, Locht C, Thorstensson R. B-cell responses after intranasal vaccination with the novel attenuated Bordetella pertussis vaccine strain BPZE1 in a randomized phase I clinical trial. Vaccine. 2014 Jun 5;32(27):3350-6. doi: 10.1016/j.vaccine.2014.04.048. Epub 2014 Apr 29."
#       },
#       {
#         "pmid": "24950361",
#         "type": "BACKGROUND",
#         "citation": "Feunou PF, Kammoun H, Debrie AS, Locht C. Heterologous prime-boost immunization with live attenuated B. pertussis BPZE1 followed by acellular pertussis vaccine in mice. Vaccine. 2014 Jul 23;32(34):4281-8. doi: 10.1016/j.vaccine.2014.06.019. Epub 2014 Jun 17."
#       },
#       {
#         "pmid": "22814407",
#         "type": "BACKGROUND",
#         "citation": "Kammoun H, Feunou PF, Foligne B, Debrie AS, Raze D, Mielcarek N, Locht C. Dual mechanism of protection by live attenuated Bordetella pertussis BPZE1 against Bordetella bronchiseptica in mice. Vaccine. 2012 Aug 31;30(40):5864-70. doi: 10.1016/j.vaccine.2012.07.005. Epub 2012 Jul 17."
#       },
#       {
#         "pmid": "21430219",
#         "type": "BACKGROUND",
# ...
#       },
#       {
#         "pmid": "23936509",
#         "type": "BACKGROUND",
#         "citation": "Krastinova E, Seng R, Yeni P, Viard JP, Vittecoq D, Lascoux-Combe C, Fourn E, Pahlavan G, Delfraissy JF, Goujard C, Meyer L; ANRS PRIMO and COPANA Cohorts. Is clinical practice concordant with the changes in guidelines for antiretroviral therapy initiation during primary and chronic HIV-1 infection? The ANRS PRIMO and COPANA cohorts. PLoS One. 2013 Aug 1;8(8):e71473. doi: 10.1371/journal.pone.0071473. Print 2013. Erratum In: PLoS One. 2013;8(11). doi:10.1371/annotation/aed12a66-9c76-4e49-806b-881a2fe23bba. Goujard, Cecile [added]."
#       },
#       {
#         "pmid": "24058636",
#         "type": "BACKGROUND",
#         "citation": "Legeai C, Vigouroux C, Souberbielle JC, Bouchaud O, Boufassa F, Bastard JP, Carlier R, Capeau J, Goujard C, Meyer L, Viard JP; ANRS-COPANA Cohort Study Group. Associations between 25-hydroxyvitamin D and immunologic, metabolic, inflammatory markers in treatment-naive HIV-infected persons: the ANRS CO9 <<COPANA>> cohort study. PLoS One. 2013 Sep 18;8(9):e74868. doi: 10.1371/journal.pone.0074868. eCollection 2013."
#       },
#       {
#         "pmid": "24465584",
#         "type": "BACKGROUND",
#         "citation": "Boufassa F, Lechenadec J, Meyer L, Costagliola D, Hunt PW, Pereyra F, Deeks S, Pancino G, Taulera O, Lichterfeld M, Delobel P, Saez-Cirion A, Lambotte O; ANRS CO18 HIV Controllers Cohort; Cascade Collaboration in Eurocoord; SCOPE Cohort; International HIV Controllers Study. Blunted response to combination antiretroviral therapy in HIV elite controllers: an international HIV controller collaboration. PLoS One. 2014 Jan 17;9(1):e85516. doi: 10.1371/journal.pone.0085516. eCollection 2014."
#       },
#       {
#         "pmid": "25573889",
#         "type": "BACKGROUND",
#         "citation": "El Khoury P, Ghislain M, Villard EF, Le Goff W, Lascoux-Combe C, Yeni P, Meyer L, Vigouroux C, Goujard C, Guerin M. Plasma cholesterol efflux capacity from human THP-1 macrophages is reduced in HIV-infected patients: impact of HAART. J Lipid Res. 2015 Mar;56(3):692-702. doi: 10.1194/jlr.M054510. Epub 2015 Jan 8."
#       },
#       {
#         "pmid": "26636578",
#         "type": "BACKGROUND",
#         "citation": "Ghislain M, Bastard JP, Meyer L, Capeau J, Fellahi S, Gerard L, May T, Simon A, Vigouroux C, Goujard C; ANRS-COPANA Cohort Study Group. Late Antiretroviral Therapy (ART) Initiation Is Associated with Long-Term Persistence of Systemic Inflammation and Metabolic Abnormalities. PLoS One. 2015 Dec 4;10(12):e0144317. doi: 10.1371/journal.pone.0144317. eCollection 2015."
#       },
#       {
#         "pmid": "27509048",
#         "type": "BACKGROUND",
#         "citation": "Ploquin MJ, Madec Y, Casrouge A, Huot N, Passaes C, Lecuroux C, Essat A, Boufassa F, Jacquelin B, Jochems SP, Petitjean G, Angin M, Gartner K, Garcia-Tellez T, Noel N, Booiman T, Boeser-Nunnink BD, Roques P, Saez-Cirion A, Vaslin B, Dereudre-Bosquet N, Barre-Sinoussi F, Ghislain M, Rouzioux C, Lambotte O, Albert ML, Goujard C, Kootstra N, Meyer L, Muller-Trutwin MC. Elevated Basal Pre-infection CXCL10 in Plasma and in the Small Intestine after Infection Are Associated with More Rapid HIV/SIV Disease Onset. PLoS Pathog. 2016 Aug 10;12(8):e1005774. doi: 10.1371/journal.ppat.1005774. eCollection 2016 Aug."
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT01037777",
#     "BriefTitle": "RISCA : Prospective Study of Individuals at Risk for SCA1, SCA2, SCA3, SCA6, SCA7",
#     "LeadSponsorName": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France",
#     "CollaboratorName": null,
#     "OverallStatus": "COMPLETED",
#     "StudyType": "OBSERVATIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2009-12-23",
#     "StartDate": "2009-05-07",
#     "CompletionDate": "2017-12-14",
#     "Reference": [
#       {
#         "pmid": "35264424",
#         "type": "DERIVED",
#         "citation": "Wilke C, Mengel D, Schols L, Hengel H, Rakowicz M, Klockgether T, Durr A, Filla A, Melegh B, Schule R, Reetz K, Jacobi H, Synofzik M. Levels of Neurofilament Light at the Preataxic and Ataxic Stages of Spinocerebellar Ataxia Type 1. Neurology. 2022 May 17;98(20):e1985-e1996. doi: 10.1212/WNL.0000000000200257. Epub 2022 Mar 9."
#       },
#       {
#         "pmid": "32822634",
#         "type": "DERIVED",
#         "citation": "Jacobi H, du Montcel ST, Romanzetti S, Harmuth F, Mariotti C, Nanetti L, Rakowicz M, Makowicz G, Durr A, Monin ML, Filla A, Roca A, Schols L, Hengel H, Infante J, Kang JS, Timmann D, Casali C, Masciullo M, Baliko L, Melegh B, Nachbauer W, Burk-Gergs K, Schulz JB, Riess O, Reetz K, Klockgether T. Conversion of individuals at risk for spinocerebellar ataxia types 1, 2, 3, and 6 to manifest ataxia (RISCA): a longitudinal cohort study. Lancet Neurol. 2020 Sep;19(9):738-747. doi: 10.1016/S1474-4422(20)30235-0."
#       },
#       {
#         "pmid": "24780882",
#         "type": "DERIVED",
#         "citation": "Tezenas du Montcel S, Durr A, Rakowicz M, Nanetti L, Charles P, Sulek A, Mariotti C, Rola R, Schols L, Bauer P, Dufaure-Gare I, Jacobi H, Forlani S, Schmitz-Hubsch T, Filla A, Timmann D, van de Warrenburg BP, Marelli C, Kang JS, Giunti P, Cook A, Baliko L, Melegh B, Boesch S, Szymanski S, Berciano J, Infante J, Buerk K, Masciullo M, Di Fabio R, Depondt C, Ratka S, Stevanin G, Klockgether T, Brice A, Golmard JL. Prediction of the age at onset in spinocerebellar ataxia type 1, 2, 3 and 6. J Med Genet. 2014 Jul;51(7):479-86. doi: 10.1136/jmedgenet-2013-102200. Epub 2014 Apr 29. Erratum In: J Med Genet. 2014 Sep;51(9):613. Bela, Melegh [corrected to Melegh, Bela]."
#       },
#       {
#         "pmid": "23707147",
#         "type": "DERIVED",
#         "citation": "Jacobi H, Reetz K, du Montcel ST, Bauer P, Mariotti C, Nanetti L, Rakowicz M, Sulek A, Durr A, Charles P, Filla A, Antenora A, Schols L, Schicks J, Infante J, Kang JS, Timmann D, Di Fabio R, Masciullo M, Baliko L, Melegh B, Boesch S, Burk K, Peltz A, Schulz JB, Dufaure-Gare I, Klockgether T. Biological and clinical characteristics of individuals at risk for spinocerebellar ataxia types 1, 2, 3, and 6 in the longitudinal RISCA study: analysis of baseline data. Lancet Neurol. 2013 Jul;12(7):650-8. doi: 10.1016/S1474-4422(13)70104-2. Epub 2013 May 22. Erratum In: Lancet Neurol. 2013 Jul;12(7):630."
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT01842477",
#     "BriefTitle": "Evaluation of Efficacy and Safety of Autologous MSCs Combined to Biomaterials to Enhance Bone Healing",
#     "LeadSponsorName": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France",
#     "CollaboratorName": null,
#     "OverallStatus": "COMPLETED",
#     "StudyType": "INTERVENTIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2013-04-29",
#     "StartDate": "2013-05",
#     "CompletionDate": "2016-02-05",
#     "Reference": []
#   },
#   {
#     "NCTId": "NCT02721745",
#     "BriefTitle": "Cause and Consequence of Neural Fatigue",
#     "LeadSponsorName": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France",
#     "CollaboratorName": null,
#     "OverallStatus": "COMPLETED",
#     "StudyType": "INTERVENTIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2016-03-29",
#     "StartDate": "2016-05-23",
#     "CompletionDate": "2020-12",
#     "Reference": []
#   },
#   {
#     "NCTId": "NCT02408354",
#     "BriefTitle": "Pilot Study, Comparative, Single-center, Randomized, Crossover, Double-blind, Against Placebo, Testing the Effectiveness of Triheptanoin Oil in Alternating Hemiplegia of Childhood",
#     "LeadSponsorName": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France",
#     "CollaboratorName": null,
#     "OverallStatus": "COMPLETED",
#     "StudyType": "INTERVENTIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2015-04-03",
#     "StartDate": "2015-04-15",
#     "CompletionDate": "2017-04-05",
#     "Reference": [
#       {
#         "pmid": "28969699",
#         "type": "DERIVED",
#         "citation": "Hainque E, Caillet S, Leroy S, Flamand-Roze C, Adanyeguh I, Charbonnier-Beaupel F, Retail M, Le Toullec B, Atencio M, Rivaud-Pechoux S, Brochard V, Habarou F, Ottolenghi C, Cormier F, Meneret A, Ruiz M, Doulazmi M, Roubergue A, Corvol JC, Vidailhet M, Mochel F, Roze E. A randomized, controlled, double-blind, crossover trial of triheptanoin in alternating hemiplegia of childhood. Orphanet J Rare Dis. 2017 Oct 2;12(1):160. doi: 10.1186/s13023-017-0713-2."
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT01688453",
#     "BriefTitle": "Overweight Management and Social Inequalities",
#     "LeadSponsorName": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France",
#     "CollaboratorName": null,
#     "OverallStatus": "COMPLETED",
#     "StudyType": "INTERVENTIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2012-09-19",
#     "StartDate": "2012-04",
#     "CompletionDate": "2015-11",
#     "Reference": [
#       {
#         "pmid": "34087324",
#         "type": "DERIVED",
#         "citation": "Manneville F, Omorou AY, Legrand K, Lecomte E, Rydberg JA, Briancon S, Guillemin F; PRALIMAP Trial Group. Sociodemographic and psychological characteristics associated with discrepancy between body satisfaction and weight change among adolescents. Prev Med. 2021 Sep;150:106668. doi: 10.1016/j.ypmed.2021.106668. Epub 2021 Jun 1."
#       },
#       {
#         "pmid": "32097754",
#         "type": "DERIVED",
#         "citation": "Omorou AY, Manneville F, Langlois J, Legrand K, Bohme P, Muller L, Guillemin F, Briancon S, Lecomte E; PRALIMAP-INES Trial Group. Physical activity rather than sedentary behaviour is socially determined in French adolescents with overweight and obesity. Prev Med. 2020 May;134:106043. doi: 10.1016/j.ypmed.2020.106043. Epub 2020 Feb 22."
#       },
#       {
#         "pmid": "29934380",
#         "type": "DERIVED",
#         "citation": "Saez L, Legrand K, Alleyrat C, Ramisasoa S, Langlois J, Muller L, Omorou AY, De Lavenne R, Kivits J, Lecomte E, Briancon S; PRALIMAP-INES Trial Group. Using facilitator-receiver peer dyads matched according to socioeconomic status to promote behaviour change in overweight adolescents: a feasibility study. BMJ Open. 2018 Jun 22;8(6):e019731. doi: 10.1136/bmjopen-2017-019731."
#       },
#       {
#         "pmid": "29776897",
#         "type": "DERIVED",
#         "citation": "Saez L, Langlois J, Legrand K, Quinet MH, Lecomte E, Omorou AY, Briancon S; PRALIMAP-INES Trial Group. Reach and Acceptability of a Mobile Reminder Strategy and Facebook Group Intervention for Weight Management in Less Advantaged Adolescents: Insights From the PRALIMAP-INES Trial. JMIR Mhealth Uhealth. 2018 May 18;6(5):e110. doi: 10.2196/mhealth.7657."
#       },
#       {
#         "pmid": "29696179",
#         "type": "DERIVED",
#         "citation": "Legrand K, Lecomte E, Langlois J, Muller L, Saez L, Quinet MH, Bohme P, Spitz E, Omorou AY, Briancon S; PRALIMAP-INES trial group. Reducing social inequalities in access to overweight and obesity care management for adolescents: The PRALIMAP-INES trial protocol and inclusion data analysis. Contemp Clin Trials Commun. 2017 Jun 16;7:141-157. doi: 10.1016/j.conctc.2017.05.010. eCollection 2017 Sep."
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT02172677",
#     "BriefTitle": "The Influence of Collective Schemas on Individual Memory",
#     "LeadSponsorName": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France",
#     "CollaboratorName": "La R\u00e9gion Basse-Normandie | Universit\u00e9 de Caen Normandie | University Hospital, Caen | Ecole Pratique des Hautes Etudes | Equipement d'Excellence Matrice",
#     "OverallStatus": "COMPLETED",
#     "StudyType": "INTERVENTIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2014-06-24",
#     "StartDate": "2014-10",
#     "CompletionDate": "2016-10-14",
#     "Reference": []
#   },
#   {
#     "NCTId": "NCT01880151",
#     "BriefTitle": "Neuroelectrical Biomarkers for Alzheimer's Disease Stages",
#     "LeadSponsorName": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France",
#     "CollaboratorName": null,
#     "OverallStatus": "COMPLETED",
#     "StudyType": "INTERVENTIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2013-06-18",
#     "StartDate": "2013-07-12",
#     "CompletionDate": "2019-01",
#     "Reference": []
#   },
#   {
#     "NCTId": "NCT02658253",
#     "BriefTitle": "Trial to Evaluate the Safety and Immunogenicity of a Placental Malaria Vaccine Candidate (PRIMVAC ) in Healthy Adults",
#     "LeadSponsorName": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France",
#     "CollaboratorName": "EVI Industries, Inc. | Recherche Clinique Paris Descartes Necker Cochin Sainte Anne | Centre national de recherche et de formation sur le paludisme | EUCLID Clinical Trial Platform",
#     "OverallStatus": "COMPLETED",
#     "StudyType": "INTERVENTIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2016-01-18",
#     "StartDate": "2016-01",
#     "CompletionDate": "2019-02-21",
#     "Reference": [
#       {
#         "pmid": "33717176",
#         "type": "DERIVED",
#         "citation": "Gamain B, Chene A, Viebig NK, Tuikue Ndam N, Nielsen MA. Progress and Insights Toward an Effective Placental Malaria Vaccine. Front Immunol. 2021 Feb 25;12:634508. doi: 10.3389/fimmu.2021.634508. eCollection 2021."
#       },
#       {
#         "pmid": "32032566",
#         "type": "DERIVED",
#         "citation": "Sirima SB, Richert L, Chene A, Konate AT, Campion C, Dechavanne S, Semblat JP, Benhamouda N, Bahuaud M, Loulergue P, Ouedraogo A, Nebie I, Kabore M, Kargougou D, Barry A, Ouattara SM, Boilet V, Allais F, Roguet G, Havelange N, Lopez-Perez E, Kuppers A, Konate E, Roussillon C, Kante M, Belarbi L, Diarra A, Henry N, Soulama I, Ouedraogo A, Esperou H, Leroy O, Batteux F, Tartour E, Viebig NK, Thiebaut R, Launay O, Gamain B. PRIMVAC vaccine adjuvanted with Alhydrogel or GLA-SE to prevent placental malaria: a first-in-human, randomised, double-blind, placebo-controlled study. Lancet Infect Dis. 2020 May;20(5):585-597. doi: 10.1016/S1473-3099(19)30739-X. Epub 2020 Feb 4."
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT02027051",
#     "BriefTitle": "Etude g\u00e9n\u00e9tique Des Arm\u00e9niens",
#     "LeadSponsorName": "Institut National de la Sant\u00e9 Et de la Recherche M\u00e9dicale, France",
#     "CollaboratorName": null,
#     "OverallStatus": "COMPLETED",
#     "StudyType": "OBSERVATIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2014-01-03",
#     "StartDate": "2014-01",
#     "CompletionDate": "2017-01",
#     "Reference": []
#   },
#   {
#     "NCTId": "NCT00118677",
#     "BriefTitle": "Long-Term Supervised Treatment Interruption in HIV-Infected Patients",
#     "LeadSponsorName": "French National Agency for Research on AIDS and Viral Hepatitis",
#     "CollaboratorName": null,
#     "OverallStatus": "COMPLETED",
#     "StudyType": "INTERVENTIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2005-07-12",
#     "StartDate": "2003-02",
#     "CompletionDate": "2007-05",
#     "Reference": [
#       {
#         "pmid": "20657770",
#         "type": "DERIVED",
#         "citation": "Weiss L, Piketty C, Assoumou L, Didier C, Caccavelli L, Donkova-Petrini V, Levy Y, Girard PM, Burgard M, Viard JP, Rouzioux C, Costagliola D; ANRS 116 SALTO study group. Relationship between regulatory T cells and immune activation in human immunodeficiency virus-infected patients interrupting antiretroviral therapy. PLoS One. 2010 Jul 21;5(7):e11659. doi: 10.1371/journal.pone.0011659."
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT00647205",
#     "BriefTitle": "Evaluation of 2 Interferon \u03b3 Assays in the Diagnosis of Latent Tuberculosis in HIV-infected Patients.ANRS EP 40 QUANTI SPOT",
#     "LeadSponsorName": "French National Agency for Research on AIDS and Viral Hepatitis",
#     "CollaboratorName": null,
#     "OverallStatus": "COMPLETED",
#     "StudyType": "INTERVENTIONAL",
#     "HasResults": false,
#     "StudyFirstPostDate": "2008-03-31",
#     "StartDate": "2008-01",
#     "CompletionDate": "2010-11",
#     "Reference": []
#   }
# ]

# %% [markdown]
# On vérifie que l'on n'a pas perdu de NCTId en route:

# %%
print(f'Nombre de NCTId: {len(studies_list)}')
assert response.json()['totalCount'] == len(studies_list)
# Out:
# Nombre de NCTId: 289

# %% [markdown]
# ### Import dans Pandas

# %%
df_ct = pd.json_normalize(data=studies_list)
df_ct
# Out:
#            NCTId                                         BriefTitle  \
# 0    NCT02014727  Safety and Immunogenicity of Recombinant Pichi...
# 1    NCT00117494  Rosuvastatin Versus Pravastatin in HIV Patient...
# 2    NCT00536627  Efficacy and Tolerance of Naked DNA Vaccine in...
# 3    NCT01033760  Optimisation of Primary HIV1 Infection Treatme...
# 4    NCT05349162        Epicardial vs. Transvenous ICDs in Children
# ..           ...                                                ...
# 284  NCT01880151  Neuroelectrical Biomarkers for Alzheimer's Dis...
# 285  NCT02658253  Trial to Evaluate the Safety and Immunogenicit...
# 286  NCT02027051                      Etude génétique Des Arméniens
# 287  NCT00118677  Long-Term Supervised Treatment Interruption in...
# 288  NCT00647205  Evaluation of 2 Interferon γ Assays in the Dia...
#
#                                        LeadSponsorName  \
# 0    Institut National de la Santé Et de la Recherc...
# 1    French National Agency for Research on AIDS an...
# 2    French National Agency for Research on AIDS an...
# 3                   ANRS, Emerging Infectious Diseases
# 4    Paris Cardiovascular Research Center (Inserm U...
# ..                                                 ...
# 284  Institut National de la Santé Et de la Recherc...
# 285  Institut National de la Santé Et de la Recherc...
# 286  Institut National de la Santé Et de la Recherc...
# 287  French National Agency for Research on AIDS an...
# 288  French National Agency for Research on AIDS an...
#
#                                       CollaboratorName OverallStatus  \
# 0    EVI Industries, Inc. | BPRC | Recherche Cliniq...     COMPLETED
# 1                                                 None     COMPLETED
# 2                                                 None     COMPLETED
# 3    Gilead Sciences | Merck Sharp & Dohme LLC | Pf...     COMPLETED
# 4                       Hôpital Necker-Enfants Malades     COMPLETED
# ..                                                 ...           ...
# 284                                               None     COMPLETED
# 285  EVI Industries, Inc. | Recherche Clinique Pari...     COMPLETED
# 286                                               None     COMPLETED
# 287                                               None     COMPLETED
# 288                                               None     COMPLETED
#
#           StudyType  HasResults StudyFirstPostDate   StartDate CompletionDate  \
# 0    INTERVENTIONAL       False         2013-12-18     2014-01        2015-07
# 1    INTERVENTIONAL       False         2005-07-07     2005-10        2007-06
# 2    INTERVENTIONAL       False         2007-09-28     2008-01        2010-11
# 3    INTERVENTIONAL       False         2009-12-16     2010-04        2013-12
# 4     OBSERVATIONAL       False         2022-04-27  2003-01-01     2022-04-01
# ..              ...         ...                ...         ...            ...
# 284  INTERVENTIONAL       False         2013-06-18  2013-07-12        2019-01
# 285  INTERVENTIONAL       False         2016-01-18     2016-01     2019-02-21
# 286   OBSERVATIONAL       False         2014-01-03     2014-01        2017-01
# 287  INTERVENTIONAL       False         2005-07-12     2003-02        2007-05
# 288  INTERVENTIONAL       False         2008-03-31     2008-01        2010-11
#
#                                              Reference
# 0    [{'pmid': '28947345', 'type': 'DERIVED', 'cita...
# 1    [{'pmid': '22739396', 'type': 'DERIVED', 'cita...
# 2    [{'pmid': '16310901', 'type': 'BACKGROUND', 'c...
# 3    [{'pmid': '28708873', 'type': 'DERIVED', 'cita...
# 4                                                   []
# ..                                                 ...
# 284                                                 []
# 285  [{'pmid': '33717176', 'type': 'DERIVED', 'cita...
# 286                                                 []
# 287  [{'pmid': '20657770', 'type': 'DERIVED', 'cita...
# 288                                                 []
#
# [289 rows x 11 columns]

# %% [markdown]
# #### On "explose" la colonne "References":
#
# Pour chaque NCTId, la colonne réferences contient potentiellement une liste de plusieurs références.
# Si par exemple, on a 3 références, on veut se retrouver avec 3 lignes, chacune indexée par le même NCTId et contenant une unique réference.
#
# *Avant*:
# **`NCTId    References`**
# `NCT0001, [Ref1, Ref2, Ref3]`
#
# *Après*:
# **`NCTId    References`**
# `NCT0001,   Ref1`
# `NCT0001,   Ref2`
# `NCT0001,   Ref3`

# %%
df_ct = df_ct.explode('Reference', ignore_index=True)
df_ct
# Out:
#            NCTId                                         BriefTitle  \
# 0    NCT02014727  Safety and Immunogenicity of Recombinant Pichi...
# 1    NCT00117494  Rosuvastatin Versus Pravastatin in HIV Patient...
# 2    NCT00117494  Rosuvastatin Versus Pravastatin in HIV Patient...
# 3    NCT00536627  Efficacy and Tolerance of Naked DNA Vaccine in...
# 4    NCT00536627  Efficacy and Tolerance of Naked DNA Vaccine in...
# ..           ...                                                ...
# 686  NCT02658253  Trial to Evaluate the Safety and Immunogenicit...
# 687  NCT02658253  Trial to Evaluate the Safety and Immunogenicit...
# 688  NCT02027051                      Etude génétique Des Arméniens
# 689  NCT00118677  Long-Term Supervised Treatment Interruption in...
# 690  NCT00647205  Evaluation of 2 Interferon γ Assays in the Dia...
#
#                                        LeadSponsorName  \
# 0    Institut National de la Santé Et de la Recherc...
# 1    French National Agency for Research on AIDS an...
# 2    French National Agency for Research on AIDS an...
# 3    French National Agency for Research on AIDS an...
# 4    French National Agency for Research on AIDS an...
# ..                                                 ...
# 686  Institut National de la Santé Et de la Recherc...
# 687  Institut National de la Santé Et de la Recherc...
# 688  Institut National de la Santé Et de la Recherc...
# 689  French National Agency for Research on AIDS an...
# 690  French National Agency for Research on AIDS an...
#
#                                       CollaboratorName OverallStatus  \
# 0    EVI Industries, Inc. | BPRC | Recherche Cliniq...     COMPLETED
# 1                                                 None     COMPLETED
# 2                                                 None     COMPLETED
# 3                                                 None     COMPLETED
# 4                                                 None     COMPLETED
# ..                                                 ...           ...
# 686  EVI Industries, Inc. | Recherche Clinique Pari...     COMPLETED
# 687  EVI Industries, Inc. | Recherche Clinique Pari...     COMPLETED
# 688                                               None     COMPLETED
# 689                                               None     COMPLETED
# 690                                               None     COMPLETED
#
#           StudyType  HasResults StudyFirstPostDate StartDate CompletionDate  \
# 0    INTERVENTIONAL       False         2013-12-18   2014-01        2015-07
# 1    INTERVENTIONAL       False         2005-07-07   2005-10        2007-06
# 2    INTERVENTIONAL       False         2005-07-07   2005-10        2007-06
# 3    INTERVENTIONAL       False         2007-09-28   2008-01        2010-11
# 4    INTERVENTIONAL       False         2007-09-28   2008-01        2010-11
# ..              ...         ...                ...       ...            ...
# 686  INTERVENTIONAL       False         2016-01-18   2016-01     2019-02-21
# 687  INTERVENTIONAL       False         2016-01-18   2016-01     2019-02-21
# 688   OBSERVATIONAL       False         2014-01-03   2014-01        2017-01
# 689  INTERVENTIONAL       False         2005-07-12   2003-02        2007-05
# 690  INTERVENTIONAL       False         2008-03-31   2008-01        2010-11
#
#                                              Reference
# 0    {'pmid': '28947345', 'type': 'DERIVED', 'citat...
# 1    {'pmid': '22739396', 'type': 'DERIVED', 'citat...
# 2    {'pmid': '22318219', 'type': 'DERIVED', 'citat...
# 3    {'pmid': '16310901', 'type': 'BACKGROUND', 'ci...
# 4    {'pmid': '15382173', 'type': 'BACKGROUND', 'ci...
# ..                                                 ...
# 686  {'pmid': '33717176', 'type': 'DERIVED', 'citat...
# 687  {'pmid': '32032566', 'type': 'DERIVED', 'citat...
# 688                                                NaN
# 689  {'pmid': '20657770', 'type': 'DERIVED', 'citat...
# 690                                                NaN
#
# [691 rows x 11 columns]

# %% [markdown]
# Pour chaque NCTId, la colonne réference contient maintenant un dictionnaire de la forme:
# `{
# "pmid": "17545707",
# "type": "BACKGROUND",
# "citation": "...",
# }`
#
# Dont on veut extraire de nouvelles colonnes en utilant les clés du dictionnaire:
# **`pmid     type        citation`**
# `17545707, BACKGROUND, "..."`

# %%
df_ct_references = pd.json_normalize(df_ct.pop('Reference'))
df_ct_references
# Out:
#          pmid        type                                           citation
# 0    28947345     DERIVED  Sirima SB, Durier C, Kara L, Houard S, Gansane...
# 1    22739396     DERIVED  Bittar R, Giral P, Aslangul E, Assoumou L, Val...
# 2    22318219     DERIVED  Bittar R, Giral P, Aslangul E, Assoumou L, Val...
# 3    16310901  BACKGROUND  Mancini-Bourgine M, Fontaine H, Brechot C, Pol...
# 4    15382173  BACKGROUND  Mancini-Bourgine M, Fontaine H, Scott-Algara D...
# ..        ...         ...                                                ...
# 686  33717176     DERIVED  Gamain B, Chene A, Viebig NK, Tuikue Ndam N, N...
# 687  32032566     DERIVED  Sirima SB, Richert L, Chene A, Konate AT, Camp...
# 688       NaN         NaN                                                NaN
# 689  20657770     DERIVED  Weiss L, Piketty C, Assoumou L, Didier C, Cacc...
# 690       NaN         NaN                                                NaN
#
# [691 rows x 3 columns]

# %% [markdown]
# On réassemble la dataFrame complète:

# %%
df_ct = df_ct.join(df_ct_references)
df_ct
# Out:
#            NCTId                                         BriefTitle  \
# 0    NCT02014727  Safety and Immunogenicity of Recombinant Pichi...
# 1    NCT00117494  Rosuvastatin Versus Pravastatin in HIV Patient...
# 2    NCT00117494  Rosuvastatin Versus Pravastatin in HIV Patient...
# 3    NCT00536627  Efficacy and Tolerance of Naked DNA Vaccine in...
# 4    NCT00536627  Efficacy and Tolerance of Naked DNA Vaccine in...
# ..           ...                                                ...
# 686  NCT02658253  Trial to Evaluate the Safety and Immunogenicit...
# 687  NCT02658253  Trial to Evaluate the Safety and Immunogenicit...
# 688  NCT02027051                      Etude génétique Des Arméniens
# 689  NCT00118677  Long-Term Supervised Treatment Interruption in...
# 690  NCT00647205  Evaluation of 2 Interferon γ Assays in the Dia...
#
#                                        LeadSponsorName  \
# 0    Institut National de la Santé Et de la Recherc...
# 1    French National Agency for Research on AIDS an...
# 2    French National Agency for Research on AIDS an...
# 3    French National Agency for Research on AIDS an...
# 4    French National Agency for Research on AIDS an...
# ..                                                 ...
# 686  Institut National de la Santé Et de la Recherc...
# 687  Institut National de la Santé Et de la Recherc...
# 688  Institut National de la Santé Et de la Recherc...
# 689  French National Agency for Research on AIDS an...
# 690  French National Agency for Research on AIDS an...
#
#                                       CollaboratorName OverallStatus  \
# 0    EVI Industries, Inc. | BPRC | Recherche Cliniq...     COMPLETED
# 1                                                 None     COMPLETED
# 2                                                 None     COMPLETED
# 3                                                 None     COMPLETED
# 4                                                 None     COMPLETED
# ..                                                 ...           ...
# 686  EVI Industries, Inc. | Recherche Clinique Pari...     COMPLETED
# 687  EVI Industries, Inc. | Recherche Clinique Pari...     COMPLETED
# 688                                               None     COMPLETED
# 689                                               None     COMPLETED
# 690                                               None     COMPLETED
#
#           StudyType  HasResults StudyFirstPostDate StartDate CompletionDate  \
# 0    INTERVENTIONAL       False         2013-12-18   2014-01        2015-07
# 1    INTERVENTIONAL       False         2005-07-07   2005-10        2007-06
# 2    INTERVENTIONAL       False         2005-07-07   2005-10        2007-06
# 3    INTERVENTIONAL       False         2007-09-28   2008-01        2010-11
# 4    INTERVENTIONAL       False         2007-09-28   2008-01        2010-11
# ..              ...         ...                ...       ...            ...
# 686  INTERVENTIONAL       False         2016-01-18   2016-01     2019-02-21
# 687  INTERVENTIONAL       False         2016-01-18   2016-01     2019-02-21
# 688   OBSERVATIONAL       False         2014-01-03   2014-01        2017-01
# 689  INTERVENTIONAL       False         2005-07-12   2003-02        2007-05
# 690  INTERVENTIONAL       False         2008-03-31   2008-01        2010-11
#
#          pmid        type                                           citation
# 0    28947345     DERIVED  Sirima SB, Durier C, Kara L, Houard S, Gansane...
# 1    22739396     DERIVED  Bittar R, Giral P, Aslangul E, Assoumou L, Val...
# 2    22318219     DERIVED  Bittar R, Giral P, Aslangul E, Assoumou L, Val...
# 3    16310901  BACKGROUND  Mancini-Bourgine M, Fontaine H, Brechot C, Pol...
# 4    15382173  BACKGROUND  Mancini-Bourgine M, Fontaine H, Scott-Algara D...
# ..        ...         ...                                                ...
# 686  33717176     DERIVED  Gamain B, Chene A, Viebig NK, Tuikue Ndam N, N...
# 687  32032566     DERIVED  Sirima SB, Richert L, Chene A, Konate AT, Camp...
# 688       NaN         NaN                                                NaN
# 689  20657770     DERIVED  Weiss L, Piketty C, Assoumou L, Didier C, Cacc...
# 690       NaN         NaN                                                NaN
#
# [691 rows x 13 columns]

# %% [markdown]
# ***On reconstruit l'index :***

# %%
# df_studies_v2.set_index('NCTId', inplace = True)

# %% [markdown]
# ***On précise les types :***

# %%
df_ct = df_ct.convert_dtypes()
# df_ct = df_ct.astype({"OverallStatus" : 'category', "StudyType" : 'category', "type": 'category',})
df_ct = df_ct.astype({'OverallStatus': 'category', 'StudyType': 'category'})
df_ct.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 691 entries, 0 to 690
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   NCTId               691 non-null    string
#  1   BriefTitle          691 non-null    string
#  2   LeadSponsorName     691 non-null    string
#  3   CollaboratorName    350 non-null    string
#  4   OverallStatus       691 non-null    category
#  5   StudyType           691 non-null    category
#  6   HasResults          691 non-null    boolean
#  7   StudyFirstPostDate  691 non-null    string
#  8   StartDate           691 non-null    string
#  9   CompletionDate      690 non-null    string
#  10  pmid                541 non-null    string
#  11  type                541 non-null    string
#  12  citation            541 non-null    string
# dtypes: boolean(1), category(2), string(10)
# memory usage: 57.0 KB

# %%
df_ct
# Out:
#            NCTId                                         BriefTitle  \
# 0    NCT02014727  Safety and Immunogenicity of Recombinant Pichi...
# 1    NCT00117494  Rosuvastatin Versus Pravastatin in HIV Patient...
# 2    NCT00117494  Rosuvastatin Versus Pravastatin in HIV Patient...
# 3    NCT00536627  Efficacy and Tolerance of Naked DNA Vaccine in...
# 4    NCT00536627  Efficacy and Tolerance of Naked DNA Vaccine in...
# ..           ...                                                ...
# 686  NCT02658253  Trial to Evaluate the Safety and Immunogenicit...
# 687  NCT02658253  Trial to Evaluate the Safety and Immunogenicit...
# 688  NCT02027051                      Etude génétique Des Arméniens
# 689  NCT00118677  Long-Term Supervised Treatment Interruption in...
# 690  NCT00647205  Evaluation of 2 Interferon γ Assays in the Dia...
#
#                                        LeadSponsorName  \
# 0    Institut National de la Santé Et de la Recherc...
# 1    French National Agency for Research on AIDS an...
# 2    French National Agency for Research on AIDS an...
# 3    French National Agency for Research on AIDS an...
# 4    French National Agency for Research on AIDS an...
# ..                                                 ...
# 686  Institut National de la Santé Et de la Recherc...
# 687  Institut National de la Santé Et de la Recherc...
# 688  Institut National de la Santé Et de la Recherc...
# 689  French National Agency for Research on AIDS an...
# 690  French National Agency for Research on AIDS an...
#
#                                       CollaboratorName OverallStatus  \
# 0    EVI Industries, Inc. | BPRC | Recherche Cliniq...     COMPLETED
# 1                                                 <NA>     COMPLETED
# 2                                                 <NA>     COMPLETED
# 3                                                 <NA>     COMPLETED
# 4                                                 <NA>     COMPLETED
# ..                                                 ...           ...
# 686  EVI Industries, Inc. | Recherche Clinique Pari...     COMPLETED
# 687  EVI Industries, Inc. | Recherche Clinique Pari...     COMPLETED
# 688                                               <NA>     COMPLETED
# 689                                               <NA>     COMPLETED
# 690                                               <NA>     COMPLETED
#
#           StudyType  HasResults StudyFirstPostDate StartDate CompletionDate  \
# 0    INTERVENTIONAL       False         2013-12-18   2014-01        2015-07
# 1    INTERVENTIONAL       False         2005-07-07   2005-10        2007-06
# 2    INTERVENTIONAL       False         2005-07-07   2005-10        2007-06
# 3    INTERVENTIONAL       False         2007-09-28   2008-01        2010-11
# 4    INTERVENTIONAL       False         2007-09-28   2008-01        2010-11
# ..              ...         ...                ...       ...            ...
# 686  INTERVENTIONAL       False         2016-01-18   2016-01     2019-02-21
# 687  INTERVENTIONAL       False         2016-01-18   2016-01     2019-02-21
# 688   OBSERVATIONAL       False         2014-01-03   2014-01        2017-01
# 689  INTERVENTIONAL       False         2005-07-12   2003-02        2007-05
# 690  INTERVENTIONAL       False         2008-03-31   2008-01        2010-11
#
#          pmid        type                                           citation
# 0    28947345     DERIVED  Sirima SB, Durier C, Kara L, Houard S, Gansane...
# 1    22739396     DERIVED  Bittar R, Giral P, Aslangul E, Assoumou L, Val...
# 2    22318219     DERIVED  Bittar R, Giral P, Aslangul E, Assoumou L, Val...
# 3    16310901  BACKGROUND  Mancini-Bourgine M, Fontaine H, Brechot C, Pol...
# 4    15382173  BACKGROUND  Mancini-Bourgine M, Fontaine H, Scott-Algara D...
# ..        ...         ...                                                ...
# 686  33717176     DERIVED  Gamain B, Chene A, Viebig NK, Tuikue Ndam N, N...
# 687  32032566     DERIVED  Sirima SB, Richert L, Chene A, Konate AT, Camp...
# 688      <NA>        <NA>                                               <NA>
# 689  20657770     DERIVED  Weiss L, Piketty C, Assoumou L, Didier C, Cacc...
# 690      <NA>        <NA>                                               <NA>
#
# [691 rows x 13 columns]

# %% [markdown]
# #### Export en CSV :

# %%
# df_ct.to_csv('Data/outputs/extract_CT_api_v2.csv', sep=";", encoding='utf-8-sig')
df_ct.to_csv(
    'Data/outputs/extract_CT_api_v2.csv',
    sep=';',
    index=False,
    encoding='utf-8-sig',
)

# %% [markdown]
# # PubMed

# %% [markdown]
# ### Utilisation d'une clé pour l'API Pubmed :

# %% [markdown]
# Il est recommandé d'utiliser une clé pour accéder à l'API Pubmed, ce qui permet de lancer jusqu'à 10 requêtes par seconde.
# Sans clé, la limite est de 3 requêtes par seconde.
#
# > E-utils users are allowed 3 requests/second without an API key. Create an API key to increase your e-utils limit to 10 requests/second.
#
# **En pratique, l'API Pubmed étant beaucoup plus lente (~1 requête par seconde), cela ne semble pas changer grand chose.**
#
# Pour récupérer sa clé, se rendre sur la page en étant loggué:
# https://account.ncbi.nlm.nih.gov/settings/
#
# Une fois la clé récupérée, l'ajouter aux variables d'environnement avec la commande suivante:
#
# **Windows :**
#
# `setx NCBI_API_KEY “123456"`
#
# **Linux/MacOS :**
#
# `export NCBI_API_KEY = 123456`

# %%
import os

assert os.getenv('NCBI_API_KEY', None) is not None

# %% [markdown]
# ### Installer metapub :
# - Dans Conda Navigator, se placer dans le meme environnement que celui qui execute Jupyter
# - Lancer Powershell Prompt dans cet environnement
# - Taper la commande suivante :  `pip install metapub`

# %%
from metapub import PubMedFetcher
from metapub.exceptions import InvalidPMID

fetch = PubMedFetcher(cachedir='./.cache/')

# %% [markdown]
# ### Récupération des PMIDs via PubMed:

# %% [markdown]
# Pour chaque NCTId de CT, on récupère les PMIDs des publications associées via PubMed:

# %%
# Liste unique des NCTId extraits de ClinicalTrial
nctid_array = df_ct.loc[:, 'NCTId'].unique()

pmids_pubmed_dict = {}
for i, nctid in enumerate(nctid_array):
    # Display the progress on a single line
    print(f'\r{i+1}/{len(nctid_array)}...', end='', flush=True)

    pmids = [pmid for pmid in fetch.pmids_for_query(nctid)]
    pmids_pubmed_dict[nctid] = set(pmids)
# Out:
# 289/289...

# %%
pmids_pubmed_dict
# Out:
# {'NCT02014727': {'28947345'},
#  'NCT00117494': {'22318219', '22739396'},
#  'NCT00536627': {'24394187', '24555998'},
#  'NCT01033760': {'25701561', '28708873'},
#  'NCT05349162': {'36735263'},
#  'NCT01164462': set(),
#  'NCT02777229': {'31339676', '33010241', '33355914', '37851566', '38156046'},
#  'NCT00480792': {'21486976', '27064975'},
#  'NCT01095744': set(),
#  'NCT01489592': set(),
#  'NCT01453192': {'30688008'},
#  'NCT00460382': set(),
#  'NCT02486731': set(),
#  'NCT02116374': set(),
#  'NCT02497274': set(),
#  'NCT01022476': set(),
#  'NCT00528060': {'23459496'},
#  'NCT02078076': set(),
#  'NCT04008927': {'35774932'},
#  'NCT01331876': set(),
#  'NCT00820820': set(),
#  'NCT02273765': {'33667406'},
#  'NCT02107365': set(),
#  'NCT00113282': set(),
#  'NCT01055873': {'22427678'},
#  'NCT05199831': set(),
#  'NCT01359774': set(),
#  'NCT02099474': {'32661003'},
#  'NCT03546127': set(),
#  'NCT04315948': {'32304640',
#   '32958495',
#   '33264556',
#   '34048876',
#   '34350582',
#   '34473343',
#   '34534511',
#   '35233617',
#   '35512728',
#   '36695483',
#   '37728045'},
#  'NCT02987530': set(),
#  'NCT05311865': {'36438274', '37795682'},
#  'NCT00122616': {'23800784'},
#  'NCT02428816': set(),
#  'NCT02453048': {'31945015', '32687804'},
#  'NCT00120757': {'22353022'},
#  'NCT02566148': {'29307383', '29437866', '29982518'},
#  'NCT00640263': {'23039034',
#   '26603917',
#   '27895016',
#   '28469697',
#   '30814028',
#   '31633158',
#   '31994250',
#   '32067040',
#   '32228542',
#   '32991450',
#   '34425825'},
#  'NCT01693835': set(),
#  'NCT04470648': set(),
#  'NCT02573948': set(),
#  'NCT01693848': set(),
#  'NCT01895920': set(),
#  'NCT01039220': set(),
#  'NCT00820118': {'26568566'},
#  'NCT01801618': {'29662875'},
#  'NCT02405013': {'36686592'},
#  'NCT01779713': {'30354977'},
#  'NCT03235258': set(),
#  'NCT03071458': set(),
#  'NCT02886416': set(),
#  'NCT01899196': set(),
#  'NCT00944541': set(),
#  'NCT02160119': set(),
#  'NCT00158496': set(),
#  'NCT02192658': {'26846895'},
#  'NCT00383734': {'23432777'},
#  'NCT02051413': set(),
#  'NCT03109067': set(),
#  'NCT02073604': set(),
#  'NCT01490489': set(),
#  'NCT01335529': {'27077673'},
#  'NCT00545194': set(),
#  'NCT03298360': set(),
#  'NCT01508494': set(),
#  'NCT00573001': set(),
#  'NCT00236340': set(),
#  'NCT02542891': {'27488181', '34874888'},
#  'NCT03671291': set(),
#  'NCT01066962': {'25103176', '26520926', '30365452', '33794182'},
#  'NCT01703962': {'37668523'},
#  'NCT03642704': set(),
#  'NCT01086904': set(),
#  'NCT01127204': {'27015798',
#   '28434406',
#   '28453240',
#   '28483965',
#   '28800382',
#   '31334298',
#   '34723858'},
#  'NCT01771562': {'27881690', '30081838'},
#  'NCT00196612': set(),
#  'NCT01226446': {'25987791'},
#  'NCT02496312': set(),
#  'NCT04133012': set(),
#  'NCT01100281': set(),
#  'NCT01647295': set(),
#  'NCT00424814': {'23766338', '25838291'},
#  'NCT02488395': set(),
#  'NCT00658346': {'31063537'},
#  'NCT01188512': {'24261996', '24421886', '24793938'},
#  'NCT04945655': {'35332045'},
#  'NCT01942655': set(),
#  'NCT01332955': {'25139963'},
#  'NCT01552044': set(),
#  'NCT02592174': {'31755936'},
#  'NCT02100774': {'24808487', '26063065', '27798339'},
#  'NCT00490074': set(),
#  'NCT01882062': {'25568297'},
#  'NCT01525472': set(),
#  'NCT02650427': set(),
#  'NCT01473472': {'26624850', '28747274', '29229440', '31784343', '36601747'},
#  'NCT02267304': set(),
#  'NCT04780191': set(),
#  'NCT00495326': {'23433590', '24663014'},
#  'NCT03459157': {'34048794'},
#  'NCT01620957': set(),
#  'NCT00339157': {'21173013'},
#  'NCT01555450': {'28823681', '29909873'},
#  'NCT01348308': {'32040959'},
#  'NCT01696708': {'25568297'},
#  'NCT01509508': {'23880306',
#   '25880823',
#   '27504637',
#   '28329393',
#   '29199100',
#   '29890048',
#   '30027600',
#   '30321314',
#   '30412926',
#   '31637821',
#   '32970730'},
#  'NCT01874808': set(),
#  'NCT02126384': set(),
#  'NCT03150290': set(),
#  'NCT03519503': set(),
#  'NCT00465790': set(),
#  'NCT00122603': {'19420019'},
#  'NCT02314208': set(),
#  'NCT00121121': {'17712402'},
#  'NCT01432821': set(),
#  'NCT02071784': set(),
#  'NCT02738502': set(),
#  'NCT02992184': {'29615488'},
#  'NCT01514890': {'23669289', '24704719', '25556540'},
#  'NCT02212379': {'31269208'},
#  'NCT03652090': set(),
#  'NCT00196664': set(),
#  'NCT03335995': {'32026446', '37497675'},
#  'NCT00946595': {'29767684', '30968368'},
#  'NCT02469350': {'29636105'},
#  'NCT01546181': {'23620431',
#   '24406779',
#   '24576889',
#   '25077537',
#   '26418443',
#   '26523388',
#   '30010022'},
#  'NCT00122538': {'20516271', '21857286', '23719348'},
#  'NCT01426243': {'26314624', '30096071'},
#  'NCT04824638': set(),
#  'NCT02113943': set(),
#  'NCT00299143': set(),
#  'NCT03870438': {'38484756'},
#  'NCT01605890': {'29590335'},
#  'NCT00391638': set(),
#  'NCT02323308': set(),
#  'NCT02384967': {'29905808'},
#  'NCT00988767': {'20090916'},
#  'NCT00323804': set(),
#  'NCT04849767': {'34916316'},
#  'NCT03047967': set(),
#  'NCT00120367': {'21738597'},
#  'NCT01038401': set(),
#  'NCT04484740': set(),
#  'NCT03078439': {'38408861'},
#  'NCT00148863': {'23190183'},
#  'NCT01548586': set(),
#  'NCT00302822': set(),
#  'NCT00196625': set(),
#  'NCT01188525': set(),
#  'NCT00670839': {'26257021'},
#  'NCT00158522': set(),
#  'NCT00196586': set(),
#  'NCT04808986': set(),
#  'NCT02626286': {'33753460', '34022820', '34352834'},
#  'NCT01207986': set(),
#  'NCT03537196': {'33208326'},
#  'NCT04684758': set(),
#  'NCT00121758': {'20625264', '23759749'},
#  'NCT02527096': set(),
#  'NCT00158457': set(),
#  'NCT00136630': {'22491195', '24780882'},
#  'NCT01579435': set(),
#  'NCT02057796': {'32558469', '36883573'},
#  'NCT01713335': set(),
#  'NCT02073630': set(),
#  'NCT05040048': set(),
#  'NCT03446430': set(),
#  'NCT01094899': set(),
#  'NCT03193099': set(),
#  'NCT03831906': {'32853411', '33743621', '36395782'},
#  'NCT00148824': {'20210645'},
#  'NCT00901524': {'24905490'},
#  'NCT00870649': {'30532268'},
#  'NCT01207349': {'22030240'},
#  'NCT01531036': set(),
#  'NCT00651066': {'24465443'},
#  'NCT02081066': set(),
#  'NCT01164436': set(),
#  'NCT01038999': {'22829920', '23285253'},
#  'NCT00604149': set(),
#  'NCT01569399': set(),
#  'NCT01917175': set(),
#  'NCT01592175': set(),
#  'NCT01271842': {'22948576'},
#  'NCT00265642': set(),
#  'NCT01008813': set(),
#  'NCT00158470': set(),
#  'NCT04265742': set(),
#  'NCT04631224': set(),
#  'NCT01493934': set(),
#  'NCT02978924': set(),
#  'NCT00226434': {'24096631', '24759827'},
#  'NCT04392388': {'34293141'},
#  'NCT00928187': {'31273686'},
#  'NCT00640887': {'25406657', '26482301'},
#  'NCT01952587': set(),
#  'NCT01089387': {'25974235', '26439886', '28753830'},
#  'NCT02833961': {'36318030'},
#  'NCT02453061': {'31381524'},
#  'NCT01494961': {'23343912', '29178852', '34329355'},
#  'NCT00301561': {'21831714', '35248123'},
#  'NCT01167283': set(),
#  'NCT02150993': set(),
#  'NCT01075061': set(),
#  'NCT02014883': {'26536893'},
#  'NCT00158483': {'19530940'},
#  'NCT02481453': {'38273639'},
#  'NCT02329054': {'26930627', '28231247'},
#  'NCT02027233': set(),
#  'NCT02093754': set(),
#  'NCT03324633': {'30570526', '32798585', '34212476'},
#  'NCT04842851': set(),
#  'NCT04409405': {'38043556'},
#  'NCT00158405': {'16782488', '18986246'},
#  'NCT02960698': set(),
#  'NCT02931097': set(),
#  'NCT00657397': {'22741944',
#   '24268548',
#   '25209306',
#   '25393311',
#   '27048152',
#   '27770695'},
#  'NCT00421551': {'20802297', '22848481', '29767684'},
#  'NCT00623051': set(),
#  'NCT00116454': set(),
#  'NCT03954054': {'35012570'},
#  'NCT02976298': set(),
#  'NCT02101398': set(),
#  'NCT05472051': set(),
#  'NCT00495651': {'23639243',
#   '24985779',
#   '25330161',
#   '26193126',
#   '29020361',
#   '29297443',
#   '35093007'},
#  'NCT01693861': set(),
#  'NCT00272428': {'19491388',
#   '19828715',
#   '20176858',
#   '20431391',
#   '20605091',
#   '21106918',
#   '21490142',
#   '21775560',
#   '21955649',
#   '22158670',
#   '22378736',
#   '22633793',
#   '23082222',
#   '23283500',
#   '23284983',
#   '24027184',
#   '24089418',
#   '24527713',
#   '24553693',
#   '25651444',
#   '25994566',
#   '26156743',
#   '26409628',
#   '26447153',
#   '26812508',
#   '26817718',
#   '26864363',
#   '26962176',
#   '27000099',
#   '27055851',
#   '28033414',
#   '28356432',
#   '28494135',
#   '29546305',
#   '29649036',
#   '30517725',
#   '31164347',
#   '31927670',
#   '33738534'},
#  'NCT02052271': set(),
#  'NCT01534728': set(),
#  'NCT01492985': {'33568510'},
#  'NCT00120185': {'19508157'},
#  'NCT01463956': set(),
#  'NCT00334256': set(),
#  'NCT00822315': {'24726095'},
#  'NCT04120415': set(),
#  'NCT02567071': set(),
#  'NCT01331811': {'26908804', '29174612', '30689814', '31455612'},
#  'NCT02214511': set(),
#  'NCT01698411': set(),
#  'NCT04288128': {'38419144', '38421662'},
#  'NCT02157311': {'29186458'},
#  'NCT02082171': set(),
#  'NCT00918307': {'29329763', '34611902'},
#  'NCT05090956': set(),
#  'NCT02346409': set(),
#  'NCT00196599': set(),
#  'NCT02102737': set(),
#  'NCT00454337': {'19757993', '21712241', '27042193'},
#  'NCT02656407': set(),
#  'NCT00158509': {'17314338', '18593294', '18596069'},
#  'NCT02038842': set(),
#  'NCT01725542': {'25977266'},
#  'NCT06260319': set(),
#  'NCT01842919': set(),
#  'NCT02906137': set(),
#  'NCT01192737': set(),
#  'NCT02647632': {'29077864'},
#  'NCT01065207': set(),
#  'NCT02542800': set(),
#  'NCT01089400': {'24646009'},
#  'NCT00574652': {'22129253'},
#  'NCT01905059': {'28566227'},
#  'NCT02125500': set(),
#  'NCT01413152': set(),
#  'NCT02236832': set(),
#  'NCT00115609': set(),
#  'NCT04396288': set(),
#  'NCT00445575': set(),
#  'NCT01024400': {'22147712'},
#  'NCT01779752': set(),
#  'NCT03215732': {'31320358', '37143029'},
#  'NCT03005652': {'33873195', '35853750', '36068621', '38100477'},
#  'NCT02916732': {'29539287', '33657112'},
#  'NCT01311752': set(),
#  'NCT01269632': set(),
#  'NCT01495897': set(),
#  'NCT00463983': {'22379151'},
#  'NCT03137797': set(),
#  'NCT01037777': {'23707147', '24780882', '32822634', '35264424'},
#  'NCT01842477': set(),
#  'NCT02721745': set(),
#  'NCT02408354': {'28969699'},
#  'NCT01688453': {'29696179',
#   '29776897',
#   '29934380',
#   '32097754',
#   '34087324',
#   '35272723'},
#  'NCT02172677': set(),
#  'NCT01880151': set(),
#  'NCT02658253': {'32032566', '33717176'},
#  'NCT02027051': set(),
#  'NCT00118677': {'20657770'},
#  'NCT00647205': set()}

# %% [markdown]
# **On veut fusionner la liste PMIDs que l'on vient de récupérer sur PubMed, à la liste des PMIDs déjà récupérés via CT.**

# %% [markdown]
# On met les PMIDs de CT sous la même forme:

# %%
pmids_ct_dict = {}
for nctid in nctid_array:
    pmids = df_ct[df_ct.loc[:, 'NCTId'] == nctid].loc[:, 'pmid'].dropna()
    pmids_ct_dict[nctid] = set(pmids)
pmids_ct_dict
# Out:
# {'NCT02014727': {'28947345'},
#  'NCT00117494': {'22318219', '22739396'},
#  'NCT00536627': {'15382173', '16310901', '24394187', '24555998'},
#  'NCT01033760': {'25701561', '28708873'},
#  'NCT05349162': set(),
#  'NCT01164462': set(),
#  'NCT02777229': {'31339676', '33010241', '33355914'},
#  'NCT00480792': {'21486976', '27064975'},
#  'NCT01095744': set(),
#  'NCT01489592': {'15501961', '15974953', '16946298', '18559556', '20169331'},
#  'NCT01453192': set(),
#  'NCT00460382': set(),
#  'NCT02486731': set(),
#  'NCT02116374': set(),
#  'NCT02497274': set(),
#  'NCT01022476': set(),
#  'NCT00528060': {'23459496'},
#  'NCT02078076': set(),
#  'NCT04008927': {'22310560',
#   '26806260',
#   '27168667',
#   '27178119',
#   '27537841',
#   '28004616',
#   '29432973',
#   '35774932'},
#  'NCT01331876': set(),
#  'NCT00820820': set(),
#  'NCT02273765': {'33667406'},
#  'NCT02107365': set(),
#  'NCT00113282': set(),
#  'NCT01055873': {'22427678'},
#  'NCT05199831': set(),
#  'NCT01359774': {'17653274', '21285522', '21320997'},
#  'NCT02099474': {'32661003'},
#  'NCT03546127': set(),
#  'NCT04315948': {'32304640',
#   '32473020',
#   '32958495',
#   '33089306',
#   '33264556',
#   '34048876',
#   '34350582',
#   '34473343',
#   '34534511',
#   '34763056',
#   '35233617',
#   '35512728',
#   '35533972',
#   '35623577',
#   '35643099',
#   '36680782',
#   '36828006',
#   '37269068',
#   '37302469',
#   '37728045'},
#  'NCT02987530': set(),
#  'NCT05311865': set(),
#  'NCT00122616': {'23800784'},
#  'NCT02428816': set(),
#  'NCT02453048': {'18762220',
#   '19625486',
#   '20107007',
#   '20419113',
#   '20708998',
#   '21147936',
#   '21430219',
#   '22814407',
#   '24421886',
#   '24793938',
#   '24950361',
#   '31945015',
#   '32687804'},
#  'NCT00120757': {'22353022'},
#  'NCT02566148': {'29307383', '29437866', '29982518'},
#  'NCT00640263': {'17825642',
#   '23039034',
#   '26603917',
#   '27895016',
#   '28469697',
#   '30814028',
#   '31633158',
#   '31994250',
#   '32067040',
#   '32228542',
#   '32991450'},
#  'NCT01693835': set(),
#  'NCT04470648': {'31978945',
#   '31995857',
#   '32046819',
#   '32070465',
#   '32109013',
#   '32224310',
#   '32338732',
#   '32371096'},
#  'NCT02573948': {'25540950',
#   '26032121',
#   '26050614',
#   '26075647',
#   '26080690',
#   '27006257',
#   '27178119',
#   '28612212',
#   '28800503'},
#  'NCT01693848': set(),
#  'NCT01895920': set(),
#  'NCT01039220': set(),
#  'NCT00820118': {'26568566'},
#  'NCT01801618': set(),
#  'NCT02405013': set(),
#  'NCT01779713': {'30354977'},
#  'NCT03235258': {'17712765',
#   '18614870',
#   '19194272',
#   '20536367',
#   '21511330',
#   '21971357',
#   '22198788',
#   '22427678',
#   '24253249',
#   '24705410',
#   '24945880',
#   '26762993'},
#  'NCT03071458': set(),
#  'NCT02886416': set(),
#  'NCT01899196': set(),
#  'NCT00944541': set(),
#  'NCT02160119': set(),
#  'NCT00158496': {'16019104', '16434426', '16847958', '16956918'},
#  'NCT02192658': {'26846895'},
#  'NCT00383734': {'23432777'},
#  'NCT02051413': set(),
#  'NCT03109067': set(),
#  'NCT02073604': set(),
#  'NCT01490489': {'16384869', '17531315', '19602057'},
#  'NCT01335529': {'27077673'},
#  'NCT00545194': {'11236117', '16553177', '17071427'},
#  'NCT03298360': set(),
#  'NCT01508494': set(),
#  'NCT00573001': set(),
#  'NCT00236340': {'11438952', '14770396', '7970458', '9464739'},
#  'NCT02542891': {'27488181', '34874888'},
#  'NCT03671291': set(),
#  'NCT01066962': {'25103176', '26520926', '30365452', '33794182'},
#  'NCT01703962': set(),
#  'NCT03642704': set(),
#  'NCT01086904': set(),
#  'NCT01127204': {'27015798',
#   '28434406',
#   '28453240',
#   '28483965',
#   '28800382',
#   '31334298',
#   '34723858'},
#  'NCT01771562': {'27881690', '30081838'},
#  'NCT00196612': {'15717256'},
#  'NCT01226446': {'25987791'},
#  'NCT02496312': {'10436334',
#   '10678322',
#   '10941190',
#   '12461757',
#   '15897497',
#   '16207933',
#   '16421064',
#   '17027767',
#   '17131230',
#   '1821241',
#   '18307266',
#   '19533496',
#   '19713543',
#   '19933975',
#   '21895376'},
#  'NCT04133012': set(),
#  'NCT01100281': set(),
#  'NCT01647295': set(),
#  'NCT00424814': {'23766338', '25838291'},
#  'NCT02488395': {'22639796', '23916713', '6774653'},
#  'NCT00658346': {'31063537'},
#  'NCT01188512': {'16839199',
#   '18762220',
#   '19625486',
#   '20107007',
#   '20184606',
#   '24261996',
#   '24421886',
#   '24793938'},
#  'NCT04945655': {'35332045'},
#  'NCT01942655': set(),
#  'NCT01332955': {'25139963'},
#  'NCT01552044': set(),
#  'NCT02592174': {'31755936'},
#  'NCT02100774': {'21957063', '24808487', '26063065', '27798339'},
#  'NCT00490074': set(),
#  'NCT01882062': {'25568297'},
#  'NCT01525472': set(),
#  'NCT02650427': set(),
#  'NCT01473472': {'26624850', '28747274', '29229440', '31784343'},
#  'NCT02267304': set(),
#  'NCT04780191': {'32232101'},
#  'NCT00495326': {'23433590', '24663014'},
#  'NCT03459157': {'34048794'},
#  'NCT01620957': set(),
#  'NCT00339157': {'21173013'},
#  'NCT01555450': {'21256688', '28823681', '29909873'},
#  'NCT01348308': {'32040959'},
#  'NCT01696708': {'25568297'},
#  'NCT01509508': {'23880306',
#   '25880823',
#   '27504637',
#   '28329393',
#   '29199100',
#   '29890048',
#   '30027600',
#   '30321314',
#   '30412926',
#   '31637821',
#   '32970730'},
#  'NCT01874808': set(),
#  'NCT02126384': set(),
#  'NCT03150290': set(),
#  'NCT03519503': {'21602695', '22814853', '26603917'},
#  'NCT00465790': set(),
#  'NCT00122603': {'19420019'},
#  'NCT02314208': set(),
#  'NCT00121121': {'17712402'},
#  'NCT01432821': {'12914551', '15037514', '15249613', '15777732', '2271377'},
#  'NCT02071784': set(),
#  'NCT02738502': {'22160145',
#   '22848481',
#   '23559464',
#   '23766338',
#   '26197844',
#   '26709605',
#   '26854809'},
#  'NCT02992184': {'29615488'},
#  'NCT01514890': {'23669289', '24704719', '25556540'},
#  'NCT02212379': set(),
#  'NCT03652090': set(),
#  'NCT00196664': set(),
#  'NCT03335995': {'32026446'},
#  'NCT00946595': {'29767684', '30968368'},
#  'NCT02469350': {'29636105'},
#  'NCT01546181': {'23620431',
#   '24337723',
#   '24406779',
#   '24576889',
#   '25077537',
#   '25284764',
#   '25997175',
#   '26344727',
#   '26418443',
#   '26523388',
#   '27009576',
#   '27065002',
#   '28900746',
#   '29369084',
#   '30010022',
#   '30947025',
#   '31568064',
#   '31573376',
#   '31922497',
#   '31972545'},
#  'NCT00122538': {'20516271', '21857286', '23719348'},
#  'NCT01426243': {'30096071'},
#  'NCT04824638': set(),
#  'NCT02113943': set(),
#  'NCT00299143': set(),
#  'NCT03870438': {'26603917', '33872801'},
#  'NCT01605890': {'29590335'},
#  'NCT00391638': set(),
#  'NCT02323308': set(),
#  'NCT02384967': {'29905808'},
#  'NCT00988767': {'15382173', '16310901', '20090916'},
#  'NCT00323804': set(),
#  'NCT04849767': {'34916316'},
#  'NCT03047967': set(),
#  'NCT00120367': {'21738597'},
#  'NCT01038401': set(),
#  'NCT04484740': set(),
#  'NCT03078439': set(),
#  'NCT00148863': {'23190183'},
#  'NCT01548586': {'10990547',
#   '11723286',
#   '15272049',
#   '15634731',
#   '16002441',
#   '19805746',
#   '20161639',
#   '22085959',
#   '8756819'},
#  'NCT00302822': set(),
#  'NCT00196625': {'15060509', '15456093'},
#  'NCT01188525': set(),
#  'NCT00670839': {'26257021'},
#  'NCT00158522': {'15977225', '16434426'},
#  'NCT00196586': set(),
#  'NCT04808986': set(),
#  'NCT02626286': {'33753460', '34022820', '34352834'},
#  'NCT01207986': set(),
#  'NCT03537196': {'19839502',
#   '20041309',
#   '20196807',
#   '20572071',
#   '22098550',
#   '22564041',
#   '22828983',
#   '23172780',
#   '23553643',
#   '23675659',
#   '23728143',
#   '23884064',
#   '25086286',
#   '25245939',
#   '25920094',
#   '26298331',
#   '27148964',
#   '27178119',
#   '27227200',
#   '27349488',
#   '27427455',
#   '27667367',
#   '33208326'},
#  'NCT04684758': set(),
#  'NCT00121758': {'20625264', '23759749'},
#  'NCT02527096': set(),
#  'NCT00158457': set(),
#  'NCT00136630': {'15313841',
#   '15365159',
#   '16055926',
#   '16193476',
#   '16501573',
#   '17098887',
#   '17597328',
#   '17605047',
#   '17957230',
#   '18378516',
#   '18853458',
#   '22491195',
#   '24780882'},
#  'NCT01579435': set(),
#  'NCT02057796': {'32558469'},
#  'NCT01713335': set(),
#  'NCT02073630': set(),
#  'NCT05040048': set(),
#  'NCT03446430': set(),
#  'NCT01094899': set(),
#  'NCT03193099': set(),
#  'NCT03831906': {'32853411', '33743621', '36395782'},
#  'NCT00148824': {'20210645'},
#  'NCT00901524': {'24905490'},
#  'NCT00870649': {'30532268'},
#  'NCT01207349': {'22030240'},
#  'NCT01531036': {'20505064'},
#  'NCT00651066': {'24465443'},
#  'NCT02081066': set(),
#  'NCT01164436': set(),
#  'NCT01038999': {'22829920', '23285253'},
#  'NCT00604149': set(),
#  'NCT01569399': set(),
#  'NCT01917175': set(),
#  'NCT01592175': set(),
#  'NCT01271842': {'22948576'},
#  'NCT00265642': set(),
#  'NCT01008813': set(),
#  'NCT00158470': set(),
#  'NCT04265742': set(),
#  'NCT04631224': set(),
#  'NCT01493934': set(),
#  'NCT02978924': set(),
#  'NCT00226434': {'17624825',
#   '22010913',
#   '23237982',
#   '24096631',
#   '24608960',
#   '24759827'},
#  'NCT04392388': set(),
#  'NCT00928187': {'31273686'},
#  'NCT00640887': {'25406657', '26482301'},
#  'NCT01952587': set(),
#  'NCT01089387': {'25974235', '28753830'},
#  'NCT02833961': set(),
#  'NCT02453061': {'31381524'},
#  'NCT01494961': {'20403152', '21857289', '23343912', '29178852', '34329355'},
#  'NCT00301561': {'21831714', '35248123'},
#  'NCT01167283': set(),
#  'NCT02150993': set(),
#  'NCT01075061': set(),
#  'NCT02014883': {'26536893'},
#  'NCT00158483': {'16455895', '18385443', '19530940'},
#  'NCT02481453': {'20413309', '24975859'},
#  'NCT02329054': {'25435054', '26930627', '27046271', '28231247'},
#  'NCT02027233': set(),
#  'NCT02093754': set(),
#  'NCT03324633': {'20493576',
#   '20876416',
#   '20969743',
#   '21239121',
#   '21692942',
#   '21819472',
#   '21888878',
#   '21920402',
#   '22173166',
#   '22285372',
#   '22409788',
#   '22535683',
#   '22781224',
#   '23052829',
#   '23226258',
#   '23421419',
#   '23461846',
#   '23978720',
#   '24166726',
#   '24499953',
#   '24580042',
#   '25015913',
#   '25778750',
#   '26372388',
#   '26528903',
#   '27073179',
#   '27177169',
#   '27317796',
#   '27339598',
#   '28235612',
#   '28418984',
#   '28430385',
#   '28780609',
#   '28942916',
#   '30570526',
#   '32798585',
#   '34212476'},
#  'NCT04842851': set(),
#  'NCT04409405': set(),
#  'NCT00158405': {'16152755', '16782488', '18986246'},
#  'NCT02960698': set(),
#  'NCT02931097': set(),
#  'NCT00657397': {'22741944',
#   '24268548',
#   '25209306',
#   '25393311',
#   '27048152',
#   '27770695'},
#  'NCT00421551': {'20802297', '22848481', '29767684'},
#  'NCT00623051': set(),
#  'NCT00116454': set(),
#  'NCT03954054': {'35012570'},
#  'NCT02976298': set(),
#  'NCT02101398': set(),
#  'NCT05472051': set(),
#  'NCT00495651': {'23639243',
#   '24985779',
#   '25330161',
#   '26193126',
#   '29020361',
#   '29297443',
#   '35093007'},
#  'NCT01693861': set(),
#  'NCT00272428': {'15557412',
#   '19491388',
#   '19828715',
#   '20176858',
#   '20431391',
#   '20605091',
#   '21106918',
#   '21490142',
#   '21775560',
#   '21955649',
#   '22158670',
#   '22378736',
#   '22633793',
#   '23082222',
#   '23283500',
#   '23284983',
#   '24027184',
#   '24089418',
#   '24527713',
#   '24553693',
#   '25651444',
#   '25994566',
#   '26156743',
#   '26409628',
#   '26447153',
#   '26812508',
#   '26817718',
#   '26864363',
#   '26962176',
#   '27000099',
#   '27055851',
#   '28033414',
#   '28356432',
#   '28494135',
#   '29546305',
#   '29649036',
#   '30517725',
#   '31164347',
#   '31927670',
#   '33738534'},
#  'NCT02052271': set(),
#  'NCT01534728': set(),
#  'NCT01492985': {'33568510'},
#  'NCT00120185': {'19508157'},
#  'NCT01463956': set(),
#  'NCT00334256': {'18987623', '19104016', '19307941'},
#  'NCT00822315': {'24726095'},
#  'NCT04120415': set(),
#  'NCT02567071': set(),
#  'NCT01331811': {'26908804', '29174612', '30689814', '31455612'},
#  'NCT02214511': set(),
#  'NCT01698411': set(),
#  'NCT04288128': set(),
#  'NCT02157311': {'29186458'},
#  'NCT02082171': set(),
#  'NCT00918307': {'29329763', '34611902'},
#  'NCT05090956': set(),
#  'NCT02346409': set(),
#  'NCT00196599': {'10915095', '15012649'},
#  'NCT02102737': set(),
#  'NCT00454337': {'19757993',
#   '19995925',
#   '20683319',
#   '21126958',
#   '21326075',
#   '21576452',
#   '21712241',
#   '22416781',
#   '27042193'},
#  'NCT02656407': {'25955583'},
#  'NCT00158509': {'16044019', '17314338', '18593294', '18596069'},
#  'NCT02038842': set(),
#  'NCT01725542': {'25977266'},
#  'NCT06260319': set(),
#  'NCT01842919': set(),
#  'NCT02906137': set(),
#  'NCT01192737': set(),
#  'NCT02647632': {'29077864'},
#  'NCT01065207': set(),
#  'NCT02542800': set(),
#  'NCT01089400': {'24646009'},
#  'NCT00574652': {'22129253'},
#  'NCT01905059': {'16249701',
#   '16549962',
#   '17545707',
#   '18097218',
#   '18540803',
#   '20010070',
#   '20802297',
#   '20802298',
#   '21811554',
#   '21886816',
#   '22441252',
#   '22814125',
#   '23075703',
#   '28566227'},
#  'NCT02125500': set(),
#  'NCT01413152': set(),
#  'NCT02236832': set(),
#  'NCT00115609': set(),
#  'NCT04396288': set(),
#  'NCT00445575': set(),
#  'NCT01024400': {'22147712'},
#  'NCT01779752': set(),
#  'NCT03215732': {'31320358'},
#  'NCT03005652': {'33873195', '35853750', '36068621'},
#  'NCT02916732': {'29539287', '33657112'},
#  'NCT01311752': set(),
#  'NCT01269632': set(),
#  'NCT01495897': set(),
#  'NCT00463983': {'16883006', '22379151'},
#  'NCT03137797': {'22008658',
#   '22267473',
#   '23079802',
#   '23936509',
#   '24058636',
#   '24465584',
#   '25573889',
#   '26636578',
#   '27509048'},
#  'NCT01037777': {'23707147', '24780882', '32822634', '35264424'},
#  'NCT01842477': set(),
#  'NCT02721745': set(),
#  'NCT02408354': {'28969699'},
#  'NCT01688453': {'29696179', '29776897', '29934380', '32097754', '34087324'},
#  'NCT02172677': set(),
#  'NCT01880151': set(),
#  'NCT02658253': {'32032566', '33717176'},
#  'NCT02027051': set(),
#  'NCT00118677': {'20657770'},
#  'NCT00647205': set()}

# %% [markdown]
# Pour un NCTDId donné, on fait l'union des deux ensembles de PMIDs:

# %%
pmids_complete_dict = {}
for nctid in nctid_array:
    # L'ensemble des PMIds présents dans PubMed et CT
    pmids_complete_dict[nctid] = pmids_pubmed_dict[nctid] | pmids_ct_dict[nctid]
pmids_complete_dict
# Out:
# {'NCT02014727': {'28947345'},
#  'NCT00117494': {'22318219', '22739396'},
#  'NCT00536627': {'15382173', '16310901', '24394187', '24555998'},
#  'NCT01033760': {'25701561', '28708873'},
#  'NCT05349162': {'36735263'},
#  'NCT01164462': set(),
#  'NCT02777229': {'31339676', '33010241', '33355914', '37851566', '38156046'},
#  'NCT00480792': {'21486976', '27064975'},
#  'NCT01095744': set(),
#  'NCT01489592': {'15501961', '15974953', '16946298', '18559556', '20169331'},
#  'NCT01453192': {'30688008'},
#  'NCT00460382': set(),
#  'NCT02486731': set(),
#  'NCT02116374': set(),
#  'NCT02497274': set(),
#  'NCT01022476': set(),
#  'NCT00528060': {'23459496'},
#  'NCT02078076': set(),
#  'NCT04008927': {'22310560',
#   '26806260',
#   '27168667',
#   '27178119',
#   '27537841',
#   '28004616',
#   '29432973',
#   '35774932'},
#  'NCT01331876': set(),
#  'NCT00820820': set(),
#  'NCT02273765': {'33667406'},
#  'NCT02107365': set(),
#  'NCT00113282': set(),
#  'NCT01055873': {'22427678'},
#  'NCT05199831': set(),
#  'NCT01359774': {'17653274', '21285522', '21320997'},
#  'NCT02099474': {'32661003'},
#  'NCT03546127': set(),
#  'NCT04315948': {'32304640',
#   '32473020',
#   '32958495',
#   '33089306',
#   '33264556',
#   '34048876',
#   '34350582',
#   '34473343',
#   '34534511',
#   '34763056',
#   '35233617',
#   '35512728',
#   '35533972',
#   '35623577',
#   '35643099',
#   '36680782',
#   '36695483',
#   '36828006',
#   '37269068',
#   '37302469',
#   '37728045'},
#  'NCT02987530': set(),
#  'NCT05311865': {'36438274', '37795682'},
#  'NCT00122616': {'23800784'},
#  'NCT02428816': set(),
#  'NCT02453048': {'18762220',
#   '19625486',
#   '20107007',
#   '20419113',
#   '20708998',
#   '21147936',
#   '21430219',
#   '22814407',
#   '24421886',
#   '24793938',
#   '24950361',
#   '31945015',
#   '32687804'},
#  'NCT00120757': {'22353022'},
#  'NCT02566148': {'29307383', '29437866', '29982518'},
#  'NCT00640263': {'17825642',
#   '23039034',
#   '26603917',
#   '27895016',
#   '28469697',
#   '30814028',
#   '31633158',
#   '31994250',
#   '32067040',
#   '32228542',
#   '32991450',
#   '34425825'},
#  'NCT01693835': set(),
#  'NCT04470648': {'31978945',
#   '31995857',
#   '32046819',
#   '32070465',
#   '32109013',
#   '32224310',
#   '32338732',
#   '32371096'},
#  'NCT02573948': {'25540950',
#   '26032121',
#   '26050614',
#   '26075647',
#   '26080690',
#   '27006257',
#   '27178119',
#   '28612212',
#   '28800503'},
#  'NCT01693848': set(),
#  'NCT01895920': set(),
#  'NCT01039220': set(),
#  'NCT00820118': {'26568566'},
#  'NCT01801618': {'29662875'},
#  'NCT02405013': {'36686592'},
#  'NCT01779713': {'30354977'},
#  'NCT03235258': {'17712765',
#   '18614870',
#   '19194272',
#   '20536367',
#   '21511330',
#   '21971357',
#   '22198788',
#   '22427678',
#   '24253249',
#   '24705410',
#   '24945880',
#   '26762993'},
#  'NCT03071458': set(),
#  'NCT02886416': set(),
#  'NCT01899196': set(),
#  'NCT00944541': set(),
#  'NCT02160119': set(),
#  'NCT00158496': {'16019104', '16434426', '16847958', '16956918'},
#  'NCT02192658': {'26846895'},
#  'NCT00383734': {'23432777'},
#  'NCT02051413': set(),
#  'NCT03109067': set(),
#  'NCT02073604': set(),
#  'NCT01490489': {'16384869', '17531315', '19602057'},
#  'NCT01335529': {'27077673'},
#  'NCT00545194': {'11236117', '16553177', '17071427'},
#  'NCT03298360': set(),
#  'NCT01508494': set(),
#  'NCT00573001': set(),
#  'NCT00236340': {'11438952', '14770396', '7970458', '9464739'},
#  'NCT02542891': {'27488181', '34874888'},
#  'NCT03671291': set(),
#  'NCT01066962': {'25103176', '26520926', '30365452', '33794182'},
#  'NCT01703962': {'37668523'},
#  'NCT03642704': set(),
#  'NCT01086904': set(),
#  'NCT01127204': {'27015798',
#   '28434406',
#   '28453240',
#   '28483965',
#   '28800382',
#   '31334298',
#   '34723858'},
#  'NCT01771562': {'27881690', '30081838'},
#  'NCT00196612': {'15717256'},
#  'NCT01226446': {'25987791'},
#  'NCT02496312': {'10436334',
#   '10678322',
#   '10941190',
#   '12461757',
#   '15897497',
#   '16207933',
#   '16421064',
#   '17027767',
#   '17131230',
#   '1821241',
#   '18307266',
#   '19533496',
#   '19713543',
#   '19933975',
#   '21895376'},
#  'NCT04133012': set(),
#  'NCT01100281': set(),
#  'NCT01647295': set(),
#  'NCT00424814': {'23766338', '25838291'},
#  'NCT02488395': {'22639796', '23916713', '6774653'},
#  'NCT00658346': {'31063537'},
#  'NCT01188512': {'16839199',
#   '18762220',
#   '19625486',
#   '20107007',
#   '20184606',
#   '24261996',
#   '24421886',
#   '24793938'},
#  'NCT04945655': {'35332045'},
#  'NCT01942655': set(),
#  'NCT01332955': {'25139963'},
#  'NCT01552044': set(),
#  'NCT02592174': {'31755936'},
#  'NCT02100774': {'21957063', '24808487', '26063065', '27798339'},
#  'NCT00490074': set(),
#  'NCT01882062': {'25568297'},
#  'NCT01525472': set(),
#  'NCT02650427': set(),
#  'NCT01473472': {'26624850', '28747274', '29229440', '31784343', '36601747'},
#  'NCT02267304': set(),
#  'NCT04780191': {'32232101'},
#  'NCT00495326': {'23433590', '24663014'},
#  'NCT03459157': {'34048794'},
#  'NCT01620957': set(),
#  'NCT00339157': {'21173013'},
#  'NCT01555450': {'21256688', '28823681', '29909873'},
#  'NCT01348308': {'32040959'},
#  'NCT01696708': {'25568297'},
#  'NCT01509508': {'23880306',
#   '25880823',
#   '27504637',
#   '28329393',
#   '29199100',
#   '29890048',
#   '30027600',
#   '30321314',
#   '30412926',
#   '31637821',
#   '32970730'},
#  'NCT01874808': set(),
#  'NCT02126384': set(),
#  'NCT03150290': set(),
#  'NCT03519503': {'21602695', '22814853', '26603917'},
#  'NCT00465790': set(),
#  'NCT00122603': {'19420019'},
#  'NCT02314208': set(),
#  'NCT00121121': {'17712402'},
#  'NCT01432821': {'12914551', '15037514', '15249613', '15777732', '2271377'},
#  'NCT02071784': set(),
#  'NCT02738502': {'22160145',
#   '22848481',
#   '23559464',
#   '23766338',
#   '26197844',
#   '26709605',
#   '26854809'},
#  'NCT02992184': {'29615488'},
#  'NCT01514890': {'23669289', '24704719', '25556540'},
#  'NCT02212379': {'31269208'},
#  'NCT03652090': set(),
#  'NCT00196664': set(),
#  'NCT03335995': {'32026446', '37497675'},
#  'NCT00946595': {'29767684', '30968368'},
#  'NCT02469350': {'29636105'},
#  'NCT01546181': {'23620431',
#   '24337723',
#   '24406779',
#   '24576889',
#   '25077537',
#   '25284764',
#   '25997175',
#   '26344727',
#   '26418443',
#   '26523388',
#   '27009576',
#   '27065002',
#   '28900746',
#   '29369084',
#   '30010022',
#   '30947025',
#   '31568064',
#   '31573376',
#   '31922497',
#   '31972545'},
#  'NCT00122538': {'20516271', '21857286', '23719348'},
#  'NCT01426243': {'26314624', '30096071'},
#  'NCT04824638': set(),
#  'NCT02113943': set(),
#  'NCT00299143': set(),
#  'NCT03870438': {'26603917', '33872801', '38484756'},
#  'NCT01605890': {'29590335'},
#  'NCT00391638': set(),
#  'NCT02323308': set(),
#  'NCT02384967': {'29905808'},
#  'NCT00988767': {'15382173', '16310901', '20090916'},
#  'NCT00323804': set(),
#  'NCT04849767': {'34916316'},
#  'NCT03047967': set(),
#  'NCT00120367': {'21738597'},
#  'NCT01038401': set(),
#  'NCT04484740': set(),
#  'NCT03078439': {'38408861'},
#  'NCT00148863': {'23190183'},
#  'NCT01548586': {'10990547',
#   '11723286',
#   '15272049',
#   '15634731',
#   '16002441',
#   '19805746',
#   '20161639',
#   '22085959',
#   '8756819'},
#  'NCT00302822': set(),
#  'NCT00196625': {'15060509', '15456093'},
#  'NCT01188525': set(),
#  'NCT00670839': {'26257021'},
#  'NCT00158522': {'15977225', '16434426'},
#  'NCT00196586': set(),
#  'NCT04808986': set(),
#  'NCT02626286': {'33753460', '34022820', '34352834'},
#  'NCT01207986': set(),
#  'NCT03537196': {'19839502',
#   '20041309',
#   '20196807',
#   '20572071',
#   '22098550',
#   '22564041',
#   '22828983',
#   '23172780',
#   '23553643',
#   '23675659',
#   '23728143',
#   '23884064',
#   '25086286',
#   '25245939',
#   '25920094',
#   '26298331',
#   '27148964',
#   '27178119',
#   '27227200',
#   '27349488',
#   '27427455',
#   '27667367',
#   '33208326'},
#  'NCT04684758': set(),
#  'NCT00121758': {'20625264', '23759749'},
#  'NCT02527096': set(),
#  'NCT00158457': set(),
#  'NCT00136630': {'15313841',
#   '15365159',
#   '16055926',
#   '16193476',
#   '16501573',
#   '17098887',
#   '17597328',
#   '17605047',
#   '17957230',
#   '18378516',
#   '18853458',
#   '22491195',
#   '24780882'},
#  'NCT01579435': set(),
#  'NCT02057796': {'32558469', '36883573'},
#  'NCT01713335': set(),
#  'NCT02073630': set(),
#  'NCT05040048': set(),
#  'NCT03446430': set(),
#  'NCT01094899': set(),
#  'NCT03193099': set(),
#  'NCT03831906': {'32853411', '33743621', '36395782'},
#  'NCT00148824': {'20210645'},
#  'NCT00901524': {'24905490'},
#  'NCT00870649': {'30532268'},
#  'NCT01207349': {'22030240'},
#  'NCT01531036': {'20505064'},
#  'NCT00651066': {'24465443'},
#  'NCT02081066': set(),
#  'NCT01164436': set(),
#  'NCT01038999': {'22829920', '23285253'},
#  'NCT00604149': set(),
#  'NCT01569399': set(),
#  'NCT01917175': set(),
#  'NCT01592175': set(),
#  'NCT01271842': {'22948576'},
#  'NCT00265642': set(),
#  'NCT01008813': set(),
#  'NCT00158470': set(),
#  'NCT04265742': set(),
#  'NCT04631224': set(),
#  'NCT01493934': set(),
#  'NCT02978924': set(),
#  'NCT00226434': {'17624825',
#   '22010913',
#   '23237982',
#   '24096631',
#   '24608960',
#   '24759827'},
#  'NCT04392388': {'34293141'},
#  'NCT00928187': {'31273686'},
#  'NCT00640887': {'25406657', '26482301'},
#  'NCT01952587': set(),
#  'NCT01089387': {'25974235', '26439886', '28753830'},
#  'NCT02833961': {'36318030'},
#  'NCT02453061': {'31381524'},
#  'NCT01494961': {'20403152', '21857289', '23343912', '29178852', '34329355'},
#  'NCT00301561': {'21831714', '35248123'},
#  'NCT01167283': set(),
#  'NCT02150993': set(),
#  'NCT01075061': set(),
#  'NCT02014883': {'26536893'},
#  'NCT00158483': {'16455895', '18385443', '19530940'},
#  'NCT02481453': {'20413309', '24975859', '38273639'},
#  'NCT02329054': {'25435054', '26930627', '27046271', '28231247'},
#  'NCT02027233': set(),
#  'NCT02093754': set(),
#  'NCT03324633': {'20493576',
#   '20876416',
#   '20969743',
#   '21239121',
#   '21692942',
#   '21819472',
#   '21888878',
#   '21920402',
#   '22173166',
#   '22285372',
#   '22409788',
#   '22535683',
#   '22781224',
#   '23052829',
#   '23226258',
#   '23421419',
#   '23461846',
#   '23978720',
#   '24166726',
#   '24499953',
#   '24580042',
#   '25015913',
#   '25778750',
#   '26372388',
#   '26528903',
#   '27073179',
#   '27177169',
#   '27317796',
#   '27339598',
#   '28235612',
#   '28418984',
#   '28430385',
#   '28780609',
#   '28942916',
#   '30570526',
#   '32798585',
#   '34212476'},
#  'NCT04842851': set(),
#  'NCT04409405': {'38043556'},
#  'NCT00158405': {'16152755', '16782488', '18986246'},
#  'NCT02960698': set(),
#  'NCT02931097': set(),
#  'NCT00657397': {'22741944',
#   '24268548',
#   '25209306',
#   '25393311',
#   '27048152',
#   '27770695'},
#  'NCT00421551': {'20802297', '22848481', '29767684'},
#  'NCT00623051': set(),
#  'NCT00116454': set(),
#  'NCT03954054': {'35012570'},
#  'NCT02976298': set(),
#  'NCT02101398': set(),
#  'NCT05472051': set(),
#  'NCT00495651': {'23639243',
#   '24985779',
#   '25330161',
#   '26193126',
#   '29020361',
#   '29297443',
#   '35093007'},
#  'NCT01693861': set(),
#  'NCT00272428': {'15557412',
#   '19491388',
#   '19828715',
#   '20176858',
#   '20431391',
#   '20605091',
#   '21106918',
#   '21490142',
#   '21775560',
#   '21955649',
#   '22158670',
#   '22378736',
#   '22633793',
#   '23082222',
#   '23283500',
#   '23284983',
#   '24027184',
#   '24089418',
#   '24527713',
#   '24553693',
#   '25651444',
#   '25994566',
#   '26156743',
#   '26409628',
#   '26447153',
#   '26812508',
#   '26817718',
#   '26864363',
#   '26962176',
#   '27000099',
#   '27055851',
#   '28033414',
#   '28356432',
#   '28494135',
#   '29546305',
#   '29649036',
#   '30517725',
#   '31164347',
#   '31927670',
#   '33738534'},
#  'NCT02052271': set(),
#  'NCT01534728': set(),
#  'NCT01492985': {'33568510'},
#  'NCT00120185': {'19508157'},
#  'NCT01463956': set(),
#  'NCT00334256': {'18987623', '19104016', '19307941'},
#  'NCT00822315': {'24726095'},
#  'NCT04120415': set(),
#  'NCT02567071': set(),
#  'NCT01331811': {'26908804', '29174612', '30689814', '31455612'},
#  'NCT02214511': set(),
#  'NCT01698411': set(),
#  'NCT04288128': {'38419144', '38421662'},
#  'NCT02157311': {'29186458'},
#  'NCT02082171': set(),
#  'NCT00918307': {'29329763', '34611902'},
#  'NCT05090956': set(),
#  'NCT02346409': set(),
#  'NCT00196599': {'10915095', '15012649'},
#  'NCT02102737': set(),
#  'NCT00454337': {'19757993',
#   '19995925',
#   '20683319',
#   '21126958',
#   '21326075',
#   '21576452',
#   '21712241',
#   '22416781',
#   '27042193'},
#  'NCT02656407': {'25955583'},
#  'NCT00158509': {'16044019', '17314338', '18593294', '18596069'},
#  'NCT02038842': set(),
#  'NCT01725542': {'25977266'},
#  'NCT06260319': set(),
#  'NCT01842919': set(),
#  'NCT02906137': set(),
#  'NCT01192737': set(),
#  'NCT02647632': {'29077864'},
#  'NCT01065207': set(),
#  'NCT02542800': set(),
#  'NCT01089400': {'24646009'},
#  'NCT00574652': {'22129253'},
#  'NCT01905059': {'16249701',
#   '16549962',
#   '17545707',
#   '18097218',
#   '18540803',
#   '20010070',
#   '20802297',
#   '20802298',
#   '21811554',
#   '21886816',
#   '22441252',
#   '22814125',
#   '23075703',
#   '28566227'},
#  'NCT02125500': set(),
#  'NCT01413152': set(),
#  'NCT02236832': set(),
#  'NCT00115609': set(),
#  'NCT04396288': set(),
#  'NCT00445575': set(),
#  'NCT01024400': {'22147712'},
#  'NCT01779752': set(),
#  'NCT03215732': {'31320358', '37143029'},
#  'NCT03005652': {'33873195', '35853750', '36068621', '38100477'},
#  'NCT02916732': {'29539287', '33657112'},
#  'NCT01311752': set(),
#  'NCT01269632': set(),
#  'NCT01495897': set(),
#  'NCT00463983': {'16883006', '22379151'},
#  'NCT03137797': {'22008658',
#   '22267473',
#   '23079802',
#   '23936509',
#   '24058636',
#   '24465584',
#   '25573889',
#   '26636578',
#   '27509048'},
#  'NCT01037777': {'23707147', '24780882', '32822634', '35264424'},
#  'NCT01842477': set(),
#  'NCT02721745': set(),
#  'NCT02408354': {'28969699'},
#  'NCT01688453': {'29696179',
#   '29776897',
#   '29934380',
#   '32097754',
#   '34087324',
#   '35272723'},
#  'NCT02172677': set(),
#  'NCT01880151': set(),
#  'NCT02658253': {'32032566', '33717176'},
#  'NCT02027051': set(),
#  'NCT00118677': {'20657770'},
#  'NCT00647205': set()}

# %% [markdown]
# #### Verifications:

# %%
num_pmids_ct = sum((len(v) for v in pmids_ct_dict.values()))
print(f'Nombre total de publications issus de CT: {num_pmids_ct}')
# Out:
# Nombre total de publications issus de CT: 541

# %%
num_pmids_complete = sum((len(v) for v in pmids_complete_dict.values()))
print(f'Nombre total de publications après consultation PubMed: {num_pmids_complete}')
# Out:
# Nombre total de publications après consultation PubMed: 569

# %%
pmids_pubmed_only_dict = {}
for nctid in nctid_array:
    # L'ensemble des PMIds présents dans PubMed uniquement
    pmids_pubmed_only_dict[nctid] = pmids_pubmed_dict[nctid] - pmids_ct_dict[nctid]

# %%
num_pmids_pubmed_only = sum((len(v) for v in pmids_pubmed_only_dict.values()))
print(f'Nombre de nouveaux PMIDs trouvés via Pubmed: {num_pmids_pubmed_only}')
# Out:
# Nombre de nouveaux PMIDs trouvés via Pubmed: 28

# %%
assert num_pmids_complete - num_pmids_ct == num_pmids_pubmed_only

# %%
print('NCTId des nouveaux PMIDs trouvés via Pubmed:')
{k: v for k, v in pmids_pubmed_only_dict.items() if v != set()}
# Out:
# NCTId des nouveaux PMIDs trouvés via Pubmed:
# {'NCT05349162': {'36735263'},
#  'NCT02777229': {'37851566', '38156046'},
#  'NCT01453192': {'30688008'},
#  'NCT04315948': {'36695483'},
#  'NCT05311865': {'36438274', '37795682'},
#  'NCT00640263': {'34425825'},
#  'NCT01801618': {'29662875'},
#  'NCT02405013': {'36686592'},
#  'NCT01703962': {'37668523'},
#  'NCT01473472': {'36601747'},
#  'NCT02212379': {'31269208'},
#  'NCT03335995': {'37497675'},
#  'NCT01426243': {'26314624'},
#  'NCT03870438': {'38484756'},
#  'NCT03078439': {'38408861'},
#  'NCT02057796': {'36883573'},
#  'NCT04392388': {'34293141'},
#  'NCT01089387': {'26439886'},
#  'NCT02833961': {'36318030'},
#  'NCT02481453': {'38273639'},
#  'NCT04409405': {'38043556'},
#  'NCT04288128': {'38419144', '38421662'},
#  'NCT03215732': {'37143029'},
#  'NCT03005652': {'38100477'},
#  'NCT01688453': {'35272723'}}

# %%
num_nctid_empty_ct = sum((1 for v in pmids_ct_dict.values() if v == set()))
print(f"Nombre d'études sans PMIDs issus de CT: {num_nctid_empty_ct}")
# Out:
# Nombre d'études sans PMIDs issus de CT: 150

# %%
num_nctid_empty_pubmed = sum((1 for v in pmids_complete_dict.values() if v == set()))
print(f"Nombre d'études sans PMIDs après consultation PubMed: {num_nctid_empty_pubmed}")
# Out:
# Nombre d'études sans PMIDs après consultation PubMed: 138

# %%
print("NCTIds qui n'avait aucun PMIDs sous CT, mais enrichis via Pubmed:")
nctids_previously_empty = {k for k, v in pmids_ct_dict.items() if v == set()} - {k for k, v in pmids_complete_dict.items() if v == set()}
{k: pmids_complete_dict[k] for k in nctids_previously_empty}
# Out:
# NCTIds qui n'avait aucun PMIDs sous CT, mais enrichis via Pubmed:
# {'NCT02405013': {'36686592'},
#  'NCT05349162': {'36735263'},
#  'NCT04288128': {'38419144', '38421662'},
#  'NCT01453192': {'30688008'},
#  'NCT01801618': {'29662875'},
#  'NCT02212379': {'31269208'},
#  'NCT01703962': {'37668523'},
#  'NCT03078439': {'38408861'},
#  'NCT04409405': {'38043556'},
#  'NCT02833961': {'36318030'},
#  'NCT04392388': {'34293141'},
#  'NCT05311865': {'36438274', '37795682'}}

# %%
len(nctids_previously_empty)
# Out:
# 12

# %%
assert num_nctid_empty_ct - num_nctid_empty_pubmed == len(nctids_previously_empty)

# %% [markdown]
# ### Enrichissement des PMIDs via l'API Pubmed

# %% [markdown]
# Pour chaque PMID récupéré, on l'enrichit avec les données de PubMed tel que le titre, les auteurs, ...:

# %%
counter = 0   # To keep track of progress
book_counter = 0   # type different from 'article', get ignored
total_publications_list = []

# For each NTCID...
for nctid, pmids in pmids_complete_dict.items():
    pmids_list = []

    # We process each PMID...
    for pmid in pmids:

        # Display the progress on a single line
        print(f'\r{counter+1} / {num_pmids_complete}...', end='', flush=True)

        try:
            # Fetch article details from Pubmed
            article = fetch.article_by_pmid(pmid)

            # We are not interested by articles with type 'book'
            # TODO: book special case ?
            if article.pubmed_type == 'article':
                pmids_list.append(
                    {
                        'pmid': pmid,
                        'title': article.title,
                        'authors': article.authors_str.strip(),
                        'doi': article.doi,
                        'year': article.year,
                        'publication_types': list(article.publication_types.values()),
                        'citation': article.citation,
                    }
                )
            else:
                book_counter += 1
                book = (nctid, pmid)

            counter += 1
        except InvalidPMID as e:
            print(f'\n{e}')

    publication_dict = {'NCTId': nctid, 'publications': pmids_list}

    total_publications_list.append(publication_dict)
# Out:
# 569 / 569...

# %%
print(f'Nb de publications avec un type différent d"article": {book_counter}')
print(book)
# Out:
# Nb de publications avec un type différent d"article": 1
# ('NCT03537196', '27227200')

# %%
print(json.dumps(total_publications_list, indent=2))
# Out:
# [
#   {
#     "NCTId": "NCT02014727",
#     "publications": [
#       {
#         "pmid": "28947345",
#         "title": "Safety and immunogenicity of a recombinant Plasmodium falciparum AMA1-DiCo malaria vaccine adjuvanted with GLA-SE or Alhydrogel\u00ae in European and African adults: A phase 1a/1b, randomized, double-blind multi-centre trial.",
#         "authors": "Sirima SB; Durier C; Kara L; Houard S; Gansane A; Loulergue P; Bahuaud M; Benhamouda N; Nebi\u00e9 I; Faber B; Remarque E; Launay O; AMA1-DiCo Study Group",
#         "doi": "10.1016/j.vaccine.2017.09.027",
#         "year": "2017",
#         "publication_types": [
#           "Clinical Trial, Phase I",
#           "Journal Article",
#           "Randomized Controlled Trial",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Sirima SB, et al. Safety and immunogenicity of a recombinant Plasmodium falciparum AMA1-DiCo malaria vaccine adjuvanted with GLA-SE or Alhydrogel\u00ae in European and African adults: A phase 1a/1b, randomized, double-blind multi-centre trial. Safety and immunogenicity of a recombinant Plasmodium falciparum AMA1-DiCo malaria vaccine adjuvanted with GLA-SE or Alhydrogel\u00ae in European and African adults: A phase 1a/1b, randomized, double-blind multi-centre trial. 2017; 35:6218-6227. doi: 10.1016/j.vaccine.2017.09.027"
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT00117494",
#     "publications": [
#       {
#         "pmid": "22739396",
#         "title": "Effects of rosuvastatin versus pravastatin on low-density lipoprotein diameter in HIV-1-infected patients receiving ritonavir-boosted protease inhibitor.",
#         "authors": "Bittar R; Giral P; Aslangul E; Assoumou L; Valantin MA; Kalmykova O; Federspiel MC; Cherfils C; Costagliola D; Bonnefont-Rousselot D; French National Agency for AIDS and Viral Hepatitis Research (ANRS) 126 study group",
#         "doi": "10.1097/QAD.0b013e328357063c",
#         "year": "2012",
#         "publication_types": [
#           "Comparative Study",
#           "Journal Article",
#           "Multicenter Study",
#           "Randomized Controlled Trial",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Bittar R, et al. Effects of rosuvastatin versus pravastatin on low-density lipoprotein diameter in HIV-1-infected patients receiving ritonavir-boosted protease inhibitor. Effects of rosuvastatin versus pravastatin on low-density lipoprotein diameter in HIV-1-infected patients receiving ritonavir-boosted protease inhibitor. 2012; 26:1801-5. doi: 10.1097/QAD.0b013e328357063c"
#       },
#       {
#         "pmid": "22318219",
#         "title": "Determinants of low-density lipoprotein particle diameter during antiretroviral therapy including protease inhibitors in HIV-1-infected patients.",
#         "authors": "Bittar R; Giral P; Aslangul E; Assoumou L; Valantin MA; Kalmykova O; Fesel-Fouquier V; Costagliola D; Bonnefont-Rousselot D; ANRS 126 study group",
#         "doi": "10.3851/IMP2065",
#         "year": "2012",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Bittar R, et al. Determinants of low-density lipoprotein particle diameter during antiretroviral therapy including protease inhibitors in HIV-1-infected patients. Determinants of low-density lipoprotein particle diameter during antiretroviral therapy including protease inhibitors in HIV-1-infected patients. 2012; 17:855-60. doi: 10.3851/IMP2065"
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT00536627",
#     "publications": [
#       {
#         "pmid": "24394187",
#         "title": "Immunological and antiviral responses after therapeutic DNA immunization in chronic hepatitis B patients efficiently treated by analogues.",
#         "authors": "Godon O; Fontaine H; Kahi S; Meritet JF; Scott-Algara D; Pol S; Michel ML; Bourgine M; ANRS HB02 study group",
#         "doi": "10.1038/mt.2013.274",
#         "year": "2014",
#         "publication_types": [
#           "Clinical Trial, Phase I",
#           "Clinical Trial, Phase II",
#           "Journal Article",
#           "Multicenter Study",
#           "Randomized Controlled Trial",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Godon O, et al. Immunological and antiviral responses after therapeutic DNA immunization in chronic hepatitis B patients efficiently treated by analogues. Immunological and antiviral responses after therapeutic DNA immunization in chronic hepatitis B patients efficiently treated by analogues. 2014; 22:675-684. doi: 10.1038/mt.2013.274"
#       },
#       {
#         "pmid": "15382173",
#         "title": "Induction or expansion of T-cell responses by a hepatitis B DNA vaccine administered to chronic HBV carriers.",
#         "authors": "Mancini-Bourgine M; Fontaine H; Scott-Algara D; Pol S; Br\u00e9chot C; Michel ML",
#         "doi": "10.1002/hep.20408",
#         "year": "2004",
#         "publication_types": [
#           "Clinical Trial",
#           "Clinical Trial, Phase I",
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Mancini-Bourgine M, et al. Induction or expansion of T-cell responses by a hepatitis B DNA vaccine administered to chronic HBV carriers. Induction or expansion of T-cell responses by a hepatitis B DNA vaccine administered to chronic HBV carriers. 2004; 40:874-82. doi: 10.1002/hep.20408"
#       },
#       {
#         "pmid": "24555998",
#         "title": "Anti-HBV DNA vaccination does not prevent relapse after discontinuation of analogues in the treatment of chronic hepatitis B: a randomised trial--ANRS HB02 VAC-ADN.",
#         "authors": "Fontaine H; Kahi S; Chazallon C; Bourgine M; Varaut A; Buffet C; Godon O; Meritet JF; Sa\u00efdi Y; Michel ML; Scott-Algara D; Aboulker JP; Pol S; ANRS HB02 study group",
#         "doi": "10.1136/gutjnl-2013-305707",
#         "year": "2015",
#         "publication_types": [
#           "Clinical Trial, Phase I",
#           "Clinical Trial, Phase II",
#           "Journal Article",
#           "Multicenter Study",
#           "Randomized Controlled Trial",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Fontaine H, et al. Anti-HBV DNA vaccination does not prevent relapse after discontinuation of analogues in the treatment of chronic hepatitis B: a randomised trial--ANRS HB02 VAC-ADN. Anti-HBV DNA vaccination does not prevent relapse after discontinuation of analogues in the treatment of chronic hepatitis B: a randomised trial--ANRS HB02 VAC-ADN. 2015; 64:139-47. doi: 10.1136/gutjnl-2013-305707"
#       },
#       {
#         "pmid": "16310901",
#         "title": "Immunogenicity of a hepatitis B DNA vaccine administered to chronic HBV carriers.",
#         "authors": "Mancini-Bourgine M; Fontaine H; Br\u00e9chot C; Pol S; Michel ML",
#         "doi": "10.1016/j.vaccine.2005.08.013",
#         "year": "2006",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Mancini-Bourgine M, et al. Immunogenicity of a hepatitis B DNA vaccine administered to chronic HBV carriers. Immunogenicity of a hepatitis B DNA vaccine administered to chronic HBV carriers. 2006; 24:4482-9. doi: 10.1016/j.vaccine.2005.08.013"
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT01033760",
#     "publications": [
#       {
#         "pmid": "25701561",
#         "title": "Intensive five-drug antiretroviral therapy regimen versus standard triple-drug therapy during primary HIV-1 infection (OPTIPRIM-ANRS 147): a randomised, open-label, phase 3 trial.",
#         "authors": "Ch\u00e9ret A; Nembot G; M\u00e9lard A; Lascoux C; Slama L; Miailhes P; Yeni P; Abel S; Avettand-Fenoel V; Venet A; Chaix ML; Molina JM; Katlama C; Goujard C; Tamalet C; Raffi F; Lafeuillade A; Reynes J; Ravaux I; Ho\u00ebn B; Delfraissy JF; Meyer L; Rouzioux C; OPTIPRIM ANRS Study Group",
#         "doi": "10.1016/S1473-3099(15)70021-6",
#         "year": "2015",
#         "publication_types": [
#           "Clinical Trial, Phase III",
#           "Comparative Study",
#           "Journal Article",
#           "Randomized Controlled Trial",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Ch\u00e9ret A, et al. Intensive five-drug antiretroviral therapy regimen versus standard triple-drug therapy during primary HIV-1 infection (OPTIPRIM-ANRS 147): a randomised, open-label, phase 3 trial. Intensive five-drug antiretroviral therapy regimen versus standard triple-drug therapy during primary HIV-1 infection (OPTIPRIM-ANRS 147): a randomised, open-label, phase 3 trial. 2015; 15:387-96. doi: 10.1016/S1473-3099(15)70021-6"
#       },
#       {
#         "pmid": "28708873",
#         "title": "Impact of early cART on HIV blood and semen compartments at the time of primary infection.",
#         "authors": "Ch\u00e9ret A; Durier C; M\u00e9lard A; Ploquin M; Heitzmann J; L\u00e9curoux C; Avettand-Feno\u00ebl V; David L; Pialoux G; Chennebault JM; M\u00fcller-Trutwin M; Goujard C; Rouzioux C; Meyer L; ANRS OPTIPRIM study group",
#         "doi": "10.1371/journal.pone.0180191",
#         "year": "2017",
#         "publication_types": [
#           "Clinical Trial, Phase III",
#           "Journal Article",
#           "Randomized Controlled Trial"
#         ],
#         "citation": "Ch\u00e9ret A, et al. Impact of early cART on HIV blood and semen compartments at the time of primary infection. Impact of early cART on HIV blood and semen compartments at the time of primary infection. 2017; 12:e0180191. doi: 10.1371/journal.pone.0180191"
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT05349162",
#     "publications": [
#       {
#         "pmid": "36735263",
#         "title": "Epicardial vs. transvenous implantable cardioverter defibrillators in children.",
#         "authors": "Le Bos PA; Pontailler M; Maltret A; Kraiche D; Gaudin R; Barbanti C; Marijon E; Raisky O; Bonnet D; Waldmann V",
#         "doi": "10.1093/europace/euad015",
#         "year": "2023",
#         "publication_types": [
#           "Clinical Trial",
#           "Journal Article"
#         ],
#         "citation": "Le Bos PA, et al. Epicardial vs. transvenous implantable cardioverter defibrillators in children. Epicardial vs. transvenous implantable cardioverter defibrillators in children. 2023; 25:961-968. doi: 10.1093/europace/euad015"
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT01164462",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT02777229",
#     "publications": [
#       {
#         "pmid": "37851566",
#         "title": "Improvements in Patient-Reported Outcomes Following Initiation of Dolutegravir-Based or Low-Dose Efavirenz-Based First-Line Antiretroviral Therapy: A Four-Year Longitudinal Analysis in Cameroon (NAMSAL ANRS 12313 Trial).",
#         "authors": "Bousmah MA; Protopopescu C; Mpoudi-Etame M; Omgba Bassega P; Maradan G; Olinga J; Varloteaux M; Tovar-Sanchez T; Delaporte \u00c9; Kouanfack C; Boyer S; NAMSAL ANRS 12313 Study Group",
#         "doi": "10.1097/QAI.0000000000003273",
#         "year": "2023",
#         "publication_types": [
#           "Randomized Controlled Trial",
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Bousmah MA, et al. Improvements in Patient-Reported Outcomes Following Initiation of Dolutegravir-Based or Low-Dose Efavirenz-Based First-Line Antiretroviral Therapy: A Four-Year Longitudinal Analysis in Cameroon (NAMSAL ANRS 12313 Trial). Improvements in Patient-Reported Outcomes Following Initiation of Dolutegravir-Based or Low-Dose Efavirenz-Based First-Line Antiretroviral Therapy: A Four-Year Longitudinal Analysis in Cameroon (NAMSAL ANRS 12313 Trial). 2023; 94:262-272. doi: 10.1097/QAI.0000000000003273"
#       },
#       {
#         "pmid": "33010241",
#         "title": "Dolutegravir-based and low-dose efavirenz-based regimen for the initial treatment of HIV-1 infection (NAMSAL): week 96 results from a two-group, multicentre, randomised, open label, phase 3 non-inferiority trial in Cameroon.",
#         "authors": "Calmy A; Tovar Sanchez T; Kouanfack C; Mpoudi-Etame M; Leroy S; Perrineau S; Lantche Wandji M; Tetsa Tata D; Omgba Bassega P; Abong Bwenda T; Varloteaux M; Tongo M; Mpoudi-Ngol\u00e9 E; Montoyo A; Mercier N; LeMoing V; Peeters M; Reynes J; Delaporte E; New Antiretroviral and Monitoring Strategies in HIV-infected Adults in Low-Income Countries (NAMSAL) ANRS 12313 Study Group",
#         "doi": "10.1016/S2352-3018(20)30238-1",
#         "year": "2020",
#         "publication_types": [
#           "Clinical Trial, Phase III",
#           "Journal Article",
#           "Multicenter Study",
#           "Randomized Controlled Trial",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Calmy A, et al. Dolutegravir-based and low-dose efavirenz-based regimen for the initial treatment of HIV-1 infection (NAMSAL): week 96 results from a two-group, multicentre, randomised, open label, phase 3 non-inferiority trial in Cameroon. Dolutegravir-based and low-dose efavirenz-based regimen for the initial treatment of HIV-1 infection (NAMSAL): week 96 results from a two-group, multicentre, randomised, open label, phase 3 non-inferiority trial in Cameroon. 2020; 7:e677-e687. doi: 10.1016/S2352-3018(20)30238-1"
#       },
#       {
#         "pmid": "33355914",
#         "title": "Cost-Utility Analysis of a Dolutegravir-Based Versus Low-Dose Efavirenz-Based Regimen for the Initial Treatment of HIV-Infected Patients in Cameroon (NAMSAL ANRS 12313 Trial).",
#         "authors": "Bousmah MA; Nishimwe ML; Tovar-Sanchez T; Lantche Wandji M; Mpoudi-Etame M; Maradan G; Omgba Bassega P; Varloteaux M; Montoyo A; Kouanfack C; Delaporte E; Boyer S; New Antiretroviral\u00a0and Monitoring Strategies in HIV-infected Adults in Low-Income Countries (NAMSAL) ANRS 12313 Study Group",
#         "doi": "10.1007/s40273-020-00987-3",
#         "year": "2021",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Bousmah MA, et al. Cost-Utility Analysis of a Dolutegravir-Based Versus Low-Dose Efavirenz-Based Regimen for the Initial Treatment of HIV-Infected Patients in Cameroon (NAMSAL ANRS 12313 Trial). Cost-Utility Analysis of a Dolutegravir-Based Versus Low-Dose Efavirenz-Based Regimen for the Initial Treatment of HIV-Infected Patients in Cameroon (NAMSAL ANRS 12313 Trial). 2021; 39:331-343. doi: 10.1007/s40273-020-00987-3"
#       },
#       {
#         "pmid": "38156046",
#         "title": "Durability of the Efficacy and Safety of Dolutegravir-Based and Low-Dose Efavirenz-Based Regimens for the Initial Treatment of Human Immunodeficiency Virus Type 1 Infection in Cameroon: Week 192 Data of the NAMSAL-ANRS-12313 Study.",
#         "authors": "Mpoudi-Etame M; Tovar Sanchez T; Bousmah MA; Omgba Bassega P; Olinga J; Mimbe E; Foalem M; Chiep C; Edimo S; Varloteaux M; Pelloquin R; Lamare N; Boyer S; Peeters M; Reynes J; Calmy A; Hill A; Delaporte E; Kouanfack C; New Antiretroviral and Monitoring Strategies in HIV-infected Adults in Low-income countries (NAMSAL-ANRS-12313) study group",
#         "doi": "10.1093/ofid/ofad582",
#         "year": "2023",
#         "publication_types": [
#           "Journal Article"
#         ],
#         "citation": "Mpoudi-Etame M, et al. Durability of the Efficacy and Safety of Dolutegravir-Based and Low-Dose Efavirenz-Based Regimens for the Initial Treatment of Human Immunodeficiency Virus Type 1 Infection in Cameroon: Week 192 Data of the NAMSAL-ANRS-12313 Study. Durability of the Efficacy and Safety of Dolutegravir-Based and Low-Dose Efavirenz-Based Regimens for the Initial Treatment of Human Immunodeficiency Virus Type 1 Infection in Cameroon: Week 192 Data of the NAMSAL-ANRS-12313 Study. 2023; 10:ofad582. doi: 10.1093/ofid/ofad582"
#       },
#       {
#         "pmid": "31339676",
#         "title": "Dolutegravir-Based or Low-Dose Efavirenz-Based Regimen for the Treatment of HIV-1.",
#         "authors": "NAMSAL ANRS 12313 Study Group; Kouanfack C; Mpoudi-Etame M; Omgba Bassega P; Eymard-Duvernay S; Leroy S; Boyer S; Peeters M; Calmy A; Delaporte E",
#         "doi": "10.1056/NEJMoa1904340",
#         "year": "2019",
#         "publication_types": [
#           "Clinical Trial, Phase III",
#           "Equivalence Trial",
#           "Journal Article",
#           "Multicenter Study",
#           "Randomized Controlled Trial",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "NAMSAL ANRS 12313 Study Group, et al. Dolutegravir-Based or Low-Dose Efavirenz-Based Regimen for the Treatment of HIV-1. Dolutegravir-Based or Low-Dose Efavirenz-Based Regimen for the Treatment of HIV-1. 2019; 381:816-826. doi: 10.1056/NEJMoa1904340"
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT00480792",
#     "publications": [
#       {
#         "pmid": "21486976",
#         "title": "Safety and immunogenicity of 4 intramuscular double doses and 4 intradermal low doses vs standard hepatitis B vaccine regimen in adults with HIV-1: a randomized controlled trial.",
#         "authors": "Launay O; van der Vliet D; Rosenberg AR; Michel ML; Piroth L; Rey D; Colin de Verdi\u00e8re N; Slama L; Martin K; Lortholary O; Carrat F; ANRS HB03 VIHVAC-B Trial",
#         "doi": "10.1001/jama.2011.351",
#         "year": "2011",
#         "publication_types": [
#           "Clinical Trial, Phase III",
#           "Journal Article",
#           "Multicenter Study",
#           "Randomized Controlled Trial",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Launay O, et al. Safety and immunogenicity of 4 intramuscular double doses and 4 intradermal low doses vs standard hepatitis B vaccine regimen in adults with HIV-1: a randomized controlled trial. Safety and immunogenicity of 4 intramuscular double doses and 4 intradermal low doses vs standard hepatitis B vaccine regimen in adults with HIV-1: a randomized controlled trial. 2011; 305:1432-40. doi: 10.1001/jama.2011.351"
#       },
#       {
#         "pmid": "27064975",
#         "title": "Long-term Immune Response to Hepatitis B Virus Vaccination Regimens in Adults With Human Immunodeficiency Virus 1: Secondary Analysis of a Randomized Clinical Trial.",
#         "authors": "Launay O; Rosenberg AR; Rey D; Pouget N; Michel ML; Reynes J; Neau D; Raffi F; Piroth L; Carrat F; ANRS HB03 VIHVAC-B (Trial Comparing 3 Strategies of Vaccination Against the Virus of Hepatitis B in HIV-Infected Patients) Group",
#         "doi": "10.1001/jamainternmed.2016.0741",
#         "year": "2016",
#         "publication_types": [
#           "Clinical Trial",
#           "Clinical Trial, Phase III",
#           "Comparative Study",
#           "Journal Article",
#           "Multicenter Study",
#           "Randomized Controlled Trial",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Launay O, et al. Long-term Immune Response to Hepatitis B Virus Vaccination Regimens in Adults With Human Immunodeficiency Virus 1: Secondary Analysis of a Randomized Clinical Trial. Long-term Immune Response to Hepatitis B Virus Vaccination Regimens in Adults With Human Immunodeficiency Virus 1: Secondary Analysis of a Randomized Clinical Trial. 2016; 176:603-10. doi: 10.1001/jamainternmed.2016.0741"
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT01095744",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT01489592",
#     "publications": [
#       {
#         "pmid": "15974953",
#         "title": "Hepcidin in iron metabolism.",
#         "authors": "Lor\u00e9al O; Haziza-Pigeon C; Troadec MB; Detivaud L; Turlin B; Courselaud B; Ilyin G; Brissot P",
#         "doi": "10.2174/1389203054065392",
#         "year": "2005",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't",
#           "Review"
#         ],
#         "citation": "Lor\u00e9al O, et al. Hepcidin in iron metabolism. Hepcidin in iron metabolism. 2005; 6:279-91. doi: 10.2174/1389203054065392"
#       },
#       {
#         "pmid": "18559556",
#         "title": "Pharmacokinetics of curcumin conjugate metabolites in healthy human subjects.",
#         "authors": "Vareed SK; Kakarala M; Ruffin MT; Crowell JA; Normolle DP; Djuric Z; Brenner DE",
#         "doi": "10.1158/1055-9965.EPI-07-2693",
#         "year": "2008",
#         "publication_types": [
#           "Journal Article",
#           "Randomized Controlled Trial",
#           "Research Support, N.I.H., Extramural",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Vareed SK, et al. Pharmacokinetics of curcumin conjugate metabolites in healthy human subjects. Pharmacokinetics of curcumin conjugate metabolites in healthy human subjects. 2008; 17:1411-7. doi: 10.1158/1055-9965.EPI-07-2693"
#       },
#       {
#         "pmid": "20169331",
#         "title": "Natural and synthetic STAT3 inhibitors reduce hepcidin expression in differentiated mouse hepatocytes expressing the active phosphorylated STAT3 form.",
#         "authors": "Fatih N; Camberlein E; Island ML; Corlu A; Abgueguen E; D\u00e9tivaud L; Leroyer P; Brissot P; Lor\u00e9al O",
#         "doi": "10.1007/s00109-009-0588-3",
#         "year": "2010",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Fatih N, et al. Natural and synthetic STAT3 inhibitors reduce hepcidin expression in differentiated mouse hepatocytes expressing the active phosphorylated STAT3 form. Natural and synthetic STAT3 inhibitors reduce hepcidin expression in differentiated mouse hepatocytes expressing the active phosphorylated STAT3 form. 2010; 88:477-86. doi: 10.1007/s00109-009-0588-3"
#       },
#       {
#         "pmid": "15501961",
#         "title": "Phase I clinical trial of oral curcumin: biomarkers of systemic activity and compliance.",
#         "authors": "Sharma RA; Euden SA; Platton SL; Cooke DN; Shafayat A; Hewitt HR; Marczylo TH; Morgan B; Hemingway D; Plummer SM; Pirmohamed M; Gescher AJ; Steward WP",
#         "doi": "10.1158/1078-0432.CCR-04-0744",
#         "year": "2004",
#         "publication_types": [
#           "Clinical Trial",
#           "Clinical Trial, Phase I",
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Sharma RA, et al. Phase I clinical trial of oral curcumin: biomarkers of systemic activity and compliance. Phase I clinical trial of oral curcumin: biomarkers of systemic activity and compliance. 2004; 10:6847-54. doi: 10.1158/1078-0432.CCR-04-0744"
#       },
#       {
#         "pmid": "16946298",
#         "title": "STAT3 mediates hepatic hepcidin expression and its inflammatory stimulation.",
#         "authors": "Verga Falzacappa MV; Vujic Spasic M; Kessler R; Stolte J; Hentze MW; Muckenthaler MU",
#         "doi": "10.1182/blood-2006-07-033969",
#         "year": "2007",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Verga Falzacappa MV, et al. STAT3 mediates hepatic hepcidin expression and its inflammatory stimulation. STAT3 mediates hepatic hepcidin expression and its inflammatory stimulation. 2007; 109:353-8. doi: 10.1182/blood-2006-07-033969"
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT01453192",
#     "publications": [
#       {
#         "pmid": "30688008",
#         "title": "Low incidence of acute rejection within 6 months of kidney transplantation in HIV-infected recipients treated with raltegravir: the Agence Nationale de Recherche sur le Sida et les H\u00e9patites Virales (ANRS) 153 TREVE trial.",
#         "authors": "Matignon M; Leli\u00e8vre JD; Lahiani A; Abbassi K; Desvaux D; Diallo A; Peraldi MN; Taburet AM; Saillard J; Delaugerre C; Costagliola D; Assoumou L; Grimbert P; ANRS 153 TREVE study group",
#         "doi": "10.1111/hiv.12700",
#         "year": "2019",
#         "publication_types": [
#           "Journal Article",
#           "Multicenter Study",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Matignon M, et al. Low incidence of acute rejection within 6 months of kidney transplantation in HIV-infected recipients treated with raltegravir: the Agence Nationale de Recherche sur le Sida et les H\u00e9patites Virales (ANRS) 153 TREVE trial. Low incidence of acute rejection within 6 months of kidney transplantation in HIV-infected recipients treated with raltegravir: the Agence Nationale de Recherche sur le Sida et les H\u00e9patites Virales (ANRS) 153 TREVE trial. 2019; 20:202-213. doi: 10.1111/hiv.12700"
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT00460382",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT02486731",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT02116374",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT02497274",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT01022476",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT00528060",
#     "publications": [
#       {
#         "pmid": "23459496",
#         "title": "Adherence profiles and therapeutic responses of treatment-naive HIV-infected patients starting boosted atazanavir-based therapy in the ANRS 134-COPHAR 3 trial.",
#         "authors": "Parienti JJ; Barrail-Tran A; Duval X; Nembot G; Descamps D; Vigan M; Vrijens B; Panhard X; Taburet AM; Mentr\u00e9 F; Goujard C",
#         "doi": "10.1128/AAC.02605-12",
#         "year": "2013",
#         "publication_types": [
#           "Clinical Trial",
#           "Journal Article",
#           "Multicenter Study",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Parienti JJ, et al. Adherence profiles and therapeutic responses of treatment-naive HIV-infected patients starting boosted atazanavir-based therapy in the ANRS 134-COPHAR 3 trial. Adherence profiles and therapeutic responses of treatment-naive HIV-infected patients starting boosted atazanavir-based therapy in the ANRS 134-COPHAR 3 trial. 2013; 57:2265-71. doi: 10.1128/AAC.02605-12"
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT02078076",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT04008927",
#     "publications": [
#       {
#         "pmid": "22310560",
#         "title": "Effectiveness-implementation hybrid designs: combining elements of clinical effectiveness and implementation research to enhance public health impact.",
#         "authors": "Curran GM; Bauer M; Mittman B; Pyne JM; Stetler C",
#         "doi": "10.1097/MLR.0b013e3182408812",
#         "year": "2012",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, N.I.H., Extramural",
#           "Research Support, U.S. Gov't, Non-P.H.S."
#         ],
#         "citation": "Curran GM, et al. Effectiveness-implementation hybrid designs: combining elements of clinical effectiveness and implementation research to enhance public health impact. Effectiveness-implementation hybrid designs: combining elements of clinical effectiveness and implementation research to enhance public health impact. 2012; 50:217-26. doi: 10.1097/MLR.0b013e3182408812"
#       },
#       {
#         "pmid": "28004616",
#         "title": "Age- and time-dependent prevalence and incidence of hepatitis C virus infection in drug users in France, 2004-2011: model-based estimation from two national cross-sectional serosurveys.",
#         "authors": "Leon L; Kasereka S; Barin F; Larsen C; Weill-Barillet L; Pascal X; Chevaliez S; Pillonel J; Jauffret-Roustide M; LE Strat Y",
#         "doi": "10.1017/S0950268816002934",
#         "year": "2017",
#         "publication_types": [
#           "Journal Article"
#         ],
#         "citation": "Leon L, et al. Age- and time-dependent prevalence and incidence of hepatitis C virus infection in drug users in France, 2004-2011: model-based estimation from two national cross-sectional serosurveys. Age- and time-dependent prevalence and incidence of hepatitis C virus infection in drug users in France, 2004-2011: model-based estimation from two national cross-sectional serosurveys. 2017; 145:895-907. doi: 10.1017/S0950268816002934"
#       },
#       {
#         "pmid": "27537841",
#         "title": "Elbasvir-Grazoprevir to Treat Hepatitis C Virus Infection in Persons Receiving Opioid Agonist Therapy: A Randomized Trial.",
#         "authors": "Dore GJ; Altice F; Litwin AH; Dalgard O; Gane EJ; Shibolet O; Luetkemeyer A; Nahass R; Peng CY; Conway B; Grebely J; Howe AY; Gendrano IN; Chen E; Huang HC; Dutko FJ; Nickle DC; Nguyen BY; Wahl J; Barr E; Robertson MN; Platt HL; C-EDGE CO-STAR Study Group",
#         "doi": "10.7326/M16-0816",
#         "year": "2016",
#         "publication_types": [
#           "Journal Article",
#           "Multicenter Study",
#           "Randomized Controlled Trial"
#         ],
#         "citation": "Dore GJ, et al. Elbasvir-Grazoprevir to Treat Hepatitis C Virus Infection in Persons Receiving Opioid Agonist Therapy: A Randomized Trial. Elbasvir-Grazoprevir to Treat Hepatitis C Virus Infection in Persons Receiving Opioid Agonist Therapy: A Randomized Trial. 2016; 165:625-634. doi: 10.7326/M16-0816"
#       },
#       {
#         "pmid": "26806260",
#         "title": "Prospective assessment of rapid diagnostic tests for the detection of antibodies to hepatitis C virus, a tool for improving access to care.",
#         "authors": "Chevaliez S; Poiteau L; Rosa I; Soulier A; Roudot-Thoraval F; Laperche S; H\u00e9zode C; Pawlotsky JM",
#         "doi": "10.1016/j.cmi.2016.01.009",
#         "year": "2016",
#         "publication_types": [
#           "Comparative Study",
#           "Evaluation Study",
#           "Journal Article"
#         ],
#         "citation": "Chevaliez S, et al. Prospective assessment of rapid diagnostic tests for the detection of antibodies to hepatitis C virus, a tool for improving access to care. Prospective assessment of rapid diagnostic tests for the detection of antibodies to hepatitis C virus, a tool for improving access to care. 2016; 22:459.e1-6. doi: 10.1016/j.cmi.2016.01.009"
#       },
#       {
#         "pmid": "27178119",
#         "title": "Integrated respondent-driven sampling and peer support for persons who inject drugs in Haiphong, Vietnam: a case study with implications for interventions.",
#         "authors": "Des Jarlais D; Duong HT; Pham Minh K; Khuat OH; Nham TT; Arasteh K; Feelemyer J; Heckathorn DD; Peries M; Moles JP; Laureillard D; Nagot N; (The Drive Study Team)",
#         "doi": "10.1080/09540121.2016.1178698",
#         "year": "2016",
#         "publication_types": [
#           "Journal Article"
#         ],
#         "citation": "Des Jarlais D, et al. Integrated respondent-driven sampling and peer support for persons who inject drugs in Haiphong, Vietnam: a case study with implications for interventions. Integrated respondent-driven sampling and peer support for persons who inject drugs in Haiphong, Vietnam: a case study with implications for interventions. 2016; 28:1312-5. doi: 10.1080/09540121.2016.1178698"
#       },
#       {
#         "pmid": "29432973",
#         "title": "Using dual capture/recapture studies to estimate the population size of persons who inject drugs (PWID) in the city of Hai Phong, Vietnam.",
#         "authors": "Des Jarlais D; Khue PM; Feelemyer J; Arasteh K; Thi Huong D; Thi Hai Oanh K; Thi Giang H; Thi Tuyet Thanh N; Vinh VH; Heckathorn DD; Moles JP; Vallo R; Quillet C; Rapoud D; Michel L; Laureillard D; Hammett T; Nagot N",
#         "doi": "10.1016/j.drugalcdep.2017.11.033",
#         "year": "2018",
#         "publication_types": [
#           "Journal Article"
#         ],
#         "citation": "Des Jarlais D, et al. Using dual capture/recapture studies to estimate the population size of persons who inject drugs (PWID) in the city of Hai Phong, Vietnam. Using dual capture/recapture studies to estimate the population size of persons who inject drugs (PWID) in the city of Hai Phong, Vietnam. 2018; 185:106-111. doi: 10.1016/j.drugalcdep.2017.11.033"
#       },
#       {
#         "pmid": "35774932",
#         "title": "Reaching Hard-to-Reach People Who Use Drugs: A Community-Based Strategy for the Elimination of Hepatitis C.",
#         "authors": "Nagot N; D'Ottavi M; Quillet C; Debellefontaine A; Castellani J; Langendorfer N; Hanslik B; Guichard S; Baglioni R; Faucherre V; Tuaillon E; Pageaux GP; Laureillard D; Donnadieu-Rigole H",
#         "doi": "10.1093/ofid/ofac181",
#         "year": "2022",
#         "publication_types": [
#           "Journal Article"
#         ],
#         "citation": "Nagot N, et al. Reaching Hard-to-Reach People Who Use Drugs: A Community-Based Strategy for the Elimination of Hepatitis C. Reaching Hard-to-Reach People Who Use Drugs: A Community-Based Strategy for the Elimination of Hepatitis C. 2022; 9:ofac181. doi: 10.1093/ofid/ofac181"
#       },
#       {
#         "pmid": "27168667",
#         "title": "Improving Screening Methods for Hepatitis C Among People Who Inject Drugs: Findings from the HepTLC Initiative, 2012-2014.",
#         "authors": "Blackburn NA; Patel RC; Zibbell JE",
#         "doi": "10.1177/00333549161310S214",
#         "year": "2016",
#         "publication_types": [
#           "Journal Article"
#         ],
#         "citation": "Blackburn NA, et al. Improving Screening Methods for Hepatitis C Among People Who Inject Drugs: Findings from the HepTLC Initiative, 2012-2014. Improving Screening Methods for Hepatitis C Among People Who Inject Drugs: Findings from the HepTLC Initiative, 2012-2014. 2016; 131 Suppl 2:91-7. doi: 10.1177/00333549161310S214"
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT01331876",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT00820820",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT02273765",
#     "publications": [
#       {
#         "pmid": "33667406",
#         "title": "Standard dose raltegravir or efavirenz-based antiretroviral treatment for patients co-infected with HIV and tuberculosis (ANRS 12\u2008300 Reflate TB 2): an open-label, non-inferiority, randomised, phase 3 trial.",
#         "authors": "De Castro N; Marcy O; Chazallon C; Messou E; Eholi\u00e9 S; N'takpe JB; Bhatt N; Khosa C; Timana Massango I; Laureillard D; Chau GD; Domergue A; Veloso V; Escada R; Wagner Cardoso S; Delaugerre C; Anglaret X; Molina JM; Grinsztejn B; ANRS 12300 Reflate TB2 study group",
#         "doi": "10.1016/S1473-3099(20)30869-0",
#         "year": "2021",
#         "publication_types": [
#           "Clinical Trial, Phase III",
#           "Comparative Study",
#           "Journal Article",
#           "Multicenter Study",
#           "Randomized Controlled Trial",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "De Castro N, et al. Standard dose raltegravir or efavirenz-based antiretroviral treatment for patients co-infected with HIV and tuberculosis (ANRS 12\u2008300 Reflate TB 2): an open-label, non-inferiority, randomised, phase 3 trial. Standard dose raltegravir or efavirenz-based antiretroviral treatment for patients co-infected with HIV and tuberculosis (ANRS 12\u2008300 Reflate TB 2): an open-label, non-inferiority, randomised, phase 3 trial. 2021; 21:813-822. doi: 10.1016/S1473-3099(20)30869-0"
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT02107365",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT00113282",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT01055873",
#     "publications": [
#       {
#         "pmid": "22427678",
#         "title": "Relationships between HIV disease history and blood HIV-1 DNA load in perinatally infected adolescents and young adults: the ANRS-EP38-IMMIP study.",
#         "authors": "Avettand-Fenoel V; Blanche S; Le Chenadec J; Scott-Algara D; Dollfus C; Viard JP; Bouallag N; Benmebarek Y; Rivi\u00e8re Y; Warszawski J; Rouzioux C; Buseyne F",
#         "doi": "10.1093/infdis/jis233",
#         "year": "2012",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Avettand-Fenoel V, et al. Relationships between HIV disease history and blood HIV-1 DNA load in perinatally infected adolescents and young adults: the ANRS-EP38-IMMIP study. Relationships between HIV disease history and blood HIV-1 DNA load in perinatally infected adolescents and young adults: the ANRS-EP38-IMMIP study. 2012; 205:1520-8. doi: 10.1093/infdis/jis233"
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT05199831",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT01359774",
#     "publications": [
#       {
#         "pmid": "17653274",
#         "title": "Early energy deficit in Huntington disease: identification of a plasma biomarker traceable during disease progression.",
#         "authors": "Mochel F; Charles P; Seguin F; Barritault J; Coussieu C; Perin L; Le Bouc Y; Gervais C; Carcelain G; Vassault A; Feingold J; Rabier D; Durr A",
#         "doi": "10.1371/journal.pone.0000647",
#         "year": "2007",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Mochel F, et al. Early energy deficit in Huntington disease: identification of a plasma biomarker traceable during disease progression. Early energy deficit in Huntington disease: identification of a plasma biomarker traceable during disease progression. 2007; 2:e647. doi: 10.1371/journal.pone.0000647"
#       },
#       {
#         "pmid": "21320997",
#         "title": "Validation of plasma branched chain amino acids as biomarkers in Huntington disease.",
#         "authors": "Mochel F; Benaich S; Rabier D; Durr A",
#         "doi": "10.1001/archneurol.2010.358",
#         "year": "2011",
#         "publication_types": [
#           "Letter",
#           "Validation Study"
#         ],
#         "citation": "Mochel F, et al. Validation of plasma branched chain amino acids as biomarkers in Huntington disease. Validation of plasma branched chain amino acids as biomarkers in Huntington disease. 2011; 68:265-7. doi: 10.1001/archneurol.2010.358"
#       },
#       {
#         "pmid": "21285522",
#         "title": "Energy deficit in Huntington disease: why it matters.",
#         "authors": "Mochel F; Haller RG",
#         "doi": "10.1172/JCI45691",
#         "year": "2011",
#         "publication_types": [
#           "Journal Article",
#           "Review"
#         ],
#         "citation": "Mochel F and Haller RG. Energy deficit in Huntington disease: why it matters. Energy deficit in Huntington disease: why it matters. 2011; 121:493-9. doi: 10.1172/JCI45691"
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT02099474",
#     "publications": [
#       {
#         "pmid": "32661003",
#         "title": "Effect of Pregnancy on Unbound Raltegravir Concentrations in the ANRS 160 RalFe Trial.",
#         "authors": "Zheng Y; Hirt D; Delmas S; Lui G; Benaboud S; Lechedanec J; Tr\u00e9luyer JM; Chenevier-Gobeaux C; Arezes E; Gelley A; Amri I; Urien S; Bouazza N; Foissac F; Warszawski J; Ghosn J",
#         "doi": "10.1128/AAC.00759-20",
#         "year": "2020",
#         "publication_types": [
#           "Journal Article",
#           "Multicenter Study",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Zheng Y, et al. Effect of Pregnancy on Unbound Raltegravir Concentrations in the ANRS 160 RalFe Trial. Effect of Pregnancy on Unbound Raltegravir Concentrations in the ANRS 160 RalFe Trial. 2020; 64:(unknown pages). doi: 10.1128/AAC.00759-20"
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT03546127",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT04315948",
#     "publications": [
#       {
#         "pmid": "34350582",
#         "title": "Remdesivir for the treatment of COVID-19.",
#         "authors": "Ansems K; Grundeis F; Dahms K; Mikolajewska A; Thieme V; Piechotta V; Metzendorf MI; Stegemann M; Benstoem C; Fichtner F",
#         "doi": "10.1002/14651858.CD014962",
#         "year": "2021",
#         "publication_types": [
#           "Journal Article",
#           "Systematic Review"
#         ],
#         "citation": "Ansems K, et al. Remdesivir for the treatment of COVID-19. Remdesivir for the treatment of COVID-19. 2021; 8:CD014962. doi: 10.1002/14651858.CD014962"
#       },
#       {
#         "pmid": "37269068",
#         "title": "Management of pharmacovigilance during the COVID-19 pandemic crisis by the safety department of an academic sponsor: Lessons learnt and challenges from the EU DisCoVeRy clinical trial.",
#         "authors": "Mercier N; Belhadi D; DeChanet A; Delmas C; Saillard J; Dumousseaux M; Le Mestre S; Fougerou-Leurent C; Ferrane A; Burdet C; Esp\u00e9rou H; Ader F; Hites M; Peiffer-Smadja N; Poissy J; Andrejak C; Paiva JA; Tacconelli E; Staub T; Greil R; Costagliola D; Mentre F; Yazdanpanah Y; Diallo A; DisCoVeRy Safety Working group",
#         "doi": "10.1002/prp2.1072",
#         "year": "2023",
#         "publication_types": [
#           "Journal Article",
#           "Review",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Mercier N, et al. Management of pharmacovigilance during the COVID-19 pandemic crisis by the safety department of an academic sponsor: Lessons learnt and challenges from the EU DisCoVeRy clinical trial. Management of pharmacovigilance during the COVID-19 pandemic crisis by the safety department of an academic sponsor: Lessons learnt and challenges from the EU DisCoVeRy clinical trial. 2023; 11:e01072. doi: 10.1002/prp2.1072"
#       },
#       {
#         "pmid": "32473020",
#         "title": "Rationale of a loading dose initiation for hydroxychloroquine treatment in COVID-19 infection in the DisCoVeRy trial.",
#         "authors": "L\u00ea MP; Peiffer-Smadja N; Guedj J; N\u00e9ant N; Mentr\u00e9 F; Ader F; Yazdanpanah Y; Peytavin G",
#         "doi": "10.1093/jac/dkaa191",
#         "year": "2020",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't",
#           "Review"
#         ],
#         "citation": "L\u00ea MP, et al. Rationale of a loading dose initiation for hydroxychloroquine treatment in COVID-19 infection in the DisCoVeRy trial. Rationale of a loading dose initiation for hydroxychloroquine treatment in COVID-19 infection in the DisCoVeRy trial. 2020; 75:2376-2380. doi: 10.1093/jac/dkaa191"
#       },
#       {
#         "pmid": "37302469",
#         "title": "Ensuring quality control in a COVID-19 clinical trial during the pandemic: The experience of the Inserm C20-15 DisCoVeRy study.",
#         "authors": "Fougerou-Leurent C; Delmas C; Saillard J; Dumousseaux M; Ferrane A; Mercier N; Terzic V; Le Mestre S; Dechanet A; Belhadi D; Metois A; Burdet C; Mentr\u00e9 F; Noret M; Diallo A; Petrov-Sanchez V; Couffin-Cadiergues S; Hites M; Ader F; Esperou H",
#         "doi": "10.1016/j.cct.2023.107267",
#         "year": "2023",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Fougerou-Leurent C, et al. Ensuring quality control in a COVID-19 clinical trial during the pandemic: The experience of the Inserm C20-15 DisCoVeRy study. Ensuring quality control in a COVID-19 clinical trial during the pandemic: The experience of the Inserm C20-15 DisCoVeRy study. 2023; 131:107267. doi: 10.1016/j.cct.2023.107267"
#       },
#       {
#         "pmid": "35512728",
#         "title": "Remdesivir and three other drugs for hospitalised patients with COVID-19: final results of the WHO Solidarity randomised trial and updated meta-analyses.",
#         "authors": "WHO Solidarity Trial Consortium",
#         "doi": "10.1016/S0140-6736(22)00519-0",
#         "year": "2022",
#         "publication_types": [
#           "Journal Article",
#           "Meta-Analysis"
#         ],
#         "citation": "WHO Solidarity Trial Consortium. Remdesivir and three other drugs for hospitalised patients with COVID-19: final results of the WHO Solidarity randomised trial and updated meta-analyses. Remdesivir and three other drugs for hospitalised patients with COVID-19: final results of the WHO Solidarity randomised trial and updated meta-analyses. 2022; 399:1941-1953. doi: 10.1016/S0140-6736(22)00519-0"
#       },
#       {
#         "pmid": "34048876",
#         "title": "An open-label randomized controlled trial of the effect of lopinavir/ritonavir, lopinavir/ritonavir plus IFN-\u03b2-1a and hydroxychloroquine in hospitalized patients with COVID-19.",
#         "authors": "Ader F; Peiffer-Smadja N; Poissy J; Bouscambert-Duchamp M; Belhadi D; Diallo A; Delmas C; Saillard J; Dechanet A; Mercier N; Dupont A; Alfaiate T; Lescure FX; Raffi F; Goehringer F; Kimmoun A; Jaureguiberry S; Reignier J; Nseir S; Danion F; Clere-Jehl R; Bouiller K; Navellou JC; Tolsma V; Cabi\u00e9 A; Dubost C; Courjon J; Leroy S; Mootien J; Gaci R; Mourvillier B; Faure E; Pourcher V; Gallien S; Launay O; Lacombe K; Lanoix JP; Makinson A; Martin-Blondel G; Bouadma L; Botelho-Nevers E; Gagneux-Brunon A; Epaulard O; Piroth L; Wallet F; Richard JC; Reuter J; Staub T; Lina B; Noret M; Andrejak C; L\u00ea MP; Peytavin G; Hites M; Costagliola D; Yazdanpanah Y; Burdet C; Mentr\u00e9 F; DisCoVeRy study group",
#         "doi": "10.1016/j.cmi.2021.05.020",
#         "year": "2021",
#         "publication_types": [
#           "Clinical Trial, Phase III",
#           "Journal Article",
#           "Multicenter Study",
#           "Randomized Controlled Trial"
#         ],
#         "citation": "Ader F, et al. An open-label randomized controlled trial of the effect of lopinavir/ritonavir, lopinavir/ritonavir plus IFN-\u03b2-1a and hydroxychloroquine in hospitalized patients with COVID-19. An open-label randomized controlled trial of the effect of lopinavir/ritonavir, lopinavir/ritonavir plus IFN-\u03b2-1a and hydroxychloroquine in hospitalized patients with COVID-19. 2021; 27:1826-1837. doi: 10.1016/j.cmi.2021.05.020"
#       },
#       {
#         "pmid": "36680782",
#         "title": "Implementation of a centralized pharmacovigilance system in academic pan-European clinical trials: Experience from EU-Response and conect4children consortia.",
#         "authors": "Terzi\u0107 V; Levoyer L; Figarella M; Bigagli E; Mercier N; De Gastines L; Gibowski S; Tr\u00f8seid M; Demotes J; Olsen IC; Hites M; Ader F; Lopez JRA; Mentr\u00e9 F; Esp\u00e9rou H; Costagliola D; R\u00f8ttingen JA; Poissy J; Roz\u00e9 JC; Warris A; O'Leary J; Fernandes RM; Assoumou L; Hankard R; Turner MA; Yazdanpanah Y; Diallo A; EU-Response safety group; c4c safety group",
#         "doi": "10.1111/bcp.15669",
#         "year": "2023",
#         "publication_types": [
#           "Journal Article",
#           "Review",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Terzi\u0107 V, et al. Implementation of a centralized pharmacovigilance system in academic pan-European clinical trials: Experience from EU-Response and conect4children consortia. Implementation of a centralized pharmacovigilance system in academic pan-European clinical trials: Experience from EU-Response and conect4children consortia. 2023; 89:1318-1328. doi: 10.1111/bcp.15669"
#       },
#       {
#         "pmid": "34763056",
#         "title": "Accelerating clinical trial implementation in the context of the COVID-19 pandemic: challenges, lessons learned and recommendations from DisCoVeRy and the EU-SolidAct EU response group.",
#         "authors": "EU-Response investigators group; Diallo A; Tr\u00f8seid M; Simensen VC; Boston A; Demotes J; Olsen IC; Chung F; Paiva JA; Hites M; Ader F; Arribas JR; Baratt-Due A; Melien \u00d8; Tacconelli E; Staub T; Greil R; Tsiodras S; Briel M; Esperou H; Mentr\u00e9 F; Eustace J; Saillard J; Delmas C; LeMestre S; Dumousseaux M; Costagliola D; R\u00f8ttingen JA; Yazdanpanah Y",
#         "doi": "10.1016/j.cmi.2021.10.011",
#         "year": "2022",
#         "publication_types": [
#           "Journal Article"
#         ],
#         "citation": "EU-Response investigators group, et al. Accelerating clinical trial implementation in the context of the COVID-19 pandemic: challenges, lessons learned and recommendations from DisCoVeRy and the EU-SolidAct EU response group. Accelerating clinical trial implementation in the context of the COVID-19 pandemic: challenges, lessons learned and recommendations from DisCoVeRy and the EU-SolidAct EU response group. 2022; 28:1-5. doi: 10.1016/j.cmi.2021.10.011"
#       },
#       {
#         "pmid": "36695483",
#         "title": "Remdesivir for the treatment of COVID-19.",
#         "authors": "Grundeis F; Ansems K; Dahms K; Thieme V; Metzendorf MI; Skoetz N; Benstoem C; Mikolajewska A; Griesel M; Fichtner F; Stegemann M",
#         "doi": "10.1002/14651858.CD014962.pub2",
# ...
#         "publication_types": [
#           "Clinical Trial",
#           "Journal Article",
#           "Multicenter Study",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "El Khoury P, et al. Plasma cholesterol efflux capacity from human THP-1 macrophages is reduced in HIV-infected patients: impact of HAART. Plasma cholesterol efflux capacity from human THP-1 macrophages is reduced in HIV-infected patients: impact of HAART. 2015; 56:692-702. doi: 10.1194/jlr.M054510"
#       },
#       {
#         "pmid": "22008658",
#         "title": "Burden of HIV disease and comorbidities on the chances of maintaining employment in the era of sustained combined antiretoviral therapies use.",
#         "authors": "Dray-Spira R; Legeai C; Le Den M; Bou\u00e9 F; Lascoux-Combe C; Simon A; May T; Goujard C; Meyer L; ANRS-COPANA Cohort Study Group",
#         "doi": "10.1097/QAD.0b013e32834dcf61",
#         "year": "2012",
#         "publication_types": [
#           "Journal Article",
#           "Multicenter Study",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Dray-Spira R, et al. Burden of HIV disease and comorbidities on the chances of maintaining employment in the era of sustained combined antiretoviral therapies use. Burden of HIV disease and comorbidities on the chances of maintaining employment in the era of sustained combined antiretoviral therapies use. 2012; 26:207-15. doi: 10.1097/QAD.0b013e32834dcf61"
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT01037777",
#     "publications": [
#       {
#         "pmid": "23707147",
#         "title": "Biological and clinical characteristics of individuals at risk for spinocerebellar ataxia types 1, 2, 3, and 6 in the longitudinal RISCA study: analysis of baseline data.",
#         "authors": "Jacobi H; Reetz K; du Montcel ST; Bauer P; Mariotti C; Nanetti L; Rakowicz M; Sulek A; Durr A; Charles P; Filla A; Antenora A; Sch\u00f6ls L; Schicks J; Infante J; Kang JS; Timmann D; Di Fabio R; Masciullo M; Baliko L; Melegh B; Boesch S; B\u00fcrk K; Peltz A; Schulz JB; Dufaure-Gar\u00e9 I; Klockgether T",
#         "doi": "10.1016/S1474-4422(13)70104-2",
#         "year": "2013",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Jacobi H, et al. Biological and clinical characteristics of individuals at risk for spinocerebellar ataxia types 1, 2, 3, and 6 in the longitudinal RISCA study: analysis of baseline data. Biological and clinical characteristics of individuals at risk for spinocerebellar ataxia types 1, 2, 3, and 6 in the longitudinal RISCA study: analysis of baseline data. 2013; 12:650-8. doi: 10.1016/S1474-4422(13)70104-2"
#       },
#       {
#         "pmid": "24780882",
#         "title": "Prediction of the age at onset in spinocerebellar ataxia type 1, 2, 3 and 6.",
#         "authors": "Tezenas du Montcel S; Durr A; Rakowicz M; Nanetti L; Charles P; Sulek A; Mariotti C; Rola R; Schols L; Bauer P; Dufaure-Gar\u00e9 I; Jacobi H; Forlani S; Schmitz-H\u00fcbsch T; Filla A; Timmann D; van de Warrenburg BP; Marelli C; Kang JS; Giunti P; Cook A; Baliko L; Melegh B; Boesch S; Szymanski S; Berciano J; Infante J; Buerk K; Masciullo M; Di Fabio R; Depondt C; Ratka S; Stevanin G; Klockgether T; Brice A; Golmard JL",
#         "doi": "10.1136/jmedgenet-2013-102200",
#         "year": "2014",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Tezenas du Montcel S, et al. Prediction of the age at onset in spinocerebellar ataxia type 1, 2, 3 and 6. Prediction of the age at onset in spinocerebellar ataxia type 1, 2, 3 and 6. 2014; 51:479-86. doi: 10.1136/jmedgenet-2013-102200"
#       },
#       {
#         "pmid": "32822634",
#         "title": "Conversion of individuals at risk for spinocerebellar ataxia types 1, 2, 3, and 6 to manifest ataxia (RISCA): a longitudinal cohort study.",
#         "authors": "Jacobi H; du Montcel ST; Romanzetti S; Harmuth F; Mariotti C; Nanetti L; Rakowicz M; Makowicz G; Durr A; Monin ML; Filla A; Roca A; Sch\u00f6ls L; Hengel H; Infante J; Kang JS; Timmann D; Casali C; Masciullo M; Baliko L; Melegh B; Nachbauer W; B\u00fcrk-Gergs K; Schulz JB; Riess O; Reetz K; Klockgether T",
#         "doi": "10.1016/S1474-4422(20)30235-0",
#         "year": "2020",
#         "publication_types": [
#           "Clinical Trial",
#           "Journal Article",
#           "Multicenter Study",
#           "Observational Study",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Jacobi H, et al. Conversion of individuals at risk for spinocerebellar ataxia types 1, 2, 3, and 6 to manifest ataxia (RISCA): a longitudinal cohort study. Conversion of individuals at risk for spinocerebellar ataxia types 1, 2, 3, and 6 to manifest ataxia (RISCA): a longitudinal cohort study. 2020; 19:738-747. doi: 10.1016/S1474-4422(20)30235-0"
#       },
#       {
#         "pmid": "35264424",
#         "title": "Levels of Neurofilament Light at the Preataxic and Ataxic Stages of Spinocerebellar Ataxia Type 1.",
#         "authors": "Wilke C; Mengel D; Sch\u00f6ls L; Hengel H; Rakowicz M; Klockgether T; Durr A; Filla A; Melegh B; Sch\u00fcle R; Reetz K; Jacobi H; Synofzik M",
#         "doi": "10.1212/WNL.0000000000200257",
#         "year": "2022",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Wilke C, et al. Levels of Neurofilament Light at the Preataxic and Ataxic Stages of Spinocerebellar Ataxia Type 1. Levels of Neurofilament Light at the Preataxic and Ataxic Stages of Spinocerebellar Ataxia Type 1. 2022; 98:e1985-e1996. doi: 10.1212/WNL.0000000000200257"
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT01842477",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT02721745",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT02408354",
#     "publications": [
#       {
#         "pmid": "28969699",
#         "title": "A randomized, controlled, double-blind, crossover trial of triheptanoin in alternating hemiplegia of childhood.",
#         "authors": "Hainque E; Caillet S; Leroy S; Flamand-Roze C; Adanyeguh I; Charbonnier-Beaupel F; Retail M; Le Toullec B; Atencio M; Rivaud-P\u00e9choux S; Brochard V; Habarou F; Ottolenghi C; Cormier F; M\u00e9neret A; Ruiz M; Doulazmi M; Roubergue A; Corvol JC; Vidailhet M; Mochel F; Roze E",
#         "doi": "10.1186/s13023-017-0713-2",
#         "year": "2017",
#         "publication_types": [
#           "Journal Article",
#           "Randomized Controlled Trial"
#         ],
#         "citation": "Hainque E, et al. A randomized, controlled, double-blind, crossover trial of triheptanoin in alternating hemiplegia of childhood. A randomized, controlled, double-blind, crossover trial of triheptanoin in alternating hemiplegia of childhood. 2017; 12:160. doi: 10.1186/s13023-017-0713-2"
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT01688453",
#     "publications": [
#       {
#         "pmid": "29696179",
#         "title": "Reducing social inequalities in access to overweight and obesity care management for adolescents: The PRALIMAP-IN\u00c8S trial protocol and inclusion data analysis.",
#         "authors": "Legrand K; Lecomte E; Langlois J; Muller L; Saez L; Quinet MH; B\u00f6hme P; Spitz E; Omorou AY; Brian\u00e7on S; PRALIMAP-IN\u00c8S trial group",
#         "doi": "10.1016/j.conctc.2017.05.010",
#         "year": "2017",
#         "publication_types": [
#           "Journal Article"
#         ],
#         "citation": "Legrand K, et al. Reducing social inequalities in access to overweight and obesity care management for adolescents: The PRALIMAP-IN\u00c8S trial protocol and inclusion data analysis. Reducing social inequalities in access to overweight and obesity care management for adolescents: The PRALIMAP-IN\u00c8S trial protocol and inclusion data analysis. 2017; 7:141-157. doi: 10.1016/j.conctc.2017.05.010"
#       },
#       {
#         "pmid": "32097754",
#         "title": "Physical activity rather than sedentary behaviour is socially determined in French adolescents with overweight and obesity.",
#         "authors": "Omorou AY; Manneville F; Langlois J; Legrand K; B\u00f6hme P; Muller L; Guillemin F; Brian\u00e7on S; Lecomte E; PRALIMAP-IN\u00c8S Trial Group",
#         "doi": "10.1016/j.ypmed.2020.106043",
#         "year": "2020",
#         "publication_types": [
#           "Journal Article",
#           "Multicenter Study",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Omorou AY, et al. Physical activity rather than sedentary behaviour is socially determined in French adolescents with overweight and obesity. Physical activity rather than sedentary behaviour is socially determined in French adolescents with overweight and obesity. 2020; 134:106043. doi: 10.1016/j.ypmed.2020.106043"
#       },
#       {
#         "pmid": "34087324",
#         "title": "Sociodemographic and psychological characteristics associated with discrepancy between body satisfaction and weight change among adolescents.",
#         "authors": "Manneville F; Omorou AY; Legrand K; Lecomte E; Rydberg JA; Brian\u00e7on S; Guillemin F; PRALIMAP Trial Group",
#         "doi": "10.1016/j.ypmed.2021.106668",
#         "year": "2021",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Manneville F, et al. Sociodemographic and psychological characteristics associated with discrepancy between body satisfaction and weight change among adolescents. Sociodemographic and psychological characteristics associated with discrepancy between body satisfaction and weight change among adolescents. 2021; 150:106668. doi: 10.1016/j.ypmed.2021.106668"
#       },
#       {
#         "pmid": "29776897",
#         "title": "Reach and Acceptability of a Mobile Reminder Strategy and Facebook Group Intervention for Weight Management in Less Advantaged Adolescents: Insights From the PRALIMAP-IN\u00c8S Trial.",
#         "authors": "Saez L; Langlois J; Legrand K; Quinet MH; Lecomte E; Omorou AY; Brian\u00e7on S; PRALIMAP-IN\u00c8S Trial Group",
#         "doi": "10.2196/mhealth.7657",
#         "year": "2018",
#         "publication_types": [
#           "Journal Article"
#         ],
#         "citation": "Saez L, et al. Reach and Acceptability of a Mobile Reminder Strategy and Facebook Group Intervention for Weight Management in Less Advantaged Adolescents: Insights From the PRALIMAP-IN\u00c8S Trial. Reach and Acceptability of a Mobile Reminder Strategy and Facebook Group Intervention for Weight Management in Less Advantaged Adolescents: Insights From the PRALIMAP-IN\u00c8S Trial. 2018; 6:e110. doi: 10.2196/mhealth.7657"
#       },
#       {
#         "pmid": "35272723",
#         "title": "Behavioural risk patterns in adolescents with excess weight participating in the PRALIMAP-IN\u00c8S trial.",
#         "authors": "Julia C; Omorou A; Lecomte E; Langlois J; Touvier M; Hercberg S; Brian\u00e7on S; Kesse-Guyot E; Guillemin F; PRALIMAP-IN\u00c8S Trial Group",
#         "doi": "10.1017/S136898002200057X",
#         "year": "2023",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Julia C, et al. Behavioural risk patterns in adolescents with excess weight participating in the PRALIMAP-IN\u00c8S trial. Behavioural risk patterns in adolescents with excess weight participating in the PRALIMAP-IN\u00c8S trial. 2023; 26:96-105. doi: 10.1017/S136898002200057X"
#       },
#       {
#         "pmid": "29934380",
#         "title": "Using facilitator-receiver peer dyads matched according to socioeconomic status to promote behaviour change in overweight adolescents: a feasibility study.",
#         "authors": "Saez L; Legrand K; Alleyrat C; Ramisasoa S; Langlois J; Muller L; Omorou AY; De Lavenne R; Kivits J; Lecomte E; Brian\u00e7on S; PRALIMAP-IN\u00c8S Trial Group",
#         "doi": "10.1136/bmjopen-2017-019731",
#         "year": "2018",
#         "publication_types": [
#           "Journal Article",
#           "Multicenter Study",
#           "Randomized Controlled Trial",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Saez L, et al. Using facilitator-receiver peer dyads matched according to socioeconomic status to promote behaviour change in overweight adolescents: a feasibility study. Using facilitator-receiver peer dyads matched according to socioeconomic status to promote behaviour change in overweight adolescents: a feasibility study. 2018; 8:e019731. doi: 10.1136/bmjopen-2017-019731"
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT02172677",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT01880151",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT02658253",
#     "publications": [
#       {
#         "pmid": "33717176",
#         "title": "Progress and Insights Toward an Effective Placental Malaria Vaccine.",
#         "authors": "Gamain B; Ch\u00eane A; Viebig NK; Tuikue Ndam N; Nielsen MA",
#         "doi": "10.3389/fimmu.2021.634508",
#         "year": "2021",
#         "publication_types": [
#           "Journal Article",
#           "Research Support, Non-U.S. Gov't",
#           "Review"
#         ],
#         "citation": "Gamain B, et al. Progress and Insights Toward an Effective Placental Malaria Vaccine. Progress and Insights Toward an Effective Placental Malaria Vaccine. 2021; 12:634508. doi: 10.3389/fimmu.2021.634508"
#       },
#       {
#         "pmid": "32032566",
#         "title": "PRIMVAC vaccine adjuvanted with Alhydrogel or GLA-SE to prevent placental malaria: a first-in-human, randomised, double-blind, placebo-controlled study.",
#         "authors": "Sirima SB; Richert L; Ch\u00eane A; Konate AT; Campion C; Dechavanne S; Semblat JP; Benhamouda N; Bahuaud M; Loulergue P; Ou\u00e9draogo A; N\u00e9bi\u00e9 I; Kabore M; Kargougou D; Barry A; Ouattara SM; Boilet V; Allais F; Roguet G; Havelange N; Lopez-Perez E; Kuppers A; Konat\u00e9 E; Roussillon C; Kant\u00e9 M; Belarbi L; Diarra A; Henry N; Soulama I; Ou\u00e9draogo A; Esperou H; Leroy O; Batteux F; Tartour E; Viebig NK; Thiebaut R; Launay O; Gamain B",
#         "doi": "10.1016/S1473-3099(19)30739-X",
#         "year": "2020",
#         "publication_types": [
#           "Clinical Trial, Phase I",
#           "Journal Article",
#           "Randomized Controlled Trial",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Sirima SB, et al. PRIMVAC vaccine adjuvanted with Alhydrogel or GLA-SE to prevent placental malaria: a first-in-human, randomised, double-blind, placebo-controlled study. PRIMVAC vaccine adjuvanted with Alhydrogel or GLA-SE to prevent placental malaria: a first-in-human, randomised, double-blind, placebo-controlled study. 2020; 20:585-597. doi: 10.1016/S1473-3099(19)30739-X"
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT02027051",
#     "publications": []
#   },
#   {
#     "NCTId": "NCT00118677",
#     "publications": [
#       {
#         "pmid": "20657770",
#         "title": "Relationship between regulatory T cells and immune activation in human immunodeficiency virus-infected patients interrupting antiretroviral therapy.",
#         "authors": "Weiss L; Piketty C; Assoumou L; Didier C; Caccavelli L; Donkova-Petrini V; Levy Y; Girard PM; Burgard M; Viard JP; Rouzioux C; Costagliola D; ANRS 116 SALTO study group",
#         "doi": "10.1371/journal.pone.0011659",
#         "year": "2010",
#         "publication_types": [
#           "Clinical Trial",
#           "Journal Article",
#           "Multicenter Study",
#           "Research Support, Non-U.S. Gov't"
#         ],
#         "citation": "Weiss L, et al. Relationship between regulatory T cells and immune activation in human immunodeficiency virus-infected patients interrupting antiretroviral therapy. Relationship between regulatory T cells and immune activation in human immunodeficiency virus-infected patients interrupting antiretroviral therapy. 2010; 5:e11659. doi: 10.1371/journal.pone.0011659"
#       }
#     ]
#   },
#   {
#     "NCTId": "NCT00647205",
#     "publications": []
#   }
# ]

# %%
# The number of NCTId didn't change
assert len(total_publications_list) == len(studies_list)

# %% [markdown]
# ### Import dans Pandas

# %%
df_pubmed = pd.DataFrame.from_records(total_publications_list)
df_pubmed
# Out:
#            NCTId                                       publications
# 0    NCT02014727  [{'pmid': '28947345', 'title': 'Safety and imm...
# 1    NCT00117494  [{'pmid': '22739396', 'title': 'Effects of ros...
# 2    NCT00536627  [{'pmid': '24394187', 'title': 'Immunological ...
# 3    NCT01033760  [{'pmid': '25701561', 'title': 'Intensive five...
# 4    NCT05349162  [{'pmid': '36735263', 'title': 'Epicardial vs....
# ..           ...                                                ...
# 284  NCT01880151                                                 []
# 285  NCT02658253  [{'pmid': '33717176', 'title': 'Progress and I...
# 286  NCT02027051                                                 []
# 287  NCT00118677  [{'pmid': '20657770', 'title': 'Relationship b...
# 288  NCT00647205                                                 []
#
# [289 rows x 2 columns]

# %% [markdown]
# #### On "explose" la colonne "publications":
#
# Pour chaque NCTId, la colonne 'publications' contient potentiellement une liste de plusieurs publications.
# Si par exemple, on a 3 publications, on veut se retrouver avec 3 lignes, chacune indexée par le même NCTId et contenant une unique publication.
#
# *Avant*:
# **`NCTId    Reference`**
# `NCT0001, [Pub1, Pub2, Pub3]`
#
# *Après*:
# **`NCTId    Reference`**
# `NCT0001,   Pub1`
# `NCT0001,   Pub2`
# `NCT0001,   Pub3`

# %%
df_pubmed = df_pubmed.explode('publications', ignore_index=True)
df_pubmed
# Out:
#            NCTId                                       publications
# 0    NCT02014727  {'pmid': '28947345', 'title': 'Safety and immu...
# 1    NCT00117494  {'pmid': '22739396', 'title': 'Effects of rosu...
# 2    NCT00117494  {'pmid': '22318219', 'title': 'Determinants of...
# 3    NCT00536627  {'pmid': '24394187', 'title': 'Immunological a...
# 4    NCT00536627  {'pmid': '15382173', 'title': 'Induction or ex...
# ..           ...                                                ...
# 701  NCT02658253  {'pmid': '33717176', 'title': 'Progress and In...
# 702  NCT02658253  {'pmid': '32032566', 'title': 'PRIMVAC vaccine...
# 703  NCT02027051                                                NaN
# 704  NCT00118677  {'pmid': '20657770', 'title': 'Relationship be...
# 705  NCT00647205                                                NaN
#
# [706 rows x 2 columns]

# %% [markdown]
# On vérifie que l'on a retrouvé plus de publications avec PubMed + CT que CT tout seul:

# %%
assert len(df_pubmed) >= len(df_ct)

# %% [markdown]
# Pour chaque NCTId, la colonne 'publications' contient maintenant un dictionnaire de la forme:
# `{
# "pmid": "17545707",
# "title": "Haematological ...",
# "authors": "Smith DJ; ...",
# }`
#
# Dont on veut extraire de nouvelles colonnes en utilant les clés du dictionnaire:
# **`pmid      title                 authors`**
# `17545707, "Haematological ...", "Smith DJ; ..."`

# %%
df_pubmed_publications = pd.json_normalize(df_pubmed.pop('publications'))
df_pubmed_publications
# Out:
#          pmid                                              title  \
# 0    28947345  Safety and immunogenicity of a recombinant Pla...
# 1    22739396  Effects of rosuvastatin versus pravastatin on ...
# 2    22318219  Determinants of low-density lipoprotein partic...
# 3    24394187  Immunological and antiviral responses after th...
# 4    15382173  Induction or expansion of T-cell responses by ...
# ..        ...                                                ...
# 701  33717176  Progress and Insights Toward an Effective Plac...
# 702  32032566  PRIMVAC vaccine adjuvanted with Alhydrogel or ...
# 703       NaN                                                NaN
# 704  20657770  Relationship between regulatory T cells and im...
# 705       NaN                                                NaN
#
#                                                authors  \
# 0    Sirima SB; Durier C; Kara L; Houard S; Gansane...
# 1    Bittar R; Giral P; Aslangul E; Assoumou L; Val...
# 2    Bittar R; Giral P; Aslangul E; Assoumou L; Val...
# 3    Godon O; Fontaine H; Kahi S; Meritet JF; Scott...
# 4    Mancini-Bourgine M; Fontaine H; Scott-Algara D...
# ..                                                 ...
# 701  Gamain B; Chêne A; Viebig NK; Tuikue Ndam N; N...
# 702  Sirima SB; Richert L; Chêne A; Konate AT; Camp...
# 703                                                NaN
# 704  Weiss L; Piketty C; Assoumou L; Didier C; Cacc...
# 705                                                NaN
#
#                                doi  year  \
# 0    10.1016/j.vaccine.2017.09.027  2017
# 1     10.1097/QAD.0b013e328357063c  2012
# 2                  10.3851/IMP2065  2012
# 3              10.1038/mt.2013.274  2014
# 4                10.1002/hep.20408  2004
# ..                             ...   ...
# 701      10.3389/fimmu.2021.634508  2021
# 702  10.1016/S1473-3099(19)30739-X  2020
# 703                            NaN   NaN
# 704   10.1371/journal.pone.0011659  2010
# 705                            NaN   NaN
#
#                                      publication_types  \
# 0    [Clinical Trial, Phase I, Journal Article, Ran...
# 1    [Comparative Study, Journal Article, Multicent...
# 2    [Journal Article, Research Support, Non-U.S. G...
# 3    [Clinical Trial, Phase I, Clinical Trial, Phas...
# 4    [Clinical Trial, Clinical Trial, Phase I, Jour...
# ..                                                 ...
# 701  [Journal Article, Research Support, Non-U.S. G...
# 702  [Clinical Trial, Phase I, Journal Article, Ran...
# 703                                                NaN
# 704  [Clinical Trial, Journal Article, Multicenter ...
# 705                                                NaN
#
#                                               citation
# 0    Sirima SB, et al. Safety and immunogenicity of...
# 1    Bittar R, et al. Effects of rosuvastatin versu...
# 2    Bittar R, et al. Determinants of low-density l...
# 3    Godon O, et al. Immunological and antiviral re...
# 4    Mancini-Bourgine M, et al. Induction or expans...
# ..                                                 ...
# 701  Gamain B, et al. Progress and Insights Toward ...
# 702  Sirima SB, et al. PRIMVAC vaccine adjuvanted w...
# 703                                                NaN
# 704  Weiss L, et al. Relationship between regulator...
# 705                                                NaN
#
# [706 rows x 7 columns]

# %% [markdown]
# On réassemble la dataFrame complète:

# %%
df_pubmed = df_pubmed.join(df_pubmed_publications)
df_pubmed
# Out:
#            NCTId      pmid                                              title  \
# 0    NCT02014727  28947345  Safety and immunogenicity of a recombinant Pla...
# 1    NCT00117494  22739396  Effects of rosuvastatin versus pravastatin on ...
# 2    NCT00117494  22318219  Determinants of low-density lipoprotein partic...
# 3    NCT00536627  24394187  Immunological and antiviral responses after th...
# 4    NCT00536627  15382173  Induction or expansion of T-cell responses by ...
# ..           ...       ...                                                ...
# 701  NCT02658253  33717176  Progress and Insights Toward an Effective Plac...
# 702  NCT02658253  32032566  PRIMVAC vaccine adjuvanted with Alhydrogel or ...
# 703  NCT02027051       NaN                                                NaN
# 704  NCT00118677  20657770  Relationship between regulatory T cells and im...
# 705  NCT00647205       NaN                                                NaN
#
#                                                authors  \
# 0    Sirima SB; Durier C; Kara L; Houard S; Gansane...
# 1    Bittar R; Giral P; Aslangul E; Assoumou L; Val...
# 2    Bittar R; Giral P; Aslangul E; Assoumou L; Val...
# 3    Godon O; Fontaine H; Kahi S; Meritet JF; Scott...
# 4    Mancini-Bourgine M; Fontaine H; Scott-Algara D...
# ..                                                 ...
# 701  Gamain B; Chêne A; Viebig NK; Tuikue Ndam N; N...
# 702  Sirima SB; Richert L; Chêne A; Konate AT; Camp...
# 703                                                NaN
# 704  Weiss L; Piketty C; Assoumou L; Didier C; Cacc...
# 705                                                NaN
#
#                                doi  year  \
# 0    10.1016/j.vaccine.2017.09.027  2017
# 1     10.1097/QAD.0b013e328357063c  2012
# 2                  10.3851/IMP2065  2012
# 3              10.1038/mt.2013.274  2014
# 4                10.1002/hep.20408  2004
# ..                             ...   ...
# 701      10.3389/fimmu.2021.634508  2021
# 702  10.1016/S1473-3099(19)30739-X  2020
# 703                            NaN   NaN
# 704   10.1371/journal.pone.0011659  2010
# 705                            NaN   NaN
#
#                                      publication_types  \
# 0    [Clinical Trial, Phase I, Journal Article, Ran...
# 1    [Comparative Study, Journal Article, Multicent...
# 2    [Journal Article, Research Support, Non-U.S. G...
# 3    [Clinical Trial, Phase I, Clinical Trial, Phas...
# 4    [Clinical Trial, Clinical Trial, Phase I, Jour...
# ..                                                 ...
# 701  [Journal Article, Research Support, Non-U.S. G...
# 702  [Clinical Trial, Phase I, Journal Article, Ran...
# 703                                                NaN
# 704  [Clinical Trial, Journal Article, Multicenter ...
# 705                                                NaN
#
#                                               citation
# 0    Sirima SB, et al. Safety and immunogenicity of...
# 1    Bittar R, et al. Effects of rosuvastatin versu...
# 2    Bittar R, et al. Determinants of low-density l...
# 3    Godon O, et al. Immunological and antiviral re...
# 4    Mancini-Bourgine M, et al. Induction or expans...
# ..                                                 ...
# 701  Gamain B, et al. Progress and Insights Toward ...
# 702  Sirima SB, et al. PRIMVAC vaccine adjuvanted w...
# 703                                                NaN
# 704  Weiss L, et al. Relationship between regulator...
# 705                                                NaN
#
# [706 rows x 8 columns]

# %% [markdown]
# ### Jointure des DataFrame de CT et Pubmed:

# %%
df_final = df_ct.merge(df_pubmed, on=['NCTId', 'pmid'], how='right')
df_final
# Out:
#            NCTId                                         BriefTitle  \
# 0    NCT02014727  Safety and Immunogenicity of Recombinant Pichi...
# 1    NCT00117494  Rosuvastatin Versus Pravastatin in HIV Patient...
# 2    NCT00117494  Rosuvastatin Versus Pravastatin in HIV Patient...
# 3    NCT00536627  Efficacy and Tolerance of Naked DNA Vaccine in...
# 4    NCT00536627  Efficacy and Tolerance of Naked DNA Vaccine in...
# ..           ...                                                ...
# 701  NCT02658253  Trial to Evaluate the Safety and Immunogenicit...
# 702  NCT02658253  Trial to Evaluate the Safety and Immunogenicit...
# 703  NCT02027051                      Etude génétique Des Arméniens
# 704  NCT00118677  Long-Term Supervised Treatment Interruption in...
# 705  NCT00647205  Evaluation of 2 Interferon γ Assays in the Dia...
#
#                                        LeadSponsorName  \
# 0    Institut National de la Santé Et de la Recherc...
# 1    French National Agency for Research on AIDS an...
# 2    French National Agency for Research on AIDS an...
# 3    French National Agency for Research on AIDS an...
# 4    French National Agency for Research on AIDS an...
# ..                                                 ...
# 701  Institut National de la Santé Et de la Recherc...
# 702  Institut National de la Santé Et de la Recherc...
# 703  Institut National de la Santé Et de la Recherc...
# 704  French National Agency for Research on AIDS an...
# 705  French National Agency for Research on AIDS an...
#
#                                       CollaboratorName OverallStatus  \
# 0    EVI Industries, Inc. | BPRC | Recherche Cliniq...     COMPLETED
# 1                                                 <NA>     COMPLETED
# 2                                                 <NA>     COMPLETED
# 3                                                 <NA>     COMPLETED
# 4                                                 <NA>     COMPLETED
# ..                                                 ...           ...
# 701  EVI Industries, Inc. | Recherche Clinique Pari...     COMPLETED
# 702  EVI Industries, Inc. | Recherche Clinique Pari...     COMPLETED
# 703                                               <NA>     COMPLETED
# 704                                               <NA>     COMPLETED
# 705                                               <NA>     COMPLETED
#
#           StudyType  HasResults StudyFirstPostDate StartDate CompletionDate  \
# 0    INTERVENTIONAL       False         2013-12-18   2014-01        2015-07
# 1    INTERVENTIONAL       False         2005-07-07   2005-10        2007-06
# 2    INTERVENTIONAL       False         2005-07-07   2005-10        2007-06
# 3    INTERVENTIONAL       False         2007-09-28   2008-01        2010-11
# 4    INTERVENTIONAL       False         2007-09-28   2008-01        2010-11
# ..              ...         ...                ...       ...            ...
# 701  INTERVENTIONAL       False         2016-01-18   2016-01     2019-02-21
# 702  INTERVENTIONAL       False         2016-01-18   2016-01     2019-02-21
# 703   OBSERVATIONAL       False         2014-01-03   2014-01        2017-01
# 704  INTERVENTIONAL       False         2005-07-12   2003-02        2007-05
# 705  INTERVENTIONAL       False         2008-03-31   2008-01        2010-11
#
#          pmid        type                                         citation_x  \
# 0    28947345     DERIVED  Sirima SB, Durier C, Kara L, Houard S, Gansane...
# 1    22739396     DERIVED  Bittar R, Giral P, Aslangul E, Assoumou L, Val...
# 2    22318219     DERIVED  Bittar R, Giral P, Aslangul E, Assoumou L, Val...
# 3    24394187     DERIVED  Godon O, Fontaine H, Kahi S, Meritet JF, Scott...
# 4    15382173  BACKGROUND  Mancini-Bourgine M, Fontaine H, Scott-Algara D...
# ..        ...         ...                                                ...
# 701  33717176     DERIVED  Gamain B, Chene A, Viebig NK, Tuikue Ndam N, N...
# 702  32032566     DERIVED  Sirima SB, Richert L, Chene A, Konate AT, Camp...
# 703      <NA>        <NA>                                               <NA>
# 704  20657770     DERIVED  Weiss L, Piketty C, Assoumou L, Didier C, Cacc...
# 705      <NA>        <NA>                                               <NA>
#
#                                                  title  \
# 0    Safety and immunogenicity of a recombinant Pla...
# 1    Effects of rosuvastatin versus pravastatin on ...
# 2    Determinants of low-density lipoprotein partic...
# 3    Immunological and antiviral responses after th...
# 4    Induction or expansion of T-cell responses by ...
# ..                                                 ...
# 701  Progress and Insights Toward an Effective Plac...
# 702  PRIMVAC vaccine adjuvanted with Alhydrogel or ...
# 703                                                NaN
# 704  Relationship between regulatory T cells and im...
# 705                                                NaN
#
#                                                authors  \
# 0    Sirima SB; Durier C; Kara L; Houard S; Gansane...
# 1    Bittar R; Giral P; Aslangul E; Assoumou L; Val...
# 2    Bittar R; Giral P; Aslangul E; Assoumou L; Val...
# 3    Godon O; Fontaine H; Kahi S; Meritet JF; Scott...
# 4    Mancini-Bourgine M; Fontaine H; Scott-Algara D...
# ..                                                 ...
# 701  Gamain B; Chêne A; Viebig NK; Tuikue Ndam N; N...
# 702  Sirima SB; Richert L; Chêne A; Konate AT; Camp...
# 703                                                NaN
# 704  Weiss L; Piketty C; Assoumou L; Didier C; Cacc...
# 705                                                NaN
#
#                                doi  year  \
# 0    10.1016/j.vaccine.2017.09.027  2017
# 1     10.1097/QAD.0b013e328357063c  2012
# 2                  10.3851/IMP2065  2012
# 3              10.1038/mt.2013.274  2014
# 4                10.1002/hep.20408  2004
# ..                             ...   ...
# 701      10.3389/fimmu.2021.634508  2021
# 702  10.1016/S1473-3099(19)30739-X  2020
# 703                            NaN   NaN
# 704   10.1371/journal.pone.0011659  2010
# 705                            NaN   NaN
#
#                                      publication_types  \
# 0    [Clinical Trial, Phase I, Journal Article, Ran...
# 1    [Comparative Study, Journal Article, Multicent...
# 2    [Journal Article, Research Support, Non-U.S. G...
# 3    [Clinical Trial, Phase I, Clinical Trial, Phas...
# 4    [Clinical Trial, Clinical Trial, Phase I, Jour...
# ..                                                 ...
# 701  [Journal Article, Research Support, Non-U.S. G...
# 702  [Clinical Trial, Phase I, Journal Article, Ran...
# 703                                                NaN
# 704  [Clinical Trial, Journal Article, Multicenter ...
# 705                                                NaN
#
#                                             citation_y
# 0    Sirima SB, et al. Safety and immunogenicity of...
# 1    Bittar R, et al. Effects of rosuvastatin versu...
# 2    Bittar R, et al. Determinants of low-density l...
# 3    Godon O, et al. Immunological and antiviral re...
# 4    Mancini-Bourgine M, et al. Induction or expans...
# ..                                                 ...
# 701  Gamain B, et al. Progress and Insights Toward ...
# 702  Sirima SB, et al. PRIMVAC vaccine adjuvanted w...
# 703                                                NaN
# 704  Weiss L, et al. Relationship between regulator...
# 705                                                NaN
#
# [706 rows x 19 columns]

# %% [markdown]
# Suppression des colonnes 'citation':

# %%
df_final.drop(['citation_x', 'citation_y'], axis=1, inplace=True)

# %%
df_final
# Out:
#            NCTId                                         BriefTitle  \
# 0    NCT02014727  Safety and Immunogenicity of Recombinant Pichi...
# 1    NCT00117494  Rosuvastatin Versus Pravastatin in HIV Patient...
# 2    NCT00117494  Rosuvastatin Versus Pravastatin in HIV Patient...
# 3    NCT00536627  Efficacy and Tolerance of Naked DNA Vaccine in...
# 4    NCT00536627  Efficacy and Tolerance of Naked DNA Vaccine in...
# ..           ...                                                ...
# 701  NCT02658253  Trial to Evaluate the Safety and Immunogenicit...
# 702  NCT02658253  Trial to Evaluate the Safety and Immunogenicit...
# 703  NCT02027051                      Etude génétique Des Arméniens
# 704  NCT00118677  Long-Term Supervised Treatment Interruption in...
# 705  NCT00647205  Evaluation of 2 Interferon γ Assays in the Dia...
#
#                                        LeadSponsorName  \
# 0    Institut National de la Santé Et de la Recherc...
# 1    French National Agency for Research on AIDS an...
# 2    French National Agency for Research on AIDS an...
# 3    French National Agency for Research on AIDS an...
# 4    French National Agency for Research on AIDS an...
# ..                                                 ...
# 701  Institut National de la Santé Et de la Recherc...
# 702  Institut National de la Santé Et de la Recherc...
# 703  Institut National de la Santé Et de la Recherc...
# 704  French National Agency for Research on AIDS an...
# 705  French National Agency for Research on AIDS an...
#
#                                       CollaboratorName OverallStatus  \
# 0    EVI Industries, Inc. | BPRC | Recherche Cliniq...     COMPLETED
# 1                                                 <NA>     COMPLETED
# 2                                                 <NA>     COMPLETED
# 3                                                 <NA>     COMPLETED
# 4                                                 <NA>     COMPLETED
# ..                                                 ...           ...
# 701  EVI Industries, Inc. | Recherche Clinique Pari...     COMPLETED
# 702  EVI Industries, Inc. | Recherche Clinique Pari...     COMPLETED
# 703                                               <NA>     COMPLETED
# 704                                               <NA>     COMPLETED
# 705                                               <NA>     COMPLETED
#
#           StudyType  HasResults StudyFirstPostDate StartDate CompletionDate  \
# 0    INTERVENTIONAL       False         2013-12-18   2014-01        2015-07
# 1    INTERVENTIONAL       False         2005-07-07   2005-10        2007-06
# 2    INTERVENTIONAL       False         2005-07-07   2005-10        2007-06
# 3    INTERVENTIONAL       False         2007-09-28   2008-01        2010-11
# 4    INTERVENTIONAL       False         2007-09-28   2008-01        2010-11
# ..              ...         ...                ...       ...            ...
# 701  INTERVENTIONAL       False         2016-01-18   2016-01     2019-02-21
# 702  INTERVENTIONAL       False         2016-01-18   2016-01     2019-02-21
# 703   OBSERVATIONAL       False         2014-01-03   2014-01        2017-01
# 704  INTERVENTIONAL       False         2005-07-12   2003-02        2007-05
# 705  INTERVENTIONAL       False         2008-03-31   2008-01        2010-11
#
#          pmid        type                                              title  \
# 0    28947345     DERIVED  Safety and immunogenicity of a recombinant Pla...
# 1    22739396     DERIVED  Effects of rosuvastatin versus pravastatin on ...
# 2    22318219     DERIVED  Determinants of low-density lipoprotein partic...
# 3    24394187     DERIVED  Immunological and antiviral responses after th...
# 4    15382173  BACKGROUND  Induction or expansion of T-cell responses by ...
# ..        ...         ...                                                ...
# 701  33717176     DERIVED  Progress and Insights Toward an Effective Plac...
# 702  32032566     DERIVED  PRIMVAC vaccine adjuvanted with Alhydrogel or ...
# 703      <NA>        <NA>                                                NaN
# 704  20657770     DERIVED  Relationship between regulatory T cells and im...
# 705      <NA>        <NA>                                                NaN
#
#                                                authors  \
# 0    Sirima SB; Durier C; Kara L; Houard S; Gansane...
# 1    Bittar R; Giral P; Aslangul E; Assoumou L; Val...
# 2    Bittar R; Giral P; Aslangul E; Assoumou L; Val...
# 3    Godon O; Fontaine H; Kahi S; Meritet JF; Scott...
# 4    Mancini-Bourgine M; Fontaine H; Scott-Algara D...
# ..                                                 ...
# 701  Gamain B; Chêne A; Viebig NK; Tuikue Ndam N; N...
# 702  Sirima SB; Richert L; Chêne A; Konate AT; Camp...
# 703                                                NaN
# 704  Weiss L; Piketty C; Assoumou L; Didier C; Cacc...
# 705                                                NaN
#
#                                doi  year  \
# 0    10.1016/j.vaccine.2017.09.027  2017
# 1     10.1097/QAD.0b013e328357063c  2012
# 2                  10.3851/IMP2065  2012
# 3              10.1038/mt.2013.274  2014
# 4                10.1002/hep.20408  2004
# ..                             ...   ...
# 701      10.3389/fimmu.2021.634508  2021
# 702  10.1016/S1473-3099(19)30739-X  2020
# 703                            NaN   NaN
# 704   10.1371/journal.pone.0011659  2010
# 705                            NaN   NaN
#
#                                      publication_types
# 0    [Clinical Trial, Phase I, Journal Article, Ran...
# 1    [Comparative Study, Journal Article, Multicent...
# 2    [Journal Article, Research Support, Non-U.S. G...
# 3    [Clinical Trial, Phase I, Clinical Trial, Phas...
# 4    [Clinical Trial, Clinical Trial, Phase I, Jour...
# ..                                                 ...
# 701  [Journal Article, Research Support, Non-U.S. G...
# 702  [Clinical Trial, Phase I, Journal Article, Ran...
# 703                                                NaN
# 704  [Clinical Trial, Journal Article, Multicenter ...
# 705                                                NaN
#
# [706 rows x 17 columns]

# %% [markdown]
# Les nouveaux PMIDs trouvés via Pubmed, n'ont aucune des infos associées avec CT présentes: BriefTitle, LeadSponsorName, etc ...

# %%
# Index of empty rows we need to fill
index_empty_rows = df_final.loc[:, 'BriefTitle'].isna()

df_final[index_empty_rows]
# Out:
#            NCTId BriefTitle LeadSponsorName CollaboratorName OverallStatus  \
# 9    NCT05349162       <NA>            <NA>             <NA>          <NA>
# 11   NCT02777229       <NA>            <NA>             <NA>          <NA>
# 14   NCT02777229       <NA>            <NA>             <NA>          <NA>
# 24   NCT01453192       <NA>            <NA>             <NA>          <NA>
# 60   NCT04315948       <NA>            <NA>             <NA>          <NA>
# 74   NCT05311865       <NA>            <NA>             <NA>          <NA>
# 75   NCT05311865       <NA>            <NA>             <NA>          <NA>
# 103  NCT00640263       <NA>            <NA>             <NA>          <NA>
# 129  NCT01801618       <NA>            <NA>             <NA>          <NA>
# 130  NCT02405013       <NA>            <NA>             <NA>          <NA>
# 179  NCT01703962       <NA>            <NA>             <NA>          <NA>
# 241  NCT01473472       <NA>            <NA>             <NA>          <NA>
# 293  NCT02212379       <NA>            <NA>             <NA>          <NA>
# 297  NCT03335995       <NA>            <NA>             <NA>          <NA>
# 325  NCT01426243       <NA>            <NA>             <NA>          <NA>
# 329  NCT03870438       <NA>            <NA>             <NA>          <NA>
# 345  NCT03078439       <NA>            <NA>             <NA>          <NA>
# 410  NCT02057796       <NA>            <NA>             <NA>          <NA>
# 449  NCT04392388       <NA>            <NA>             <NA>          <NA>
# 456  NCT01089387       <NA>            <NA>             <NA>          <NA>
# 457  NCT02833961       <NA>            <NA>             <NA>          <NA>
# 475  NCT02481453       <NA>            <NA>             <NA>          <NA>
# 520  NCT04409405       <NA>            <NA>             <NA>          <NA>
# 606  NCT04288128       <NA>            <NA>             <NA>          <NA>
# 607  NCT04288128       <NA>            <NA>             <NA>          <NA>
# 664  NCT03215732       <NA>            <NA>             <NA>          <NA>
# 667  NCT03005652       <NA>            <NA>             <NA>          <NA>
# 697  NCT01688453       <NA>            <NA>             <NA>          <NA>
#
#     StudyType  HasResults StudyFirstPostDate StartDate CompletionDate  \
# 9        <NA>        <NA>               <NA>      <NA>           <NA>
# 11       <NA>        <NA>               <NA>      <NA>           <NA>
# 14       <NA>        <NA>               <NA>      <NA>           <NA>
# 24       <NA>        <NA>               <NA>      <NA>           <NA>
# 60       <NA>        <NA>               <NA>      <NA>           <NA>
# 74       <NA>        <NA>               <NA>      <NA>           <NA>
# 75       <NA>        <NA>               <NA>      <NA>           <NA>
# 103      <NA>        <NA>               <NA>      <NA>           <NA>
# 129      <NA>        <NA>               <NA>      <NA>           <NA>
# 130      <NA>        <NA>               <NA>      <NA>           <NA>
# 179      <NA>        <NA>               <NA>      <NA>           <NA>
# 241      <NA>        <NA>               <NA>      <NA>           <NA>
# 293      <NA>        <NA>               <NA>      <NA>           <NA>
# 297      <NA>        <NA>               <NA>      <NA>           <NA>
# 325      <NA>        <NA>               <NA>      <NA>           <NA>
# 329      <NA>        <NA>               <NA>      <NA>           <NA>
# 345      <NA>        <NA>               <NA>      <NA>           <NA>
# 410      <NA>        <NA>               <NA>      <NA>           <NA>
# 449      <NA>        <NA>               <NA>      <NA>           <NA>
# 456      <NA>        <NA>               <NA>      <NA>           <NA>
# 457      <NA>        <NA>               <NA>      <NA>           <NA>
# 475      <NA>        <NA>               <NA>      <NA>           <NA>
# 520      <NA>        <NA>               <NA>      <NA>           <NA>
# 606      <NA>        <NA>               <NA>      <NA>           <NA>
# 607      <NA>        <NA>               <NA>      <NA>           <NA>
# 664      <NA>        <NA>               <NA>      <NA>           <NA>
# 667      <NA>        <NA>               <NA>      <NA>           <NA>
# 697      <NA>        <NA>               <NA>      <NA>           <NA>
#
#          pmid  type                                              title  \
# 9    36735263  <NA>  Epicardial vs. transvenous implantable cardiov...
# 11   37851566  <NA>  Improvements in Patient-Reported Outcomes Foll...
# 14   38156046  <NA>  Durability of the Efficacy and Safety of Dolut...
# 24   30688008  <NA>  Low incidence of acute rejection within 6 mont...
# 60   36695483  <NA>          Remdesivir for the treatment of COVID-19.
# 74   37795682  <NA>  A randomised controlled trial to study the tra...
# 75   36438274  <NA>  Transmission of SARS-CoV-2 during indoor clubb...
# 103  34425825  <NA>  The prevalence and socio-behavioural and clini...
# 129  29662875  <NA>  Positive Virological Outcomes of HIV-Infected ...
# 130  36686592  <NA>  Patient-reported outcomes with direct-acting a...
# 179  37668523  <NA>  Neurochemical Differences between 1p/19q Codel...
# 241  36601747  <NA>  Hepatitis A and B vaccine uptake and immunisat...
# 293  31269208  <NA>  Dual therapy combining raltegravir with etravi...
# 297  37497675  <NA>  One-Year Outcomes in Patients With Acute Strok...
# 325  26314624  <NA>  Molecular characterization of the 17D-204 yell...
# 329  38484756  <NA>  Optimised prevention of postnatal HIV transmis...
# 345  38408861  <NA>  Birth weight and head circumference discordanc...
# 410  36883573  <NA>  High performance of systematic combined urine ...
# 449  34293141  <NA>  Antibody status and cumulative incidence of SA...
# 456  26439886  <NA>  Safety of Intracavernous Bone Marrow-Mononucle...
# 457  36318030  <NA>  Longitudinal Monitoring of Microstructural Alt...
# 475  38273639  <NA>  Sirolimus for treatment of patients with inclu...
# 520  38043556  <NA>  Effect of anti-Ebola virus monoclonal antibodi...
# 606  38419144  <NA>  Digital Gait Measures Capture 1-Year Progressi...
# 607  38421662  <NA>  ATXN7-Related Cone-Rod Dystrophy: The Integrat...
# 664  37143029  <NA>  Hepatitis B prevention and treatment needs in ...
# 667  38100477  <NA>  Effects of a mindfulness-based intervention an...
# 697  35272723  <NA>  Behavioural risk patterns in adolescents with ...
#
#                                                authors  \
# 9    Le Bos PA; Pontailler M; Maltret A; Kraiche D;...
# 11   Bousmah MA; Protopopescu C; Mpoudi-Etame M; Om...
# 14   Mpoudi-Etame M; Tovar Sanchez T; Bousmah MA; O...
# 24   Matignon M; Lelièvre JD; Lahiani A; Abbassi K;...
# 60   Grundeis F; Ansems K; Dahms K; Thieme V; Metze...
# 74   Luong Nguyen LB; Goupil de Bouillé J; Menant L...
# 75   Goupil de Bouillé J; Luong Nguyen LB; Crépey P...
# 103  Birungi N; Fadnes LT; Engebretsen IMS; Tumwine...
# 129  Ségéral O; Nerrienet E; Neth S; Spire B; Khol ...
# 130  Marcellin F; Mourad A; Lemoine M; Kouanfack C;...
# 179  Branzoli F; Liserre R; Deelchand DK; Poliani P...
# 241  Le Turnier P; Charreau I; Gabassi A; Carette D...
# 293  Katlama C; Assoumou L; Valantin MA; Soulié C; ...
# 297  Sonneville R; Mazighi M; Collet M; Gayat E; De...
# 325  Salmona M; Gazaignes S; Mercier-Delarue S; Gar...
# 329  Kankasa C; Mennecier A; Sakana BLD; Molès JP; ...
# 345  Guellec I; Brunet A; Lapillonne A; Taine M; To...
# 410  Bonnet M; Gabillard D; Domoua S; Muzoora C; Me...
# 449  Carrat F; de Lamballerie X; Rahib D; Blanché H...
# 456  Yiou R; Hamidou L; Birebent B; Bitari D; Lecor...
# 457  Genovese G; Diaz-Fernandez B; Lejeune FX; Rone...
# 475  Benveniste O; Hogrel JY; Belin L; Annoussamy M...
# 520  Nkuba-Ndaye A; Dilu-Keti A; Tovar-Sanchez T; D...
# 606  Seemann J; Daghsen L; Cazier M; Lamy JC; Welte...
# 607  Nassisi M; Coarelli G; Blanchard B; Dubec-Fleu...
# 664  Djaogol T; Périères L; Marcellin F; Diouf A; C...
# 667  Schlosser M; Demnitz-King H; Barnhofer T; Coll...
# 697  Julia C; Omorou A; Lecomte E; Langlois J; Touv...
#
#                                   doi  year  \
# 9            10.1093/europace/euad015  2023
# 11       10.1097/QAI.0000000000003273  2023
# 14               10.1093/ofid/ofad582  2023
# 24                  10.1111/hiv.12700  2019
# 60     10.1002/14651858.CD014962.pub2  2023
# 74                10.1093/cid/ciad603  2023
# 75          10.3389/fpubh.2022.981213  2022
# 103        10.1186/s12955-021-01844-3  2021
# 129          10.3389/fpubh.2018.00063  2018
# 130       10.1016/j.jhepr.2022.100665  2023
# 179             10.1148/radiol.223255  2023
# 241      10.1136/sextrans-2022-055634  2023
# 293                10.1093/jac/dkz224  2019
# 297      10.1161/STROKEAHA.123.042910  2023
# 325     10.1016/j.vaccine.2015.08.055  2015
# 329     10.1016/S0140-6736(23)02464-9  2024
# 345  10.1136/archdischild-2023-326336  2024
# 410               10.1093/cid/ciad125  2023
# 449               10.1093/ije/dyab110  2021
# 456      10.1016/j.eururo.2015.09.026  2016
# 457             10.1148/radiol.220430  2023
# 475     10.1016/S2665-9913(20)30280-0  2021
# 520     10.1016/S1473-3099(23)00552-2  2024
# 606                 10.1002/mds.29757  2024
# 607  10.1001/jamaophthalmol.2024.0001  2024
# 664        10.1186/s12889-023-15710-y  2023
# 667      10.1371/journal.pone.0295175  2023
# 697         10.1017/S136898002200057X  2023
#
#                                      publication_types
# 9                    [Clinical Trial, Journal Article]
# 11   [Randomized Controlled Trial, Journal Article,...
# 14                                   [Journal Article]
# 24   [Journal Article, Multicenter Study, Research ...
# 60   [Journal Article, Review, Research Support, No...
# 74                                   [Journal Article]
# 75   [Clinical Trial Protocol, Journal Article, Res...
# 103                                  [Journal Article]
# 129                                  [Journal Article]
# 130                                  [Journal Article]
# 179  [Journal Article, Observational Study, Researc...
# 241  [Clinical Trial, Research Support, Non-U.S. Go...
# 293  [Journal Article, Multicenter Study, Research ...
# 297  [Multicenter Study, Journal Article, Research ...
# 325  [Journal Article, Research Support, Non-U.S. G...
# 329                                  [Journal Article]
# 345                                  [Journal Article]
# 410                                  [Journal Article]
# 449                                  [Journal Article]
# 456  [Journal Article, Research Support, Non-U.S. G...
# 457  [Journal Article, Research Support, Non-U.S. G...
# 475                                  [Journal Article]
# 520             [Observational Study, Journal Article]
# 606                                  [Journal Article]
# 607                                  [Journal Article]
# 664  [Journal Article, Research Support, Non-U.S. G...
# 667     [Randomized Controlled Trial, Journal Article]
# 697  [Journal Article, Research Support, Non-U.S. G...

# %% [markdown]
# On rajoute un type 'PUBMED' pour les PMIDs issues de PubMed uniquement:

# %%
# We add a 'PUBMED' type to the PMIDs extracted from Pubmed exclusively
df_final.loc[index_empty_rows, 'type'] = 'PUBMED'

# %%
df_final[index_empty_rows]
# Out:
#            NCTId BriefTitle LeadSponsorName CollaboratorName OverallStatus  \
# 9    NCT05349162       <NA>            <NA>             <NA>          <NA>
# 11   NCT02777229       <NA>            <NA>             <NA>          <NA>
# 14   NCT02777229       <NA>            <NA>             <NA>          <NA>
# 24   NCT01453192       <NA>            <NA>             <NA>          <NA>
# 60   NCT04315948       <NA>            <NA>             <NA>          <NA>
# 74   NCT05311865       <NA>            <NA>             <NA>          <NA>
# 75   NCT05311865       <NA>            <NA>             <NA>          <NA>
# 103  NCT00640263       <NA>            <NA>             <NA>          <NA>
# 129  NCT01801618       <NA>            <NA>             <NA>          <NA>
# 130  NCT02405013       <NA>            <NA>             <NA>          <NA>
# 179  NCT01703962       <NA>            <NA>             <NA>          <NA>
# 241  NCT01473472       <NA>            <NA>             <NA>          <NA>
# 293  NCT02212379       <NA>            <NA>             <NA>          <NA>
# 297  NCT03335995       <NA>            <NA>             <NA>          <NA>
# 325  NCT01426243       <NA>            <NA>             <NA>          <NA>
# 329  NCT03870438       <NA>            <NA>             <NA>          <NA>
# 345  NCT03078439       <NA>            <NA>             <NA>          <NA>
# 410  NCT02057796       <NA>            <NA>             <NA>          <NA>
# 449  NCT04392388       <NA>            <NA>             <NA>          <NA>
# 456  NCT01089387       <NA>            <NA>             <NA>          <NA>
# 457  NCT02833961       <NA>            <NA>             <NA>          <NA>
# 475  NCT02481453       <NA>            <NA>             <NA>          <NA>
# 520  NCT04409405       <NA>            <NA>             <NA>          <NA>
# 606  NCT04288128       <NA>            <NA>             <NA>          <NA>
# 607  NCT04288128       <NA>            <NA>             <NA>          <NA>
# 664  NCT03215732       <NA>            <NA>             <NA>          <NA>
# 667  NCT03005652       <NA>            <NA>             <NA>          <NA>
# 697  NCT01688453       <NA>            <NA>             <NA>          <NA>
#
#     StudyType  HasResults StudyFirstPostDate StartDate CompletionDate  \
# 9        <NA>        <NA>               <NA>      <NA>           <NA>
# 11       <NA>        <NA>               <NA>      <NA>           <NA>
# 14       <NA>        <NA>               <NA>      <NA>           <NA>
# 24       <NA>        <NA>               <NA>      <NA>           <NA>
# 60       <NA>        <NA>               <NA>      <NA>           <NA>
# 74       <NA>        <NA>               <NA>      <NA>           <NA>
# 75       <NA>        <NA>               <NA>      <NA>           <NA>
# 103      <NA>        <NA>               <NA>      <NA>           <NA>
# 129      <NA>        <NA>               <NA>      <NA>           <NA>
# 130      <NA>        <NA>               <NA>      <NA>           <NA>
# 179      <NA>        <NA>               <NA>      <NA>           <NA>
# 241      <NA>        <NA>               <NA>      <NA>           <NA>
# 293      <NA>        <NA>               <NA>      <NA>           <NA>
# 297      <NA>        <NA>               <NA>      <NA>           <NA>
# 325      <NA>        <NA>               <NA>      <NA>           <NA>
# 329      <NA>        <NA>               <NA>      <NA>           <NA>
# 345      <NA>        <NA>               <NA>      <NA>           <NA>
# 410      <NA>        <NA>               <NA>      <NA>           <NA>
# 449      <NA>        <NA>               <NA>      <NA>           <NA>
# 456      <NA>        <NA>               <NA>      <NA>           <NA>
# 457      <NA>        <NA>               <NA>      <NA>           <NA>
# 475      <NA>        <NA>               <NA>      <NA>           <NA>
# 520      <NA>        <NA>               <NA>      <NA>           <NA>
# 606      <NA>        <NA>               <NA>      <NA>           <NA>
# 607      <NA>        <NA>               <NA>      <NA>           <NA>
# 664      <NA>        <NA>               <NA>      <NA>           <NA>
# 667      <NA>        <NA>               <NA>      <NA>           <NA>
# 697      <NA>        <NA>               <NA>      <NA>           <NA>
#
#          pmid    type                                              title  \
# 9    36735263  PUBMED  Epicardial vs. transvenous implantable cardiov...
# 11   37851566  PUBMED  Improvements in Patient-Reported Outcomes Foll...
# 14   38156046  PUBMED  Durability of the Efficacy and Safety of Dolut...
# 24   30688008  PUBMED  Low incidence of acute rejection within 6 mont...
# 60   36695483  PUBMED          Remdesivir for the treatment of COVID-19.
# 74   37795682  PUBMED  A randomised controlled trial to study the tra...
# 75   36438274  PUBMED  Transmission of SARS-CoV-2 during indoor clubb...
# 103  34425825  PUBMED  The prevalence and socio-behavioural and clini...
# 129  29662875  PUBMED  Positive Virological Outcomes of HIV-Infected ...
# 130  36686592  PUBMED  Patient-reported outcomes with direct-acting a...
# 179  37668523  PUBMED  Neurochemical Differences between 1p/19q Codel...
# 241  36601747  PUBMED  Hepatitis A and B vaccine uptake and immunisat...
# 293  31269208  PUBMED  Dual therapy combining raltegravir with etravi...
# 297  37497675  PUBMED  One-Year Outcomes in Patients With Acute Strok...
# 325  26314624  PUBMED  Molecular characterization of the 17D-204 yell...
# 329  38484756  PUBMED  Optimised prevention of postnatal HIV transmis...
# 345  38408861  PUBMED  Birth weight and head circumference discordanc...
# 410  36883573  PUBMED  High performance of systematic combined urine ...
# 449  34293141  PUBMED  Antibody status and cumulative incidence of SA...
# 456  26439886  PUBMED  Safety of Intracavernous Bone Marrow-Mononucle...
# 457  36318030  PUBMED  Longitudinal Monitoring of Microstructural Alt...
# 475  38273639  PUBMED  Sirolimus for treatment of patients with inclu...
# 520  38043556  PUBMED  Effect of anti-Ebola virus monoclonal antibodi...
# 606  38419144  PUBMED  Digital Gait Measures Capture 1-Year Progressi...
# 607  38421662  PUBMED  ATXN7-Related Cone-Rod Dystrophy: The Integrat...
# 664  37143029  PUBMED  Hepatitis B prevention and treatment needs in ...
# 667  38100477  PUBMED  Effects of a mindfulness-based intervention an...
# 697  35272723  PUBMED  Behavioural risk patterns in adolescents with ...
#
#                                                authors  \
# 9    Le Bos PA; Pontailler M; Maltret A; Kraiche D;...
# 11   Bousmah MA; Protopopescu C; Mpoudi-Etame M; Om...
# 14   Mpoudi-Etame M; Tovar Sanchez T; Bousmah MA; O...
# 24   Matignon M; Lelièvre JD; Lahiani A; Abbassi K;...
# 60   Grundeis F; Ansems K; Dahms K; Thieme V; Metze...
# 74   Luong Nguyen LB; Goupil de Bouillé J; Menant L...
# 75   Goupil de Bouillé J; Luong Nguyen LB; Crépey P...
# 103  Birungi N; Fadnes LT; Engebretsen IMS; Tumwine...
# 129  Ségéral O; Nerrienet E; Neth S; Spire B; Khol ...
# 130  Marcellin F; Mourad A; Lemoine M; Kouanfack C;...
# 179  Branzoli F; Liserre R; Deelchand DK; Poliani P...
# 241  Le Turnier P; Charreau I; Gabassi A; Carette D...
# 293  Katlama C; Assoumou L; Valantin MA; Soulié C; ...
# 297  Sonneville R; Mazighi M; Collet M; Gayat E; De...
# 325  Salmona M; Gazaignes S; Mercier-Delarue S; Gar...
# 329  Kankasa C; Mennecier A; Sakana BLD; Molès JP; ...
# 345  Guellec I; Brunet A; Lapillonne A; Taine M; To...
# 410  Bonnet M; Gabillard D; Domoua S; Muzoora C; Me...
# 449  Carrat F; de Lamballerie X; Rahib D; Blanché H...
# 456  Yiou R; Hamidou L; Birebent B; Bitari D; Lecor...
# 457  Genovese G; Diaz-Fernandez B; Lejeune FX; Rone...
# 475  Benveniste O; Hogrel JY; Belin L; Annoussamy M...
# 520  Nkuba-Ndaye A; Dilu-Keti A; Tovar-Sanchez T; D...
# 606  Seemann J; Daghsen L; Cazier M; Lamy JC; Welte...
# 607  Nassisi M; Coarelli G; Blanchard B; Dubec-Fleu...
# 664  Djaogol T; Périères L; Marcellin F; Diouf A; C...
# 667  Schlosser M; Demnitz-King H; Barnhofer T; Coll...
# 697  Julia C; Omorou A; Lecomte E; Langlois J; Touv...
#
#                                   doi  year  \
# 9            10.1093/europace/euad015  2023
# 11       10.1097/QAI.0000000000003273  2023
# 14               10.1093/ofid/ofad582  2023
# 24                  10.1111/hiv.12700  2019
# 60     10.1002/14651858.CD014962.pub2  2023
# 74                10.1093/cid/ciad603  2023
# 75          10.3389/fpubh.2022.981213  2022
# 103        10.1186/s12955-021-01844-3  2021
# 129          10.3389/fpubh.2018.00063  2018
# 130       10.1016/j.jhepr.2022.100665  2023
# 179             10.1148/radiol.223255  2023
# 241      10.1136/sextrans-2022-055634  2023
# 293                10.1093/jac/dkz224  2019
# 297      10.1161/STROKEAHA.123.042910  2023
# 325     10.1016/j.vaccine.2015.08.055  2015
# 329     10.1016/S0140-6736(23)02464-9  2024
# 345  10.1136/archdischild-2023-326336  2024
# 410               10.1093/cid/ciad125  2023
# 449               10.1093/ije/dyab110  2021
# 456      10.1016/j.eururo.2015.09.026  2016
# 457             10.1148/radiol.220430  2023
# 475     10.1016/S2665-9913(20)30280-0  2021
# 520     10.1016/S1473-3099(23)00552-2  2024
# 606                 10.1002/mds.29757  2024
# 607  10.1001/jamaophthalmol.2024.0001  2024
# 664        10.1186/s12889-023-15710-y  2023
# 667      10.1371/journal.pone.0295175  2023
# 697         10.1017/S136898002200057X  2023
#
#                                      publication_types
# 9                    [Clinical Trial, Journal Article]
# 11   [Randomized Controlled Trial, Journal Article,...
# 14                                   [Journal Article]
# 24   [Journal Article, Multicenter Study, Research ...
# 60   [Journal Article, Review, Research Support, No...
# 74                                   [Journal Article]
# 75   [Clinical Trial Protocol, Journal Article, Res...
# 103                                  [Journal Article]
# 129                                  [Journal Article]
# 130                                  [Journal Article]
# 179  [Journal Article, Observational Study, Researc...
# 241  [Clinical Trial, Research Support, Non-U.S. Go...
# 293  [Journal Article, Multicenter Study, Research ...
# 297  [Multicenter Study, Journal Article, Research ...
# 325  [Journal Article, Research Support, Non-U.S. G...
# 329                                  [Journal Article]
# 345                                  [Journal Article]
# 410                                  [Journal Article]
# 449                                  [Journal Article]
# 456  [Journal Article, Research Support, Non-U.S. G...
# 457  [Journal Article, Research Support, Non-U.S. G...
# 475                                  [Journal Article]
# 520             [Observational Study, Journal Article]
# 606                                  [Journal Article]
# 607                                  [Journal Article]
# 664  [Journal Article, Research Support, Non-U.S. G...
# 667     [Randomized Controlled Trial, Journal Article]
# 697  [Journal Article, Research Support, Non-U.S. G...

# %% [markdown]
# On va remplir ces colonnes avec les infos contenus dans la DataFrame CT:

# %%
# NCTIds of empty rows
NCTIds_empty_rows = df_final.loc[index_empty_rows, 'NCTId']
NCTIds_empty_rows

# Columns we wish to copy
columns_to_copy = [
    'BriefTitle',
    'LeadSponsorName',
    'CollaboratorName',
    'OverallStatus',
    'StudyType',
    'HasResults',
    'StudyFirstPostDate',
    'StartDate',
    'CompletionDate',
]

# We copy the missing values from the CT dataframe
for index, nctid in NCTIds_empty_rows.items():
    # For an NCTId, we look in the CT dataframe for the first row with this NCTDId
    # and copy the missings columns
    df_final.loc[index, columns_to_copy] = df_ct.loc[
        df_ct.loc[:, 'NCTId'] == nctid, columns_to_copy
    ].iloc[0]

# %%
df_final[index_empty_rows]
# Out:
#            NCTId                                         BriefTitle  \
# 9    NCT05349162        Epicardial vs. Transvenous ICDs in Children
# 11   NCT02777229  Efficacy and Safety of a Dolutegravir-based Re...
# 14   NCT02777229  Efficacy and Safety of a Dolutegravir-based Re...
# 24   NCT01453192  Renal Transplantation and Raltegravir in HIV-I...
# 60   NCT04315948  Trial of Treatments for COVID-19 in Hospitaliz...
# 74   NCT05311865  Transmission of Covid-19 During Clubbing Event...
# 75   NCT05311865  Transmission of Covid-19 During Clubbing Event...
# 103  NCT00640263  Comparison of Efficacy and Safety of Infant Pe...
# 129  NCT01801618  National Evaluation of PI-based 2nd Line Effic...
# 130  NCT02405013  Feasibility, Tolerance and Efficacy of Interfe...
# 179  NCT01703962  Non Invasive IDentification of Gliomas With ID...
# 241  NCT01473472  On Demand Antiretroviral Pre-exposure Prophyla...
# 293  NCT02212379  Capacity of the Dual Combination Raltegravir/E...
# 297  NCT03335995                 Stroke Prognosis in Intensive CarE
# 325  NCT01426243  The Yellow Fever Vaccine Immunity in HIV Infec...
# 329  NCT03870438  Prevention of Mother-to-child Transmission of ...
# 345  NCT03078439  EPIPAGE2 Cohort Study Follow up at Five and a ...
# 410  NCT02057796  Systematic Empirical vs. Test-guided Anti-TB T...
# 449  NCT04392388  Health, Perception, Practices, Relations and S...
# 456  NCT01089387  Intracavernous Bone Marrow Stem-cell Injection...
# 457  NCT02833961                   Diffusion Spectroscopy in Stroke
# 475  NCT02481453  Rapamycine vs Placebo for the Treatment of Inc...
# 520  NCT04409405  Evaluation and Support to EVD Cured Patients a...
# 606  NCT04288128  Integrated Functional Evaluation of the Cerebe...
# 607  NCT04288128  Integrated Functional Evaluation of the Cerebe...
# 664  NCT03215732  Cross Sectional Survey on the Burden and Impac...
# 667  NCT03005652  Effects Of An 8-Weeks Mindfulness-based Interv...
# 697  NCT01688453      Overweight Management and Social Inequalities
#
#                                        LeadSponsorName  \
# 9    Paris Cardiovascular Research Center (Inserm U...
# 11                  ANRS, Emerging Infectious Diseases
# 14                  ANRS, Emerging Infectious Diseases
# 24                  ANRS, Emerging Infectious Diseases
# 60   Institut National de la Santé Et de la Recherc...
# 74                  ANRS, Emerging Infectious Diseases
# 75                  ANRS, Emerging Infectious Diseases
# 103  French National Agency for Research on AIDS an...
# 129                 ANRS, Emerging Infectious Diseases
# 130                 ANRS, Emerging Infectious Diseases
# 179  Institut National de la Santé Et de la Recherc...
# 241                 ANRS, Emerging Infectious Diseases
# 293                 ANRS, Emerging Infectious Diseases
# 297  Institut National de la Santé Et de la Recherc...
# 325  French National Agency for Research on AIDS an...
# 329                 ANRS, Emerging Infectious Diseases
# 345  Institut National de la Santé Et de la Recherc...
# 410                 ANRS, Emerging Infectious Diseases
# 449  Institut National de la Santé Et de la Recherc...
# 456  Institut National de la Santé Et de la Recherc...
# 457  Institut National de la Santé Et de la Recherc...
# 475  Institut National de la Santé Et de la Recherc...
# 520  Institut National de la Santé Et de la Recherc...
# 606  Institut National de la Santé Et de la Recherc...
# 607  Institut National de la Santé Et de la Recherc...
# 664                 ANRS, Emerging Infectious Diseases
# 667  Institut National de la Santé Et de la Recherc...
# 697  Institut National de la Santé Et de la Recherc...
#
#                                       CollaboratorName OverallStatus  \
# 9                       Hôpital Necker-Enfants Malades     COMPLETED
# 11   Institut de Recherche pour le Developpement | ...     COMPLETED
# 14   Institut de Recherche pour le Developpement | ...     COMPLETED
# 24                             Merck Sharp & Dohme LLC     COMPLETED
# 60                                                <NA>     COMPLETED
# 74                          Cerballiance | Kappa Santé     COMPLETED
# 75                          Cerballiance | Kappa Santé     COMPLETED
# 103  European and Developing Countries Clinical Tri...     COMPLETED
# 129                                               <NA>     COMPLETED
# 130                                               <NA>     COMPLETED
# 179                                               <NA>     COMPLETED
# 241                                               <NA>     COMPLETED
# 293       Merck Sharp & Dohme LLC | Janssen-Cilag Ltd.     COMPLETED
# 297                                               <NA>     COMPLETED
# 325                                               <NA>     COMPLETED
# 329  University Teaching Hospital, Lusaka, Zambia |...     COMPLETED
# 345                                               <NA>     COMPLETED
# 410                                               <NA>     COMPLETED
# 449                                               <NA>     COMPLETED
# 456                                               <NA>     COMPLETED
# 457                                               <NA>     COMPLETED
# 475                                               <NA>     COMPLETED
# 520  Institut National de Recherche Biomédicale. Ki...     COMPLETED
# 606               Biogen | Ionis Pharmaceuticals, Inc.     COMPLETED
# 607               Biogen | Ionis Pharmaceuticals, Inc.     COMPLETED
# 664      Institute of Research for Development, France     COMPLETED
# 667                                               <NA>     COMPLETED
# 697                                               <NA>     COMPLETED
#
#           StudyType  HasResults StudyFirstPostDate   StartDate CompletionDate  \
# 9     OBSERVATIONAL       False         2022-04-27  2003-01-01     2022-04-01
# 11   INTERVENTIONAL       False         2016-05-19     2016-07        2021-07
# 14   INTERVENTIONAL       False         2016-05-19     2016-07        2021-07
# 24   INTERVENTIONAL       False         2011-10-17     2011-12        2015-11
# 60   INTERVENTIONAL       False         2020-03-20  2020-03-22     2023-09-25
# 74   INTERVENTIONAL       False         2022-04-05  2021-09-04     2022-02-26
# 75   INTERVENTIONAL       False         2022-04-05  2021-09-04     2022-02-26
# 103  INTERVENTIONAL       False         2008-03-21     2009-12        2014-02
# 129   OBSERVATIONAL       False         2013-03-01     2013-02        2014-12
# 130  INTERVENTIONAL       False         2015-04-01     2015-10        2017-11
# 179   OBSERVATIONAL       False         2012-10-11  2012-03-14     2014-03-20
# 241  INTERVENTIONAL       False         2011-11-17     2012-01     2016-12-15
# 293  INTERVENTIONAL        True         2014-08-08     2015-01        2018-04
# 297   OBSERVATIONAL       False         2017-11-08  2017-10-18     2020-11-18
# 325  INTERVENTIONAL       False         2011-08-31     2011-07        2017-12
# 329  INTERVENTIONAL       False         2019-03-12  2019-12-14     2022-10-31
# 345   OBSERVATIONAL       False         2017-03-13  2016-09-02     2018-01-08
# 410  INTERVENTIONAL       False         2014-02-07     2014-09        2018-04
# 449   OBSERVATIONAL       False         2020-05-18  2020-05-01     2023-04-11
# 456  INTERVENTIONAL       False         2010-03-18     2010-05        2015-03
# 457  INTERVENTIONAL       False         2016-07-14  2016-07-28     2019-10-25
# 475  INTERVENTIONAL       False         2015-06-25  2015-07-15     2018-01-22
# 520   OBSERVATIONAL       False         2020-06-01  2020-04-16     2021-10-18
# 606   OBSERVATIONAL       False         2020-02-28  2020-05-28     2022-06-01
# 607   OBSERVATIONAL       False         2020-02-28  2020-05-28     2022-06-01
# 664   OBSERVATIONAL       False         2017-07-12  2017-10-19     2019-07-31
# 667  INTERVENTIONAL       False         2016-12-29  2017-04-21     2018-09-18
# 697  INTERVENTIONAL       False         2012-09-19     2012-04        2015-11
#
#          pmid    type                                              title  \
# 9    36735263  PUBMED  Epicardial vs. transvenous implantable cardiov...
# 11   37851566  PUBMED  Improvements in Patient-Reported Outcomes Foll...
# 14   38156046  PUBMED  Durability of the Efficacy and Safety of Dolut...
# 24   30688008  PUBMED  Low incidence of acute rejection within 6 mont...
# 60   36695483  PUBMED          Remdesivir for the treatment of COVID-19.
# 74   37795682  PUBMED  A randomised controlled trial to study the tra...
# 75   36438274  PUBMED  Transmission of SARS-CoV-2 during indoor clubb...
# 103  34425825  PUBMED  The prevalence and socio-behavioural and clini...
# 129  29662875  PUBMED  Positive Virological Outcomes of HIV-Infected ...
# 130  36686592  PUBMED  Patient-reported outcomes with direct-acting a...
# 179  37668523  PUBMED  Neurochemical Differences between 1p/19q Codel...
# 241  36601747  PUBMED  Hepatitis A and B vaccine uptake and immunisat...
# 293  31269208  PUBMED  Dual therapy combining raltegravir with etravi...
# 297  37497675  PUBMED  One-Year Outcomes in Patients With Acute Strok...
# 325  26314624  PUBMED  Molecular characterization of the 17D-204 yell...
# 329  38484756  PUBMED  Optimised prevention of postnatal HIV transmis...
# 345  38408861  PUBMED  Birth weight and head circumference discordanc...
# 410  36883573  PUBMED  High performance of systematic combined urine ...
# 449  34293141  PUBMED  Antibody status and cumulative incidence of SA...
# 456  26439886  PUBMED  Safety of Intracavernous Bone Marrow-Mononucle...
# 457  36318030  PUBMED  Longitudinal Monitoring of Microstructural Alt...
# 475  38273639  PUBMED  Sirolimus for treatment of patients with inclu...
# 520  38043556  PUBMED  Effect of anti-Ebola virus monoclonal antibodi...
# 606  38419144  PUBMED  Digital Gait Measures Capture 1-Year Progressi...
# 607  38421662  PUBMED  ATXN7-Related Cone-Rod Dystrophy: The Integrat...
# 664  37143029  PUBMED  Hepatitis B prevention and treatment needs in ...
# 667  38100477  PUBMED  Effects of a mindfulness-based intervention an...
# 697  35272723  PUBMED  Behavioural risk patterns in adolescents with ...
#
#                                                authors  \
# 9    Le Bos PA; Pontailler M; Maltret A; Kraiche D;...
# 11   Bousmah MA; Protopopescu C; Mpoudi-Etame M; Om...
# 14   Mpoudi-Etame M; Tovar Sanchez T; Bousmah MA; O...
# 24   Matignon M; Lelièvre JD; Lahiani A; Abbassi K;...
# 60   Grundeis F; Ansems K; Dahms K; Thieme V; Metze...
# 74   Luong Nguyen LB; Goupil de Bouillé J; Menant L...
# 75   Goupil de Bouillé J; Luong Nguyen LB; Crépey P...
# 103  Birungi N; Fadnes LT; Engebretsen IMS; Tumwine...
# 129  Ségéral O; Nerrienet E; Neth S; Spire B; Khol ...
# 130  Marcellin F; Mourad A; Lemoine M; Kouanfack C;...
# 179  Branzoli F; Liserre R; Deelchand DK; Poliani P...
# 241  Le Turnier P; Charreau I; Gabassi A; Carette D...
# 293  Katlama C; Assoumou L; Valantin MA; Soulié C; ...
# 297  Sonneville R; Mazighi M; Collet M; Gayat E; De...
# 325  Salmona M; Gazaignes S; Mercier-Delarue S; Gar...
# 329  Kankasa C; Mennecier A; Sakana BLD; Molès JP; ...
# 345  Guellec I; Brunet A; Lapillonne A; Taine M; To...
# 410  Bonnet M; Gabillard D; Domoua S; Muzoora C; Me...
# 449  Carrat F; de Lamballerie X; Rahib D; Blanché H...
# 456  Yiou R; Hamidou L; Birebent B; Bitari D; Lecor...
# 457  Genovese G; Diaz-Fernandez B; Lejeune FX; Rone...
# 475  Benveniste O; Hogrel JY; Belin L; Annoussamy M...
# 520  Nkuba-Ndaye A; Dilu-Keti A; Tovar-Sanchez T; D...
# 606  Seemann J; Daghsen L; Cazier M; Lamy JC; Welte...
# 607  Nassisi M; Coarelli G; Blanchard B; Dubec-Fleu...
# 664  Djaogol T; Périères L; Marcellin F; Diouf A; C...
# 667  Schlosser M; Demnitz-King H; Barnhofer T; Coll...
# 697  Julia C; Omorou A; Lecomte E; Langlois J; Touv...
#
#                                   doi  year  \
# 9            10.1093/europace/euad015  2023
# 11       10.1097/QAI.0000000000003273  2023
# 14               10.1093/ofid/ofad582  2023
# 24                  10.1111/hiv.12700  2019
# 60     10.1002/14651858.CD014962.pub2  2023
# 74                10.1093/cid/ciad603  2023
# 75          10.3389/fpubh.2022.981213  2022
# 103        10.1186/s12955-021-01844-3  2021
# 129          10.3389/fpubh.2018.00063  2018
# 130       10.1016/j.jhepr.2022.100665  2023
# 179             10.1148/radiol.223255  2023
# 241      10.1136/sextrans-2022-055634  2023
# 293                10.1093/jac/dkz224  2019
# 297      10.1161/STROKEAHA.123.042910  2023
# 325     10.1016/j.vaccine.2015.08.055  2015
# 329     10.1016/S0140-6736(23)02464-9  2024
# 345  10.1136/archdischild-2023-326336  2024
# 410               10.1093/cid/ciad125  2023
# 449               10.1093/ije/dyab110  2021
# 456      10.1016/j.eururo.2015.09.026  2016
# 457             10.1148/radiol.220430  2023
# 475     10.1016/S2665-9913(20)30280-0  2021
# 520     10.1016/S1473-3099(23)00552-2  2024
# 606                 10.1002/mds.29757  2024
# 607  10.1001/jamaophthalmol.2024.0001  2024
# 664        10.1186/s12889-023-15710-y  2023
# 667      10.1371/journal.pone.0295175  2023
# 697         10.1017/S136898002200057X  2023
#
#                                      publication_types
# 9                    [Clinical Trial, Journal Article]
# 11   [Randomized Controlled Trial, Journal Article,...
# 14                                   [Journal Article]
# 24   [Journal Article, Multicenter Study, Research ...
# 60   [Journal Article, Review, Research Support, No...
# 74                                   [Journal Article]
# 75   [Clinical Trial Protocol, Journal Article, Res...
# 103                                  [Journal Article]
# 129                                  [Journal Article]
# 130                                  [Journal Article]
# 179  [Journal Article, Observational Study, Researc...
# 241  [Clinical Trial, Research Support, Non-U.S. Go...
# 293  [Journal Article, Multicenter Study, Research ...
# 297  [Multicenter Study, Journal Article, Research ...
# 325  [Journal Article, Research Support, Non-U.S. G...
# 329                                  [Journal Article]
# 345                                  [Journal Article]
# 410                                  [Journal Article]
# 449                                  [Journal Article]
# 456  [Journal Article, Research Support, Non-U.S. G...
# 457  [Journal Article, Research Support, Non-U.S. G...
# 475                                  [Journal Article]
# 520             [Observational Study, Journal Article]
# 606                                  [Journal Article]
# 607                                  [Journal Article]
# 664  [Journal Article, Research Support, Non-U.S. G...
# 667     [Randomized Controlled Trial, Journal Article]
# 697  [Journal Article, Research Support, Non-U.S. G...

# %% [markdown]
# ### Resultat final:

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 706 entries, 0 to 705
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   NCTId               706 non-null    object
#  1   BriefTitle          706 non-null    string
#  2   LeadSponsorName     706 non-null    string
#  3   CollaboratorName    357 non-null    string
#  4   OverallStatus       706 non-null    category
#  5   StudyType           706 non-null    category
#  6   HasResults          706 non-null    boolean
#  7   StudyFirstPostDate  706 non-null    string
#  8   StartDate           706 non-null    string
#  9   CompletionDate      705 non-null    string
#  10  pmid                568 non-null    object
#  11  type                568 non-null    string
#  12  title               568 non-null    object
#  13  authors             568 non-null    object
#  14  doi                 563 non-null    object
#  15  year                568 non-null    object
#  16  publication_types   568 non-null    object
# dtypes: boolean(1), category(2), object(7), string(7)
# memory usage: 80.3+ KB

# %%
df_final = df_final.convert_dtypes()
# df_final = df_final.astype({"OverallStatus" : 'category', "StudyType" : 'category'})
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 706 entries, 0 to 705
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   NCTId               706 non-null    string
#  1   BriefTitle          706 non-null    string
#  2   LeadSponsorName     706 non-null    string
#  3   CollaboratorName    357 non-null    string
#  4   OverallStatus       706 non-null    category
#  5   StudyType           706 non-null    category
#  6   HasResults          706 non-null    boolean
#  7   StudyFirstPostDate  706 non-null    string
#  8   StartDate           706 non-null    string
#  9   CompletionDate      705 non-null    string
#  10  pmid                568 non-null    string
#  11  type                568 non-null    string
#  12  title               568 non-null    string
#  13  authors             568 non-null    string
#  14  doi                 563 non-null    string
#  15  year                568 non-null    string
#  16  publication_types   568 non-null    object
# dtypes: boolean(1), category(2), object(1), string(13)
# memory usage: 80.3+ KB

# %% [markdown]
# ### Export en CSV:

# %%
df_final.to_csv(
    'Data/outputs/extract_df_final.csv',
    sep=';',
    index=False,
    encoding='utf-8-sig',
)
