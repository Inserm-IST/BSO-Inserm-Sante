# %% [markdown]
# # Objectif:
#
# On souhaite évaluer le nombre de publications qui sont le résultat d'études cliniques liées à l'INSERM.
#
# En particulier, on souhaite identifier les études cliniques qui ne donnent lieu à aucune publication et essayer de comprendre les raisons de cette absence de publication.

# %% [markdown]
# # Organisation :
# - On récupère via l'API de *ClinicalTrial* les *ID* (**NCTId**) des études cliniques qui ont pour sponsors l'*INSERM*, l'*ANRS* etc.
#
# - A partir de ces **NCTIds**, on récupère sur *ClinicalTrial* les **PMIDs** des publications liées à ces études.
#     Ces publications sont de 2 types:
#     1. Elles ont été uploadées sur *CT* par les auteurs de l'étude: `BACKGROUND, RESULT`
#     2. Elles ont été automatiquement récupérés sur PubMed par *CT*: `DERIVED`
# - A partir de ces **NCTIds**, on récupère sur *PubMed* les **PMIDs** des publications liées à ces études.
#     On retrouve général un peu plus de publications que le traitement automatique réalisé par *CT*.
#
# - Pour chaque **NCTIds**, on fusionne l'ensemble des **PMIDs** retournées par *CT* et *PubMed*.
#
# - A partir de cet ensemble de **PMIDs**, on récupère les infos liés : `titre, auteurs, doi`...

# %% [markdown]
# # Extraction des NCTIds dans ClinicalTrial:

# %% [markdown]
# ## API v1:

# %% [markdown]
# Pour faciliter la récupération des données via l'API v1 de ClinicalTrial, on utilise le wrapper Python: [pytrials](https://github.com/jvfe/pytrials)

# %% [markdown]
# Installer ***pytrials***:
# - Dans Conda Navigator, se placer dans le meme environnement que celui qui execute Jupyter
# - Lancer Powershell Prompt dans cet environnement
# - Taper: `pip install pytrials`

# %%
from pytrials.client import ClinicalTrials
import urllib.parse

# %%
ct = ClinicalTrials()

# %% [markdown]
# ### Création de la requête:

# %% [markdown]
# On crée la requête qui sera envoyé à l'API de ClinicalTrial

# %% [markdown]
# #### Sponsors:

# %%
sponsors = [
    'anrs',
    'inserm',
    'institut national de la santé et de la recherche médicale',
    'french national agency for research on aids and viral hepatitis',
]

# %%
sponsors_expr = [f'AREA[LeadSponsorName]{sponsor}' for sponsor in sponsors]

# Add OR keyword
sponsors_expr = ' OR '.join(sponsors_expr)

# Add parenthesis for correct interpretation of OR expression
sponsors_expr = f'({sponsors_expr})'

sponsors_expr
# Out:
# '(AREA[LeadSponsorName]anrs OR AREA[LeadSponsorName]inserm OR AREA[LeadSponsorName]institut national de la santé et de la recherche médicale OR AREA[LeadSponsorName]french national agency for research on aids and viral hepatitis)'

# %% [markdown]
# #### Status:

# %%
status = 'completed'

# %%
status_expr = f'AREA[OverallStatus]{status}'
status_expr
# Out:
# 'AREA[OverallStatus]completed'

# %% [markdown]
# #### Date de fin d'étude supérieure ou égale à 2013:

# %%
date_expr = 'AREA[CompletionDate]RANGE[01/01/2013,MAX]'
date_expr
# Out:
# 'AREA[CompletionDate]RANGE[01/01/2013,MAX]'

# %% [markdown]
# #### Search Expression:

# %%
search_expr = ' AND '.join([sponsors_expr, status_expr, date_expr])
search_expr
# Out:
# '(AREA[LeadSponsorName]anrs OR AREA[LeadSponsorName]inserm OR AREA[LeadSponsorName]institut national de la santé et de la recherche médicale OR AREA[LeadSponsorName]french national agency for research on aids and viral hepatitis) AND AREA[OverallStatus]completed AND AREA[CompletionDate]RANGE[01/01/2013,MAX]'

# %% [markdown]
# #### URL encode:

# %%
search_expr_url_encode = urllib.parse.quote_plus(search_expr)
search_expr_url_encode
# Out:
# '%28AREA%5BLeadSponsorName%5Danrs+OR+AREA%5BLeadSponsorName%5Dinserm+OR+AREA%5BLeadSponsorName%5Dinstitut+national+de+la+sant%C3%A9+et+de+la+recherche+m%C3%A9dicale+OR+AREA%5BLeadSponsorName%5Dfrench+national+agency+for+research+on+aids+and+viral+hepatitis%29+AND+AREA%5BOverallStatus%5Dcompleted+AND+AREA%5BCompletionDate%5DRANGE%5B01%2F01%2F2013%2CMAX%5D'

# %% [markdown]
# #### Fields:

# %% [markdown]
# Les champs que l'on veut récupérer:

# %%
fields = [
    'NCTId',
    'BriefTitle',
    'OverallStatus',
    'StudyType',
    'LeadSponsorName',
    'CollaboratorName',
    'OrgStudyId',
    'SecondaryId',
    'StudyFirstPostDate',
    'ReferencePMID',
    'ReferenceCitation',
    'ReferenceType',
]

# %% [markdown]
# ### Envoi de la requête :

# %%
study_fields = ct.get_study_fields(
    search_expr=search_expr_url_encode,
    fields=fields,
    max_studies=1000,
    fmt='csv',
)

# %%
print(f'NStudiesReturned: {len(study_fields[1:])}')
# Out:
# NStudiesReturned: 200

# %% [markdown]
# ### Lire le résultat de la requête dans Pandas :

# %%
import pandas as pd

# %%
pd.DataFrame.from_records(study_fields[1:], index='Rank', columns=study_fields[0])
# Out:
#             NCTId                                         BriefTitle  \
# Rank
# 1     NCT03671291  Missed Opportunities to Pre-exposure Prophylax...
# 2     NCT01463956  Efficacy of PegInterferon-Ribavirin-Boceprevir...
# 3     NCT01426243  The Yellow Fever Vaccine Immunity in HIV Infec...
# 4     NCT01269632  Cohort of Young Adults Infected With HIV Since...
# 5     NCT01226446  Efficacy of Vitamin D on Top of Pegylated Inte...
# ...           ...                                                ...
# 196   NCT00265642  Evaluation of Irbesartan on Hepatic Fibrosis i...
# 197   NCT00116454  Trial for Hepatocellular Carcinoma Adjuvant Tr...
# 198   NCT05349162        Epicardial vs. Transvenous ICDs in Children
# 199   NCT04842851  Cardiac Resynchronization Therapy in Congenita...
# 200   NCT05199831  Situational Analysis of HIV-related Disability...
#
#      OverallStatus       StudyType  \
# Rank
# 1        Completed  Interventional
# 2        Completed  Interventional
# 3        Completed  Interventional
# 4        Completed  Interventional
# 5        Completed  Interventional
# ...            ...             ...
# 196      Completed  Interventional
# 197      Completed  Interventional
# 198      Completed   Observational
# 199      Completed   Observational
# 200      Completed   Observational
#
#                                         LeadSponsorName  \
# Rank
# 1     French National Agency for Research on AIDS an...
# 2     French National Agency for Research on AIDS an...
# 3     French National Agency for Research on AIDS an...
# 4     French National Agency for Research on AIDS an...
# 5     French National Agency for Research on AIDS an...
# ...                                                 ...
# 196                  ANRS, Emerging Infectious Diseases
# 197                  ANRS, Emerging Infectious Diseases
# 198   Paris Cardiovascular Research Center (Inserm U...
# 199   Paris Cardiovascular Research Center (Inserm U...
# 200    Programme PAC-CI, Site ANRS-MIE de Côte d'Ivoire
#
#                                        CollaboratorName  \
# Rank
# 1     University Hospital, Marseille|University Hosp...
# 2                               Merck Sharp & Dohme LLC
# 3
# 4
# 5
# ...                                                 ...
# 196                                              Sanofi
# 197
# 198                      Hôpital Necker-Enfants Malades
# 199   Marie Lannelongue Hospital, Le Plessis Robinso...
# 200   Institute of Research for Development, France|...
#
#                          OrgStudyId          SecondaryId  StudyFirstPostDate  \
# Rank
# 1     ANRS 95041 Missed Opportunity                       September 14, 2018
# 2                  2011- 001089 -17                         November 2, 2011
# 3                    2009-014921-17                          August 31, 2011
# 4                    2009-AO1219-48                          January 4, 2011
# 5                    2010-021967-34                         October 22, 2010
# ...                             ...                  ...                 ...
# 196                  2005-006027-37  ANRS HC 19 Fibrosar   December 15, 2005
# 197                  2004-003883-31   ANRS HC06 LIPIOCIS       June 30, 2005
# 198                          134526                           April 27, 2022
# 199                         2219047                           April 13, 2021
# 200                          VIRAGE                         January 20, 2022
#
#      ReferencePMID                                  ReferenceCitation  \
# Rank
# 1
# 2
# 3         30096071  Colin de Verdiere N, Durier C, Samri A, Meiffr...
# 4
# 5         25987791  Terrier B, Lapidus N, Pol S, Serfaty L, Ratziu...
# ...            ...                                                ...
# 196
# 197
# 198
# 199
# 200
#
#      ReferenceType
# Rank
# 1
# 2
# 3          derived
# 4
# 5          derived
# ...            ...
# 196
# 197
# 198
# 199
# 200
#
# [200 rows x 12 columns]

# %% [markdown]
# ## API v2:

# %% [markdown]
# L'API v1 ne sera plus supporté a [partir de mi-2024](https://clinicaltrials.gov/data-api/api) :

# %% [markdown]
# >***Notice to API users:
# >The new ClinicalTrials.gov API, version 2.0 is available. Classic API users are strongly encouraged to switch to the modernized API. We will continue to support the classic API until mid-2024 and are planning blackouts for the spring to help with the transition to the modernized API.***

# %% [markdown]
# De plus, l'API v2 supporte un nouveau champs **"HasResults"**, qui pour l'instant n'est que très peu utilisé mais qui pourrait être utile à l'avenir.
#
# En contre-partie, l'export des données sous forme de CSV est limité à un certain nombre de champs visible sur cette page: https://clinicaltrials.gov/data-api/about-api/csv-download
#
# On est donc obligé d'utiliser l'export de données sous forme de JSON.

# %% [markdown]
# ### Création de la requête:

# %% [markdown]
# `pytrials` n'étant pas compatible avec la v2, on envoie la requête manuellement en utilisant [Requests](https://requests.readthedocs.io/en/latest/)

# %% [markdown]
# #### Format:

# %%
format = 'json'

# %% [markdown]
# #### Sponsors:

# %%
sponsors
# Out:
# ['anrs',
#  'inserm',
#  'institut national de la santé et de la recherche médicale',
#  'french national agency for research on aids and viral hepatitis']

# %%
sponsors_expr_v2 = ' OR '.join(sponsors)
sponsors_expr_v2 = urllib.parse.quote_plus(sponsors_expr_v2)
sponsors_expr_v2
# Out:
# 'anrs+OR+inserm+OR+institut+national+de+la+sant%C3%A9+et+de+la+recherche+m%C3%A9dicale+OR+french+national+agency+for+research+on+aids+and+viral+hepatitis'

# %% [markdown]
# #### Overall_status:

# %%
overall_status = 'COMPLETED'

# %% [markdown]
# #### Fields:

# %%
fields_v2 = [
    'NCTId',
    'BriefTitle',
    # 'OfficialTitle',
    'OverallStatus',
    'StudyType',
    'LeadSponsorName',
    'CollaboratorName',
    # 'OrgStudyId',
    # 'SecondaryId',
    'StudyFirstPostDate',
    'StartDate',
    # 'PrimaryCompletionDate',
    'CompletionDate',
    'ReferencePMID',
    'ReferenceCitation',
    'ReferenceType',
    'hasResults',
]
fields_v2
# Out:
# ['NCTId',
#  'BriefTitle',
#  'OverallStatus',
#  'StudyType',
#  'LeadSponsorName',
#  'CollaboratorName',
#  'StudyFirstPostDate',
#  'StartDate',
#  'CompletionDate',
#  'ReferencePMID',
#  'ReferenceCitation',
#  'ReferenceType',
#  'hasResults']

# %%
fields_expr_v2 = ','.join(fields_v2)
fields_expr_v2 = urllib.parse.quote_plus(fields_expr_v2)
fields_expr_v2
# Out:
# 'NCTId%2CBriefTitle%2COverallStatus%2CStudyType%2CLeadSponsorName%2CCollaboratorName%2CStudyFirstPostDate%2CStartDate%2CCompletionDate%2CReferencePMID%2CReferenceCitation%2CReferenceType%2ChasResults'

# %% [markdown]
# #### Date de fin d'étude postérieure à 2013:

# %%
date = 'AREA[CompletionDate]RANGE[01/01/2013, MAX]'
date_expr = urllib.parse.quote_plus(date)
date_expr
# Out:
# 'AREA%5BCompletionDate%5DRANGE%5B01%2F01%2F2013%2C+MAX%5D'

# %% [markdown]
# #### Nombre de résultats max :

# %%
count_total = 'true'

# %%
page_size = 1000

# %% [markdown]
# #### URL api:

# %%
query_url = f'https://clinicaltrials.gov/api/v2/studies?format={format}&query.lead={sponsors_expr_v2}&filter.overallStatus={overall_status}&fields={fields_expr_v2}&filter.advanced={date_expr}&countTotal={count_total}&pageSize={page_size}'
query_url
# Out:
# 'https://clinicaltrials.gov/api/v2/studies?format=json&query.lead=anrs+OR+inserm+OR+institut+national+de+la+sant%C3%A9+et+de+la+recherche+m%C3%A9dicale+OR+french+national+agency+for+research+on+aids+and+viral+hepatitis&filter.overallStatus=COMPLETED&fields=NCTId%2CBriefTitle%2COverallStatus%2CStudyType%2CLeadSponsorName%2CCollaboratorName%2CStudyFirstPostDate%2CStartDate%2CCompletionDate%2CReferencePMID%2CReferenceCitation%2CReferenceType%2ChasResults&filter.advanced=AREA%5BCompletionDate%5DRANGE%5B01%2F01%2F2013%2C+MAX%5D&countTotal=true&pageSize=1000'

# %% [markdown]
# ### Envoi de la requête :

# %%
import requests

# %%
response = requests.get(query_url)
response.raise_for_status()
response
# Out:
# <Response [200]>

# %%
print(f'Studies returned: {response.json()["totalCount"]}')
# Out:
# Studies returned: 200

# %% [markdown]
# ### Traitement du JSON retourné:

# %%
import json

# %%
# print(json.dumps(response.json(), indent=2))

# %% [markdown]
# ***La structure du JSON est bien trop imbriquée pour le normaliser avec Pandas, du coup on l'applatit à la main:***

# %% [markdown]
# A partir du JSON on construit un dictionnaire équivalent mais beaucoup plus "plat"

# %%
# Si la liste des collaborateurs est vide on renvoie None, sinon on concatène les valeurs de la liste
# sous la forme "collaborateur_0 | collaborateur_1 | ..."
def concatenate_collaborator_list(collaborator_list):
    if collaborator_list == []:
        return None
    else:
        return ' | '.join(collaborator_list)

# %%
studies_list = []
for study in response.json()['studies']:
    study_dict = {
        'NCTId': study['protocolSection']['identificationModule']['nctId'],
        'BriefTitle': study['protocolSection']['identificationModule']['briefTitle'],
        'LeadSponsorName': study['protocolSection']['sponsorCollaboratorsModule']['leadSponsor']['name'],
        'CollaboratorName': concatenate_collaborator_list(
            [
                c['name']
                for c in (
                    study['protocolSection']['sponsorCollaboratorsModule'].get('collaborators', [])  # can be missing
                )
            ]
        ),
        'OverallStatus': study['protocolSection']['statusModule']['overallStatus'],
        'StudyType': study['protocolSection']['designModule']['studyType'],
        'HasResults': study['hasResults'],
        'StudyFirstPostDate': study['protocolSection']['statusModule']['studyFirstPostDateStruct']['date'],
        'StartDate': study['protocolSection']['statusModule'].get('startDateStruct', {}).get('date', None),  # can be missing
        # 'PrimaryCompletionDate' : study["protocolSection"]["statusModule"].get('primaryCompletionDateStruct', {}).get('date', None), # can be missing
        'CompletionDate': study['protocolSection']['statusModule'].get('completionDateStruct', {}).get('date', None),  # can be missing
        'Reference': study['protocolSection'].get('referencesModule', {}).get('references', []),  # can be missing
    }
    studies_list.append(study_dict)

# print(json.dumps(studies_list, indent=2))

# %% [markdown]
# On vérifie que l'on n'a pas perdu de NCTId en route:

# %%
print(f'Nombre de NCTId: {len(studies_list)}')
assert response.json()['totalCount'] == len(studies_list)
# Out:
# Nombre de NCTId: 200

# %% [markdown]
# ### Import dans Pandas

# %%
df_ct = pd.json_normalize(data=studies_list)
df_ct
# Out:
#            NCTId                                         BriefTitle  \
# 0    NCT02081066  Identification of CETP as a Marker of Atherosc...
# 1    NCT05199831  Situational Analysis of HIV-related Disability...
# 2    NCT01895920  Viral Biofilms: Hijacking T Cell Extracellular...
# 3    NCT02116374  Physiopathology Study of the Microbiota Biodiv...
# 4    NCT02107365  Therapy With Asunaprevir, Daclatasvir, Ribavir...
# ..           ...                                                ...
# 195  NCT03215732  Cross Sectional Survey on the Burden and Impac...
# 196  NCT02052271  Experimental Therapeutics in Essential Tremor ...
# 197  NCT00918307  Efficacy and Safety of Varenicline Among HIV-i...
# 198  NCT01698411  Study of the Influence of Sleep on Hemodynamic...
# 199  NCT02214511  Biomarkers of Social Sensitivity in Major Depr...
#
#                                        LeadSponsorName  \
# 0    Institut National de la Santé Et de la Recherc...
# 1     Programme PAC-CI, Site ANRS-MIE de Côte d'Ivoire
# 2                   ANRS, Emerging Infectious Diseases
# 3                   ANRS, Emerging Infectious Diseases
# 4                   ANRS, Emerging Infectious Diseases
# ..                                                 ...
# 195                 ANRS, Emerging Infectious Diseases
# 196  Institut National de la Santé Et de la Recherc...
# 197                 ANRS, Emerging Infectious Diseases
# 198  Institut National de la Santé Et de la Recherc...
# 199  Institut National de la Santé Et de la Recherc...
#
#                                       CollaboratorName OverallStatus  \
# 0                                                 None     COMPLETED
# 1    Institute of Research for Development, France ...     COMPLETED
# 2                                                 None     COMPLETED
# 3                                                 None     COMPLETED
# 4                                 Bristol-Myers Squibb     COMPLETED
# ..                                                 ...           ...
# 195      Institute of Research for Development, France     COMPLETED
# 196                                               None     COMPLETED
# 197                                             Pfizer     COMPLETED
# 198                                               None     COMPLETED
# 199                                               None     COMPLETED
#
#           StudyType  HasResults StudyFirstPostDate   StartDate CompletionDate  \
# 0    INTERVENTIONAL       False         2014-03-07  2014-09-25        2020-09
# 1     OBSERVATIONAL       False         2022-01-20  2021-02-05     2022-08-10
# 2    INTERVENTIONAL       False         2013-07-11     2013-01        2018-02
# 3     OBSERVATIONAL       False         2014-04-16     2014-12        2016-06
# 4    INTERVENTIONAL       False         2014-04-08     2013-11        2015-04
# ..              ...         ...                ...         ...            ...
# 195   OBSERVATIONAL       False         2017-07-12  2017-10-19     2019-07-31
# 196  INTERVENTIONAL       False         2014-02-03  2014-06-03     2018-03-27
# 197  INTERVENTIONAL       False         2009-06-11     2009-10        2014-07
# 198   OBSERVATIONAL       False         2012-10-03     2012-10        2015-02
# 199   OBSERVATIONAL       False         2014-08-12  2014-10-23     2017-03-01
#
#                                              Reference
# 0                                                   []
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 195  [{'pmid': '31320358', 'type': 'DERIVED', 'cita...
# 196                                                 []
# 197  [{'pmid': '34611902', 'type': 'DERIVED', 'cita...
# 198                                                 []
# 199                                                 []
#
# [200 rows x 11 columns]

# %% [markdown]
# #### On "explose" la colonne "References":
#
# Pour chaque NCTId, la colonne réferences contient potentiellement une liste de plusieurs références.
# Si par exemple, on a 3 références, on veut se retrouver avec 3 lignes, chacune indexée par le même NCTId et contenant une unique réference.
#
# *Avant*:
# **`NCTId    References`**
# `NCT0001, [Ref1, Ref2, Ref3]`
#
# *Après*:
# **`NCTId    References`**
# `NCT0001,   Ref1`
# `NCT0001,   Ref2`
# `NCT0001,   Ref3`

# %%
df_ct = df_ct.explode('Reference', ignore_index=True)
df_ct.loc[:, ['NCTId', 'Reference']]
# Out:
#            NCTId                                          Reference
# 0    NCT02081066                                                NaN
# 1    NCT05199831                                                NaN
# 2    NCT01895920                                                NaN
# 3    NCT02116374                                                NaN
# 4    NCT02107365                                                NaN
# ..           ...                                                ...
# 477  NCT02052271                                                NaN
# 478  NCT00918307  {'pmid': '34611902', 'type': 'DERIVED', 'citat...
# 479  NCT00918307  {'pmid': '29329763', 'type': 'DERIVED', 'citat...
# 480  NCT01698411                                                NaN
# 481  NCT02214511                                                NaN
#
# [482 rows x 2 columns]

# %% [markdown]
# Pour chaque NCTId, la colonne réference contient maintenant un dictionnaire de la forme:
# `{
# "pmid": "17545707",
# "type": "BACKGROUND",
# "citation": "...",
# }`
#
# Dont on veut extraire de nouvelles colonnes en utilant les clés du dictionnaire:
# **`pmid     type        citation`**
# `17545707, BACKGROUND, "..."`

# %%
df_ct_references = pd.json_normalize(df_ct.pop('Reference'))
df_ct_references
# Out:
#          pmid     type                                           citation
# 0         NaN      NaN                                                NaN
# 1         NaN      NaN                                                NaN
# 2         NaN      NaN                                                NaN
# 3         NaN      NaN                                                NaN
# 4         NaN      NaN                                                NaN
# ..        ...      ...                                                ...
# 477       NaN      NaN                                                NaN
# 478  34611902  DERIVED  Hartmann-Boyce J, Theodoulou A, Farley A, Haje...
# 479  29329763  DERIVED  Mercie P, Arsandaux J, Katlama C, Ferret S, Be...
# 480       NaN      NaN                                                NaN
# 481       NaN      NaN                                                NaN
#
# [482 rows x 3 columns]

# %% [markdown]
# On réassemble la dataFrame complète:

# %%
df_ct = df_ct.join(df_ct_references)
df_ct
# Out:
#            NCTId                                         BriefTitle  \
# 0    NCT02081066  Identification of CETP as a Marker of Atherosc...
# 1    NCT05199831  Situational Analysis of HIV-related Disability...
# 2    NCT01895920  Viral Biofilms: Hijacking T Cell Extracellular...
# 3    NCT02116374  Physiopathology Study of the Microbiota Biodiv...
# 4    NCT02107365  Therapy With Asunaprevir, Daclatasvir, Ribavir...
# ..           ...                                                ...
# 477  NCT02052271  Experimental Therapeutics in Essential Tremor ...
# 478  NCT00918307  Efficacy and Safety of Varenicline Among HIV-i...
# 479  NCT00918307  Efficacy and Safety of Varenicline Among HIV-i...
# 480  NCT01698411  Study of the Influence of Sleep on Hemodynamic...
# 481  NCT02214511  Biomarkers of Social Sensitivity in Major Depr...
#
#                                        LeadSponsorName  \
# 0    Institut National de la Santé Et de la Recherc...
# 1     Programme PAC-CI, Site ANRS-MIE de Côte d'Ivoire
# 2                   ANRS, Emerging Infectious Diseases
# 3                   ANRS, Emerging Infectious Diseases
# 4                   ANRS, Emerging Infectious Diseases
# ..                                                 ...
# 477  Institut National de la Santé Et de la Recherc...
# 478                 ANRS, Emerging Infectious Diseases
# 479                 ANRS, Emerging Infectious Diseases
# 480  Institut National de la Santé Et de la Recherc...
# 481  Institut National de la Santé Et de la Recherc...
#
#                                       CollaboratorName OverallStatus  \
# 0                                                 None     COMPLETED
# 1    Institute of Research for Development, France ...     COMPLETED
# 2                                                 None     COMPLETED
# 3                                                 None     COMPLETED
# 4                                 Bristol-Myers Squibb     COMPLETED
# ..                                                 ...           ...
# 477                                               None     COMPLETED
# 478                                             Pfizer     COMPLETED
# 479                                             Pfizer     COMPLETED
# 480                                               None     COMPLETED
# 481                                               None     COMPLETED
#
#           StudyType  HasResults StudyFirstPostDate   StartDate CompletionDate  \
# 0    INTERVENTIONAL       False         2014-03-07  2014-09-25        2020-09
# 1     OBSERVATIONAL       False         2022-01-20  2021-02-05     2022-08-10
# 2    INTERVENTIONAL       False         2013-07-11     2013-01        2018-02
# 3     OBSERVATIONAL       False         2014-04-16     2014-12        2016-06
# 4    INTERVENTIONAL       False         2014-04-08     2013-11        2015-04
# ..              ...         ...                ...         ...            ...
# 477  INTERVENTIONAL       False         2014-02-03  2014-06-03     2018-03-27
# 478  INTERVENTIONAL       False         2009-06-11     2009-10        2014-07
# 479  INTERVENTIONAL       False         2009-06-11     2009-10        2014-07
# 480   OBSERVATIONAL       False         2012-10-03     2012-10        2015-02
# 481   OBSERVATIONAL       False         2014-08-12  2014-10-23     2017-03-01
#
#          pmid     type                                           citation
# 0         NaN      NaN                                                NaN
# 1         NaN      NaN                                                NaN
# 2         NaN      NaN                                                NaN
# 3         NaN      NaN                                                NaN
# 4         NaN      NaN                                                NaN
# ..        ...      ...                                                ...
# 477       NaN      NaN                                                NaN
# 478  34611902  DERIVED  Hartmann-Boyce J, Theodoulou A, Farley A, Haje...
# 479  29329763  DERIVED  Mercie P, Arsandaux J, Katlama C, Ferret S, Be...
# 480       NaN      NaN                                                NaN
# 481       NaN      NaN                                                NaN
#
# [482 rows x 13 columns]

# %% [markdown]
# ***On reconstruit l'index :***

# %%
# df_studies_v2.set_index('NCTId', inplace = True)

# %% [markdown]
# ***On précise les types :***

# %%
df_ct = df_ct.convert_dtypes()
# df_ct = df_ct.astype({"OverallStatus" : 'category', "StudyType" : 'category', "type": 'category',})
df_ct = df_ct.astype({'OverallStatus': 'category', 'StudyType': 'category'})
df_ct.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 482 entries, 0 to 481
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   NCTId               482 non-null    string
#  1   BriefTitle          482 non-null    string
#  2   LeadSponsorName     482 non-null    string
#  3   CollaboratorName    217 non-null    string
#  4   OverallStatus       482 non-null    category
#  5   StudyType           482 non-null    category
#  6   HasResults          482 non-null    boolean
#  7   StudyFirstPostDate  482 non-null    string
#  8   StartDate           482 non-null    string
#  9   CompletionDate      482 non-null    string
#  10  pmid                364 non-null    string
#  11  type                364 non-null    string
#  12  citation            364 non-null    string
# dtypes: boolean(1), category(2), string(10)
# memory usage: 39.9 KB

# %%
df_ct
# Out:
#            NCTId                                         BriefTitle  \
# 0    NCT02081066  Identification of CETP as a Marker of Atherosc...
# 1    NCT05199831  Situational Analysis of HIV-related Disability...
# 2    NCT01895920  Viral Biofilms: Hijacking T Cell Extracellular...
# 3    NCT02116374  Physiopathology Study of the Microbiota Biodiv...
# 4    NCT02107365  Therapy With Asunaprevir, Daclatasvir, Ribavir...
# ..           ...                                                ...
# 477  NCT02052271  Experimental Therapeutics in Essential Tremor ...
# 478  NCT00918307  Efficacy and Safety of Varenicline Among HIV-i...
# 479  NCT00918307  Efficacy and Safety of Varenicline Among HIV-i...
# 480  NCT01698411  Study of the Influence of Sleep on Hemodynamic...
# 481  NCT02214511  Biomarkers of Social Sensitivity in Major Depr...
#
#                                        LeadSponsorName  \
# 0    Institut National de la Santé Et de la Recherc...
# 1     Programme PAC-CI, Site ANRS-MIE de Côte d'Ivoire
# 2                   ANRS, Emerging Infectious Diseases
# 3                   ANRS, Emerging Infectious Diseases
# 4                   ANRS, Emerging Infectious Diseases
# ..                                                 ...
# 477  Institut National de la Santé Et de la Recherc...
# 478                 ANRS, Emerging Infectious Diseases
# 479                 ANRS, Emerging Infectious Diseases
# 480  Institut National de la Santé Et de la Recherc...
# 481  Institut National de la Santé Et de la Recherc...
#
#                                       CollaboratorName OverallStatus  \
# 0                                                 <NA>     COMPLETED
# 1    Institute of Research for Development, France ...     COMPLETED
# 2                                                 <NA>     COMPLETED
# 3                                                 <NA>     COMPLETED
# 4                                 Bristol-Myers Squibb     COMPLETED
# ..                                                 ...           ...
# 477                                               <NA>     COMPLETED
# 478                                             Pfizer     COMPLETED
# 479                                             Pfizer     COMPLETED
# 480                                               <NA>     COMPLETED
# 481                                               <NA>     COMPLETED
#
#           StudyType  HasResults StudyFirstPostDate   StartDate CompletionDate  \
# 0    INTERVENTIONAL       False         2014-03-07  2014-09-25        2020-09
# 1     OBSERVATIONAL       False         2022-01-20  2021-02-05     2022-08-10
# 2    INTERVENTIONAL       False         2013-07-11     2013-01        2018-02
# 3     OBSERVATIONAL       False         2014-04-16     2014-12        2016-06
# 4    INTERVENTIONAL       False         2014-04-08     2013-11        2015-04
# ..              ...         ...                ...         ...            ...
# 477  INTERVENTIONAL       False         2014-02-03  2014-06-03     2018-03-27
# 478  INTERVENTIONAL       False         2009-06-11     2009-10        2014-07
# 479  INTERVENTIONAL       False         2009-06-11     2009-10        2014-07
# 480   OBSERVATIONAL       False         2012-10-03     2012-10        2015-02
# 481   OBSERVATIONAL       False         2014-08-12  2014-10-23     2017-03-01
#
#          pmid     type                                           citation
# 0        <NA>     <NA>                                               <NA>
# 1        <NA>     <NA>                                               <NA>
# 2        <NA>     <NA>                                               <NA>
# 3        <NA>     <NA>                                               <NA>
# 4        <NA>     <NA>                                               <NA>
# ..        ...      ...                                                ...
# 477      <NA>     <NA>                                               <NA>
# 478  34611902  DERIVED  Hartmann-Boyce J, Theodoulou A, Farley A, Haje...
# 479  29329763  DERIVED  Mercie P, Arsandaux J, Katlama C, Ferret S, Be...
# 480      <NA>     <NA>                                               <NA>
# 481      <NA>     <NA>                                               <NA>
#
# [482 rows x 13 columns]

# %% [markdown]
# #### Export en CSV :

# %%
# df_ct.to_csv('Data/outputs/extract_CT_api_v2.csv', sep=";", encoding='utf-8-sig')
df_ct.to_csv(
    'Data/outputs/extract_CT_api_v2.csv',
    sep=';',
    index=False,
    encoding='utf-8-sig',
)

# %% [markdown]
# # PubMed

# %% [markdown]
# ### Utilisation d'une clé pour l'API Pubmed :

# %% [markdown]
# Il est recommandé d'utiliser une clé pour accéder à l'API Pubmed, ce qui permet de lancer jusqu'à 10 requêtes par seconde.
# Sans clé, la limite est de 3 requêtes par seconde.
#
# > E-utils users are allowed 3 requests/second without an API key. Create an API key to increase your e-utils limit to 10 requests/second.
#
# **En pratique, l'API Pubmed étant beaucoup plus lente (~1 requête par seconde), cela ne semble pas changer grand chose.**
#
# Pour récupérer sa clé, se rendre sur la page en étant loggué:
# https://account.ncbi.nlm.nih.gov/settings/
#
# Une fois la clé récupérée, l'ajouter aux variables d'environnement avec la commande suivante:
#
# **Windows :**
#
# `setx NCBI_API_KEY “123456"`
#
# **Linux/MacOS :**
#
# `export NCBI_API_KEY = 123456`

# %%
import os

assert os.getenv('NCBI_API_KEY', None) is not None

# %% [markdown]
# ### Installer metapub :
# - Dans Conda Navigator, se placer dans le meme environnement que celui qui execute Jupyter
# - Lancer Powershell Prompt dans cet environnement
# - Taper la commande suivante :  `pip install metapub`

# %%
from metapub import PubMedFetcher
from metapub.exceptions import InvalidPMID

fetch = PubMedFetcher(cachedir='./.cache/')

# %% [markdown]
# ### Récupération des PMIDs via PubMed:

# %% [markdown]
# Pour chaque NCTId de CT, on récupère les PMIDs des publications associées via PubMed:

# %%
# Liste unique des NCTId extraits de ClinicalTrial
nctid_array = df_ct.loc[:, 'NCTId'].unique()

pmids_pubmed_dict = {}
for i, nctid in enumerate(nctid_array):
    # Display the progress on a single line
    print(f'\r{i+1}/{len(nctid_array)}...', end='', flush=True)

    pmids = [pmid for pmid in fetch.pmids_for_query(nctid)]
    pmids_pubmed_dict[nctid] = set(pmids)
# Out:
# 200/200...

# %%
pmids_pubmed_dict
# Out:
# {'NCT01490489': set(),
#  'NCT02542891': {'27488181', '34874888'},
#  'NCT04780191': set(),
#  'NCT03546127': set(),
#  'NCT02078076': set(),
#  'NCT02014727': {'28947345'},
#  'NCT02486731': set(),
#  'NCT05311865': {'36438274', '37795682'},
#  'NCT04008927': {'35774932'},
#  'NCT01895920': set(),
#  'NCT02650427': set(),
#  'NCT02273765': {'33667406'},
#  'NCT02497274': set(),
#  'NCT02100774': {'24808487', '26063065', '27798339'},
#  'NCT02592174': {'31755936'},
#  'NCT02099474': {'32661003'},
#  'NCT04808986': set(),
#  'NCT04470648': set(),
#  'NCT01207986': set(),
#  'NCT03078439': {'38408861'},
#  'NCT02573948': set(),
#  'NCT01693848': set(),
#  'NCT00136630': {'22491195', '24780882'},
#  'NCT03459157': {'34048794'},
#  'NCT00670839': {'26257021'},
#  'NCT04315948': {'32304640',
#   '32958495',
#   '33264556',
#   '34048876',
#   '34350582',
#   '34473343',
#   '34534511',
#   '35233617',
#   '35512728',
#   '36695483',
#   '37728045',
#   '38552208'},
#  'NCT02453048': {'31945015', '32687804'},
#  'NCT03446430': set(),
#  'NCT02987530': set(),
#  'NCT01620957': set(),
#  'NCT05040048': set(),
#  'NCT00640263': {'23039034',
#   '26603917',
#   '27895016',
#   '28469697',
#   '30814028',
#   '31633158',
#   '31994250',
#   '32067040',
#   '32228542',
#   '32991450',
#   '34425825'},
#  'NCT03235258': set(),
#  'NCT03071458': set(),
#  'NCT01693835': set(),
#  'NCT01713335': set(),
#  'NCT01579435': set(),
#  'NCT01033760': {'25701561', '28708873'},
#  'NCT01127204': {'27015798',
#   '28434406',
#   '28453240',
#   '28483965',
#   '28800382',
#   '31334298',
#   '34723858'},
#  'NCT02267304': set(),
#  'NCT03642704': set(),
#  'NCT02777229': {'31339676', '33010241', '33355914', '37851566', '38156046'},
#  'NCT03298360': set(),
#  'NCT01335529': {'27077673'},
#  'NCT03671291': set(),
#  'NCT01771562': {'27881690', '30081838'},
#  'NCT01882062': {'25568297'},
#  'NCT01022476': set(),
#  'NCT01508494': set(),
#  'NCT01066962': {'25103176', '26520926', '30365452', '33794182'},
#  'NCT01703962': {'37668523'},
#  'NCT05349162': {'36735263'},
#  'NCT00658346': {'31063537'},
#  'NCT02496312': set(),
#  'NCT01226446': {'25987791'},
#  'NCT03047967': set(),
#  'NCT01552044': set(),
#  'NCT03109067': set(),
#  'NCT01453192': {'30688008'},
#  'NCT01473472': {'26624850', '28747274', '29229440', '31784343', '36601747'},
#  'NCT04484740': set(),
#  'NCT02384967': {'29905808'},
#  'NCT04849767': {'34916316'},
#  'NCT00323804': set(),
#  'NCT02073604': set(),
#  'NCT01546181': {'23620431',
#   '24406779',
#   '24576889',
#   '25077537',
#   '26418443',
#   '26523388',
#   '30010022'},
#  'NCT02566148': {'29307383', '29437866', '29982518'},
#  'NCT02107365': set(),
#  'NCT02081066': set(),
#  'NCT02116374': set(),
#  'NCT05199831': set(),
#  'NCT01426243': {'26314624', '30096071'},
#  'NCT03150290': set(),
#  'NCT03519503': set(),
#  'NCT02113943': set(),
#  'NCT02212379': {'31269208'},
#  'NCT02126384': set(),
#  'NCT01605890': {'29590335'},
#  'NCT02738502': set(),
#  'NCT01432821': set(),
#  'NCT01514890': {'23669289', '24704719', '25556540'},
#  'NCT02992184': {'29615488'},
#  'NCT02071784': set(),
#  'NCT02323308': set(),
#  'NCT01696708': {'25568297'},
#  'NCT02314208': set(),
#  'NCT04133012': set(),
#  'NCT01874808': set(),
#  'NCT04945655': {'35332045'},
#  'NCT01348308': {'32040959'},
#  'NCT01509508': {'23880306',
#   '25880823',
#   '27504637',
#   '28329393',
#   '29199100',
#   '29890048',
#   '30027600',
#   '30321314',
#   '30412926',
#   '31637821',
#   '32970730'},
#  'NCT01555450': {'28823681', '29909873'},
#  'NCT01942655': set(),
#  'NCT03652090': set(),
#  'NCT03870438': {'38484756'},
#  'NCT02469350': {'29636105'},
#  'NCT04824638': set(),
#  'NCT03335995': {'32026446', '37497675'},
#  'NCT02488395': set(),
#  'NCT01647295': set(),
#  'NCT00946595': {'29767684', '30968368'},
#  'NCT01332955': {'25139963'},
#  'NCT01525472': set(),
#  'NCT01493934': set(),
#  'NCT03831906': {'32853411', '33743621', '36395782'},
#  'NCT02073630': set(),
#  'NCT02428816': set(),
#  'NCT02051413': set(),
#  'NCT01779713': {'30354977'},
#  'NCT02405013': {'36686592'},
#  'NCT01801618': {'29662875'},
#  'NCT02886416': set(),
#  'NCT04684758': set(),
#  'NCT02978924': set(),
#  'NCT04631224': set(),
#  'NCT01164436': set(),
#  'NCT00604149': set(),
#  'NCT01899196': set(),
#  'NCT02057796': {'32558469', '36883573'},
#  'NCT02527096': set(),
#  'NCT03537196': {'33208326'},
#  'NCT02192658': {'26846895'},
#  'NCT02626286': {'33753460', '34022820', '34352834'},
#  'NCT02160119': set(),
#  'NCT06260319': set(),
#  'NCT01592175': set(),
#  'NCT03005652': {'33873195', '35853750', '36068621', '38100477'},
#  'NCT02647632': {'29077864'},
#  'NCT02236832': set(),
#  'NCT01842919': set(),
#  'NCT04120415': set(),
#  'NCT02125500': set(),
#  'NCT01905059': {'28566227'},
#  'NCT02542800': set(),
#  'NCT02038842': set(),
#  'NCT00265642': set(),
#  'NCT03193099': set(),
#  'NCT01094899': set(),
#  'NCT01569399': set(),
#  'NCT00928187': {'31273686'},
#  'NCT02093754': set(),
#  'NCT02408354': {'28969699'},
#  'NCT00116454': set(),
#  'NCT01842477': set(),
#  'NCT02172677': set(),
#  'NCT02014883': {'26536893'},
#  'NCT02960698': set(),
#  'NCT00495651': {'23639243',
#   '24985779',
#   '25330161',
#   '26193126',
#   '29020361',
#   '29297443',
#   '35093007'},
#  'NCT02329054': {'26930627', '28231247'},
#  'NCT05472051': set(),
#  'NCT01037777': {'23707147', '24780882', '32822634', '35264424'},
#  'NCT02481453': {'38273639'},
#  'NCT01688453': {'29696179',
#   '29776897',
#   '29934380',
#   '32097754',
#   '34087324',
#   '35272723'},
#  'NCT04842851': set(),
#  'NCT02658253': {'32032566', '33717176'},
#  'NCT02027051': set(),
#  'NCT04409405': {'38043556'},
#  'NCT03137797': set(),
#  'NCT01880151': set(),
#  'NCT02027233': set(),
#  'NCT02721745': set(),
#  'NCT03324633': {'30570526', '32798585', '34212476'},
#  'NCT03954054': {'35012570'},
#  'NCT00918307': {'29329763', '34611902'},
#  'NCT02656407': set(),
#  'NCT01693861': set(),
#  'NCT02157311': {'29186458'},
#  'NCT04288128': {'38419144', '38421662'},
#  'NCT02214511': set(),
#  'NCT02931097': set(),
#  'NCT01269632': set(),
#  'NCT02567071': set(),
#  'NCT04396288': set(),
#  'NCT01534728': set(),
#  'NCT02833961': {'36318030'},
#  'NCT02052271': set(),
#  'NCT05090956': set(),
#  'NCT01463956': set(),
#  'NCT00445575': set(),
#  'NCT01779752': set(),
#  'NCT02906137': set(),
#  'NCT02916732': {'29539287', '33657112'},
#  'NCT02102737': set(),
#  'NCT04265742': set(),
#  'NCT01725542': {'25977266'},
#  'NCT01917175': set(),
#  'NCT04392388': {'34293141'},
#  'NCT01331811': {'26908804', '29174612', '30689814', '31455612'},
#  'NCT02150993': set(),
#  'NCT01698411': set(),
#  'NCT02082171': set(),
#  'NCT03215732': {'31320358', '37143029'},
#  'NCT01495897': set(),
#  'NCT01492985': {'33568510'},
#  'NCT02453061': {'31381524'},
#  'NCT02346409': set(),
#  'NCT02976298': set(),
#  'NCT02101398': set(),
#  'NCT01089387': {'25974235', '26439886', '28753830'},
#  'NCT01952587': set()}

# %% [markdown]
# **On veut fusionner la liste PMIDs que l'on vient de récupérer sur PubMed, à la liste des PMIDs déjà récupérés via CT.**

# %% [markdown]
# On met les PMIDs de CT sous la même forme:

# %%
pmids_ct_dict = {}
for nctid in nctid_array:
    pmids = df_ct[df_ct.loc[:, 'NCTId'] == nctid].loc[:, 'pmid'].dropna()
    pmids_ct_dict[nctid] = set(pmids)
pmids_ct_dict
# Out:
# {'NCT01490489': {'16384869', '17531315', '19602057'},
#  'NCT02542891': {'27488181', '34874888'},
#  'NCT04780191': {'32232101'},
#  'NCT03546127': set(),
#  'NCT02078076': set(),
#  'NCT02014727': {'28947345'},
#  'NCT02486731': set(),
#  'NCT05311865': set(),
#  'NCT04008927': {'22310560',
#   '26806260',
#   '27168667',
#   '27178119',
#   '27537841',
#   '28004616',
#   '29432973',
#   '35774932'},
#  'NCT01895920': set(),
#  'NCT02650427': set(),
#  'NCT02273765': {'33667406'},
#  'NCT02497274': set(),
#  'NCT02100774': {'21957063', '24808487', '26063065', '27798339'},
#  'NCT02592174': {'31755936'},
#  'NCT02099474': {'32661003'},
#  'NCT04808986': set(),
#  'NCT04470648': {'31978945',
#   '31995857',
#   '32046819',
#   '32070465',
#   '32109013',
#   '32224310',
#   '32338732',
#   '32371096'},
#  'NCT01207986': set(),
#  'NCT03078439': set(),
#  'NCT02573948': {'25540950',
#   '26032121',
#   '26050614',
#   '26075647',
#   '26080690',
#   '27006257',
#   '27178119',
#   '28612212',
#   '28800503'},
#  'NCT01693848': set(),
#  'NCT00136630': {'15313841',
#   '15365159',
#   '16055926',
#   '16193476',
#   '16501573',
#   '17098887',
#   '17597328',
#   '17605047',
#   '17957230',
#   '18378516',
#   '18853458',
#   '22491195',
#   '24780882'},
#  'NCT03459157': {'34048794'},
#  'NCT00670839': {'26257021'},
#  'NCT04315948': {'32304640',
#   '32473020',
#   '32958495',
#   '33089306',
#   '33264556',
#   '34048876',
#   '34350582',
#   '34473343',
#   '34534511',
#   '34763056',
#   '35233617',
#   '35512728',
#   '35533972',
#   '35623577',
#   '35643099',
#   '36680782',
#   '36828006',
#   '37269068',
#   '37302469',
#   '37728045'},
#  'NCT02453048': {'18762220',
#   '19625486',
#   '20107007',
#   '20419113',
#   '20708998',
#   '21147936',
#   '21430219',
#   '22814407',
#   '24421886',
#   '24793938',
#   '24950361',
#   '31945015',
#   '32687804'},
#  'NCT03446430': set(),
#  'NCT02987530': set(),
#  'NCT01620957': set(),
#  'NCT05040048': set(),
#  'NCT00640263': {'17825642',
#   '23039034',
#   '26603917',
#   '27895016',
#   '28469697',
#   '30814028',
#   '31633158',
#   '31994250',
#   '32067040',
#   '32228542',
#   '32991450'},
#  'NCT03235258': {'17712765',
#   '18614870',
#   '19194272',
#   '20536367',
#   '21511330',
#   '21971357',
#   '22198788',
#   '22427678',
#   '24253249',
#   '24705410',
#   '24945880',
#   '26762993'},
#  'NCT03071458': set(),
#  'NCT01693835': set(),
#  'NCT01713335': set(),
#  'NCT01579435': set(),
#  'NCT01033760': {'25701561', '28708873'},
#  'NCT01127204': {'27015798',
#   '28434406',
#   '28453240',
#   '28483965',
#   '28800382',
#   '31334298',
#   '34723858'},
#  'NCT02267304': set(),
#  'NCT03642704': set(),
#  'NCT02777229': {'31339676', '33010241', '33355914'},
#  'NCT03298360': set(),
#  'NCT01335529': {'27077673'},
#  'NCT03671291': set(),
#  'NCT01771562': {'27881690', '30081838'},
#  'NCT01882062': {'25568297'},
#  'NCT01022476': set(),
#  'NCT01508494': set(),
#  'NCT01066962': {'25103176', '26520926', '30365452', '33794182'},
#  'NCT01703962': set(),
#  'NCT05349162': set(),
#  'NCT00658346': {'31063537'},
#  'NCT02496312': {'10436334',
#   '10678322',
#   '10941190',
#   '12461757',
#   '15897497',
#   '16207933',
#   '16421064',
#   '17027767',
#   '17131230',
#   '1821241',
#   '18307266',
#   '19533496',
#   '19713543',
#   '19933975',
#   '21895376'},
#  'NCT01226446': {'25987791'},
#  'NCT03047967': set(),
#  'NCT01552044': set(),
#  'NCT03109067': set(),
#  'NCT01453192': set(),
#  'NCT01473472': {'26624850', '28747274', '29229440', '31784343'},
#  'NCT04484740': set(),
#  'NCT02384967': {'29905808'},
#  'NCT04849767': {'34916316'},
#  'NCT00323804': set(),
#  'NCT02073604': set(),
#  'NCT01546181': {'23620431',
#   '24337723',
#   '24406779',
#   '24576889',
#   '25077537',
#   '25284764',
#   '25997175',
#   '26344727',
#   '26418443',
#   '26523388',
#   '27009576',
#   '27065002',
#   '28900746',
#   '29369084',
#   '30010022',
#   '30947025',
#   '31568064',
#   '31573376',
#   '31922497',
#   '31972545'},
#  'NCT02566148': {'29307383', '29437866', '29982518'},
#  'NCT02107365': set(),
#  'NCT02081066': set(),
#  'NCT02116374': set(),
#  'NCT05199831': set(),
#  'NCT01426243': {'30096071'},
#  'NCT03150290': set(),
#  'NCT03519503': {'21602695', '22814853', '26603917'},
#  'NCT02113943': set(),
#  'NCT02212379': set(),
#  'NCT02126384': set(),
#  'NCT01605890': {'29590335'},
#  'NCT02738502': {'22160145',
#   '22848481',
#   '23559464',
#   '23766338',
#   '26197844',
#   '26709605',
#   '26854809'},
#  'NCT01432821': {'12914551', '15037514', '15249613', '15777732', '2271377'},
#  'NCT01514890': {'23669289', '24704719', '25556540'},
#  'NCT02992184': {'29615488'},
#  'NCT02071784': set(),
#  'NCT02323308': set(),
#  'NCT01696708': {'25568297'},
#  'NCT02314208': set(),
#  'NCT04133012': set(),
#  'NCT01874808': set(),
#  'NCT04945655': {'35332045'},
#  'NCT01348308': {'32040959'},
#  'NCT01509508': {'23880306',
#   '25880823',
#   '27504637',
#   '28329393',
#   '29199100',
#   '29890048',
#   '30027600',
#   '30321314',
#   '30412926',
#   '31637821',
#   '32970730'},
#  'NCT01555450': {'21256688', '28823681', '29909873'},
#  'NCT01942655': set(),
#  'NCT03652090': set(),
#  'NCT03870438': {'26603917', '33872801'},
#  'NCT02469350': {'29636105'},
#  'NCT04824638': set(),
#  'NCT03335995': {'32026446'},
#  'NCT02488395': {'22639796', '23916713', '6774653'},
#  'NCT01647295': set(),
#  'NCT00946595': {'29767684', '30968368'},
#  'NCT01332955': {'25139963'},
#  'NCT01525472': set(),
#  'NCT01493934': set(),
#  'NCT03831906': {'32853411', '33743621', '36395782'},
#  'NCT02073630': set(),
#  'NCT02428816': set(),
#  'NCT02051413': set(),
#  'NCT01779713': {'30354977'},
#  'NCT02405013': set(),
#  'NCT01801618': set(),
#  'NCT02886416': set(),
#  'NCT04684758': set(),
#  'NCT02978924': set(),
#  'NCT04631224': set(),
#  'NCT01164436': set(),
#  'NCT00604149': set(),
#  'NCT01899196': set(),
#  'NCT02057796': {'32558469'},
#  'NCT02527096': set(),
#  'NCT03537196': {'19839502',
#   '20041309',
#   '20196807',
#   '20572071',
#   '22098550',
#   '22564041',
#   '22828983',
#   '23172780',
#   '23553643',
#   '23675659',
#   '23728143',
#   '23884064',
#   '25086286',
#   '25245939',
#   '25920094',
#   '26298331',
#   '27148964',
#   '27178119',
#   '27227200',
#   '27349488',
#   '27427455',
#   '27667367',
#   '33208326'},
#  'NCT02192658': {'26846895'},
#  'NCT02626286': {'33753460', '34022820', '34352834'},
#  'NCT02160119': set(),
#  'NCT06260319': set(),
#  'NCT01592175': set(),
#  'NCT03005652': {'33873195', '35853750', '36068621'},
#  'NCT02647632': {'29077864'},
#  'NCT02236832': set(),
#  'NCT01842919': set(),
#  'NCT04120415': set(),
#  'NCT02125500': set(),
#  'NCT01905059': {'16249701',
#   '16549962',
#   '17545707',
#   '18097218',
#   '18540803',
#   '20010070',
#   '20802297',
#   '20802298',
#   '21811554',
#   '21886816',
#   '22441252',
#   '22814125',
#   '23075703',
#   '28566227'},
#  'NCT02542800': set(),
#  'NCT02038842': set(),
#  'NCT00265642': set(),
#  'NCT03193099': set(),
#  'NCT01094899': set(),
#  'NCT01569399': set(),
#  'NCT00928187': {'31273686'},
#  'NCT02093754': set(),
#  'NCT02408354': {'28969699'},
#  'NCT00116454': set(),
#  'NCT01842477': set(),
#  'NCT02172677': set(),
#  'NCT02014883': {'26536893'},
#  'NCT02960698': set(),
#  'NCT00495651': {'23639243',
#   '24985779',
#   '25330161',
#   '26193126',
#   '29020361',
#   '29297443',
#   '35093007'},
#  'NCT02329054': {'25435054', '26930627', '27046271', '28231247'},
#  'NCT05472051': set(),
#  'NCT01037777': {'23707147', '24780882', '32822634', '35264424'},
#  'NCT02481453': {'20413309', '24975859'},
#  'NCT01688453': {'29696179', '29776897', '29934380', '32097754', '34087324'},
#  'NCT04842851': set(),
#  'NCT02658253': {'32032566', '33717176'},
#  'NCT02027051': set(),
#  'NCT04409405': set(),
#  'NCT03137797': {'22008658',
#   '22267473',
#   '23079802',
#   '23936509',
#   '24058636',
#   '24465584',
#   '25573889',
#   '26636578',
#   '27509048'},
#  'NCT01880151': set(),
#  'NCT02027233': set(),
#  'NCT02721745': set(),
#  'NCT03324633': {'20493576',
#   '20876416',
#   '20969743',
#   '21239121',
#   '21692942',
#   '21819472',
#   '21888878',
#   '21920402',
#   '22173166',
#   '22285372',
#   '22409788',
#   '22535683',
#   '22781224',
#   '23052829',
#   '23226258',
#   '23421419',
#   '23461846',
#   '23978720',
#   '24166726',
#   '24499953',
#   '24580042',
#   '25015913',
#   '25778750',
#   '26372388',
#   '26528903',
#   '27073179',
#   '27177169',
#   '27317796',
#   '27339598',
#   '28235612',
#   '28418984',
#   '28430385',
#   '28780609',
#   '28942916',
#   '30570526',
#   '32798585',
#   '34212476'},
#  'NCT03954054': {'35012570'},
#  'NCT00918307': {'29329763', '34611902'},
#  'NCT02656407': {'25955583'},
#  'NCT01693861': set(),
#  'NCT02157311': {'29186458'},
#  'NCT04288128': set(),
#  'NCT02214511': set(),
#  'NCT02931097': set(),
#  'NCT01269632': set(),
#  'NCT02567071': set(),
#  'NCT04396288': set(),
#  'NCT01534728': set(),
#  'NCT02833961': set(),
#  'NCT02052271': set(),
#  'NCT05090956': set(),
#  'NCT01463956': set(),
#  'NCT00445575': set(),
#  'NCT01779752': set(),
#  'NCT02906137': set(),
#  'NCT02916732': {'29539287', '33657112'},
#  'NCT02102737': set(),
#  'NCT04265742': set(),
#  'NCT01725542': {'25977266'},
#  'NCT01917175': set(),
#  'NCT04392388': set(),
#  'NCT01331811': {'26908804', '29174612', '30689814', '31455612'},
#  'NCT02150993': set(),
#  'NCT01698411': set(),
#  'NCT02082171': set(),
#  'NCT03215732': {'31320358'},
#  'NCT01495897': set(),
#  'NCT01492985': {'33568510'},
#  'NCT02453061': {'31381524'},
#  'NCT02346409': set(),
#  'NCT02976298': set(),
#  'NCT02101398': set(),
#  'NCT01089387': {'25974235', '28753830'},
#  'NCT01952587': set()}

# %% [markdown]
# Pour un NCTDId donné, on fait l'union des deux ensembles de PMIDs:

# %%
pmids_complete_dict = {}
for nctid in nctid_array:
    # L'ensemble des PMIds présents dans PubMed et CT
    pmids_complete_dict[nctid] = pmids_pubmed_dict[nctid] | pmids_ct_dict[nctid]
pmids_complete_dict
# Out:
# {'NCT01490489': {'16384869', '17531315', '19602057'},
#  'NCT02542891': {'27488181', '34874888'},
#  'NCT04780191': {'32232101'},
#  'NCT03546127': set(),
#  'NCT02078076': set(),
#  'NCT02014727': {'28947345'},
#  'NCT02486731': set(),
#  'NCT05311865': {'36438274', '37795682'},
#  'NCT04008927': {'22310560',
#   '26806260',
#   '27168667',
#   '27178119',
#   '27537841',
#   '28004616',
#   '29432973',
#   '35774932'},
#  'NCT01895920': set(),
#  'NCT02650427': set(),
#  'NCT02273765': {'33667406'},
#  'NCT02497274': set(),
#  'NCT02100774': {'21957063', '24808487', '26063065', '27798339'},
#  'NCT02592174': {'31755936'},
#  'NCT02099474': {'32661003'},
#  'NCT04808986': set(),
#  'NCT04470648': {'31978945',
#   '31995857',
#   '32046819',
#   '32070465',
#   '32109013',
#   '32224310',
#   '32338732',
#   '32371096'},
#  'NCT01207986': set(),
#  'NCT03078439': {'38408861'},
#  'NCT02573948': {'25540950',
#   '26032121',
#   '26050614',
#   '26075647',
#   '26080690',
#   '27006257',
#   '27178119',
#   '28612212',
#   '28800503'},
#  'NCT01693848': set(),
#  'NCT00136630': {'15313841',
#   '15365159',
#   '16055926',
#   '16193476',
#   '16501573',
#   '17098887',
#   '17597328',
#   '17605047',
#   '17957230',
#   '18378516',
#   '18853458',
#   '22491195',
#   '24780882'},
#  'NCT03459157': {'34048794'},
#  'NCT00670839': {'26257021'},
#  'NCT04315948': {'32304640',
#   '32473020',
#   '32958495',
#   '33089306',
#   '33264556',
#   '34048876',
#   '34350582',
#   '34473343',
#   '34534511',
#   '34763056',
#   '35233617',
#   '35512728',
#   '35533972',
#   '35623577',
#   '35643099',
#   '36680782',
#   '36695483',
#   '36828006',
#   '37269068',
#   '37302469',
#   '37728045',
#   '38552208'},
#  'NCT02453048': {'18762220',
#   '19625486',
#   '20107007',
#   '20419113',
#   '20708998',
#   '21147936',
#   '21430219',
#   '22814407',
#   '24421886',
#   '24793938',
#   '24950361',
#   '31945015',
#   '32687804'},
#  'NCT03446430': set(),
#  'NCT02987530': set(),
#  'NCT01620957': set(),
#  'NCT05040048': set(),
#  'NCT00640263': {'17825642',
#   '23039034',
#   '26603917',
#   '27895016',
#   '28469697',
#   '30814028',
#   '31633158',
#   '31994250',
#   '32067040',
#   '32228542',
#   '32991450',
#   '34425825'},
#  'NCT03235258': {'17712765',
#   '18614870',
#   '19194272',
#   '20536367',
#   '21511330',
#   '21971357',
#   '22198788',
#   '22427678',
#   '24253249',
#   '24705410',
#   '24945880',
#   '26762993'},
#  'NCT03071458': set(),
#  'NCT01693835': set(),
#  'NCT01713335': set(),
#  'NCT01579435': set(),
#  'NCT01033760': {'25701561', '28708873'},
#  'NCT01127204': {'27015798',
#   '28434406',
#   '28453240',
#   '28483965',
#   '28800382',
#   '31334298',
#   '34723858'},
#  'NCT02267304': set(),
#  'NCT03642704': set(),
#  'NCT02777229': {'31339676', '33010241', '33355914', '37851566', '38156046'},
#  'NCT03298360': set(),
#  'NCT01335529': {'27077673'},
#  'NCT03671291': set(),
#  'NCT01771562': {'27881690', '30081838'},
#  'NCT01882062': {'25568297'},
#  'NCT01022476': set(),
#  'NCT01508494': set(),
#  'NCT01066962': {'25103176', '26520926', '30365452', '33794182'},
#  'NCT01703962': {'37668523'},
#  'NCT05349162': {'36735263'},
#  'NCT00658346': {'31063537'},
#  'NCT02496312': {'10436334',
#   '10678322',
#   '10941190',
#   '12461757',
#   '15897497',
#   '16207933',
#   '16421064',
#   '17027767',
#   '17131230',
#   '1821241',
#   '18307266',
#   '19533496',
#   '19713543',
#   '19933975',
#   '21895376'},
#  'NCT01226446': {'25987791'},
#  'NCT03047967': set(),
#  'NCT01552044': set(),
#  'NCT03109067': set(),
#  'NCT01453192': {'30688008'},
#  'NCT01473472': {'26624850', '28747274', '29229440', '31784343', '36601747'},
#  'NCT04484740': set(),
#  'NCT02384967': {'29905808'},
#  'NCT04849767': {'34916316'},
#  'NCT00323804': set(),
#  'NCT02073604': set(),
#  'NCT01546181': {'23620431',
#   '24337723',
#   '24406779',
#   '24576889',
#   '25077537',
#   '25284764',
#   '25997175',
#   '26344727',
#   '26418443',
#   '26523388',
#   '27009576',
#   '27065002',
#   '28900746',
#   '29369084',
#   '30010022',
#   '30947025',
#   '31568064',
#   '31573376',
#   '31922497',
#   '31972545'},
#  'NCT02566148': {'29307383', '29437866', '29982518'},
#  'NCT02107365': set(),
#  'NCT02081066': set(),
#  'NCT02116374': set(),
#  'NCT05199831': set(),
#  'NCT01426243': {'26314624', '30096071'},
#  'NCT03150290': set(),
#  'NCT03519503': {'21602695', '22814853', '26603917'},
#  'NCT02113943': set(),
#  'NCT02212379': {'31269208'},
#  'NCT02126384': set(),
#  'NCT01605890': {'29590335'},
#  'NCT02738502': {'22160145',
#   '22848481',
#   '23559464',
#   '23766338',
#   '26197844',
#   '26709605',
#   '26854809'},
#  'NCT01432821': {'12914551', '15037514', '15249613', '15777732', '2271377'},
#  'NCT01514890': {'23669289', '24704719', '25556540'},
#  'NCT02992184': {'29615488'},
#  'NCT02071784': set(),
#  'NCT02323308': set(),
#  'NCT01696708': {'25568297'},
#  'NCT02314208': set(),
#  'NCT04133012': set(),
#  'NCT01874808': set(),
#  'NCT04945655': {'35332045'},
#  'NCT01348308': {'32040959'},
#  'NCT01509508': {'23880306',
#   '25880823',
#   '27504637',
#   '28329393',
#   '29199100',
#   '29890048',
#   '30027600',
#   '30321314',
#   '30412926',
#   '31637821',
#   '32970730'},
#  'NCT01555450': {'21256688', '28823681', '29909873'},
#  'NCT01942655': set(),
#  'NCT03652090': set(),
#  'NCT03870438': {'26603917', '33872801', '38484756'},
#  'NCT02469350': {'29636105'},
#  'NCT04824638': set(),
#  'NCT03335995': {'32026446', '37497675'},
#  'NCT02488395': {'22639796', '23916713', '6774653'},
#  'NCT01647295': set(),
#  'NCT00946595': {'29767684', '30968368'},
#  'NCT01332955': {'25139963'},
#  'NCT01525472': set(),
#  'NCT01493934': set(),
#  'NCT03831906': {'32853411', '33743621', '36395782'},
#  'NCT02073630': set(),
#  'NCT02428816': set(),
#  'NCT02051413': set(),
#  'NCT01779713': {'30354977'},
#  'NCT02405013': {'36686592'},
#  'NCT01801618': {'29662875'},
#  'NCT02886416': set(),
#  'NCT04684758': set(),
#  'NCT02978924': set(),
#  'NCT04631224': set(),
#  'NCT01164436': set(),
#  'NCT00604149': set(),
#  'NCT01899196': set(),
#  'NCT02057796': {'32558469', '36883573'},
#  'NCT02527096': set(),
#  'NCT03537196': {'19839502',
#   '20041309',
#   '20196807',
#   '20572071',
#   '22098550',
#   '22564041',
#   '22828983',
#   '23172780',
#   '23553643',
#   '23675659',
#   '23728143',
#   '23884064',
#   '25086286',
#   '25245939',
#   '25920094',
#   '26298331',
#   '27148964',
#   '27178119',
#   '27227200',
#   '27349488',
#   '27427455',
#   '27667367',
#   '33208326'},
#  'NCT02192658': {'26846895'},
#  'NCT02626286': {'33753460', '34022820', '34352834'},
#  'NCT02160119': set(),
#  'NCT06260319': set(),
#  'NCT01592175': set(),
#  'NCT03005652': {'33873195', '35853750', '36068621', '38100477'},
#  'NCT02647632': {'29077864'},
#  'NCT02236832': set(),
#  'NCT01842919': set(),
#  'NCT04120415': set(),
#  'NCT02125500': set(),
#  'NCT01905059': {'16249701',
#   '16549962',
#   '17545707',
#   '18097218',
#   '18540803',
#   '20010070',
#   '20802297',
#   '20802298',
#   '21811554',
#   '21886816',
#   '22441252',
#   '22814125',
#   '23075703',
#   '28566227'},
#  'NCT02542800': set(),
#  'NCT02038842': set(),
#  'NCT00265642': set(),
#  'NCT03193099': set(),
#  'NCT01094899': set(),
#  'NCT01569399': set(),
#  'NCT00928187': {'31273686'},
#  'NCT02093754': set(),
#  'NCT02408354': {'28969699'},
#  'NCT00116454': set(),
#  'NCT01842477': set(),
#  'NCT02172677': set(),
#  'NCT02014883': {'26536893'},
#  'NCT02960698': set(),
#  'NCT00495651': {'23639243',
#   '24985779',
#   '25330161',
#   '26193126',
#   '29020361',
#   '29297443',
#   '35093007'},
#  'NCT02329054': {'25435054', '26930627', '27046271', '28231247'},
#  'NCT05472051': set(),
#  'NCT01037777': {'23707147', '24780882', '32822634', '35264424'},
#  'NCT02481453': {'20413309', '24975859', '38273639'},
#  'NCT01688453': {'29696179',
#   '29776897',
#   '29934380',
#   '32097754',
#   '34087324',
#   '35272723'},
#  'NCT04842851': set(),
#  'NCT02658253': {'32032566', '33717176'},
#  'NCT02027051': set(),
#  'NCT04409405': {'38043556'},
#  'NCT03137797': {'22008658',
#   '22267473',
#   '23079802',
#   '23936509',
#   '24058636',
#   '24465584',
#   '25573889',
#   '26636578',
#   '27509048'},
#  'NCT01880151': set(),
#  'NCT02027233': set(),
#  'NCT02721745': set(),
#  'NCT03324633': {'20493576',
#   '20876416',
#   '20969743',
#   '21239121',
#   '21692942',
#   '21819472',
#   '21888878',
#   '21920402',
#   '22173166',
#   '22285372',
#   '22409788',
#   '22535683',
#   '22781224',
#   '23052829',
#   '23226258',
#   '23421419',
#   '23461846',
#   '23978720',
#   '24166726',
#   '24499953',
#   '24580042',
#   '25015913',
#   '25778750',
#   '26372388',
#   '26528903',
#   '27073179',
#   '27177169',
#   '27317796',
#   '27339598',
#   '28235612',
#   '28418984',
#   '28430385',
#   '28780609',
#   '28942916',
#   '30570526',
#   '32798585',
#   '34212476'},
#  'NCT03954054': {'35012570'},
#  'NCT00918307': {'29329763', '34611902'},
#  'NCT02656407': {'25955583'},
#  'NCT01693861': set(),
#  'NCT02157311': {'29186458'},
#  'NCT04288128': {'38419144', '38421662'},
#  'NCT02214511': set(),
#  'NCT02931097': set(),
#  'NCT01269632': set(),
#  'NCT02567071': set(),
#  'NCT04396288': set(),
#  'NCT01534728': set(),
#  'NCT02833961': {'36318030'},
#  'NCT02052271': set(),
#  'NCT05090956': set(),
#  'NCT01463956': set(),
#  'NCT00445575': set(),
#  'NCT01779752': set(),
#  'NCT02906137': set(),
#  'NCT02916732': {'29539287', '33657112'},
#  'NCT02102737': set(),
#  'NCT04265742': set(),
#  'NCT01725542': {'25977266'},
#  'NCT01917175': set(),
#  'NCT04392388': {'34293141'},
#  'NCT01331811': {'26908804', '29174612', '30689814', '31455612'},
#  'NCT02150993': set(),
#  'NCT01698411': set(),
#  'NCT02082171': set(),
#  'NCT03215732': {'31320358', '37143029'},
#  'NCT01495897': set(),
#  'NCT01492985': {'33568510'},
#  'NCT02453061': {'31381524'},
#  'NCT02346409': set(),
#  'NCT02976298': set(),
#  'NCT02101398': set(),
#  'NCT01089387': {'25974235', '26439886', '28753830'},
#  'NCT01952587': set()}

# %% [markdown]
# #### Verifications:

# %%
num_pmids_ct = sum((len(v) for v in pmids_ct_dict.values()))
print(f'Nombre total de publications issus de CT: {num_pmids_ct}')
# Out:
# Nombre total de publications issus de CT: 364

# %%
num_pmids_complete = sum((len(v) for v in pmids_complete_dict.values()))
print(f'Nombre total de publications après consultation PubMed: {num_pmids_complete}')
# Out:
# Nombre total de publications après consultation PubMed: 393

# %%
pmids_pubmed_only_dict = {}
for nctid in nctid_array:
    # L'ensemble des PMIds présents dans PubMed uniquement
    pmids_pubmed_only_dict[nctid] = pmids_pubmed_dict[nctid] - pmids_ct_dict[nctid]

# %%
num_pmids_pubmed_only = sum((len(v) for v in pmids_pubmed_only_dict.values()))
print(f'Nombre de nouveaux PMIDs trouvés via Pubmed: {num_pmids_pubmed_only}')
# Out:
# Nombre de nouveaux PMIDs trouvés via Pubmed: 29

# %%
assert num_pmids_complete - num_pmids_ct == num_pmids_pubmed_only

# %%
print('NCTId des nouveaux PMIDs trouvés via Pubmed:')
{k: v for k, v in pmids_pubmed_only_dict.items() if v != set()}
# Out:
# NCTId des nouveaux PMIDs trouvés via Pubmed:
# {'NCT05311865': {'36438274', '37795682'},
#  'NCT03078439': {'38408861'},
#  'NCT04315948': {'36695483', '38552208'},
#  'NCT00640263': {'34425825'},
#  'NCT02777229': {'37851566', '38156046'},
#  'NCT01703962': {'37668523'},
#  'NCT05349162': {'36735263'},
#  'NCT01453192': {'30688008'},
#  'NCT01473472': {'36601747'},
#  'NCT01426243': {'26314624'},
#  'NCT02212379': {'31269208'},
#  'NCT03870438': {'38484756'},
#  'NCT03335995': {'37497675'},
#  'NCT02405013': {'36686592'},
#  'NCT01801618': {'29662875'},
#  'NCT02057796': {'36883573'},
#  'NCT03005652': {'38100477'},
#  'NCT02481453': {'38273639'},
#  'NCT01688453': {'35272723'},
#  'NCT04409405': {'38043556'},
#  'NCT04288128': {'38419144', '38421662'},
#  'NCT02833961': {'36318030'},
#  'NCT04392388': {'34293141'},
#  'NCT03215732': {'37143029'},
#  'NCT01089387': {'26439886'}}

# %%
num_nctid_empty_ct = sum((1 for v in pmids_ct_dict.values() if v == set()))
print(f"Nombre d'études sans PMIDs issus de CT: {num_nctid_empty_ct}")
# Out:
# Nombre d'études sans PMIDs issus de CT: 118

# %%
num_nctid_empty_pubmed = sum((1 for v in pmids_complete_dict.values() if v == set()))
print(f"Nombre d'études sans PMIDs après consultation PubMed: {num_nctid_empty_pubmed}")
# Out:
# Nombre d'études sans PMIDs après consultation PubMed: 106

# %%
print("NCTIds qui n'avait aucun PMIDs sous CT, mais enrichis via Pubmed:")
nctids_previously_empty = {k for k, v in pmids_ct_dict.items() if v == set()} - {k for k, v in pmids_complete_dict.items() if v == set()}
{k: pmids_complete_dict[k] for k in nctids_previously_empty}
# Out:
# NCTIds qui n'avait aucun PMIDs sous CT, mais enrichis via Pubmed:
# {'NCT03078439': {'38408861'},
#  'NCT04392388': {'34293141'},
#  'NCT01801618': {'29662875'},
#  'NCT01703962': {'37668523'},
#  'NCT04409405': {'38043556'},
#  'NCT05311865': {'36438274', '37795682'},
#  'NCT01453192': {'30688008'},
#  'NCT02212379': {'31269208'},
#  'NCT02833961': {'36318030'},
#  'NCT02405013': {'36686592'},
#  'NCT04288128': {'38419144', '38421662'},
#  'NCT05349162': {'36735263'}}

# %%
len(nctids_previously_empty)
# Out:
# 12

# %%
assert num_nctid_empty_ct - num_nctid_empty_pubmed == len(nctids_previously_empty)

# %% [markdown]
# ### Enrichissement des PMIDs via l'API Pubmed

# %% [markdown]
# Pour chaque PMID récupéré, on l'enrichit avec les données de PubMed tel que le titre, les auteurs, ...:

# %%
counter = 0  # To keep track of progress
book_counter = 0  # type different from 'article', get ignored
total_publications_list = []

# For each NTCID...
for nctid, pmids in pmids_complete_dict.items():
    pmids_list = []

    # We process each PMID...
    for pmid in pmids:

        # Display the progress on a single line
        print(f'\r{counter+1} / {num_pmids_complete}...', end='', flush=True)

        try:
            # Fetch article details from Pubmed
            article = fetch.article_by_pmid(pmid)

            # We are not interested by articles with type 'book'
            # TODO: book special case ?
            if article.pubmed_type == 'article':
                pmids_list.append(
                    {
                        'pmid': pmid,
                        'title': article.title,
                        'authors': article.authors_str.strip(),
                        'doi': article.doi,
                        'year': article.year,
                        'publication_types': list(article.publication_types.values()),
                        'citation': article.citation,
                    }
                )
            else:
                book_counter += 1
                book = (nctid, pmid)

            counter += 1
        except InvalidPMID as e:
            print(f'\n{e}')

    publication_dict = {'NCTId': nctid, 'publications': pmids_list}

    total_publications_list.append(publication_dict)
# Out:
# 393 / 393...

# %%
print(f'Nb de publications avec un type différent d"article": {book_counter}')
print(book)
# Out:
# Nb de publications avec un type différent d"article": 1
# ('NCT03537196', '27227200')

# %%
# print(json.dumps(total_publications_list, indent=2))

# %%
# The number of NCTId didn't change
assert len(total_publications_list) == len(studies_list)

# %% [markdown]
# ### Import dans Pandas

# %%
df_pubmed = pd.DataFrame.from_records(total_publications_list)
df_pubmed
# Out:
#            NCTId                                       publications
# 0    NCT01490489  [{'pmid': '19602057', 'title': 'Role of EG-VEG...
# 1    NCT02542891  [{'pmid': '27488181', 'title': 'European COMPA...
# 2    NCT04780191  [{'pmid': '32232101', 'title': 'Non-invasive t...
# 3    NCT03546127                                                 []
# 4    NCT02078076                                                 []
# ..           ...                                                ...
# 195  NCT02346409                                                 []
# 196  NCT02976298                                                 []
# 197  NCT02101398                                                 []
# 198  NCT01089387  [{'pmid': '26439886', 'title': 'Safety of Intr...
# 199  NCT01952587                                                 []
#
# [200 rows x 2 columns]

# %% [markdown]
# #### On "explose" la colonne "publications":
#
# Pour chaque NCTId, la colonne 'publications' contient potentiellement une liste de plusieurs publications.
# Si par exemple, on a 3 publications, on veut se retrouver avec 3 lignes, chacune indexée par le même NCTId et contenant une unique publication.
#
# *Avant*:
# **`NCTId    Reference`**
# `NCT0001, [Pub1, Pub2, Pub3]`
#
# *Après*:
# **`NCTId    Reference`**
# `NCT0001,   Pub1`
# `NCT0001,   Pub2`
# `NCT0001,   Pub3`

# %%
df_pubmed = df_pubmed.explode('publications', ignore_index=True)
df_pubmed
# Out:
#            NCTId                                       publications
# 0    NCT01490489  {'pmid': '19602057', 'title': 'Role of EG-VEGF...
# 1    NCT01490489  {'pmid': '16384869', 'title': 'Expression and ...
# 2    NCT01490489  {'pmid': '17531315', 'title': 'Placental expre...
# 3    NCT02542891  {'pmid': '27488181', 'title': 'European COMPAR...
# 4    NCT02542891  {'pmid': '34874888', 'title': 'Examining the T...
# ..           ...                                                ...
# 493  NCT02101398                                                NaN
# 494  NCT01089387  {'pmid': '26439886', 'title': 'Safety of Intra...
# 495  NCT01089387  {'pmid': '28753830', 'title': 'Intracavernous ...
# 496  NCT01089387  {'pmid': '25974235', 'title': 'Mesenchymal ste...
# 497  NCT01952587                                                NaN
#
# [498 rows x 2 columns]

# %% [markdown]
# On vérifie que l'on a retrouvé plus de publications avec PubMed + CT que CT tout seul:

# %%
assert len(df_pubmed) >= len(df_ct)

# %% [markdown]
# Pour chaque NCTId, la colonne 'publications' contient maintenant un dictionnaire de la forme:
# `{
# "pmid": "17545707",
# "title": "Haematological ...",
# "authors": "Smith DJ; ...",
# }`
#
# Dont on veut extraire de nouvelles colonnes en utilant les clés du dictionnaire:
# **`pmid      title                 authors`**
# `17545707, "Haematological ...", "Smith DJ; ..."`

# %%
df_pubmed_publications = pd.json_normalize(df_pubmed.pop('publications'))
df_pubmed_publications
# Out:
#          pmid                                              title  \
# 0    19602057  Role of EG-VEGF in human placentation: Physiol...
# 1    16384869  Expression and oxygen regulation of endocrine ...
# 2    17531315  Placental expression of EG-VEGF and its recept...
# 3    27488181  European COMPARative Effectiveness research on...
# 4    34874888  Examining the Theoretical Framework of Behavio...
# ..        ...                                                ...
# 493       NaN                                                NaN
# 494  26439886  Safety of Intracavernous Bone Marrow-Mononucle...
# 495  28753830  Intracavernous Injections of Bone Marrow Monon...
# 496  25974235  Mesenchymal stem cell therapy for the treatmen...
# 497       NaN                                                NaN
#
#                                                authors  \
# 0    Hoffmann P; Saoudi Y; Benharouga M; Graham CH;...
# 1                      Hoffmann P; Feige JJ; Alfaidy N
# 2                      Hoffmann P; Feige JJ; Alfaidy N
# 3    Kleiboer A; Smit J; Bosmans J; Ruwaard J; Ande...
# 4    van Genugten CR; Schuurmans J; Hoogendoorn AW;...
# ..                                                 ...
# 493                                                NaN
# 494  Yiou R; Hamidou L; Birebent B; Bitari D; Lecor...
# 495  Yiou R; Hamidou L; Birebent B; Bitari D; Le Co...
# 496                    Khera M; Albersen M; Mulhall JP
# 497                                                NaN
#
#                                   doi  year  \
# 0    10.1111/j.1582-4934.2008.00554.x  2009
# 1                10.1210/en.2005-0912  2006
# 2      10.1016/j.placenta.2007.03.008  2007
# 3           10.1186/s13063-016-1511-1  2016
# 4                       10.2196/32007  2021
# ..                                ...   ...
# 493                               NaN   NaN
# 494      10.1016/j.eururo.2015.09.026  2016
# 495         10.1016/j.euf.2017.06.009  2017
# 496                 10.1111/jsm.12871  2015
# 497                               NaN   NaN
#
#                                      publication_types  \
# 0    [Journal Article, Research Support, Non-U.S. G...
# 1    [Journal Article, Research Support, Non-U.S. G...
# 2    [Journal Article, Research Support, Non-U.S. G...
# 3    [Equivalence Trial, Journal Article, Multicent...
# 4                                    [Journal Article]
# ..                                                 ...
# 493                                                NaN
# 494  [Journal Article, Research Support, Non-U.S. G...
# 495  [Clinical Trial, Phase I, Clinical Trial, Phas...
# 496                                  [Journal Article]
# 497                                                NaN
#
#                                               citation
# 0    Hoffmann P, et al. Role of EG-VEGF in human pl...
# 1    Hoffmann P, et al. Expression and oxygen regul...
# 2    Hoffmann P, et al. Placental expression of EG-...
# 3    Kleiboer A, et al. European COMPARative Effect...
# 4    van Genugten CR, et al. Examining the Theoreti...
# ..                                                 ...
# 493                                                NaN
# 494  Yiou R, et al. Safety of Intracavernous Bone M...
# 495  Yiou R, et al. Intracavernous Injections of Bo...
# 496  Khera M, et al. Mesenchymal stem cell therapy ...
# 497                                                NaN
#
# [498 rows x 7 columns]

# %% [markdown]
# On réassemble la dataFrame complète:

# %%
df_pubmed = df_pubmed.join(df_pubmed_publications)
df_pubmed
# Out:
#            NCTId      pmid                                              title  \
# 0    NCT01490489  19602057  Role of EG-VEGF in human placentation: Physiol...
# 1    NCT01490489  16384869  Expression and oxygen regulation of endocrine ...
# 2    NCT01490489  17531315  Placental expression of EG-VEGF and its recept...
# 3    NCT02542891  27488181  European COMPARative Effectiveness research on...
# 4    NCT02542891  34874888  Examining the Theoretical Framework of Behavio...
# ..           ...       ...                                                ...
# 493  NCT02101398       NaN                                                NaN
# 494  NCT01089387  26439886  Safety of Intracavernous Bone Marrow-Mononucle...
# 495  NCT01089387  28753830  Intracavernous Injections of Bone Marrow Monon...
# 496  NCT01089387  25974235  Mesenchymal stem cell therapy for the treatmen...
# 497  NCT01952587       NaN                                                NaN
#
#                                                authors  \
# 0    Hoffmann P; Saoudi Y; Benharouga M; Graham CH;...
# 1                      Hoffmann P; Feige JJ; Alfaidy N
# 2                      Hoffmann P; Feige JJ; Alfaidy N
# 3    Kleiboer A; Smit J; Bosmans J; Ruwaard J; Ande...
# 4    van Genugten CR; Schuurmans J; Hoogendoorn AW;...
# ..                                                 ...
# 493                                                NaN
# 494  Yiou R; Hamidou L; Birebent B; Bitari D; Lecor...
# 495  Yiou R; Hamidou L; Birebent B; Bitari D; Le Co...
# 496                    Khera M; Albersen M; Mulhall JP
# 497                                                NaN
#
#                                   doi  year  \
# 0    10.1111/j.1582-4934.2008.00554.x  2009
# 1                10.1210/en.2005-0912  2006
# 2      10.1016/j.placenta.2007.03.008  2007
# 3           10.1186/s13063-016-1511-1  2016
# 4                       10.2196/32007  2021
# ..                                ...   ...
# 493                               NaN   NaN
# 494      10.1016/j.eururo.2015.09.026  2016
# 495         10.1016/j.euf.2017.06.009  2017
# 496                 10.1111/jsm.12871  2015
# 497                               NaN   NaN
#
#                                      publication_types  \
# 0    [Journal Article, Research Support, Non-U.S. G...
# 1    [Journal Article, Research Support, Non-U.S. G...
# 2    [Journal Article, Research Support, Non-U.S. G...
# 3    [Equivalence Trial, Journal Article, Multicent...
# 4                                    [Journal Article]
# ..                                                 ...
# 493                                                NaN
# 494  [Journal Article, Research Support, Non-U.S. G...
# 495  [Clinical Trial, Phase I, Clinical Trial, Phas...
# 496                                  [Journal Article]
# 497                                                NaN
#
#                                               citation
# 0    Hoffmann P, et al. Role of EG-VEGF in human pl...
# 1    Hoffmann P, et al. Expression and oxygen regul...
# 2    Hoffmann P, et al. Placental expression of EG-...
# 3    Kleiboer A, et al. European COMPARative Effect...
# 4    van Genugten CR, et al. Examining the Theoreti...
# ..                                                 ...
# 493                                                NaN
# 494  Yiou R, et al. Safety of Intracavernous Bone M...
# 495  Yiou R, et al. Intracavernous Injections of Bo...
# 496  Khera M, et al. Mesenchymal stem cell therapy ...
# 497                                                NaN
#
# [498 rows x 8 columns]

# %% [markdown]
# ### Jointure des DataFrame de CT et Pubmed:

# %%
df_final = df_ct.merge(df_pubmed, on=['NCTId', 'pmid'], how='right')
df_final
# Out:
#            NCTId                                         BriefTitle  \
# 0    NCT01490489  EG-VEGF : Potential Marker of Pre-eclampsia an...
# 1    NCT01490489  EG-VEGF : Potential Marker of Pre-eclampsia an...
# 2    NCT01490489  EG-VEGF : Potential Marker of Pre-eclampsia an...
# 3    NCT02542891  European Comparative Effectiveness Research on...
# 4    NCT02542891  European Comparative Effectiveness Research on...
# ..           ...                                                ...
# 493  NCT02101398  Study of the Effect of Transcranial Stimulatio...
# 494  NCT01089387                                               <NA>
# 495  NCT01089387  Intracavernous Bone Marrow Stem-cell Injection...
# 496  NCT01089387  Intracavernous Bone Marrow Stem-cell Injection...
# 497  NCT01952587  X-linked Biological Response to HIV Sensing: t...
#
#                                        LeadSponsorName  \
# 0    Institut National de la Santé Et de la Recherc...
# 1    Institut National de la Santé Et de la Recherc...
# 2    Institut National de la Santé Et de la Recherc...
# 3    Institut National de la Santé Et de la Recherc...
# 4    Institut National de la Santé Et de la Recherc...
# ..                                                 ...
# 493  Institut National de la Santé Et de la Recherc...
# 494                                               <NA>
# 495  Institut National de la Santé Et de la Recherc...
# 496  Institut National de la Santé Et de la Recherc...
# 497                 ANRS, Emerging Infectious Diseases
#
#                                       CollaboratorName OverallStatus  \
# 0                                                 <NA>     COMPLETED
# 1                                                 <NA>     COMPLETED
# 2                                                 <NA>     COMPLETED
# 3    European Commission | Fondation FondaMental | ...     COMPLETED
# 4    European Commission | Fondation FondaMental | ...     COMPLETED
# ..                                                 ...           ...
# 493                                               <NA>     COMPLETED
# 494                                               <NA>          <NA>
# 495                                               <NA>     COMPLETED
# 496                                               <NA>     COMPLETED
# 497                                               <NA>     COMPLETED
#
#           StudyType  HasResults StudyFirstPostDate   StartDate CompletionDate  \
# 0    INTERVENTIONAL       False         2011-12-13  2011-07-11     2015-03-13
# 1    INTERVENTIONAL       False         2011-12-13  2011-07-11     2015-03-13
# 2    INTERVENTIONAL       False         2011-12-13  2011-07-11     2015-03-13
# 3    INTERVENTIONAL       False         2015-09-07     2015-09     2018-09-15
# 4    INTERVENTIONAL       False         2015-09-07     2015-09     2018-09-15
# ..              ...         ...                ...         ...            ...
# 493  INTERVENTIONAL       False         2014-04-02  2014-10-02        2016-07
# 494            <NA>        <NA>               <NA>        <NA>           <NA>
# 495  INTERVENTIONAL       False         2010-03-18     2010-05        2015-03
# 496  INTERVENTIONAL       False         2010-03-18     2010-05        2015-03
# 497  INTERVENTIONAL       False         2013-09-30     2013-11        2015-06
#
#          pmid     type                                         citation_x  \
# 0    19602057   RESULT  Hoffmann P, Saoudi Y, Benharouga M, Graham CH,...
# 1    16384869   RESULT  Hoffmann P, Feige JJ, Alfaidy N. Expression an...
# 2    17531315   RESULT  Hoffmann P, Feige JJ, Alfaidy N. Placental exp...
# 3    27488181  DERIVED  Kleiboer A, Smit J, Bosmans J, Ruwaard J, Ande...
# 4    34874888  DERIVED  van Genugten CR, Schuurmans J, Hoogendoorn AW,...
# ..        ...      ...                                                ...
# 493      <NA>     <NA>                                               <NA>
# 494  26439886     <NA>                                               <NA>
# 495  28753830  DERIVED  Yiou R, Hamidou L, Birebent B, Bitari D, Le Co...
# 496  25974235  DERIVED  Khera M, Albersen M, Mulhall JP. Mesenchymal s...
# 497      <NA>     <NA>                                               <NA>
#
#                                                  title  \
# 0    Role of EG-VEGF in human placentation: Physiol...
# 1    Expression and oxygen regulation of endocrine ...
# 2    Placental expression of EG-VEGF and its recept...
# 3    European COMPARative Effectiveness research on...
# 4    Examining the Theoretical Framework of Behavio...
# ..                                                 ...
# 493                                                NaN
# 494  Safety of Intracavernous Bone Marrow-Mononucle...
# 495  Intracavernous Injections of Bone Marrow Monon...
# 496  Mesenchymal stem cell therapy for the treatmen...
# 497                                                NaN
#
#                                                authors  \
# 0    Hoffmann P; Saoudi Y; Benharouga M; Graham CH;...
# 1                      Hoffmann P; Feige JJ; Alfaidy N
# 2                      Hoffmann P; Feige JJ; Alfaidy N
# 3    Kleiboer A; Smit J; Bosmans J; Ruwaard J; Ande...
# 4    van Genugten CR; Schuurmans J; Hoogendoorn AW;...
# ..                                                 ...
# 493                                                NaN
# 494  Yiou R; Hamidou L; Birebent B; Bitari D; Lecor...
# 495  Yiou R; Hamidou L; Birebent B; Bitari D; Le Co...
# 496                    Khera M; Albersen M; Mulhall JP
# 497                                                NaN
#
#                                   doi  year  \
# 0    10.1111/j.1582-4934.2008.00554.x  2009
# 1                10.1210/en.2005-0912  2006
# 2      10.1016/j.placenta.2007.03.008  2007
# 3           10.1186/s13063-016-1511-1  2016
# 4                       10.2196/32007  2021
# ..                                ...   ...
# 493                               NaN   NaN
# 494      10.1016/j.eururo.2015.09.026  2016
# 495         10.1016/j.euf.2017.06.009  2017
# 496                 10.1111/jsm.12871  2015
# 497                               NaN   NaN
#
#                                      publication_types  \
# 0    [Journal Article, Research Support, Non-U.S. G...
# 1    [Journal Article, Research Support, Non-U.S. G...
# 2    [Journal Article, Research Support, Non-U.S. G...
# 3    [Equivalence Trial, Journal Article, Multicent...
# 4                                    [Journal Article]
# ..                                                 ...
# 493                                                NaN
# 494  [Journal Article, Research Support, Non-U.S. G...
# 495  [Clinical Trial, Phase I, Clinical Trial, Phas...
# 496                                  [Journal Article]
# 497                                                NaN
#
#                                             citation_y
# 0    Hoffmann P, et al. Role of EG-VEGF in human pl...
# 1    Hoffmann P, et al. Expression and oxygen regul...
# 2    Hoffmann P, et al. Placental expression of EG-...
# 3    Kleiboer A, et al. European COMPARative Effect...
# 4    van Genugten CR, et al. Examining the Theoreti...
# ..                                                 ...
# 493                                                NaN
# 494  Yiou R, et al. Safety of Intracavernous Bone M...
# 495  Yiou R, et al. Intracavernous Injections of Bo...
# 496  Khera M, et al. Mesenchymal stem cell therapy ...
# 497                                                NaN
#
# [498 rows x 19 columns]

# %% [markdown]
# Suppression des colonnes 'citation':

# %%
df_final.drop(['citation_x', 'citation_y'], axis=1, inplace=True)

# %%
df_final
# Out:
#            NCTId                                         BriefTitle  \
# 0    NCT01490489  EG-VEGF : Potential Marker of Pre-eclampsia an...
# 1    NCT01490489  EG-VEGF : Potential Marker of Pre-eclampsia an...
# 2    NCT01490489  EG-VEGF : Potential Marker of Pre-eclampsia an...
# 3    NCT02542891  European Comparative Effectiveness Research on...
# 4    NCT02542891  European Comparative Effectiveness Research on...
# ..           ...                                                ...
# 493  NCT02101398  Study of the Effect of Transcranial Stimulatio...
# 494  NCT01089387                                               <NA>
# 495  NCT01089387  Intracavernous Bone Marrow Stem-cell Injection...
# 496  NCT01089387  Intracavernous Bone Marrow Stem-cell Injection...
# 497  NCT01952587  X-linked Biological Response to HIV Sensing: t...
#
#                                        LeadSponsorName  \
# 0    Institut National de la Santé Et de la Recherc...
# 1    Institut National de la Santé Et de la Recherc...
# 2    Institut National de la Santé Et de la Recherc...
# 3    Institut National de la Santé Et de la Recherc...
# 4    Institut National de la Santé Et de la Recherc...
# ..                                                 ...
# 493  Institut National de la Santé Et de la Recherc...
# 494                                               <NA>
# 495  Institut National de la Santé Et de la Recherc...
# 496  Institut National de la Santé Et de la Recherc...
# 497                 ANRS, Emerging Infectious Diseases
#
#                                       CollaboratorName OverallStatus  \
# 0                                                 <NA>     COMPLETED
# 1                                                 <NA>     COMPLETED
# 2                                                 <NA>     COMPLETED
# 3    European Commission | Fondation FondaMental | ...     COMPLETED
# 4    European Commission | Fondation FondaMental | ...     COMPLETED
# ..                                                 ...           ...
# 493                                               <NA>     COMPLETED
# 494                                               <NA>          <NA>
# 495                                               <NA>     COMPLETED
# 496                                               <NA>     COMPLETED
# 497                                               <NA>     COMPLETED
#
#           StudyType  HasResults StudyFirstPostDate   StartDate CompletionDate  \
# 0    INTERVENTIONAL       False         2011-12-13  2011-07-11     2015-03-13
# 1    INTERVENTIONAL       False         2011-12-13  2011-07-11     2015-03-13
# 2    INTERVENTIONAL       False         2011-12-13  2011-07-11     2015-03-13
# 3    INTERVENTIONAL       False         2015-09-07     2015-09     2018-09-15
# 4    INTERVENTIONAL       False         2015-09-07     2015-09     2018-09-15
# ..              ...         ...                ...         ...            ...
# 493  INTERVENTIONAL       False         2014-04-02  2014-10-02        2016-07
# 494            <NA>        <NA>               <NA>        <NA>           <NA>
# 495  INTERVENTIONAL       False         2010-03-18     2010-05        2015-03
# 496  INTERVENTIONAL       False         2010-03-18     2010-05        2015-03
# 497  INTERVENTIONAL       False         2013-09-30     2013-11        2015-06
#
#          pmid     type                                              title  \
# 0    19602057   RESULT  Role of EG-VEGF in human placentation: Physiol...
# 1    16384869   RESULT  Expression and oxygen regulation of endocrine ...
# 2    17531315   RESULT  Placental expression of EG-VEGF and its recept...
# 3    27488181  DERIVED  European COMPARative Effectiveness research on...
# 4    34874888  DERIVED  Examining the Theoretical Framework of Behavio...
# ..        ...      ...                                                ...
# 493      <NA>     <NA>                                                NaN
# 494  26439886     <NA>  Safety of Intracavernous Bone Marrow-Mononucle...
# 495  28753830  DERIVED  Intracavernous Injections of Bone Marrow Monon...
# 496  25974235  DERIVED  Mesenchymal stem cell therapy for the treatmen...
# 497      <NA>     <NA>                                                NaN
#
#                                                authors  \
# 0    Hoffmann P; Saoudi Y; Benharouga M; Graham CH;...
# 1                      Hoffmann P; Feige JJ; Alfaidy N
# 2                      Hoffmann P; Feige JJ; Alfaidy N
# 3    Kleiboer A; Smit J; Bosmans J; Ruwaard J; Ande...
# 4    van Genugten CR; Schuurmans J; Hoogendoorn AW;...
# ..                                                 ...
# 493                                                NaN
# 494  Yiou R; Hamidou L; Birebent B; Bitari D; Lecor...
# 495  Yiou R; Hamidou L; Birebent B; Bitari D; Le Co...
# 496                    Khera M; Albersen M; Mulhall JP
# 497                                                NaN
#
#                                   doi  year  \
# 0    10.1111/j.1582-4934.2008.00554.x  2009
# 1                10.1210/en.2005-0912  2006
# 2      10.1016/j.placenta.2007.03.008  2007
# 3           10.1186/s13063-016-1511-1  2016
# 4                       10.2196/32007  2021
# ..                                ...   ...
# 493                               NaN   NaN
# 494      10.1016/j.eururo.2015.09.026  2016
# 495         10.1016/j.euf.2017.06.009  2017
# 496                 10.1111/jsm.12871  2015
# 497                               NaN   NaN
#
#                                      publication_types
# 0    [Journal Article, Research Support, Non-U.S. G...
# 1    [Journal Article, Research Support, Non-U.S. G...
# 2    [Journal Article, Research Support, Non-U.S. G...
# 3    [Equivalence Trial, Journal Article, Multicent...
# 4                                    [Journal Article]
# ..                                                 ...
# 493                                                NaN
# 494  [Journal Article, Research Support, Non-U.S. G...
# 495  [Clinical Trial, Phase I, Clinical Trial, Phas...
# 496                                  [Journal Article]
# 497                                                NaN
#
# [498 rows x 17 columns]

# %% [markdown]
# Les nouveaux PMIDs trouvés via Pubmed, n'ont aucune des infos associées avec CT présentes: BriefTitle, LeadSponsorName, etc ...

# %%
# Index of empty rows we need to fill
index_empty_rows = df_final.loc[:, 'BriefTitle'].isna()

# Columns we need to fill
columns_to_fill = [
    'BriefTitle',
    'LeadSponsorName',
    'CollaboratorName',
    'OverallStatus',
    'StudyType',
    'HasResults',
    'StudyFirstPostDate',
    'StartDate',
    'CompletionDate',
    'type',
]

df_final.loc[index_empty_rows, ['NCTId'] + columns_to_fill]
# Out:
#            NCTId BriefTitle LeadSponsorName CollaboratorName OverallStatus  \
# 10   NCT05311865       <NA>            <NA>             <NA>          <NA>
# 11   NCT05311865       <NA>            <NA>             <NA>          <NA>
# 40   NCT03078439       <NA>            <NA>             <NA>          <NA>
# 69   NCT04315948       <NA>            <NA>             <NA>          <NA>
# 81   NCT04315948       <NA>            <NA>             <NA>          <NA>
# 112  NCT00640263       <NA>            <NA>             <NA>          <NA>
# 146  NCT02777229       <NA>            <NA>             <NA>          <NA>
# 148  NCT02777229       <NA>            <NA>             <NA>          <NA>
# 161  NCT01703962       <NA>            <NA>             <NA>          <NA>
# 162  NCT05349162       <NA>            <NA>             <NA>          <NA>
# 183  NCT01453192       <NA>            <NA>             <NA>          <NA>
# 186  NCT01473472       <NA>            <NA>             <NA>          <NA>
# 222  NCT01426243       <NA>            <NA>             <NA>          <NA>
# 228  NCT02212379       <NA>            <NA>             <NA>          <NA>
# 272  NCT03870438       <NA>            <NA>             <NA>          <NA>
# 277  NCT03335995       <NA>            <NA>             <NA>          <NA>
# 294  NCT02405013       <NA>            <NA>             <NA>          <NA>
# 295  NCT01801618       <NA>            <NA>             <NA>          <NA>
# 304  NCT02057796       <NA>            <NA>             <NA>          <NA>
# 335  NCT03005652       <NA>            <NA>             <NA>          <NA>
# 388  NCT02481453       <NA>            <NA>             <NA>          <NA>
# 394  NCT01688453       <NA>            <NA>             <NA>          <NA>
# 401  NCT04409405       <NA>            <NA>             <NA>          <NA>
# 457  NCT04288128       <NA>            <NA>             <NA>          <NA>
# 458  NCT04288128       <NA>            <NA>             <NA>          <NA>
# 465  NCT02833961       <NA>            <NA>             <NA>          <NA>
# 478  NCT04392388       <NA>            <NA>             <NA>          <NA>
# 487  NCT03215732       <NA>            <NA>             <NA>          <NA>
# 494  NCT01089387       <NA>            <NA>             <NA>          <NA>
#
#     StudyType  HasResults StudyFirstPostDate StartDate CompletionDate  type
# 10       <NA>        <NA>               <NA>      <NA>           <NA>  <NA>
# 11       <NA>        <NA>               <NA>      <NA>           <NA>  <NA>
# 40       <NA>        <NA>               <NA>      <NA>           <NA>  <NA>
# 69       <NA>        <NA>               <NA>      <NA>           <NA>  <NA>
# 81       <NA>        <NA>               <NA>      <NA>           <NA>  <NA>
# 112      <NA>        <NA>               <NA>      <NA>           <NA>  <NA>
# 146      <NA>        <NA>               <NA>      <NA>           <NA>  <NA>
# 148      <NA>        <NA>               <NA>      <NA>           <NA>  <NA>
# 161      <NA>        <NA>               <NA>      <NA>           <NA>  <NA>
# 162      <NA>        <NA>               <NA>      <NA>           <NA>  <NA>
# 183      <NA>        <NA>               <NA>      <NA>           <NA>  <NA>
# 186      <NA>        <NA>               <NA>      <NA>           <NA>  <NA>
# 222      <NA>        <NA>               <NA>      <NA>           <NA>  <NA>
# 228      <NA>        <NA>               <NA>      <NA>           <NA>  <NA>
# 272      <NA>        <NA>               <NA>      <NA>           <NA>  <NA>
# 277      <NA>        <NA>               <NA>      <NA>           <NA>  <NA>
# 294      <NA>        <NA>               <NA>      <NA>           <NA>  <NA>
# 295      <NA>        <NA>               <NA>      <NA>           <NA>  <NA>
# 304      <NA>        <NA>               <NA>      <NA>           <NA>  <NA>
# 335      <NA>        <NA>               <NA>      <NA>           <NA>  <NA>
# 388      <NA>        <NA>               <NA>      <NA>           <NA>  <NA>
# 394      <NA>        <NA>               <NA>      <NA>           <NA>  <NA>
# 401      <NA>        <NA>               <NA>      <NA>           <NA>  <NA>
# 457      <NA>        <NA>               <NA>      <NA>           <NA>  <NA>
# 458      <NA>        <NA>               <NA>      <NA>           <NA>  <NA>
# 465      <NA>        <NA>               <NA>      <NA>           <NA>  <NA>
# 478      <NA>        <NA>               <NA>      <NA>           <NA>  <NA>
# 487      <NA>        <NA>               <NA>      <NA>           <NA>  <NA>
# 494      <NA>        <NA>               <NA>      <NA>           <NA>  <NA>

# %% [markdown]
# On rajoute un type 'PUBMED' pour les PMIDs issues de PubMed uniquement:

# %%
# We add a 'PUBMED' type to the PMIDs extracted from Pubmed exclusively
df_final.loc[index_empty_rows, 'type'] = 'PUBMED'

# %%
df_final.loc[index_empty_rows, ['NCTId'] + columns_to_fill]
# Out:
#            NCTId                                         BriefTitle  \
# 10   NCT05311865  Transmission of Covid-19 During Clubbing Event...
# 11   NCT05311865  Transmission of Covid-19 During Clubbing Event...
# 40   NCT03078439  EPIPAGE2 Cohort Study Follow up at Five and a ...
# 69   NCT04315948  Trial of Treatments for COVID-19 in Hospitaliz...
# 81   NCT04315948  Trial of Treatments for COVID-19 in Hospitaliz...
# 112  NCT00640263  Comparison of Efficacy and Safety of Infant Pe...
# 146  NCT02777229  Efficacy and Safety of a Dolutegravir-based Re...
# 148  NCT02777229  Efficacy and Safety of a Dolutegravir-based Re...
# 161  NCT01703962  Non Invasive IDentification of Gliomas With ID...
# 162  NCT05349162        Epicardial vs. Transvenous ICDs in Children
# 183  NCT01453192  Renal Transplantation and Raltegravir in HIV-I...
# 186  NCT01473472  On Demand Antiretroviral Pre-exposure Prophyla...
# 222  NCT01426243  The Yellow Fever Vaccine Immunity in HIV Infec...
# 228  NCT02212379  Capacity of the Dual Combination Raltegravir/E...
# 272  NCT03870438  Prevention of Mother-to-child Transmission of ...
# 277  NCT03335995                 Stroke Prognosis in Intensive CarE
# 294  NCT02405013  Feasibility, Tolerance and Efficacy of Interfe...
# 295  NCT01801618  National Evaluation of PI-based 2nd Line Effic...
# 304  NCT02057796  Systematic Empirical vs. Test-guided Anti-TB T...
# 335  NCT03005652  Effects Of An 8-Weeks Mindfulness-based Interv...
# 388  NCT02481453  Rapamycine vs Placebo for the Treatment of Inc...
# 394  NCT01688453      Overweight Management and Social Inequalities
# 401  NCT04409405  Evaluation and Support to EVD Cured Patients a...
# 457  NCT04288128  Integrated Functional Evaluation of the Cerebe...
# 458  NCT04288128  Integrated Functional Evaluation of the Cerebe...
# 465  NCT02833961                   Diffusion Spectroscopy in Stroke
# 478  NCT04392388  Health, Perception, Practices, Relations and S...
# 487  NCT03215732  Cross Sectional Survey on the Burden and Impac...
# 494  NCT01089387  Intracavernous Bone Marrow Stem-cell Injection...
#
#                                        LeadSponsorName  \
# 10                  ANRS, Emerging Infectious Diseases
# 11                  ANRS, Emerging Infectious Diseases
# 40   Institut National de la Santé Et de la Recherc...
# 69   Institut National de la Santé Et de la Recherc...
# 81   Institut National de la Santé Et de la Recherc...
# 112  French National Agency for Research on AIDS an...
# 146                 ANRS, Emerging Infectious Diseases
# 148                 ANRS, Emerging Infectious Diseases
# 161  Institut National de la Santé Et de la Recherc...
# 162  Paris Cardiovascular Research Center (Inserm U...
# 183                 ANRS, Emerging Infectious Diseases
# 186                 ANRS, Emerging Infectious Diseases
# 222  French National Agency for Research on AIDS an...
# 228                 ANRS, Emerging Infectious Diseases
# 272                 ANRS, Emerging Infectious Diseases
# 277  Institut National de la Santé Et de la Recherc...
# 294                 ANRS, Emerging Infectious Diseases
# 295                 ANRS, Emerging Infectious Diseases
# 304                 ANRS, Emerging Infectious Diseases
# 335  Institut National de la Santé Et de la Recherc...
# 388  Institut National de la Santé Et de la Recherc...
# 394  Institut National de la Santé Et de la Recherc...
# 401  Institut National de la Santé Et de la Recherc...
# 457  Institut National de la Santé Et de la Recherc...
# 458  Institut National de la Santé Et de la Recherc...
# 465  Institut National de la Santé Et de la Recherc...
# 478  Institut National de la Santé Et de la Recherc...
# 487                 ANRS, Emerging Infectious Diseases
# 494  Institut National de la Santé Et de la Recherc...
#
#                                       CollaboratorName OverallStatus  \
# 10                          Cerballiance | Kappa Santé     COMPLETED
# 11                          Cerballiance | Kappa Santé     COMPLETED
# 40                                                <NA>     COMPLETED
# 69                                                <NA>     COMPLETED
# 81                                                <NA>     COMPLETED
# 112  European and Developing Countries Clinical Tri...     COMPLETED
# 146  Institut de Recherche pour le Developpement | ...     COMPLETED
# 148  Institut de Recherche pour le Developpement | ...     COMPLETED
# 161                                               <NA>     COMPLETED
# 162                     Hôpital Necker-Enfants Malades     COMPLETED
# 183                            Merck Sharp & Dohme LLC     COMPLETED
# 186                                               <NA>     COMPLETED
# 222                                               <NA>     COMPLETED
# 228       Merck Sharp & Dohme LLC | Janssen-Cilag Ltd.     COMPLETED
# 272  University Teaching Hospital, Lusaka, Zambia |...     COMPLETED
# 277                                               <NA>     COMPLETED
# 294                                               <NA>     COMPLETED
# 295                                               <NA>     COMPLETED
# 304                                               <NA>     COMPLETED
# 335                                               <NA>     COMPLETED
# 388                                               <NA>     COMPLETED
# 394                                               <NA>     COMPLETED
# 401  Institut National de Recherche Biomédicale. Ki...     COMPLETED
# 457               Biogen | Ionis Pharmaceuticals, Inc.     COMPLETED
# 458               Biogen | Ionis Pharmaceuticals, Inc.     COMPLETED
# 465                                               <NA>     COMPLETED
# 478                                               <NA>     COMPLETED
# 487      Institute of Research for Development, France     COMPLETED
# 494                                               <NA>     COMPLETED
#
#           StudyType  HasResults StudyFirstPostDate   StartDate CompletionDate  \
# 10   INTERVENTIONAL       False         2022-04-05  2021-09-04     2022-02-26
# 11   INTERVENTIONAL       False         2022-04-05  2021-09-04     2022-02-26
# 40    OBSERVATIONAL       False         2017-03-13  2016-09-02     2018-01-08
# 69   INTERVENTIONAL       False         2020-03-20  2020-03-22     2023-09-25
# 81   INTERVENTIONAL       False         2020-03-20  2020-03-22     2023-09-25
# 112  INTERVENTIONAL       False         2008-03-21     2009-12        2014-02
# 146  INTERVENTIONAL       False         2016-05-19     2016-07        2021-07
# 148  INTERVENTIONAL       False         2016-05-19     2016-07        2021-07
# 161   OBSERVATIONAL       False         2012-10-11  2012-03-14     2014-03-20
# 162   OBSERVATIONAL       False         2022-04-27  2003-01-01     2022-04-01
# 183  INTERVENTIONAL       False         2011-10-17     2011-12        2015-11
# 186  INTERVENTIONAL       False         2011-11-17     2012-01     2016-12-15
# 222  INTERVENTIONAL       False         2011-08-31     2011-07        2017-12
# 228  INTERVENTIONAL        True         2014-08-08     2015-01        2018-04
# 272  INTERVENTIONAL       False         2019-03-12  2019-12-14     2022-10-31
# 277   OBSERVATIONAL       False         2017-11-08  2017-10-18     2020-11-18
# 294  INTERVENTIONAL       False         2015-04-01     2015-10        2017-11
# 295   OBSERVATIONAL       False         2013-03-01     2013-02        2014-12
# 304  INTERVENTIONAL       False         2014-02-07     2014-09        2018-04
# 335  INTERVENTIONAL       False         2016-12-29  2017-04-21     2018-09-18
# 388  INTERVENTIONAL       False         2015-06-25  2015-07-15     2018-01-22
# 394  INTERVENTIONAL       False         2012-09-19     2012-04        2015-11
# 401   OBSERVATIONAL       False         2020-06-01  2020-04-16     2021-10-18
# 457   OBSERVATIONAL       False         2020-02-28  2020-05-28     2022-06-01
# 458   OBSERVATIONAL       False         2020-02-28  2020-05-28     2022-06-01
# 465  INTERVENTIONAL       False         2016-07-14  2016-07-28     2019-10-25
# 478   OBSERVATIONAL       False         2020-05-18  2020-05-01     2023-04-11
# 487   OBSERVATIONAL       False         2017-07-12  2017-10-19     2019-07-31
# 494  INTERVENTIONAL       False         2010-03-18     2010-05        2015-03
#
#        type
# 10   PUBMED
# 11   PUBMED
# 40   PUBMED
# 69   PUBMED
# 81   PUBMED
# 112  PUBMED
# 146  PUBMED
# 148  PUBMED
# 161  PUBMED
# 162  PUBMED
# 183  PUBMED
# 186  PUBMED
# 222  PUBMED
# 228  PUBMED
# 272  PUBMED
# 277  PUBMED
# 294  PUBMED
# 295  PUBMED
# 304  PUBMED
# 335  PUBMED
# 388  PUBMED
# 394  PUBMED
# 401  PUBMED
# 457  PUBMED
# 458  PUBMED
# 465  PUBMED
# 478  PUBMED
# 487  PUBMED
# 494  PUBMED

# %% [markdown]
# On va remplir ces colonnes avec les infos contenus dans la DataFrame CT:

# %%
# NCTIds of empty rows
NCTIds_empty_rows = df_final.loc[index_empty_rows, 'NCTId']

# Columns we wish to copy
columns_to_copy = [
    'BriefTitle',
    'LeadSponsorName',
    'CollaboratorName',
    'OverallStatus',
    'StudyType',
    'HasResults',
    'StudyFirstPostDate',
    'StartDate',
    'CompletionDate',
]

# We copy the missing values from the CT dataframe
for index, nctid in NCTIds_empty_rows.items():
    # For an NCTId, we look in the CT dataframe for the first row with this NCTDId
    # and copy the missings columns
    df_final.loc[index, columns_to_copy] = df_ct.loc[
        df_ct.loc[:, 'NCTId'] == nctid, columns_to_copy
    ].iloc[0]

# %%
df_final.loc[index_empty_rows, ['NCTId'] + columns_to_fill]
# Out:
#            NCTId                                         BriefTitle  \
# 10   NCT05311865  Transmission of Covid-19 During Clubbing Event...
# 11   NCT05311865  Transmission of Covid-19 During Clubbing Event...
# 40   NCT03078439  EPIPAGE2 Cohort Study Follow up at Five and a ...
# 69   NCT04315948  Trial of Treatments for COVID-19 in Hospitaliz...
# 81   NCT04315948  Trial of Treatments for COVID-19 in Hospitaliz...
# 112  NCT00640263  Comparison of Efficacy and Safety of Infant Pe...
# 146  NCT02777229  Efficacy and Safety of a Dolutegravir-based Re...
# 148  NCT02777229  Efficacy and Safety of a Dolutegravir-based Re...
# 161  NCT01703962  Non Invasive IDentification of Gliomas With ID...
# 162  NCT05349162        Epicardial vs. Transvenous ICDs in Children
# 183  NCT01453192  Renal Transplantation and Raltegravir in HIV-I...
# 186  NCT01473472  On Demand Antiretroviral Pre-exposure Prophyla...
# 222  NCT01426243  The Yellow Fever Vaccine Immunity in HIV Infec...
# 228  NCT02212379  Capacity of the Dual Combination Raltegravir/E...
# 272  NCT03870438  Prevention of Mother-to-child Transmission of ...
# 277  NCT03335995                 Stroke Prognosis in Intensive CarE
# 294  NCT02405013  Feasibility, Tolerance and Efficacy of Interfe...
# 295  NCT01801618  National Evaluation of PI-based 2nd Line Effic...
# 304  NCT02057796  Systematic Empirical vs. Test-guided Anti-TB T...
# 335  NCT03005652  Effects Of An 8-Weeks Mindfulness-based Interv...
# 388  NCT02481453  Rapamycine vs Placebo for the Treatment of Inc...
# 394  NCT01688453      Overweight Management and Social Inequalities
# 401  NCT04409405  Evaluation and Support to EVD Cured Patients a...
# 457  NCT04288128  Integrated Functional Evaluation of the Cerebe...
# 458  NCT04288128  Integrated Functional Evaluation of the Cerebe...
# 465  NCT02833961                   Diffusion Spectroscopy in Stroke
# 478  NCT04392388  Health, Perception, Practices, Relations and S...
# 487  NCT03215732  Cross Sectional Survey on the Burden and Impac...
# 494  NCT01089387  Intracavernous Bone Marrow Stem-cell Injection...
#
#                                        LeadSponsorName  \
# 10                  ANRS, Emerging Infectious Diseases
# 11                  ANRS, Emerging Infectious Diseases
# 40   Institut National de la Santé Et de la Recherc...
# 69   Institut National de la Santé Et de la Recherc...
# 81   Institut National de la Santé Et de la Recherc...
# 112  French National Agency for Research on AIDS an...
# 146                 ANRS, Emerging Infectious Diseases
# 148                 ANRS, Emerging Infectious Diseases
# 161  Institut National de la Santé Et de la Recherc...
# 162  Paris Cardiovascular Research Center (Inserm U...
# 183                 ANRS, Emerging Infectious Diseases
# 186                 ANRS, Emerging Infectious Diseases
# 222  French National Agency for Research on AIDS an...
# 228                 ANRS, Emerging Infectious Diseases
# 272                 ANRS, Emerging Infectious Diseases
# 277  Institut National de la Santé Et de la Recherc...
# 294                 ANRS, Emerging Infectious Diseases
# 295                 ANRS, Emerging Infectious Diseases
# 304                 ANRS, Emerging Infectious Diseases
# 335  Institut National de la Santé Et de la Recherc...
# 388  Institut National de la Santé Et de la Recherc...
# 394  Institut National de la Santé Et de la Recherc...
# 401  Institut National de la Santé Et de la Recherc...
# 457  Institut National de la Santé Et de la Recherc...
# 458  Institut National de la Santé Et de la Recherc...
# 465  Institut National de la Santé Et de la Recherc...
# 478  Institut National de la Santé Et de la Recherc...
# 487                 ANRS, Emerging Infectious Diseases
# 494  Institut National de la Santé Et de la Recherc...
#
#                                       CollaboratorName OverallStatus  \
# 10                          Cerballiance | Kappa Santé     COMPLETED
# 11                          Cerballiance | Kappa Santé     COMPLETED
# 40                                                <NA>     COMPLETED
# 69                                                <NA>     COMPLETED
# 81                                                <NA>     COMPLETED
# 112  European and Developing Countries Clinical Tri...     COMPLETED
# 146  Institut de Recherche pour le Developpement | ...     COMPLETED
# 148  Institut de Recherche pour le Developpement | ...     COMPLETED
# 161                                               <NA>     COMPLETED
# 162                     Hôpital Necker-Enfants Malades     COMPLETED
# 183                            Merck Sharp & Dohme LLC     COMPLETED
# 186                                               <NA>     COMPLETED
# 222                                               <NA>     COMPLETED
# 228       Merck Sharp & Dohme LLC | Janssen-Cilag Ltd.     COMPLETED
# 272  University Teaching Hospital, Lusaka, Zambia |...     COMPLETED
# 277                                               <NA>     COMPLETED
# 294                                               <NA>     COMPLETED
# 295                                               <NA>     COMPLETED
# 304                                               <NA>     COMPLETED
# 335                                               <NA>     COMPLETED
# 388                                               <NA>     COMPLETED
# 394                                               <NA>     COMPLETED
# 401  Institut National de Recherche Biomédicale. Ki...     COMPLETED
# 457               Biogen | Ionis Pharmaceuticals, Inc.     COMPLETED
# 458               Biogen | Ionis Pharmaceuticals, Inc.     COMPLETED
# 465                                               <NA>     COMPLETED
# 478                                               <NA>     COMPLETED
# 487      Institute of Research for Development, France     COMPLETED
# 494                                               <NA>     COMPLETED
#
#           StudyType  HasResults StudyFirstPostDate   StartDate CompletionDate  \
# 10   INTERVENTIONAL       False         2022-04-05  2021-09-04     2022-02-26
# 11   INTERVENTIONAL       False         2022-04-05  2021-09-04     2022-02-26
# 40    OBSERVATIONAL       False         2017-03-13  2016-09-02     2018-01-08
# 69   INTERVENTIONAL       False         2020-03-20  2020-03-22     2023-09-25
# 81   INTERVENTIONAL       False         2020-03-20  2020-03-22     2023-09-25
# 112  INTERVENTIONAL       False         2008-03-21     2009-12        2014-02
# 146  INTERVENTIONAL       False         2016-05-19     2016-07        2021-07
# 148  INTERVENTIONAL       False         2016-05-19     2016-07        2021-07
# 161   OBSERVATIONAL       False         2012-10-11  2012-03-14     2014-03-20
# 162   OBSERVATIONAL       False         2022-04-27  2003-01-01     2022-04-01
# 183  INTERVENTIONAL       False         2011-10-17     2011-12        2015-11
# 186  INTERVENTIONAL       False         2011-11-17     2012-01     2016-12-15
# 222  INTERVENTIONAL       False         2011-08-31     2011-07        2017-12
# 228  INTERVENTIONAL        True         2014-08-08     2015-01        2018-04
# 272  INTERVENTIONAL       False         2019-03-12  2019-12-14     2022-10-31
# 277   OBSERVATIONAL       False         2017-11-08  2017-10-18     2020-11-18
# 294  INTERVENTIONAL       False         2015-04-01     2015-10        2017-11
# 295   OBSERVATIONAL       False         2013-03-01     2013-02        2014-12
# 304  INTERVENTIONAL       False         2014-02-07     2014-09        2018-04
# 335  INTERVENTIONAL       False         2016-12-29  2017-04-21     2018-09-18
# 388  INTERVENTIONAL       False         2015-06-25  2015-07-15     2018-01-22
# 394  INTERVENTIONAL       False         2012-09-19     2012-04        2015-11
# 401   OBSERVATIONAL       False         2020-06-01  2020-04-16     2021-10-18
# 457   OBSERVATIONAL       False         2020-02-28  2020-05-28     2022-06-01
# 458   OBSERVATIONAL       False         2020-02-28  2020-05-28     2022-06-01
# 465  INTERVENTIONAL       False         2016-07-14  2016-07-28     2019-10-25
# 478   OBSERVATIONAL       False         2020-05-18  2020-05-01     2023-04-11
# 487   OBSERVATIONAL       False         2017-07-12  2017-10-19     2019-07-31
# 494  INTERVENTIONAL       False         2010-03-18     2010-05        2015-03
#
#        type
# 10   PUBMED
# 11   PUBMED
# 40   PUBMED
# 69   PUBMED
# 81   PUBMED
# 112  PUBMED
# 146  PUBMED
# 148  PUBMED
# 161  PUBMED
# 162  PUBMED
# 183  PUBMED
# 186  PUBMED
# 222  PUBMED
# 228  PUBMED
# 272  PUBMED
# 277  PUBMED
# 294  PUBMED
# 295  PUBMED
# 304  PUBMED
# 335  PUBMED
# 388  PUBMED
# 394  PUBMED
# 401  PUBMED
# 457  PUBMED
# 458  PUBMED
# 465  PUBMED
# 478  PUBMED
# 487  PUBMED
# 494  PUBMED

# %% [markdown]
# ### Resultat final:

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 498 entries, 0 to 497
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   NCTId               498 non-null    object
#  1   BriefTitle          498 non-null    string
#  2   LeadSponsorName     498 non-null    string
#  3   CollaboratorName    224 non-null    string
#  4   OverallStatus       498 non-null    category
#  5   StudyType           498 non-null    category
#  6   HasResults          498 non-null    boolean
#  7   StudyFirstPostDate  498 non-null    string
#  8   StartDate           498 non-null    string
#  9   CompletionDate      498 non-null    string
#  10  pmid                392 non-null    object
#  11  type                392 non-null    string
#  12  title               392 non-null    object
#  13  authors             392 non-null    object
#  14  doi                 391 non-null    object
#  15  year                392 non-null    object
#  16  publication_types   392 non-null    object
# dtypes: boolean(1), category(2), object(7), string(7)
# memory usage: 56.8+ KB

# %%
df_final = df_final.convert_dtypes()
# df_final = df_final.astype({"OverallStatus" : 'category', "StudyType" : 'category'})
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 498 entries, 0 to 497
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   NCTId               498 non-null    string
#  1   BriefTitle          498 non-null    string
#  2   LeadSponsorName     498 non-null    string
#  3   CollaboratorName    224 non-null    string
#  4   OverallStatus       498 non-null    category
#  5   StudyType           498 non-null    category
#  6   HasResults          498 non-null    boolean
#  7   StudyFirstPostDate  498 non-null    string
#  8   StartDate           498 non-null    string
#  9   CompletionDate      498 non-null    string
#  10  pmid                392 non-null    string
#  11  type                392 non-null    string
#  12  title               392 non-null    string
#  13  authors             392 non-null    string
#  14  doi                 391 non-null    string
#  15  year                392 non-null    string
#  16  publication_types   392 non-null    object
# dtypes: boolean(1), category(2), object(1), string(13)
# memory usage: 56.8+ KB

# %% [markdown]
# ### Export en CSV:

# %%
df_final.to_csv(
    'Data/outputs/extract_df_final.csv',
    sep=';',
    index=False,
    encoding='utf-8-sig',
)
